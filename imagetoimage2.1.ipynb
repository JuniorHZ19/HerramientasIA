# %% [markdown]
# <a href="https://colab.research.google.com/github/JuniorHZ19/HerramientasIA/blob/main/imagetoimage2.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# !unzip DIV2K_train_HR.zip # This is our dataset link. I will include this command in the description
# Out:
# --2024-02-11 02:58:23--  http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.178, 2001:67c:10ec:36c2::178
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip [following]
# --2024-02-11 02:58:24--  https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3530603713 (3.3G) [application/zip]
# Saving to: ‘DIV2K_train_HR.zip’
#
# DIV2K_train_HR.zip  100%[===================>]   3.29G  18.8MB/s    in 3m 12s
#
# 2024-02-11 03:01:36 (17.5 MB/s) - ‘DIV2K_train_HR.zip’ saved [3530603713/3530603713]
#
# Archive:  DIV2K_train_HR.zip
#   inflating: DIV2K_train_HR/0103.png
#   inflating: DIV2K_train_HR/0413.png
#   inflating: DIV2K_train_HR/0031.png
#   inflating: DIV2K_train_HR/0660.png
#   inflating: DIV2K_train_HR/0126.png
#   inflating: DIV2K_train_HR/0793.png
#   inflating: DIV2K_train_HR/0764.png
#   inflating: DIV2K_train_HR/0550.png
#   inflating: DIV2K_train_HR/0437.png
#   inflating: DIV2K_train_HR/0374.png
#   inflating: DIV2K_train_HR/0755.png
#   inflating: DIV2K_train_HR/0614.png
#   inflating: DIV2K_train_HR/0646.png
#   inflating: DIV2K_train_HR/0371.png
#   inflating: DIV2K_train_HR/0312.png
#   inflating: DIV2K_train_HR/0108.png
#   inflating: DIV2K_train_HR/0556.png
#   inflating: DIV2K_train_HR/0794.png
#   inflating: DIV2K_train_HR/0722.png
#   inflating: DIV2K_train_HR/0780.png
#   inflating: DIV2K_train_HR/0555.png
#   inflating: DIV2K_train_HR/0439.png
#   inflating: DIV2K_train_HR/0396.png
#   inflating: DIV2K_train_HR/0666.png
#   inflating: DIV2K_train_HR/0254.png
#   inflating: DIV2K_train_HR/0344.png
#   inflating: DIV2K_train_HR/0062.png
#   inflating: DIV2K_train_HR/0657.png
#   inflating: DIV2K_train_HR/0117.png
#   inflating: DIV2K_train_HR/0395.png
#   inflating: DIV2K_train_HR/0015.png
#   inflating: DIV2K_train_HR/0335.png
#   inflating: DIV2K_train_HR/0578.png
#   inflating: DIV2K_train_HR/0142.png
#   inflating: DIV2K_train_HR/0719.png
#   inflating: DIV2K_train_HR/0101.png
#   inflating: DIV2K_train_HR/0579.png
#   inflating: DIV2K_train_HR/0504.png
#   inflating: DIV2K_train_HR/0576.png
#   inflating: DIV2K_train_HR/0590.png
#   inflating: DIV2K_train_HR/0158.png
#   inflating: DIV2K_train_HR/0384.png
#   inflating: DIV2K_train_HR/0795.png
#   inflating: DIV2K_train_HR/0668.png
#   inflating: DIV2K_train_HR/0144.png
#   inflating: DIV2K_train_HR/0642.png
#   inflating: DIV2K_train_HR/0427.png
#   inflating: DIV2K_train_HR/0593.png
#   inflating: DIV2K_train_HR/0080.png
#   inflating: DIV2K_train_HR/0050.png
#   inflating: DIV2K_train_HR/0617.png
#   inflating: DIV2K_train_HR/0608.png
#   inflating: DIV2K_train_HR/0118.png
#   inflating: DIV2K_train_HR/0082.png
#   inflating: DIV2K_train_HR/0788.png
#   inflating: DIV2K_train_HR/0042.png
#   inflating: DIV2K_train_HR/0333.png
#   inflating: DIV2K_train_HR/0346.png
#   inflating: DIV2K_train_HR/0705.png
#   inflating: DIV2K_train_HR/0195.png
#   inflating: DIV2K_train_HR/0671.png
#   inflating: DIV2K_train_HR/0213.png
#   inflating: DIV2K_train_HR/0692.png
#   inflating: DIV2K_train_HR/0253.png
#   inflating: DIV2K_train_HR/0191.png
#   inflating: DIV2K_train_HR/0628.png
#   inflating: DIV2K_train_HR/0354.png
#   inflating: DIV2K_train_HR/0003.png
#   inflating: DIV2K_train_HR/0393.png
#   inflating: DIV2K_train_HR/0336.png
#   inflating: DIV2K_train_HR/0674.png
#   inflating: DIV2K_train_HR/0586.png
#   inflating: DIV2K_train_HR/0074.png
#   inflating: DIV2K_train_HR/0116.png
#   inflating: DIV2K_train_HR/0270.png
#   inflating: DIV2K_train_HR/0376.png
#   inflating: DIV2K_train_HR/0650.png
#   inflating: DIV2K_train_HR/0462.png
#   inflating: DIV2K_train_HR/0046.png
#   inflating: DIV2K_train_HR/0545.png
#   inflating: DIV2K_train_HR/0347.png
#   inflating: DIV2K_train_HR/0187.png
#   inflating: DIV2K_train_HR/0713.png
#   inflating: DIV2K_train_HR/0558.png
#   inflating: DIV2K_train_HR/0319.png
#   inflating: DIV2K_train_HR/0073.png
#   inflating: DIV2K_train_HR/0033.png
#   inflating: DIV2K_train_HR/0207.png
#   inflating: DIV2K_train_HR/0290.png
#   inflating: DIV2K_train_HR/0194.png
#   inflating: DIV2K_train_HR/0246.png
#   inflating: DIV2K_train_HR/0034.png
#   inflating: DIV2K_train_HR/0621.png
#   inflating: DIV2K_train_HR/0768.png
#   inflating: DIV2K_train_HR/0366.png
#   inflating: DIV2K_train_HR/0490.png
#   inflating: DIV2K_train_HR/0471.png
#   inflating: DIV2K_train_HR/0475.png
#   inflating: DIV2K_train_HR/0152.png
#   inflating: DIV2K_train_HR/0636.png
#   inflating: DIV2K_train_HR/0338.png
#   inflating: DIV2K_train_HR/0358.png
#   inflating: DIV2K_train_HR/0523.png
#   inflating: DIV2K_train_HR/0456.png
#   inflating: DIV2K_train_HR/0470.png
#   inflating: DIV2K_train_HR/0522.png
#   inflating: DIV2K_train_HR/0426.png
#   inflating: DIV2K_train_HR/0587.png
#   inflating: DIV2K_train_HR/0465.png
#   inflating: DIV2K_train_HR/0236.png
#   inflating: DIV2K_train_HR/0192.png
#   inflating: DIV2K_train_HR/0458.png
#   inflating: DIV2K_train_HR/0438.png
#   inflating: DIV2K_train_HR/0176.png
#   inflating: DIV2K_train_HR/0016.png
#   inflating: DIV2K_train_HR/0392.png
#   inflating: DIV2K_train_HR/0054.png
#   inflating: DIV2K_train_HR/0063.png
#   inflating: DIV2K_train_HR/0537.png
#   inflating: DIV2K_train_HR/0271.png
#   inflating: DIV2K_train_HR/0409.png
#   inflating: DIV2K_train_HR/0328.png
#   inflating: DIV2K_train_HR/0582.png
#   inflating: DIV2K_train_HR/0532.png
#   inflating: DIV2K_train_HR/0706.png
#   inflating: DIV2K_train_HR/0153.png
#   inflating: DIV2K_train_HR/0401.png
#   inflating: DIV2K_train_HR/0110.png
#   inflating: DIV2K_train_HR/0316.png
#   inflating: DIV2K_train_HR/0069.png
#   inflating: DIV2K_train_HR/0209.png
#   inflating: DIV2K_train_HR/0351.png
#   inflating: DIV2K_train_HR/0433.png
#   inflating: DIV2K_train_HR/0534.png
#   inflating: DIV2K_train_HR/0525.png
#   inflating: DIV2K_train_HR/0353.png
#   inflating: DIV2K_train_HR/0018.png
#   inflating: DIV2K_train_HR/0592.png
#   inflating: DIV2K_train_HR/0041.png
#   inflating: DIV2K_train_HR/0398.png
#   inflating: DIV2K_train_HR/0355.png
#   inflating: DIV2K_train_HR/0492.png
#   inflating: DIV2K_train_HR/0258.png
#   inflating: DIV2K_train_HR/0051.png
#   inflating: DIV2K_train_HR/0339.png
#   inflating: DIV2K_train_HR/0156.png
#   inflating: DIV2K_train_HR/0174.png
#   inflating: DIV2K_train_HR/0526.png
#   inflating: DIV2K_train_HR/0168.png
#   inflating: DIV2K_train_HR/0515.png
#   inflating: DIV2K_train_HR/0289.png
#   inflating: DIV2K_train_HR/0700.png
#   inflating: DIV2K_train_HR/0711.png
#   inflating: DIV2K_train_HR/0317.png
#   inflating: DIV2K_train_HR/0310.png
#   inflating: DIV2K_train_HR/0075.png
#   inflating: DIV2K_train_HR/0533.png
#   inflating: DIV2K_train_HR/0345.png
#   inflating: DIV2K_train_HR/0238.png
#   inflating: DIV2K_train_HR/0493.png
#   inflating: DIV2K_train_HR/0019.png
#   inflating: DIV2K_train_HR/0559.png
#   inflating: DIV2K_train_HR/0268.png
#   inflating: DIV2K_train_HR/0746.png
#   inflating: DIV2K_train_HR/0648.png
#   inflating: DIV2K_train_HR/0112.png
#   inflating: DIV2K_train_HR/0639.png
#   inflating: DIV2K_train_HR/0216.png
#   inflating: DIV2K_train_HR/0170.png
#   inflating: DIV2K_train_HR/0408.png
#   inflating: DIV2K_train_HR/0461.png
#   inflating: DIV2K_train_HR/0774.png
#   inflating: DIV2K_train_HR/0308.png
#   inflating: DIV2K_train_HR/0368.png
#   inflating: DIV2K_train_HR/0341.png
#   inflating: DIV2K_train_HR/0535.png
#   inflating: DIV2K_train_HR/0585.png
#   inflating: DIV2K_train_HR/0004.png
#   inflating: DIV2K_train_HR/0496.png
#   inflating: DIV2K_train_HR/0662.png
#   inflating: DIV2K_train_HR/0173.png
#   inflating: DIV2K_train_HR/0200.png
#   inflating: DIV2K_train_HR/0752.png
#   inflating: DIV2K_train_HR/0106.png
#   inflating: DIV2K_train_HR/0520.png
#   inflating: DIV2K_train_HR/0519.png
#   inflating: DIV2K_train_HR/0157.png
#   inflating: DIV2K_train_HR/0552.png
#   inflating: DIV2K_train_HR/0735.png
#   inflating: DIV2K_train_HR/0362.png
#   inflating: DIV2K_train_HR/0410.png
#   inflating: DIV2K_train_HR/0286.png
#   inflating: DIV2K_train_HR/0627.png
#   inflating: DIV2K_train_HR/0557.png
#   inflating: DIV2K_train_HR/0266.png
#   inflating: DIV2K_train_HR/0252.png
#   inflating: DIV2K_train_HR/0206.png
#   inflating: DIV2K_train_HR/0330.png
#   inflating: DIV2K_train_HR/0088.png
#   inflating: DIV2K_train_HR/0728.png
#   inflating: DIV2K_train_HR/0641.png
#   inflating: DIV2K_train_HR/0350.png
#   inflating: DIV2K_train_HR/0083.png
#   inflating: DIV2K_train_HR/0682.png
#   inflating: DIV2K_train_HR/0549.png
#   inflating: DIV2K_train_HR/0564.png
#   inflating: DIV2K_train_HR/0476.png
#   inflating: DIV2K_train_HR/0760.png
#   inflating: DIV2K_train_HR/0629.png
#   inflating: DIV2K_train_HR/0630.png
#   inflating: DIV2K_train_HR/0032.png
#   inflating: DIV2K_train_HR/0581.png
#   inflating: DIV2K_train_HR/0056.png
#   inflating: DIV2K_train_HR/0040.png
#   inflating: DIV2K_train_HR/0169.png
#   inflating: DIV2K_train_HR/0400.png
#   inflating: DIV2K_train_HR/0172.png
#   inflating: DIV2K_train_HR/0182.png
#   inflating: DIV2K_train_HR/0269.png
#   inflating: DIV2K_train_HR/0612.png
#   inflating: DIV2K_train_HR/0649.png
#   inflating: DIV2K_train_HR/0311.png
#   inflating: DIV2K_train_HR/0723.png
#   inflating: DIV2K_train_HR/0166.png
#   inflating: DIV2K_train_HR/0155.png
#   inflating: DIV2K_train_HR/0072.png
#   inflating: DIV2K_train_HR/0149.png
#   inflating: DIV2K_train_HR/0425.png
#   inflating: DIV2K_train_HR/0715.png
#   inflating: DIV2K_train_HR/0670.png
#   inflating: DIV2K_train_HR/0460.png
#   inflating: DIV2K_train_HR/0748.png
#   inflating: DIV2K_train_HR/0147.png
#   inflating: DIV2K_train_HR/0602.png
#   inflating: DIV2K_train_HR/0610.png
#   inflating: DIV2K_train_HR/0479.png
#   inflating: DIV2K_train_HR/0603.png
#   inflating: DIV2K_train_HR/0043.png
#   inflating: DIV2K_train_HR/0190.png
#   inflating: DIV2K_train_HR/0503.png
#   inflating: DIV2K_train_HR/0055.png
#   inflating: DIV2K_train_HR/0337.png
#   inflating: DIV2K_train_HR/0453.png
#   inflating: DIV2K_train_HR/0219.png
#   inflating: DIV2K_train_HR/0548.png
#   inflating: DIV2K_train_HR/0661.png
#   inflating: DIV2K_train_HR/0718.png
#   inflating: DIV2K_train_HR/0489.png
#   inflating: DIV2K_train_HR/0775.png
#   inflating: DIV2K_train_HR/0323.png
#   inflating: DIV2K_train_HR/0664.png
#   inflating: DIV2K_train_HR/0002.png
#   inflating: DIV2K_train_HR/0127.png
#   inflating: DIV2K_train_HR/0322.png
#   inflating: DIV2K_train_HR/0640.png
#   inflating: DIV2K_train_HR/0473.png
#   inflating: DIV2K_train_HR/0730.png
#   inflating: DIV2K_train_HR/0008.png
#   inflating: DIV2K_train_HR/0486.png
#   inflating: DIV2K_train_HR/0597.png
#   inflating: DIV2K_train_HR/0064.png
#   inflating: DIV2K_train_HR/0068.png
#   inflating: DIV2K_train_HR/0510.png
#   inflating: DIV2K_train_HR/0594.png
#   inflating: DIV2K_train_HR/0685.png
#   inflating: DIV2K_train_HR/0497.png
#   inflating: DIV2K_train_HR/0637.png
#   inflating: DIV2K_train_HR/0332.png
#   inflating: DIV2K_train_HR/0208.png
#   inflating: DIV2K_train_HR/0241.png
#   inflating: DIV2K_train_HR/0201.png
#   inflating: DIV2K_train_HR/0044.png
#   inflating: DIV2K_train_HR/0141.png
#   inflating: DIV2K_train_HR/0381.png
#   inflating: DIV2K_train_HR/0412.png
#   inflating: DIV2K_train_HR/0035.png
#   inflating: DIV2K_train_HR/0049.png
#   inflating: DIV2K_train_HR/0181.png
#   inflating: DIV2K_train_HR/0340.png
#   inflating: DIV2K_train_HR/0272.png
#   inflating: DIV2K_train_HR/0279.png
#   inflating: DIV2K_train_HR/0307.png
#   inflating: DIV2K_train_HR/0733.png
#   inflating: DIV2K_train_HR/0250.png
#   inflating: DIV2K_train_HR/0739.png
#   inflating: DIV2K_train_HR/0654.png
#   inflating: DIV2K_train_HR/0343.png
#   inflating: DIV2K_train_HR/0422.png
#   inflating: DIV2K_train_HR/0297.png
#   inflating: DIV2K_train_HR/0360.png
#   inflating: DIV2K_train_HR/0099.png
#   inflating: DIV2K_train_HR/0541.png
#   inflating: DIV2K_train_HR/0616.png
#   inflating: DIV2K_train_HR/0352.png
#   inflating: DIV2K_train_HR/0092.png
#   inflating: DIV2K_train_HR/0528.png
#   inflating: DIV2K_train_HR/0483.png
#   inflating: DIV2K_train_HR/0631.png
#   inflating: DIV2K_train_HR/0134.png
#   inflating: DIV2K_train_HR/0625.png
#   inflating: DIV2K_train_HR/0530.png
#   inflating: DIV2K_train_HR/0454.png
#   inflating: DIV2K_train_HR/0624.png
#   inflating: DIV2K_train_HR/0501.png
#   inflating: DIV2K_train_HR/0038.png
#   inflating: DIV2K_train_HR/0365.png
#   inflating: DIV2K_train_HR/0789.png
#   inflating: DIV2K_train_HR/0010.png
#   inflating: DIV2K_train_HR/0543.png
#   inflating: DIV2K_train_HR/0635.png
#   inflating: DIV2K_train_HR/0418.png
#   inflating: DIV2K_train_HR/0159.png
#   inflating: DIV2K_train_HR/0689.png
#   inflating: DIV2K_train_HR/0429.png
#   inflating: DIV2K_train_HR/0276.png
#   inflating: DIV2K_train_HR/0255.png
#   inflating: DIV2K_train_HR/0293.png
#   inflating: DIV2K_train_HR/0327.png
#   inflating: DIV2K_train_HR/0488.png
#   inflating: DIV2K_train_HR/0244.png
#   inflating: DIV2K_train_HR/0721.png
#   inflating: DIV2K_train_HR/0652.png
#   inflating: DIV2K_train_HR/0779.png
#   inflating: DIV2K_train_HR/0687.png
#   inflating: DIV2K_train_HR/0326.png
#   inflating: DIV2K_train_HR/0161.png
#   inflating: DIV2K_train_HR/0498.png
#   inflating: DIV2K_train_HR/0264.png
#   inflating: DIV2K_train_HR/0136.png
#   inflating: DIV2K_train_HR/0006.png
#   inflating: DIV2K_train_HR/0741.png
#   inflating: DIV2K_train_HR/0421.png
#   inflating: DIV2K_train_HR/0229.png
#   inflating: DIV2K_train_HR/0373.png
#   inflating: DIV2K_train_HR/0703.png
#   inflating: DIV2K_train_HR/0516.png
#   inflating: DIV2K_train_HR/0234.png
#   inflating: DIV2K_train_HR/0405.png
#   inflating: DIV2K_train_HR/0763.png
#   inflating: DIV2K_train_HR/0619.png
#   inflating: DIV2K_train_HR/0138.png
#   inflating: DIV2K_train_HR/0513.png
#   inflating: DIV2K_train_HR/0432.png
#   inflating: DIV2K_train_HR/0177.png
#   inflating: DIV2K_train_HR/0017.png
#   inflating: DIV2K_train_HR/0736.png
#   inflating: DIV2K_train_HR/0459.png
#   inflating: DIV2K_train_HR/0505.png
#   inflating: DIV2K_train_HR/0397.png
#   inflating: DIV2K_train_HR/0591.png
#   inflating: DIV2K_train_HR/0196.png
#   inflating: DIV2K_train_HR/0724.png
#   inflating: DIV2K_train_HR/0740.png
#   inflating: DIV2K_train_HR/0223.png
#   inflating: DIV2K_train_HR/0442.png
#   inflating: DIV2K_train_HR/0165.png
#   inflating: DIV2K_train_HR/0302.png
#   inflating: DIV2K_train_HR/0386.png
#   inflating: DIV2K_train_HR/0601.png
#   inflating: DIV2K_train_HR/0370.png
#   inflating: DIV2K_train_HR/0647.png
#   inflating: DIV2K_train_HR/0267.png
#   inflating: DIV2K_train_HR/0380.png
#   inflating: DIV2K_train_HR/0441.png
#   inflating: DIV2K_train_HR/0037.png
#   inflating: DIV2K_train_HR/0678.png
#   inflating: DIV2K_train_HR/0304.png
#   inflating: DIV2K_train_HR/0494.png
#   inflating: DIV2K_train_HR/0028.png
#   inflating: DIV2K_train_HR/0613.png
#   inflating: DIV2K_train_HR/0257.png
#   inflating: DIV2K_train_HR/0100.png
#   inflating: DIV2K_train_HR/0097.png
#   inflating: DIV2K_train_HR/0604.png
#   inflating: DIV2K_train_HR/0023.png
#   inflating: DIV2K_train_HR/0782.png
#   inflating: DIV2K_train_HR/0446.png
#   inflating: DIV2K_train_HR/0378.png
#   inflating: DIV2K_train_HR/0411.png
#   inflating: DIV2K_train_HR/0320.png
#   inflating: DIV2K_train_HR/0390.png
#   inflating: DIV2K_train_HR/0148.png
#   inflating: DIV2K_train_HR/0577.png
#   inflating: DIV2K_train_HR/0684.png
#   inflating: DIV2K_train_HR/0595.png
#   inflating: DIV2K_train_HR/0765.png
#   inflating: DIV2K_train_HR/0203.png
#   inflating: DIV2K_train_HR/0288.png
#   inflating: DIV2K_train_HR/0058.png
#   inflating: DIV2K_train_HR/0790.png
#   inflating: DIV2K_train_HR/0605.png
#   inflating: DIV2K_train_HR/0248.png
#   inflating: DIV2K_train_HR/0467.png
#   inflating: DIV2K_train_HR/0210.png
#   inflating: DIV2K_train_HR/0517.png
#   inflating: DIV2K_train_HR/0707.png
#   inflating: DIV2K_train_HR/0566.png
#   inflating: DIV2K_train_HR/0224.png
#   inflating: DIV2K_train_HR/0114.png
#   inflating: DIV2K_train_HR/0761.png
#   inflating: DIV2K_train_HR/0468.png
#   inflating: DIV2K_train_HR/0716.png
#   inflating: DIV2K_train_HR/0420.png
#   inflating: DIV2K_train_HR/0669.png
#   inflating: DIV2K_train_HR/0375.png
#   inflating: DIV2K_train_HR/0140.png
#   inflating: DIV2K_train_HR/0792.png
#   inflating: DIV2K_train_HR/0240.png
#   inflating: DIV2K_train_HR/0546.png
#   inflating: DIV2K_train_HR/0235.png
#   inflating: DIV2K_train_HR/0077.png
#   inflating: DIV2K_train_HR/0260.png
#   inflating: DIV2K_train_HR/0212.png
#   inflating: DIV2K_train_HR/0584.png
#   inflating: DIV2K_train_HR/0633.png
#   inflating: DIV2K_train_HR/0060.png
#   inflating: DIV2K_train_HR/0164.png
#   inflating: DIV2K_train_HR/0622.png
#   inflating: DIV2K_train_HR/0105.png
#   inflating: DIV2K_train_HR/0005.png
#   inflating: DIV2K_train_HR/0679.png
#   inflating: DIV2K_train_HR/0089.png
#   inflating: DIV2K_train_HR/0466.png
#   inflating: DIV2K_train_HR/0645.png
#   inflating: DIV2K_train_HR/0301.png
#   inflating: DIV2K_train_HR/0499.png
#   inflating: DIV2K_train_HR/0020.png
#   inflating: DIV2K_train_HR/0070.png
#   inflating: DIV2K_train_HR/0404.png
#   inflating: DIV2K_train_HR/0749.png
#   inflating: DIV2K_train_HR/0770.png
#   inflating: DIV2K_train_HR/0772.png
#   inflating: DIV2K_train_HR/0450.png
#   inflating: DIV2K_train_HR/0120.png
#   inflating: DIV2K_train_HR/0653.png
#   inflating: DIV2K_train_HR/0563.png
#   inflating: DIV2K_train_HR/0171.png
#   inflating: DIV2K_train_HR/0784.png
#   inflating: DIV2K_train_HR/0688.png
#   inflating: DIV2K_train_HR/0045.png
#   inflating: DIV2K_train_HR/0066.png
#   inflating: DIV2K_train_HR/0583.png
#   inflating: DIV2K_train_HR/0632.png
#   inflating: DIV2K_train_HR/0512.png
#   inflating: DIV2K_train_HR/0767.png
#   inflating: DIV2K_train_HR/0623.png
#   inflating: DIV2K_train_HR/0406.png
#   inflating: DIV2K_train_HR/0419.png
#   inflating: DIV2K_train_HR/0273.png
#   inflating: DIV2K_train_HR/0198.png
#   inflating: DIV2K_train_HR/0750.png
#   inflating: DIV2K_train_HR/0220.png
#   inflating: DIV2K_train_HR/0482.png
#   inflating: DIV2K_train_HR/0407.png
#   inflating: DIV2K_train_HR/0704.png
#   inflating: DIV2K_train_HR/0547.png
#   inflating: DIV2K_train_HR/0589.png
#   inflating: DIV2K_train_HR/0012.png
#   inflating: DIV2K_train_HR/0150.png
#   inflating: DIV2K_train_HR/0481.png
#   inflating: DIV2K_train_HR/0357.png
#   inflating: DIV2K_train_HR/0677.png
#   inflating: DIV2K_train_HR/0315.png
#   inflating: DIV2K_train_HR/0394.png
#   inflating: DIV2K_train_HR/0160.png
#   inflating: DIV2K_train_HR/0667.png
#   inflating: DIV2K_train_HR/0568.png
#   inflating: DIV2K_train_HR/0435.png
#   inflating: DIV2K_train_HR/0606.png
#   inflating: DIV2K_train_HR/0464.png
#   inflating: DIV2K_train_HR/0364.png
#   inflating: DIV2K_train_HR/0245.png
#   inflating: DIV2K_train_HR/0508.png
#   inflating: DIV2K_train_HR/0356.png
#   inflating: DIV2K_train_HR/0135.png
#   inflating: DIV2K_train_HR/0146.png
#   inflating: DIV2K_train_HR/0574.png
#   inflating: DIV2K_train_HR/0698.png
#   inflating: DIV2K_train_HR/0222.png
#   inflating: DIV2K_train_HR/0261.png
#   inflating: DIV2K_train_HR/0444.png
#   inflating: DIV2K_train_HR/0078.png
#   inflating: DIV2K_train_HR/0123.png
#   inflating: DIV2K_train_HR/0797.png
#   inflating: DIV2K_train_HR/0274.png
#   inflating: DIV2K_train_HR/0225.png
#   inflating: DIV2K_train_HR/0180.png
#   inflating: DIV2K_train_HR/0325.png
#   inflating: DIV2K_train_HR/0372.png
#   inflating: DIV2K_train_HR/0029.png
#   inflating: DIV2K_train_HR/0318.png
#   inflating: DIV2K_train_HR/0452.png
#   inflating: DIV2K_train_HR/0115.png
#   inflating: DIV2K_train_HR/0423.png
#   inflating: DIV2K_train_HR/0615.png
#   inflating: DIV2K_train_HR/0672.png
#   inflating: DIV2K_train_HR/0231.png
#   inflating: DIV2K_train_HR/0731.png
#   inflating: DIV2K_train_HR/0389.png
#   inflating: DIV2K_train_HR/0680.png
#   inflating: DIV2K_train_HR/0329.png
#   inflating: DIV2K_train_HR/0663.png
#   inflating: DIV2K_train_HR/0659.png
#   inflating: DIV2K_train_HR/0292.png
#   inflating: DIV2K_train_HR/0284.png
#   inflating: DIV2K_train_HR/0133.png
#   inflating: DIV2K_train_HR/0727.png
#   inflating: DIV2K_train_HR/0445.png
#   inflating: DIV2K_train_HR/0139.png
#   inflating: DIV2K_train_HR/0298.png
#   inflating: DIV2K_train_HR/0282.png
#   inflating: DIV2K_train_HR/0778.png
#   inflating: DIV2K_train_HR/0565.png
#   inflating: DIV2K_train_HR/0485.png
#   inflating: DIV2K_train_HR/0495.png
#   inflating: DIV2K_train_HR/0215.png
#   inflating: DIV2K_train_HR/0694.png
#   inflating: DIV2K_train_HR/0321.png
#   inflating: DIV2K_train_HR/0094.png
#   inflating: DIV2K_train_HR/0598.png
#   inflating: DIV2K_train_HR/0430.png
#   inflating: DIV2K_train_HR/0021.png
#   inflating: DIV2K_train_HR/0036.png
#   inflating: DIV2K_train_HR/0188.png
#   inflating: DIV2K_train_HR/0334.png
#   inflating: DIV2K_train_HR/0759.png
#   inflating: DIV2K_train_HR/0217.png
#   inflating: DIV2K_train_HR/0562.png
#   inflating: DIV2K_train_HR/0124.png
#   inflating: DIV2K_train_HR/0690.png
#   inflating: DIV2K_train_HR/0385.png
#   inflating: DIV2K_train_HR/0695.png
#   inflating: DIV2K_train_HR/0708.png
#   inflating: DIV2K_train_HR/0745.png
#   inflating: DIV2K_train_HR/0007.png
#   inflating: DIV2K_train_HR/0226.png
#   inflating: DIV2K_train_HR/0256.png
#   inflating: DIV2K_train_HR/0673.png
#   inflating: DIV2K_train_HR/0451.png
#   inflating: DIV2K_train_HR/0143.png
#   inflating: DIV2K_train_HR/0403.png
#   inflating: DIV2K_train_HR/0125.png
#   inflating: DIV2K_train_HR/0132.png
#   inflating: DIV2K_train_HR/0644.png
#   inflating: DIV2K_train_HR/0796.png
#   inflating: DIV2K_train_HR/0076.png
#   inflating: DIV2K_train_HR/0211.png
#   inflating: DIV2K_train_HR/0676.png
#   inflating: DIV2K_train_HR/0121.png
#   inflating: DIV2K_train_HR/0415.png
#   inflating: DIV2K_train_HR/0536.png
#   inflating: DIV2K_train_HR/0620.png
#   inflating: DIV2K_train_HR/0331.png
#   inflating: DIV2K_train_HR/0277.png
#   inflating: DIV2K_train_HR/0611.png
#   inflating: DIV2K_train_HR/0262.png
#   inflating: DIV2K_train_HR/0305.png
#   inflating: DIV2K_train_HR/0521.png
#   inflating: DIV2K_train_HR/0221.png
#   inflating: DIV2K_train_HR/0699.png
#   inflating: DIV2K_train_HR/0743.png
#   inflating: DIV2K_train_HR/0742.png
#   inflating: DIV2K_train_HR/0111.png
#   inflating: DIV2K_train_HR/0480.png
#   inflating: DIV2K_train_HR/0720.png
#   inflating: DIV2K_train_HR/0402.png
#   inflating: DIV2K_train_HR/0561.png
#   inflating: DIV2K_train_HR/0729.png
#   inflating: DIV2K_train_HR/0296.png
#   inflating: DIV2K_train_HR/0379.png
#   inflating: DIV2K_train_HR/0014.png
#   inflating: DIV2K_train_HR/0714.png
#   inflating: DIV2K_train_HR/0754.png
#   inflating: DIV2K_train_HR/0634.png
#   inflating: DIV2K_train_HR/0725.png
#   inflating: DIV2K_train_HR/0309.png
#   inflating: DIV2K_train_HR/0197.png
#   inflating: DIV2K_train_HR/0039.png
#   inflating: DIV2K_train_HR/0696.png
#   inflating: DIV2K_train_HR/0758.png
#   inflating: DIV2K_train_HR/0599.png
#   inflating: DIV2K_train_HR/0228.png
#   inflating: DIV2K_train_HR/0712.png
#   inflating: DIV2K_train_HR/0539.png
#   inflating: DIV2K_train_HR/0781.png
#   inflating: DIV2K_train_HR/0009.png
#   inflating: DIV2K_train_HR/0145.png
#   inflating: DIV2K_train_HR/0527.png
#   inflating: DIV2K_train_HR/0263.png
#   inflating: DIV2K_train_HR/0122.png
#   inflating: DIV2K_train_HR/0506.png
#   inflating: DIV2K_train_HR/0363.png
#   inflating: DIV2K_train_HR/0249.png
#   inflating: DIV2K_train_HR/0104.png
#   inflating: DIV2K_train_HR/0800.png
#   inflating: DIV2K_train_HR/0214.png
#   inflating: DIV2K_train_HR/0658.png
#   inflating: DIV2K_train_HR/0399.png
#   inflating: DIV2K_train_HR/0572.png
#   inflating: DIV2K_train_HR/0204.png
#   inflating: DIV2K_train_HR/0651.png
#   inflating: DIV2K_train_HR/0061.png
#   inflating: DIV2K_train_HR/0026.png
#   inflating: DIV2K_train_HR/0300.png
#   inflating: DIV2K_train_HR/0162.png
#   inflating: DIV2K_train_HR/0478.png
#   inflating: DIV2K_train_HR/0022.png
#   inflating: DIV2K_train_HR/0079.png
#   inflating: DIV2K_train_HR/0285.png
#   inflating: DIV2K_train_HR/0511.png
#   inflating: DIV2K_train_HR/0025.png
#   inflating: DIV2K_train_HR/0428.png
#   inflating: DIV2K_train_HR/0436.png
#   inflating: DIV2K_train_HR/0324.png
#   inflating: DIV2K_train_HR/0447.png
#   inflating: DIV2K_train_HR/0457.png
#   inflating: DIV2K_train_HR/0424.png
#   inflating: DIV2K_train_HR/0675.png
#   inflating: DIV2K_train_HR/0469.png
#   inflating: DIV2K_train_HR/0090.png
#   inflating: DIV2K_train_HR/0179.png
#   inflating: DIV2K_train_HR/0771.png
#   inflating: DIV2K_train_HR/0431.png
#   inflating: DIV2K_train_HR/0726.png
#   inflating: DIV2K_train_HR/0609.png
#   inflating: DIV2K_train_HR/0184.png
#   inflating: DIV2K_train_HR/0747.png
#   inflating: DIV2K_train_HR/0154.png
#   inflating: DIV2K_train_HR/0391.png
#   inflating: DIV2K_train_HR/0573.png
#   inflating: DIV2K_train_HR/0071.png
#   inflating: DIV2K_train_HR/0798.png
#   inflating: DIV2K_train_HR/0693.png
#   inflating: DIV2K_train_HR/0280.png
#   inflating: DIV2K_train_HR/0414.png
#   inflating: DIV2K_train_HR/0119.png
#   inflating: DIV2K_train_HR/0757.png
#   inflating: DIV2K_train_HR/0762.png
#   inflating: DIV2K_train_HR/0734.png
#   inflating: DIV2K_train_HR/0001.png
#   inflating: DIV2K_train_HR/0265.png
#   inflating: DIV2K_train_HR/0643.png
#   inflating: DIV2K_train_HR/0567.png
#   inflating: DIV2K_train_HR/0130.png
#   inflating: DIV2K_train_HR/0580.png
#   inflating: DIV2K_train_HR/0463.png
#   inflating: DIV2K_train_HR/0218.png
#   inflating: DIV2K_train_HR/0769.png
#   inflating: DIV2K_train_HR/0507.png
#   inflating: DIV2K_train_HR/0013.png
#   inflating: DIV2K_train_HR/0233.png
#   inflating: DIV2K_train_HR/0087.png
#   inflating: DIV2K_train_HR/0093.png
#   inflating: DIV2K_train_HR/0709.png
#   inflating: DIV2K_train_HR/0027.png
#   inflating: DIV2K_train_HR/0570.png
#   inflating: DIV2K_train_HR/0342.png
#   inflating: DIV2K_train_HR/0011.png
#   inflating: DIV2K_train_HR/0287.png
#   inflating: DIV2K_train_HR/0524.png
#   inflating: DIV2K_train_HR/0791.png
#   inflating: DIV2K_train_HR/0701.png
#   inflating: DIV2K_train_HR/0783.png
#   inflating: DIV2K_train_HR/0349.png
#   inflating: DIV2K_train_HR/0766.png
#   inflating: DIV2K_train_HR/0232.png
#   inflating: DIV2K_train_HR/0314.png
#   inflating: DIV2K_train_HR/0303.png
#   inflating: DIV2K_train_HR/0697.png
#   inflating: DIV2K_train_HR/0514.png
#   inflating: DIV2K_train_HR/0377.png
#   inflating: DIV2K_train_HR/0085.png
#   inflating: DIV2K_train_HR/0113.png
#   inflating: DIV2K_train_HR/0540.png
#   inflating: DIV2K_train_HR/0383.png
#   inflating: DIV2K_train_HR/0243.png
#   inflating: DIV2K_train_HR/0086.png
#   inflating: DIV2K_train_HR/0091.png
#   inflating: DIV2K_train_HR/0151.png
#   inflating: DIV2K_train_HR/0502.png
#   inflating: DIV2K_train_HR/0294.png
#   inflating: DIV2K_train_HR/0281.png
#   inflating: DIV2K_train_HR/0656.png
#   inflating: DIV2K_train_HR/0500.png
#   inflating: DIV2K_train_HR/0237.png
#   inflating: DIV2K_train_HR/0387.png
#   inflating: DIV2K_train_HR/0178.png
#   inflating: DIV2K_train_HR/0518.png
#   inflating: DIV2K_train_HR/0239.png
#   inflating: DIV2K_train_HR/0131.png
#   inflating: DIV2K_train_HR/0655.png
#   inflating: DIV2K_train_HR/0417.png
#   inflating: DIV2K_train_HR/0776.png
#   inflating: DIV2K_train_HR/0560.png
#   inflating: DIV2K_train_HR/0737.png
#   inflating: DIV2K_train_HR/0048.png
#   inflating: DIV2K_train_HR/0128.png
#   inflating: DIV2K_train_HR/0052.png
#   inflating: DIV2K_train_HR/0137.png
#   inflating: DIV2K_train_HR/0686.png
#   inflating: DIV2K_train_HR/0053.png
#   inflating: DIV2K_train_HR/0665.png
#   inflating: DIV2K_train_HR/0691.png
#   inflating: DIV2K_train_HR/0167.png
#   inflating: DIV2K_train_HR/0313.png
#   inflating: DIV2K_train_HR/0531.png
#   inflating: DIV2K_train_HR/0569.png
#   inflating: DIV2K_train_HR/0553.png
#   inflating: DIV2K_train_HR/0047.png
#   inflating: DIV2K_train_HR/0096.png
#   inflating: DIV2K_train_HR/0756.png
#   inflating: DIV2K_train_HR/0440.png
#   inflating: DIV2K_train_HR/0199.png
#   inflating: DIV2K_train_HR/0283.png
#   inflating: DIV2K_train_HR/0247.png
#   inflating: DIV2K_train_HR/0024.png
#   inflating: DIV2K_train_HR/0193.png
#   inflating: DIV2K_train_HR/0084.png
#   inflating: DIV2K_train_HR/0102.png
#   inflating: DIV2K_train_HR/0551.png
#   inflating: DIV2K_train_HR/0575.png
#   inflating: DIV2K_train_HR/0477.png
#   inflating: DIV2K_train_HR/0098.png
#   inflating: DIV2K_train_HR/0554.png
#   inflating: DIV2K_train_HR/0189.png
#   inflating: DIV2K_train_HR/0717.png
#   inflating: DIV2K_train_HR/0732.png
#   inflating: DIV2K_train_HR/0702.png
#   inflating: DIV2K_train_HR/0183.png
#   inflating: DIV2K_train_HR/0448.png
#   inflating: DIV2K_train_HR/0455.png
#   inflating: DIV2K_train_HR/0367.png
#   inflating: DIV2K_train_HR/0251.png
#   inflating: DIV2K_train_HR/0744.png
#   inflating: DIV2K_train_HR/0785.png
#   inflating: DIV2K_train_HR/0067.png
#   inflating: DIV2K_train_HR/0163.png
#   inflating: DIV2K_train_HR/0751.png
#   inflating: DIV2K_train_HR/0299.png
#   inflating: DIV2K_train_HR/0129.png
#   inflating: DIV2K_train_HR/0291.png
#   inflating: DIV2K_train_HR/0607.png
#   inflating: DIV2K_train_HR/0242.png
#   inflating: DIV2K_train_HR/0107.png
#   inflating: DIV2K_train_HR/0175.png
#   inflating: DIV2K_train_HR/0753.png
#   inflating: DIV2K_train_HR/0278.png
#   inflating: DIV2K_train_HR/0369.png
#   inflating: DIV2K_train_HR/0571.png
#   inflating: DIV2K_train_HR/0202.png
#   inflating: DIV2K_train_HR/0030.png
#   inflating: DIV2K_train_HR/0799.png
#   inflating: DIV2K_train_HR/0474.png
#   inflating: DIV2K_train_HR/0491.png
#   inflating: DIV2K_train_HR/0638.png
#   inflating: DIV2K_train_HR/0600.png
#   inflating: DIV2K_train_HR/0596.png
#   inflating: DIV2K_train_HR/0059.png
#   inflating: DIV2K_train_HR/0186.png
#   inflating: DIV2K_train_HR/0509.png
#   inflating: DIV2K_train_HR/0529.png
#   inflating: DIV2K_train_HR/0787.png
#   inflating: DIV2K_train_HR/0382.png
#   inflating: DIV2K_train_HR/0777.png
#   inflating: DIV2K_train_HR/0109.png
#   inflating: DIV2K_train_HR/0227.png
#   inflating: DIV2K_train_HR/0388.png
#   inflating: DIV2K_train_HR/0618.png
#   inflating: DIV2K_train_HR/0681.png
#   inflating: DIV2K_train_HR/0205.png
#   inflating: DIV2K_train_HR/0472.png
#   inflating: DIV2K_train_HR/0306.png
#   inflating: DIV2K_train_HR/0361.png
#   inflating: DIV2K_train_HR/0738.png
#   inflating: DIV2K_train_HR/0230.png
#   inflating: DIV2K_train_HR/0081.png
#   inflating: DIV2K_train_HR/0095.png
#   inflating: DIV2K_train_HR/0449.png
#   inflating: DIV2K_train_HR/0626.png
#   inflating: DIV2K_train_HR/0065.png
#   inflating: DIV2K_train_HR/0443.png
#   inflating: DIV2K_train_HR/0275.png
#   inflating: DIV2K_train_HR/0542.png
#   inflating: DIV2K_train_HR/0484.png
#   inflating: DIV2K_train_HR/0359.png
#   inflating: DIV2K_train_HR/0773.png
#   inflating: DIV2K_train_HR/0434.png
#   inflating: DIV2K_train_HR/0544.png
#   inflating: DIV2K_train_HR/0416.png
#   inflating: DIV2K_train_HR/0295.png
#   inflating: DIV2K_train_HR/0538.png
#   inflating: DIV2K_train_HR/0259.png
#   inflating: DIV2K_train_HR/0348.png
#   inflating: DIV2K_train_HR/0588.png
#   inflating: DIV2K_train_HR/0710.png
#   inflating: DIV2K_train_HR/0786.png
#   inflating: DIV2K_train_HR/0185.png
#   inflating: DIV2K_train_HR/0057.png
#   inflating: DIV2K_train_HR/0487.png
#   inflating: DIV2K_train_HR/0683.png

# %%
#@markdown # *0) ** Instalando libreria(OBLIGATORIO)

# !pip install torch torchvision torchaudio

# %%
#@markdown # *1) ** Clase Para manejo de directorios de datasets de imagenes


import os
import cv2
import pandas as pd
from PIL import Image
import torch
from torchvision import transforms
# Recorre el directorio  y elmiina los archvios que no tiene las extensioens permitidas

class DataSetManage:




 def comprobar_ext_directorios(self,directorio):

  for clase,[directorio,etiquetas] in(directorio.items()):
   lista_directorio=os.listdir(directorio)
   self._validarExt(directorio)



 def  _validarExt(self,directorio):
  print(directorio)
   # Extensiones permitidas
  extensiones_permitidas = {".jpg", ".jpeg", ".png"}
  for root, dirs, files in os.walk(directorio):

    for file in files:
        # Obtiene la extensión del archivo
        _, extension = os.path.splitext(file)

        # Verifica si la extensión no está en la lista de extensiones permitidas y elimina el archivo
        if extension.lower() not in extensiones_permitidas:
            archivo_a_eliminar = os.path.join(root, file)
            os.remove(archivo_a_eliminar)
            print(f"Se eliminó: {archivo_a_eliminar}")


# Cambia nombre de cada archivo dentro del directorio a un valor secuencial

 def cambiar_nombres_directorios(self,directorio):
   for clase,[directorio,etiquetas] in(directorio.items()):
     lista_directorio=os.listdir(directorio)
     self._cambiarNombre(directorio,clase)
     print(directorio)


 def _cambiarNombre(self,directorios,subfijo):
  archivos_en_directorio = os.listdir(directorios)
  for i, archivo in enumerate(archivos_en_directorio, start=1):
    # Construir el nuevo nombre del archivo
    nuevo_nombre = f"{subfijo}{i}{os.path.splitext(archivo)[1]}"

    # Ruta completa del archivo antiguo y nuevo
    ruta_antigua = os.path.join(directorios, archivo)
    ruta_nueva = os.path.join(directorios, nuevo_nombre)

    # Cambiar el nombre del archivo
    os.rename(ruta_antigua, ruta_nueva)
    print(f"Se cambió el nombre de {ruta_antigua} a {ruta_nueva}")


#Obtiene la cantidad de elemntos que tiene la carpeta

 def len_directorio(self,directorio):
    cantidad_elementos = sum(1 for elemento in os.listdir(directorio) if os.path.isfile(os.path.join(directorio, elemento)))
    return cantidad_elementos


#----------------------------------------------------------------------------------------------

#Valida si la imagen se puede leer usando  pill o cv2 si no se puede leer se elimina

 def validar_Img_Pill(self,directorio,):
  for etiqueta,[directorio,clase] in(directorio.items()):

    lista_paths=os.listdir(directorio)
    self._validarLecturaImgPill(directorio,lista_paths)
  print(f"Se ah validado todas las imagenes")

 def validar_Img_cv2(self,directorio):
  for etiqueta,[directorio,clase] in(directorio.items()):

    lista_paths=os.listdir(directorio)
    self._validarLecturaImg(directorio,lista_paths)
  print(f"Se ah validado todas las imagenes")

 def _validarLecturaImg(self,directorio,lista):

  for ruta in(lista):
   imagen=cv2.imread(directorio+ruta)
   if  imagen is None:
     os.remove(directorio+ruta)
     print(f"No se pudo leer y se elimino archivo:{directorio+ruta}")

 def _validarLecturaImgPill(self,directorio,lista):
    for ruta in(lista):
     try:
      imagen=Image.open(directorio+ruta)
     except Exception as e:
      os.remove(directorio+ruta)
      print(f"Archivo '{directorio+ruta}' eliminado.")



#vamos a recorrer el dicionario y validar ruta por ruta si se puede leer sino se elminara
#vamos guaradno al mismo tiempo 3 listas, los directorios , listas de paths de los directiros y de las clases ,para usarlo luego usarlo al crear el csv

 def separar_datos_directorios(self,directorios):
  listas_directorios=[]
  listas_listas_directorios=[]
  listas_clases=[]

  for etiqueta,[directorio,clase] in(directorios.items()):

       lista_paths=os.listdir(directorio)
       listas_directorios.append(directorio)
       listas_listas_directorios.append(lista_paths)
       listas_clases.append(clase)

  return listas_directorios,listas_listas_directorios,listas_clases

 def emparejar_listas_paths(self,lista_listas):

   #Tomamos el minimo tamaño dentro de las lista de cada clase
   tamaño_minimo = min(len(arr) for arr in lista_listas)

   #Vamos a emparejar todas las listas con un tamaño igual que sea la del minimo tamaño de todas,esto para tener un set de datos parejo por cada clase
   Reducido_lista_paths=[]

   #Reduce cada lista de los paths a la cantidad minimo para que todos tenga iaugal cantidad
   for listas in(lista_listas):
    Reducido_lista_paths.append(listas[:tamaño_minimo])

   return Reducido_lista_paths
#---------------------------------------------------------------------------------


 def crear_paths_csv(self,directorio_base,lista_paths,clases,nombre_archivo):

   columnas=["path","etiqueta"]
   datos_csv=[]

   for dir_base,dir_path,clase in  zip(directorio_base,lista_paths,clases):

    for path  in (dir_path):

     datos_csv.append([dir_base+path ,clase])


   df_lista=pd.DataFrame(datos_csv,columns=columnas)
   df_lista=df_lista.sort_values(by='path')
   df_lista.to_csv(nombre_archivo,index=False)
   print("Csv Creado")
#---------------------------------------------------------------------------------

#devuelve cuatnos elemtnos tiene cada clase
 def total_elementos(self,directorio,csv_path):
    df=pd.read_csv(csv_path)
    for clase,[directorio,etiqueta] in (directorio.items()):
     tamaño_etiqueta=(df["etiqueta"] == etiqueta).sum()
     print(f"la clase {clase} tiene :{tamaño_etiqueta} elementos")


#-------------------------------------------------------------------------------------------------

  #Funciones para data aumentation
 def   data_aumentation_conjunto(self,input_imagen_folder,output_path_folder,iteraciones,transformaciones,keepname=False):  #ingresa trnasformacioens como compose donde se aplicara las trasnfomracioens conjutnos pero se repteira un numero de veces por cada imagen

   for filename in os.listdir(input_imagen_folder):

    if filename.endswith('.jpg') or filename.endswith('.png'):

        input_path = os.path.join(input_imagen_folder, filename)
        if(keepname==False):
         output_path = os.path.join(output_path_folder, f'transformed_{filename}')
        else:
          output_path = os.path.join(output_path_folder, f'{filename}')
        # Aplica las transformaciones
        print(output_path)
        self._apply_transfomaciones_conjunto_it(input_path,output_path,int(iteraciones),transformaciones,keepname)


 def   data_aumentation_individual(self,input_imagen_folder,output_path_folder,transformaciones,keepname=False):  #las trnasfomaciones solo pasaremos la lista ya que ira aplicando la transformacion una por una por cada imagen

  for filename in os.listdir(input_imagen_folder):

    if filename.endswith('.jpg') or filename.endswith('.png'):
        input_path = os.path.join(input_imagen_folder, filename)
        if(keepname==False):
         output_path = os.path.join(output_path_folder, f'transformed_{filename}')
         print("opasasmos")
        else:
          output_path = os.path.join(output_path_folder, f'{filename}')
        # Aplica las transformaciones
        self._apply_transfomaciones_conjunto(input_path,output_path,transformaciones,keepname)



 def _apply_transfomaciones_conjunto_it(self,input_imagen_path,output_iamgen_path,iteraciones,transformations=None,keepname=False): #aplica las transfomracioens  conjutas por iteracion y se guarda las iamgenes

   imagen=Image.open(input_imagen_path)


   for i in range(iteraciones):
      imagen_trasformada=transformations(imagen)

      out_root, out_extension = os.path.splitext(output_iamgen_path)
      if(keepname==False):
       imagen_trasformada.save(f"{out_root}_{i}{out_extension}")
      else:
        imagen_trasformada.save(f"{out_root}{out_extension}")

 def _apply_transfomaciones_conjunto(self,input_imagen_path,output_iamgen_path,transformations=None,keepname=False): #aplica las transfomracioens individuales  y se guarda las iamgenes

  imagen=Image.open(input_imagen_path)

  for i,transformacion in enumerate(transformations):
   imagen_transformada=transformacion(imagen)
   out_root, out_extension = os.path.splitext(output_iamgen_path)
   if(keepname==False):
     imagen_transformada.save(f"{out_root}_{i}{out_extension}")
   else:
      imagen_transformada.save(f"{out_root}{out_extension}")

# %%
#Creamos las carpetas con las imagenes en hr y lw

#Creamos los arhcivo baja resolucion aparitr de imangenes alta resoulcion en hr , estos archios iran a carpaeta lw
directorio_in="/content/DIV2K_train_HR"
directorio_out="/content/imagenes/"

#antes de otrogar mediads de hr y lw , chekea como el generador va votando las resolucioens hr_fake segun la resolucion lw que especifics tiene qeu conicidr
#ya que el discriminador necsita la misma medidades tanto para el hr y el hr_fake que genera el generador

transformaciones=transforms.Compose([
transforms.Resize((256, 256)),

])




datasetmanage=DataSetManage()
datasetmanage.data_aumentation_conjunto(directorio_in,directorio_out,1,transformaciones)
# Out:
# /content/imagenes/transformed_0683.png
# /content/imagenes/transformed_0197.png
# /content/imagenes/transformed_0774.png
# /content/imagenes/transformed_0768.png
# /content/imagenes/transformed_0405.png
# /content/imagenes/transformed_0765.png
# /content/imagenes/transformed_0674.png
# /content/imagenes/transformed_0147.png
# /content/imagenes/transformed_hr_22.png
# /content/imagenes/transformed_0419.png
# /content/imagenes/transformed_0085.png
# /content/imagenes/transformed_0185.png
# /content/imagenes/transformed_0155.png
# /content/imagenes/transformed_0347.png
# /content/imagenes/transformed_hr_7.png
# /content/imagenes/transformed_hr_16.png
# /content/imagenes/transformed_0036.png
# /content/imagenes/transformed_0777.png
# /content/imagenes/transformed_0110.png
# /content/imagenes/transformed_0278.png
# /content/imagenes/transformed_0766.png
# /content/imagenes/transformed_0135.png
# /content/imagenes/transformed_0077.png
# /content/imagenes/transformed_0692.png
# /content/imagenes/transformed_0083.png
# /content/imagenes/transformed_0011.png
# /content/imagenes/transformed_0171.png
# /content/imagenes/transformed_0151.png
# /content/imagenes/transformed_0411.png
# /content/imagenes/transformed_0718.png
# /content/imagenes/transformed_0594.png
# /content/imagenes/transformed_0784.png
# /content/imagenes/transformed_hr_28.png
# /content/imagenes/transformed_0469.png
# /content/imagenes/transformed_0441.png
# /content/imagenes/transformed_0455.png
# /content/imagenes/transformed_0238.png
# /content/imagenes/transformed_0277.png
# /content/imagenes/transformed_0702.png
# /content/imagenes/transformed_0367.png
# /content/imagenes/transformed_0583.png
# /content/imagenes/transformed_0024.png
# /content/imagenes/transformed_0559.png
# /content/imagenes/transformed_0119.png
# /content/imagenes/transformed_0106.png
# /content/imagenes/transformed_0157.png
# /content/imagenes/transformed_0523.png
# /content/imagenes/transformed_0649.png
# /content/imagenes/transformed_0280.png
# /content/imagenes/transformed_0497.png
# /content/imagenes/transformed_0424.png
# /content/imagenes/transformed_0363.png
# /content/imagenes/transformed_0601.png
# /content/imagenes/transformed_0786.png
# /content/imagenes/transformed_0244.png
# /content/imagenes/transformed_0052.png
# /content/imagenes/transformed_0228.png
# /content/imagenes/transformed_0730.png
# /content/imagenes/transformed_0038.png
# /content/imagenes/transformed_0716.png
# /content/imagenes/transformed_0158.png
# /content/imagenes/transformed_0461.png
# /content/imagenes/transformed_0678.png
# /content/imagenes/transformed_0632.png
# /content/imagenes/transformed_0040.png
# /content/imagenes/transformed_0348.png
# /content/imagenes/transformed_0593.png
# /content/imagenes/transformed_0528.png
# /content/imagenes/transformed_0769.png
# /content/imagenes/transformed_0524.png
# /content/imagenes/transformed_0745.png
# /content/imagenes/transformed_0066.png
# /content/imagenes/transformed_0542.png
# /content/imagenes/transformed_0233.png
# /content/imagenes/transformed_0471.png
# /content/imagenes/transformed_0313.png
# /content/imagenes/transformed_0459.png
# /content/imagenes/transformed_0759.png
# /content/imagenes/transformed_0457.png
# /content/imagenes/transformed_0266.png
# /content/imagenes/transformed_0070.png
# /content/imagenes/transformed_0242.png
# /content/imagenes/transformed_0370.png
# /content/imagenes/transformed_0035.png
# /content/imagenes/transformed_0663.png
# /content/imagenes/transformed_0269.png
# /content/imagenes/transformed_0435.png
# /content/imagenes/transformed_0300.png
# /content/imagenes/transformed_0384.png
# /content/imagenes/transformed_0199.png
# /content/imagenes/transformed_0177.png
# /content/imagenes/transformed_0021.png
# /content/imagenes/transformed_0259.png
# /content/imagenes/transformed_0671.png
# /content/imagenes/transformed_0004.png
# /content/imagenes/transformed_0800.png
# /content/imagenes/transformed_0354.png
# /content/imagenes/transformed_0540.png
# /content/imagenes/transformed_0400.png
# /content/imagenes/transformed_0681.png
# /content/imagenes/transformed_0568.png
# /content/imagenes/transformed_0249.png
# /content/imagenes/transformed_0295.png
# /content/imagenes/transformed_0689.png
# /content/imagenes/transformed_0403.png
# /content/imagenes/transformed_0222.png
# /content/imagenes/transformed_0385.png
# /content/imagenes/transformed_0397.png
# /content/imagenes/transformed_0193.png
# /content/imagenes/transformed_hr_45.png
# /content/imagenes/transformed_0107.png
# /content/imagenes/transformed_0566.png
# /content/imagenes/transformed_0452.png
# /content/imagenes/transformed_0078.png
# /content/imagenes/transformed_0470.png
# /content/imagenes/transformed_0374.png
# /content/imagenes/transformed_0132.png
# /content/imagenes/transformed_0302.png
# /content/imagenes/transformed_hr_33.png
# /content/imagenes/transformed_0631.png
# /content/imagenes/transformed_0794.png
# /content/imagenes/transformed_0695.png
# /content/imagenes/transformed_0001.png
# /content/imagenes/transformed_hr_6.png
# /content/imagenes/transformed_0580.png
# /content/imagenes/transformed_0612.png
# /content/imagenes/transformed_0775.png
# /content/imagenes/transformed_0579.png
# /content/imagenes/transformed_0002.png
# /content/imagenes/transformed_hr_14.png
# /content/imagenes/transformed_0253.png
# /content/imagenes/transformed_0505.png
# /content/imagenes/transformed_0734.png
# /content/imagenes/transformed_0232.png
# /content/imagenes/transformed_0790.png
# /content/imagenes/transformed_0412.png
# /content/imagenes/transformed_0396.png
# /content/imagenes/transformed_0728.png
# /content/imagenes/transformed_0778.png
# /content/imagenes/transformed_0797.png
# /content/imagenes/transformed_0017.png
# /content/imagenes/transformed_0319.png
# /content/imagenes/transformed_0722.png
# /content/imagenes/transformed_0476.png
# /content/imagenes/transformed_0050.png
# /content/imagenes/transformed_0752.png
# /content/imagenes/transformed_0563.png
# /content/imagenes/transformed_0598.png
# /content/imagenes/transformed_0456.png
# /content/imagenes/transformed_0117.png
# /content/imagenes/transformed_0781.png
# /content/imagenes/transformed_0724.png
# /content/imagenes/transformed_0267.png
# /content/imagenes/transformed_0310.png
# /content/imagenes/transformed_0606.png
# /content/imagenes/transformed_0417.png
# /content/imagenes/transformed_0361.png
# /content/imagenes/transformed_0597.png
# /content/imagenes/transformed_hr_4.png
# /content/imagenes/transformed_0118.png
# /content/imagenes/transformed_0638.png
# /content/imagenes/transformed_0265.png
# /content/imagenes/transformed_0245.png
# /content/imagenes/transformed_0124.png
# /content/imagenes/transformed_0246.png
# /content/imagenes/transformed_0596.png
# /content/imagenes/transformed_0241.png
# /content/imagenes/transformed_0092.png
# /content/imagenes/transformed_0502.png
# /content/imagenes/transformed_0154.png
# /content/imagenes/transformed_0219.png
# /content/imagenes/transformed_0108.png
# /content/imagenes/transformed_0134.png
# /content/imagenes/transformed_0350.png
# /content/imagenes/transformed_0605.png
# /content/imagenes/transformed_0739.png
# /content/imagenes/transformed_0624.png
# /content/imagenes/transformed_0628.png
# /content/imagenes/transformed_0743.png
# /content/imagenes/transformed_0181.png
# /content/imagenes/transformed_0509.png
# /content/imagenes/transformed_0316.png
# /content/imagenes/transformed_0715.png
# /content/imagenes/transformed_0282.png
# /content/imagenes/transformed_0753.png
# /content/imagenes/transformed_0029.png
# /content/imagenes/transformed_0337.png
# /content/imagenes/transformed_0076.png
# /content/imagenes/transformed_0738.png
# /content/imagenes/transformed_0625.png
# /content/imagenes/transformed_0281.png
# /content/imagenes/transformed_hr_41.png
# /content/imagenes/transformed_hr_31.png
# /content/imagenes/transformed_0770.png
# /content/imagenes/transformed_0761.png
# /content/imagenes/transformed_0390.png
# /content/imagenes/transformed_0221.png
# /content/imagenes/transformed_0290.png
# /content/imagenes/transformed_0184.png
# /content/imagenes/transformed_0687.png
# /content/imagenes/transformed_hr_15.png
# /content/imagenes/transformed_0445.png
# /content/imagenes/transformed_0293.png
# /content/imagenes/transformed_0336.png
# /content/imagenes/transformed_0074.png
# /content/imagenes/transformed_0448.png
# /content/imagenes/transformed_0328.png
# /content/imagenes/transformed_0676.png
# /content/imagenes/transformed_0433.png
# /content/imagenes/transformed_0616.png
# /content/imagenes/transformed_0553.png
# /content/imagenes/transformed_0539.png
# /content/imagenes/transformed_0481.png
# /content/imagenes/transformed_0022.png
# /content/imagenes/transformed_0058.png
# /content/imagenes/transformed_hr_5.png
# /content/imagenes/transformed_0480.png
# /content/imagenes/transformed_0613.png
# /content/imagenes/transformed_0637.png
# /content/imagenes/transformed_0142.png
# /content/imagenes/transformed_0511.png
# /content/imagenes/transformed_0383.png
# /content/imagenes/transformed_0003.png
# /content/imagenes/transformed_hr_39.png
# /content/imagenes/transformed_0498.png
# /content/imagenes/transformed_0477.png
# /content/imagenes/transformed_0780.png
# /content/imagenes/transformed_0355.png
# /content/imagenes/transformed_0668.png
# /content/imagenes/transformed_0128.png
# /content/imagenes/transformed_0143.png
# /content/imagenes/transformed_0301.png
# /content/imagenes/transformed_0413.png
# /content/imagenes/transformed_0351.png
# /content/imagenes/transformed_0796.png
# /content/imagenes/transformed_0707.png
# /content/imagenes/transformed_0709.png
# /content/imagenes/transformed_0429.png
# /content/imagenes/transformed_0762.png
# /content/imagenes/transformed_0735.png
# /content/imagenes/transformed_0335.png
# /content/imagenes/transformed_0731.png
# /content/imagenes/transformed_0600.png
# /content/imagenes/transformed_0195.png
# /content/imagenes/transformed_0466.png
# /content/imagenes/transformed_0569.png
# /content/imagenes/transformed_0710.png
# /content/imagenes/transformed_0720.png
# /content/imagenes/transformed_0626.png
# /content/imagenes/transformed_0393.png
# /content/imagenes/transformed_0773.png
# /content/imagenes/transformed_0519.png
# /content/imagenes/transformed_0446.png
# /content/imagenes/transformed_0610.png
# /content/imagenes/transformed_0729.png
# /content/imagenes/transformed_0516.png
# /content/imagenes/transformed_0166.png
# /content/imagenes/transformed_0258.png
# /content/imagenes/transformed_0454.png
# /content/imagenes/transformed_0381.png
# /content/imagenes/transformed_0422.png
# /content/imagenes/transformed_0073.png
# /content/imagenes/transformed_hr_32.png
# /content/imagenes/transformed_0027.png
# /content/imagenes/transformed_0296.png
# /content/imagenes/transformed_0554.png
# /content/imagenes/transformed_0323.png
# /content/imagenes/transformed_hr_37.png
# /content/imagenes/transformed_0391.png
# /content/imagenes/transformed_0152.png
# /content/imagenes/transformed_0137.png
# /content/imagenes/transformed_0139.png
# /content/imagenes/transformed_0346.png
# /content/imagenes/transformed_0235.png
# /content/imagenes/transformed_0019.png
# /content/imagenes/transformed_0529.png
# /content/imagenes/transformed_0458.png
# /content/imagenes/transformed_0312.png
# /content/imagenes/transformed_0535.png
# /content/imagenes/transformed_0468.png
# /content/imagenes/transformed_hr_25.png
# /content/imagenes/transformed_0298.png
# /content/imagenes/transformed_0371.png
# /content/imagenes/transformed_0192.png
# /content/imagenes/transformed_0399.png
# /content/imagenes/transformed_0787.png
# /content/imagenes/transformed_0500.png
# /content/imagenes/transformed_0373.png
# /content/imagenes/transformed_0387.png
# /content/imagenes/transformed_0167.png
# /content/imagenes/transformed_0375.png
# /content/imagenes/transformed_0210.png
# /content/imagenes/transformed_hr_17.png
# /content/imagenes/transformed_0287.png
# /content/imagenes/transformed_0617.png
# /content/imagenes/transformed_0581.png
# /content/imagenes/transformed_0150.png
# /content/imagenes/transformed_0209.png
# /content/imagenes/transformed_0060.png
# /content/imagenes/transformed_0489.png
# /content/imagenes/transformed_hr_20.png
# /content/imagenes/transformed_0486.png
# /content/imagenes/transformed_0727.png
# /content/imagenes/transformed_0549.png
# /content/imagenes/transformed_0737.png
# /content/imagenes/transformed_0655.png
# /content/imagenes/transformed_0012.png
# /content/imagenes/transformed_0430.png
# /content/imagenes/transformed_0460.png
# /content/imagenes/transformed_0144.png
# /content/imagenes/transformed_0662.png
# /content/imagenes/transformed_0525.png
# /content/imagenes/transformed_0306.png
# /content/imagenes/transformed_0688.png
# /content/imagenes/transformed_0224.png
# /content/imagenes/transformed_0656.png
# /content/imagenes/transformed_0595.png
# /content/imagenes/transformed_0615.png
# /content/imagenes/transformed_0120.png
# /content/imagenes/transformed_0255.png
# /content/imagenes/transformed_0757.png
# /content/imagenes/transformed_0044.png
# /content/imagenes/transformed_0343.png
# /content/imagenes/transformed_0534.png
# /content/imagenes/transformed_0291.png
# /content/imagenes/transformed_0564.png
# /content/imagenes/transformed_0231.png
# /content/imagenes/transformed_0198.png
# /content/imagenes/transformed_0229.png
# /content/imagenes/transformed_0141.png
# /content/imagenes/transformed_0200.png
# /content/imagenes/transformed_0243.png
# /content/imagenes/transformed_0204.png
# /content/imagenes/transformed_0025.png
# /content/imagenes/transformed_0685.png
# /content/imagenes/transformed_0700.png
# /content/imagenes/transformed_0007.png
# /content/imagenes/transformed_0116.png
# /content/imagenes/transformed_0499.png
# /content/imagenes/transformed_0415.png
# /content/imagenes/transformed_0274.png
# /content/imagenes/transformed_0558.png
# /content/imagenes/transformed_0703.png
# /content/imagenes/transformed_0332.png
# /content/imagenes/transformed_0020.png
# /content/imagenes/transformed_0440.png
# /content/imagenes/transformed_0349.png
# /content/imagenes/transformed_0636.png
# /content/imagenes/transformed_0746.png
# /content/imagenes/transformed_0314.png
# /content/imagenes/transformed_0789.png
# /content/imagenes/transformed_0103.png
# /content/imagenes/transformed_hr_35.png
# /content/imagenes/transformed_0719.png
# /content/imagenes/transformed_0225.png
# /content/imagenes/transformed_0294.png
# /content/imagenes/transformed_0590.png
# /content/imagenes/transformed_0527.png
# /content/imagenes/transformed_0104.png
# /content/imagenes/transformed_hr_24.png
# /content/imagenes/transformed_0627.png
# /content/imagenes/transformed_0159.png
# /content/imagenes/transformed_0082.png
# /content/imagenes/transformed_0545.png
# /content/imagenes/transformed_0640.png
# /content/imagenes/transformed_0464.png
# /content/imagenes/transformed_0582.png
# /content/imagenes/transformed_0191.png
# /content/imagenes/transformed_0112.png
# /content/imagenes/transformed_0679.png
# /content/imagenes/transformed_0272.png
# /content/imagenes/transformed_0449.png
# /content/imagenes/transformed_0334.png
# /content/imagenes/transformed_0016.png
# /content/imagenes/transformed_0186.png
# /content/imagenes/transformed_0697.png
# /content/imagenes/transformed_0521.png
# /content/imagenes/transformed_0194.png
# /content/imagenes/transformed_0061.png
# /content/imagenes/transformed_0567.png
# /content/imagenes/transformed_0443.png
# /content/imagenes/transformed_0785.png
# /content/imagenes/transformed_0723.png
# /content/imagenes/transformed_0691.png
# /content/imagenes/transformed_0621.png
# /content/imagenes/transformed_0484.png
# /content/imagenes/transformed_0123.png
# /content/imagenes/transformed_0573.png
# /content/imagenes/transformed_0211.png
# /content/imagenes/transformed_0450.png
# /content/imagenes/transformed_0098.png
# /content/imagenes/transformed_hr_21.png
# /content/imagenes/transformed_0672.png
# /content/imagenes/transformed_0506.png
# /content/imagenes/transformed_0101.png
# /content/imagenes/transformed_hr_12.png
# /content/imagenes/transformed_0283.png
# /content/imagenes/transformed_0023.png
# /content/imagenes/transformed_0333.png
# /content/imagenes/transformed_0311.png
# /content/imagenes/transformed_0543.png
# /content/imagenes/transformed_0090.png
# /content/imagenes/transformed_0587.png
# /content/imagenes/transformed_0398.png
# /content/imagenes/transformed_0318.png
# /content/imagenes/transformed_0444.png
# /content/imagenes/transformed_0402.png
# /content/imagenes/transformed_0380.png
# /content/imagenes/transformed_0365.png
# /content/imagenes/transformed_0239.png
# /content/imagenes/transformed_0327.png
# /content/imagenes/transformed_0555.png
# /content/imagenes/transformed_0661.png
# /content/imagenes/transformed_0706.png
# /content/imagenes/transformed_0297.png
# /content/imagenes/transformed_hr_30.png
# /content/imagenes/transformed_0288.png
# /content/imagenes/transformed_0160.png
# /content/imagenes/transformed_0701.png
# /content/imagenes/transformed_0614.png
# /content/imagenes/transformed_0100.png
# /content/imagenes/transformed_hr_10.png
# /content/imagenes/transformed_0544.png
# /content/imagenes/transformed_0071.png
# /content/imagenes/transformed_0584.png
# /content/imagenes/transformed_0431.png
# /content/imagenes/transformed_0386.png
# /content/imagenes/transformed_0530.png
# /content/imagenes/transformed_0079.png
# /content/imagenes/transformed_0602.png
# /content/imagenes/transformed_0714.png
# /content/imagenes/transformed_0754.png
# /content/imagenes/transformed_0279.png
# /content/imagenes/transformed_0037.png
# /content/imagenes/transformed_0136.png
# /content/imagenes/transformed_0607.png
# /content/imagenes/transformed_0690.png
# /content/imagenes/transformed_0414.png
# /content/imagenes/transformed_0482.png
# /content/imagenes/transformed_0378.png
# /content/imagenes/transformed_0190.png
# /content/imagenes/transformed_0562.png
# /content/imagenes/transformed_0115.png
# /content/imagenes/transformed_0644.png
# /content/imagenes/transformed_0603.png
# /content/imagenes/transformed_0064.png
# /content/imagenes/transformed_0657.png
# /content/imagenes/transformed_0039.png
# /content/imagenes/transformed_0105.png
# /content/imagenes/transformed_0164.png
# /content/imagenes/transformed_0740.png
# /content/imagenes/transformed_0339.png
# /content/imagenes/transformed_0550.png
# /content/imagenes/transformed_0240.png
# /content/imagenes/transformed_0264.png
# /content/imagenes/transformed_0111.png
# /content/imagenes/transformed_0604.png
# /content/imagenes/transformed_0693.png
# /content/imagenes/transformed_0401.png
# /content/imagenes/transformed_0097.png
# /content/imagenes/transformed_0252.png
# /content/imagenes/transformed_0032.png
# /content/imagenes/transformed_0315.png
# /content/imagenes/transformed_0218.png
# /content/imagenes/transformed_0013.png
# /content/imagenes/transformed_0376.png
# /content/imagenes/transformed_0488.png
# /content/imagenes/transformed_0338.png
# /content/imagenes/transformed_0420.png
# /content/imagenes/transformed_0359.png
# /content/imagenes/transformed_0179.png
# /content/imagenes/transformed_0305.png
# /content/imagenes/transformed_0492.png
# /content/imagenes/transformed_0140.png
# /content/imagenes/transformed_0760.png
# /content/imagenes/transformed_0286.png
# /content/imagenes/transformed_0487.png
# /content/imagenes/transformed_0517.png
# /content/imagenes/transformed_0048.png
# /content/imagenes/transformed_hr_13.png
# /content/imagenes/transformed_0407.png
# /content/imagenes/transformed_0410.png
# /content/imagenes/transformed_0018.png
# /content/imagenes/transformed_0665.png
# /content/imagenes/transformed_0088.png
# /content/imagenes/transformed_0226.png
# /content/imagenes/transformed_0262.png
# /content/imagenes/transformed_0174.png
# /content/imagenes/transformed_0353.png
# /content/imagenes/transformed_0591.png
# /content/imagenes/transformed_0388.png
# /content/imagenes/transformed_0736.png
# /content/imagenes/transformed_0442.png
# /content/imagenes/transformed_0329.png
# /content/imagenes/transformed_0126.png
# /content/imagenes/transformed_0483.png
# /content/imagenes/transformed_0206.png
# /content/imagenes/transformed_0237.png
# /content/imagenes/transformed_0330.png
# /content/imagenes/transformed_0006.png
# /content/imagenes/transformed_0161.png
# /content/imagenes/transformed_0254.png
# /content/imagenes/transformed_0320.png
# /content/imagenes/transformed_0575.png
# /content/imagenes/transformed_0507.png
# /content/imagenes/transformed_0081.png
# /content/imagenes/transformed_0432.png
# /content/imagenes/transformed_0490.png
# /content/imagenes/transformed_0114.png
# /content/imagenes/transformed_0485.png
# /content/imagenes/transformed_0541.png
# /content/imagenes/transformed_0182.png
# /content/imagenes/transformed_0589.png
# /content/imagenes/transformed_hr_46.png
# /content/imagenes/transformed_0276.png
# /content/imagenes/transformed_0409.png
# /content/imagenes/transformed_0357.png
# /content/imagenes/transformed_hr_18.png
# /content/imagenes/transformed_0217.png
# /content/imagenes/transformed_0178.png
# /content/imagenes/transformed_0726.png
# /content/imagenes/transformed_0669.png
# /content/imagenes/transformed_0340.png
# /content/imagenes/transformed_0189.png
# /content/imagenes/transformed_0725.png
# /content/imagenes/transformed_0531.png
# /content/imagenes/transformed_0547.png
# /content/imagenes/transformed_0366.png
# /content/imagenes/transformed_hr_3.png
# /content/imagenes/transformed_0495.png
# /content/imagenes/transformed_0145.png
# /content/imagenes/transformed_0425.png
# /content/imagenes/transformed_0473.png
# /content/imagenes/transformed_0358.png
# /content/imagenes/transformed_hr_19.png
# /content/imagenes/transformed_0713.png
# /content/imagenes/transformed_0234.png
# /content/imagenes/transformed_0791.png
# /content/imagenes/transformed_0129.png
# /content/imagenes/transformed_0578.png
# /content/imagenes/transformed_0493.png
# /content/imagenes/transformed_0362.png
# /content/imagenes/transformed_0125.png
# /content/imagenes/transformed_0372.png
# /content/imagenes/transformed_0084.png
# /content/imagenes/transformed_0503.png
# /content/imagenes/transformed_0067.png
# /content/imagenes/transformed_0057.png
# /content/imagenes/transformed_0653.png
# /content/imagenes/transformed_0538.png
# /content/imagenes/transformed_0102.png
# /content/imagenes/transformed_0395.png
# /content/imagenes/transformed_0065.png
# /content/imagenes/transformed_0256.png
# /content/imagenes/transformed_0292.png
# /content/imagenes/transformed_0756.png
# /content/imagenes/transformed_0767.png
# /content/imagenes/transformed_0131.png
# /content/imagenes/transformed_0677.png
# /content/imagenes/transformed_hr_43.png
# /content/imagenes/transformed_0586.png
# /content/imagenes/transformed_0570.png
# /content/imagenes/transformed_0404.png
# /content/imagenes/transformed_hr_29.png
# /content/imagenes/transformed_0028.png
# /content/imagenes/transformed_0223.png
# /content/imagenes/transformed_0799.png
# /content/imagenes/transformed_0031.png
# /content/imagenes/transformed_0170.png
# /content/imagenes/transformed_0646.png
# /content/imagenes/transformed_0127.png
# /content/imagenes/transformed_0475.png
# /content/imagenes/transformed_0515.png
# /content/imagenes/transformed_0047.png
# /content/imagenes/transformed_0462.png
# /content/imagenes/transformed_0772.png
# /content/imagenes/transformed_0684.png
# /content/imagenes/transformed_0699.png
# /content/imagenes/transformed_0437.png
# /content/imagenes/transformed_hr_2.png
# /content/imagenes/transformed_0793.png
# /content/imagenes/transformed_0536.png
# /content/imagenes/transformed_0721.png
# /content/imagenes/transformed_0436.png
# /content/imagenes/transformed_0324.png
# /content/imagenes/transformed_hr_11.png
# /content/imagenes/transformed_0749.png
# /content/imagenes/transformed_0087.png
# /content/imagenes/transformed_0634.png
# /content/imagenes/transformed_0236.png
# /content/imagenes/transformed_0321.png
# /content/imagenes/transformed_0463.png
# /content/imagenes/transformed_0510.png
# /content/imagenes/transformed_0056.png
# /content/imagenes/transformed_0686.png
# /content/imagenes/transformed_hr_40.png
# /content/imagenes/transformed_0599.png
# /content/imagenes/transformed_0289.png
# /content/imagenes/transformed_0268.png
# /content/imagenes/transformed_0421.png
# /content/imagenes/transformed_0275.png
# /content/imagenes/transformed_0030.png
# /content/imagenes/transformed_0080.png
# /content/imagenes/transformed_0089.png
# /content/imagenes/transformed_0741.png
# /content/imagenes/transformed_0113.png
# /content/imagenes/transformed_0526.png
# /content/imagenes/transformed_0352.png
# /content/imagenes/transformed_0651.png
# /content/imagenes/transformed_0369.png
# /content/imagenes/transformed_0664.png
# /content/imagenes/transformed_0096.png
# /content/imagenes/transformed_0747.png
# /content/imagenes/transformed_0046.png
# /content/imagenes/transformed_0630.png
# /content/imagenes/transformed_0043.png
# /content/imagenes/transformed_hr_23.png
# /content/imagenes/transformed_0648.png
# /content/imagenes/transformed_0180.png
# /content/imagenes/transformed_0779.png
# /content/imagenes/transformed_0075.png
# /content/imagenes/transformed_0620.png
# /content/imagenes/transformed_0382.png
# /content/imagenes/transformed_0639.png
# /content/imagenes/transformed_0776.png
# /content/imagenes/transformed_0230.png
# /content/imagenes/transformed_0379.png
# /content/imagenes/transformed_0643.png
# /content/imagenes/transformed_0771.png
# /content/imagenes/transformed_0049.png
# /content/imagenes/transformed_hr_1.png
# /content/imagenes/transformed_hr_9.png
# /content/imagenes/transformed_0162.png
# /content/imagenes/transformed_0748.png
# /content/imagenes/transformed_0494.png
# /content/imagenes/transformed_0163.png
# /content/imagenes/transformed_hr_34.png
# /content/imagenes/transformed_0660.png
# /content/imagenes/transformed_0764.png
# /content/imagenes/transformed_0427.png
# /content/imagenes/transformed_0658.png
# /content/imagenes/transformed_0670.png
# /content/imagenes/transformed_hr_48.png
# /content/imagenes/transformed_0556.png
# /content/imagenes/transformed_0680.png
# /content/imagenes/transformed_0560.png
# /content/imagenes/transformed_0611.png
# /content/imagenes/transformed_hr_47.png
# /content/imagenes/transformed_0156.png
# /content/imagenes/transformed_0121.png
# /content/imagenes/transformed_0585.png
# /content/imagenes/transformed_0146.png
# /content/imagenes/transformed_0187.png
# /content/imagenes/transformed_0172.png
# /content/imagenes/transformed_0406.png
# /content/imagenes/transformed_0439.png
# /content/imagenes/transformed_0792.png
# /content/imagenes/transformed_0453.png
# /content/imagenes/transformed_0356.png
# /content/imagenes/transformed_0322.png
# /content/imagenes/transformed_0673.png
# /content/imagenes/transformed_0138.png
# /content/imagenes/transformed_0654.png
# /content/imagenes/transformed_0641.png
# /content/imagenes/transformed_0394.png
# /content/imagenes/transformed_0548.png
# /content/imagenes/transformed_0213.png
# /content/imagenes/transformed_0659.png
# /content/imagenes/transformed_0063.png
# /content/imagenes/transformed_0758.png
# /content/imagenes/transformed_0130.png
# /content/imagenes/transformed_0416.png
# /content/imagenes/transformed_0512.png
# /content/imagenes/transformed_0565.png
# /content/imagenes/transformed_0451.png
# /content/imagenes/transformed_0478.png
# /content/imagenes/transformed_0364.png
# /content/imagenes/transformed_0609.png
# /content/imagenes/transformed_0623.png
# /content/imagenes/transformed_0642.png
# /content/imagenes/transformed_0248.png
# /content/imagenes/transformed_0360.png
# /content/imagenes/transformed_0788.png
# /content/imagenes/transformed_0202.png
# /content/imagenes/transformed_0133.png
# /content/imagenes/transformed_0504.png
# /content/imagenes/transformed_0467.png
# /content/imagenes/transformed_0175.png
# /content/imagenes/transformed_0307.png
# /content/imagenes/transformed_0742.png
# /content/imagenes/transformed_0571.png
# /content/imagenes/transformed_0149.png
# /content/imagenes/transformed_0010.png
# /content/imagenes/transformed_0629.png
# /content/imagenes/transformed_0207.png
# /content/imagenes/transformed_0392.png
# /content/imagenes/transformed_0592.png
# /content/imagenes/transformed_0577.png
# /content/imagenes/transformed_0270.png
# /content/imagenes/transformed_0203.png
# /content/imagenes/transformed_0173.png
# /content/imagenes/transformed_0091.png
# /content/imagenes/transformed_0704.png
# /content/imagenes/transformed_0408.png
# /content/imagenes/transformed_0325.png
# /content/imagenes/transformed_0165.png
# /content/imagenes/transformed_0750.png
# /content/imagenes/transformed_0168.png
# /content/imagenes/transformed_0783.png
# /content/imagenes/transformed_0647.png
# /content/imagenes/transformed_hr_8.png
# /content/imagenes/transformed_0034.png
# /content/imagenes/transformed_0377.png
# /content/imagenes/transformed_0062.png
# /content/imagenes/transformed_0169.png
# /content/imagenes/transformed_0666.png
# /content/imagenes/transformed_0472.png
# /content/imagenes/transformed_0326.png
# /content/imagenes/transformed_0188.png
# /content/imagenes/transformed_0220.png
# /content/imagenes/transformed_0109.png
# /content/imagenes/transformed_0041.png
# /content/imagenes/transformed_0214.png
# /content/imagenes/transformed_0572.png
# /content/imagenes/transformed_0479.png
# /content/imagenes/transformed_0261.png
# /content/imagenes/transformed_0474.png
# /content/imagenes/transformed_0153.png
# /content/imagenes/transformed_0618.png
# /content/imagenes/transformed_0537.png
# /content/imagenes/transformed_0667.png
# /content/imagenes/transformed_0438.png
# /content/imagenes/transformed_0212.png
# /content/imagenes/transformed_0250.png
# /content/imagenes/transformed_0708.png
# /content/imagenes/transformed_0496.png
# /content/imagenes/transformed_0622.png
# /content/imagenes/transformed_0331.png
# /content/imagenes/transformed_0491.png
# /content/imagenes/transformed_0532.png
# /content/imagenes/transformed_0273.png
# /content/imagenes/transformed_0795.png
# /content/imagenes/transformed_0201.png
# /content/imagenes/transformed_0744.png
# /content/imagenes/transformed_0698.png
# /content/imagenes/transformed_0263.png
# /content/imagenes/transformed_hr_42.png
# /content/imagenes/transformed_0447.png
# /content/imagenes/transformed_0015.png
# /content/imagenes/transformed_0069.png
# /content/imagenes/transformed_0711.png
# /content/imagenes/transformed_0026.png
# /content/imagenes/transformed_0342.png
# /content/imagenes/transformed_0208.png
# /content/imagenes/transformed_0694.png
# /content/imagenes/transformed_0005.png
# /content/imagenes/transformed_0054.png
# /content/imagenes/transformed_hr_0.png
# /content/imagenes/transformed_0675.png
# /content/imagenes/transformed_0751.png
# /content/imagenes/transformed_0099.png
# /content/imagenes/transformed_0755.png
# /content/imagenes/transformed_0344.png
# /content/imagenes/transformed_0520.png
# /content/imagenes/transformed_0608.png
# /content/imagenes/transformed_0546.png
# /content/imagenes/transformed_0619.png
# /content/imagenes/transformed_0072.png
# /content/imagenes/transformed_0418.png
# /content/imagenes/transformed_0652.png
# /content/imagenes/transformed_0426.png
# /content/imagenes/transformed_0552.png
# /content/imagenes/transformed_0518.png
# /content/imagenes/transformed_0251.png
# /content/imagenes/transformed_0045.png
# /content/imagenes/transformed_0095.png
# /content/imagenes/transformed_0645.png
# /content/imagenes/transformed_0227.png
# /content/imagenes/transformed_0260.png
# /content/imagenes/transformed_0285.png
# /content/imagenes/transformed_hr_36.png
# /content/imagenes/transformed_0183.png
# /content/imagenes/transformed_0196.png
# /content/imagenes/transformed_0304.png
# /content/imagenes/transformed_0514.png
# /content/imagenes/transformed_0271.png
# /content/imagenes/transformed_0093.png
# /content/imagenes/transformed_0588.png
# /content/imagenes/transformed_0176.png
# /content/imagenes/transformed_hr_26.png
# /content/imagenes/transformed_0247.png
# /content/imagenes/transformed_0284.png
# /content/imagenes/transformed_0317.png
# /content/imagenes/transformed_0308.png
# /content/imagenes/transformed_0068.png
# /content/imagenes/transformed_hr_38.png
# /content/imagenes/transformed_0574.png
# /content/imagenes/transformed_0042.png
# /content/imagenes/transformed_0008.png
# /content/imagenes/transformed_0014.png
# /content/imagenes/transformed_0094.png
# /content/imagenes/transformed_0205.png
# /content/imagenes/transformed_0717.png
# /content/imagenes/transformed_0148.png
# /content/imagenes/transformed_0733.png
# /content/imagenes/transformed_0033.png
# /content/imagenes/transformed_0798.png
# /content/imagenes/transformed_0551.png
# /content/imagenes/transformed_0122.png
# /content/imagenes/transformed_0696.png
# /content/imagenes/transformed_0086.png
# /content/imagenes/transformed_0055.png
# /content/imagenes/transformed_0368.png
# /content/imagenes/transformed_0434.png
# /content/imagenes/transformed_0513.png
# /content/imagenes/transformed_0763.png
# /content/imagenes/transformed_0051.png
# /content/imagenes/transformed_0009.png
# /content/imagenes/transformed_0522.png
# /content/imagenes/transformed_0650.png
# /content/imagenes/transformed_0341.png
# /content/imagenes/transformed_0303.png
# /content/imagenes/transformed_0782.png
# /content/imagenes/transformed_0465.png
# /content/imagenes/transformed_0557.png
# /content/imagenes/transformed_0533.png
# /content/imagenes/transformed_0682.png
# /content/imagenes/transformed_0501.png
# /content/imagenes/transformed_0299.png
# /content/imagenes/transformed_0635.png
# /content/imagenes/transformed_0389.png
# /content/imagenes/transformed_0345.png
# /content/imagenes/transformed_0216.png
# /content/imagenes/transformed_0428.png
# /content/imagenes/transformed_0705.png
# /content/imagenes/transformed_0309.png
# /content/imagenes/transformed_0508.png
# /content/imagenes/transformed_0712.png
# /content/imagenes/transformed_hr_49.png
# /content/imagenes/transformed_0053.png
# /content/imagenes/transformed_0633.png
# /content/imagenes/transformed_0257.png
# /content/imagenes/transformed_0423.png
# /content/imagenes/transformed_0215.png
# /content/imagenes/transformed_0059.png
# /content/imagenes/transformed_0732.png
# /content/imagenes/transformed_0576.png
# /content/imagenes/transformed_0561.png
# /content/imagenes/transformed_hr_44.png
# /content/imagenes/transformed_hr_27.png

# %%
dmg=DataSetManage()
directoriolw={
     "img":["/content/imagenes/",1],
}



listas_directorios,listas_paths_directorios,listas_clases=dmg.separar_datos_directorios(directoriolw)
Dataset_csv="dataset.csv" #nombre que tenda nuestlo csv
dmg.crear_paths_csv(listas_directorios,listas_paths_directorios,listas_clases,Dataset_csv)
# Out:
# Csv Creado

# %%
#DEFNIIR DISPOSITIVO:
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("CUDA está disponible.")
    device = torch.device("cuda")
else:
    print("CUDA no está disponible. Se utilizará la CPU.")
    device = torch.device("cpu")
# Out:
# CUDA está disponible.

# %%
#@markdown # *2) ** Creacion de clase DATASET(OBLIGATORIO)
import torch
from torch.utils.data import Dataset,DataLoader
import pandas as pd
import numpy as np
import cv2
from PIL import Image
from skimage.color import rgb2lab, lab2rgb

class MiDataSet(Dataset):
    def __init__(self, csv, transform=None):
        self.data = pd.read_csv(csv)
        self.path = self.data["path"]
        self.samples = self.data["path"].shape[0]
        self.transform = transform

    def __getitem__(self, idx):
        ruta = self.path[idx]

        # Abrir la imagen
        img = Image.open(ruta).convert('RGB')

        l_channel,ab_channel =self.rgb_a_lab(img)

        l_arr = np.array(l_channel)
        ab_arr = np.array(ab_channel)

        if self.transform:
            l_arr = self.transform(l_channel)
            ab_arr = self.transform(ab_arr)

        return l_arr, ab_arr

    def __len__(self):
        return self.samples

    def rgb_a_lab(self,img):

      lab_image=rgb2lab(img)

      # Separa los canales L y AB
      l_channel = lab_image[:, :, 0]
      ab_channel=lab_image[:, :, 1:]
      return l_channel,ab_channel

    def lab_a_rgb(self,l,ab):
      rgb_image=np.zeros((256,256,3))
      rgb_image[:,:,0]=l
      rgb_image[:,:,1:]=ab
      return lab2rgb(rgb_image)

# %%
#CREANDO DATASETS Y DATALOADERS:
from skimage.color import lab2rgb
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
import torch
from torchvision import datasets, transforms

transformaciones = transforms.Compose([
    transforms.ToTensor(),

])

batch_size=15




dataset =MiDataSet("/content/dataset.csv",transformaciones)
data_loader=DataLoader(dataset,batch_size=batch_size)

l1,ab=dataset.__getitem__(7)

#Visualisando

l1 = l1.squeeze().numpy()
ab = ab.squeeze().permute(1, 2, 0).numpy()

# Visualizar la imagen generada
# Subfigura l1
plt.subplot(1, 3, 1)
plt.imshow(l1,cmap='gray')
plt.title('l1')

# Subfigura ab
plt.subplot(1, 3, 2)

img_ab = np.zeros((256, 256, 3))  # crea un array de ceros para la imagen RGB
img_ab[:,:,1:] = ab
plt.imshow(img_ab)
plt.title('ab')


# Subfigura rgb
plt.subplot(1, 3, 3)

img_rgb = np.zeros((256, 256, 3))  # crea un array de ceros para la imagen RGB
img_rgb[:,:,0]=l1
img_rgb[:,:,1:] = ab
plt.imshow(lab2rgb(img_rgb))
plt.title('rgb')

# Ajustar diseño
plt.tight_layout()

# Mostrar las imágenes
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#@markdown # *0) ** Creando clase Discriminadora:

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
from torch.utils.data import Dataset,DataLoader
import torchvision.transforms as transforms
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as F

class cnnBlock(nn.Module):
  def __init__(self,in_channels,out_channels,stride=2):
   super(cnnBlock,self).__init__()
   self.conv=nn.Sequential(
         nn.Conv2d(in_channels,out_channels,4,stride,padding=1),
         nn.BatchNorm2d(out_channels),
         nn.LeakyReLU(0.2),
     )
  def forward(self,x):
    return self.conv(x)

class Discriminator (nn.Module):
  def __init__(self):
   super(Discriminator,self).__init__()

   self.inicial=nn.Sequential(
                           nn.Conv2d(3,64,4,2,1),
                           nn.LeakyReLU(0.2),
                        )

   self.cnnblock1=cnnBlock(64,128)
   self.cnnblock2=cnnBlock(128,256)
   self.cnnblock3=cnnBlock(256,512,stride=1)

   self.lastconv= nn.Conv2d(512,1,4,1,1)


  def forward(self,x,y):

    x=torch.cat([x,y],dim=1)

    x=self.inicial(x)
    x=self.cnnblock1(x)
    x=self.cnnblock2(x)
    x=self.cnnblock3(x)

    x=self.lastconv(x)
    out=torch.sigmoid(x)

    return out

# %%
d=Discriminator()
x = torch.randn(2, 3, 32, 32)  # Ejemplo de tensor x con 3 canales
y = torch.randn(2, 3, 32, 32)  # Ejemplo de tensor y con 5 canales

# Concatenar los tensores x e y a lo largo de la dimensión de los canales
ju=d(x,y)
print(ju.shape)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-6d59e72f47ca> in <cell line: 6>()
#       4
#       5 # Concatenar los tensores x e y a lo largo de la dimensión de los canales
# ----> 6 ju=d(x,y)
#       7 print(ju.shape)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# <ipython-input-5-91d4102a008b> in forward(self, x, y)
#      42     x=torch.cat([x,y],dim=1)
#      43
# ---> 44     x=self.inicial(x)
#      45     x=self.cnnblock1(x)
#      46     x=self.cnnblock2(x)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     213     def forward(self, input):
#     214         for module in self:
# --> 215             input = module(input)
#     216         return input
#     217
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     458
#     459     def forward(self, input: Tensor) -> Tensor:
# --> 460         return self._conv_forward(input, self.weight, self.bias)
#     461
#     462 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     454                             weight, bias, self.stride,
#     455                             _pair(0), self.dilation, self.groups)
# --> 456         return F.conv2d(input, weight, bias, self.stride,
#     457                         self.padding, self.dilation, self.groups)
#     458
#
# RuntimeError: Given groups=1, weight of size [64, 3, 4, 4], expected input[2, 6, 32, 32] to have 3 channels, but got 6 channels instead

# %%
discriminador=Discriminator()
discriminador=discriminador.to(device)
x=torch.randn(20,3,256,256).to(device)
y=torch.randn(20,3,256,256).to(device)
print(discriminador(x,y).shape)
# Out:
# torch.Size([20, 1, 30, 30])

# %%
#---------------------GENERADOR BASADO EN U- NET---------------------------------------------------

import torch.nn.functional as F

#input debe ser 256x256 otras dimeneoins  puede que tenega eror al mometno de concat las dimenes reducidas debe de conicidir y este unetblacok se ajsuta a una etnrada 256x256
class U_Net_block(nn.Module):

  def __init__(self,in_channel,out_channel,type,activacion="leakyrelu",dropout_on="False"):
   super(U_Net_block,self).__init__()

   if type=="down" :

    self.block=nn.Conv2d(in_channel,out_channel,kernel_size=4,stride=2,padding=1,bias=False)

   elif type=="up":

    self.block=nn.ConvTranspose2d(in_channel,out_channel,kernel_size=4,stride=2,padding=1,bias=False)

   self.batchnorm=nn.BatchNorm2d(out_channel)

   self.activacion=activacion
   self.leakyrelu=nn.LeakyReLU(0.2)
   self.relu=nn.ReLU()

   self.dropout_on=dropout_on # solo si necsitmos usar el dropout

   self.dropout=nn.Dropout(0.5)

  def forward(self,x):

     x=self.block(x)
     x=self.batchnorm(x)

     if(self.activacion=="leakyrelu"):
      out=self.leakyrelu(x)
     else:
      out=self.relu(x)

     if(self.dropout_on==True):
      out=self.dropout(x)

     return out


class Generator_U_Net(nn.Module):

    def __init__(self,in_channel=3):
        super(Generator_U_Net,self).__init__()

        # Encoder Seccion:

        self.inicial=nn.Sequential(
            nn.Conv2d(in_channel,64,kernel_size=4,stride=2,padding=1,bias=False), # primer bloque convolucional down no tiene batchnorm
            nn.LeakyReLU(0.2)
        )


        self.encoder1=U_Net_block(64,128,"down",activacion="leakyrelu")
        self.encoder2=U_Net_block(128,256,"down",activacion="leakyrelu")
        self.encoder3=U_Net_block(256,512,"down",activacion="leakyrelu")
        self.encoder4=U_Net_block(512,512,"down",activacion="leakyrelu")
        self.encoder5=U_Net_block(512,512,"down",activacion="leakyrelu")
        self.encoder6=U_Net_block(512,512,"down",activacion="leakyrelu")

        self.bottleneck=nn.Sequential( nn.Conv2d(512,512,4,2,1,bias=False),
                                       nn.ReLU())

        # Decoder Seccion:


        self.decoder1=U_Net_block(512,512,"up",activacion="relu")
        self.decoder2=U_Net_block(1024,512,"up",activacion="relu")
        self.decoder3=U_Net_block(1024,512,"up",activacion="relu")
        self.decoder4=U_Net_block(1024,512,"up",activacion="relu")
        self.decoder5=U_Net_block(1024,256,"up",activacion="relu")
        self.decoder6=U_Net_block(512,128,"up",activacion="relu")
        self.decoder7=U_Net_block(256,64,"up",activacion="relu")


        # Last

        self.lastup=nn.Sequential(
            nn.ConvTranspose2d(128,2,kernel_size=4,stride=2,padding=1,bias=False),
            nn.Tanh(),
        )

    def forward(self,x):

        d1=self.inicial(x) # d1 ->64 out
        d2=self.encoder1(d1) # d2 ->128 out
        d3=self.encoder2(d2) # d3 ->256 out
        d4=self.encoder3(d3) # d4 ->512 out
        d5=self.encoder4(d4) # d5 ->512 out
        d6=self.encoder5(d5) # d6 ->512 out
        d7=self.encoder6(d6) # d7 ->512 out

        bneck=self.bottleneck(d7)  #bneck -> 512 out

        e1=self.decoder1(bneck) #e1 -> 512 out
        e2=self.decoder2(torch.cat([e1,d7],1)) # e2  in ->512+512=1024  out->512
        e3=self.decoder3(torch.cat([e2,d6],1)) # e3  in ->512+512=1024   out->512
        e4=self.decoder4(torch.cat([e3,d5],1)) # e4 in ->512+512=1024   out->512
        e5=self.decoder5(torch.cat([e4,d4],1)) # e5 in ->512+512=1024    out->256

        e6=self.decoder6(torch.cat([e5,d3],1)) # e6 in ->256+256=512   out->128
        e7=self.decoder7(torch.cat([e6,d2],1)) # e7 in ->128+128=256  out->64


        out=self.lastup(torch.cat([e7,d1],1)) # last in 64+64  out->3

        return (out+1)/2

# %%
#VAMOS A VER QUE MEDIADES EL GENERADOR DA COMO RESUTLADO CON LW RESOLUTIONS MEDIDAES:

generador=Generator_U_Net()
generador=generador.to(device)
x=torch.randn(20,3,256,512).to(device)

print(generador(x).shape)
# Out:
# pasamos
# torch.Size([20, 3, 256, 512])

# %%
#PROBAMOS EL GENERADOR INCIAL:

from PIL import Image
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt


#--------------------------------------------------------------------------------------------------------
def show_comparacion(real,generado): #deben de ingrenar don tennoren de imagen generada y real
 print(generado.shape)
 print(real.shape)
 real=real.detach().squeeze().cpu().numpy().transpose(1, 2, 0)
 generado=generado.squeeze().cpu().detach().numpy().transpose(1, 2, 0)
# Primer subgráfico: imagen original
 plt.subplot(1, 2, 1)
 plt.imshow(generado)  # Convertir a NumPy y transponer dimensiones
 plt.title('Imagen Generada')
 plt.axis('off')

# Segundo subgráfico: imagen transformada
 plt.subplot(1, 2, 2)
 plt.imshow(real)  # Convertir a NumPy y transponer dimensiones
 plt.title('Imagen Real')
 plt.axis('off')

# Ajustar el diseño para evitar superposición de títulos
 plt.tight_layout()

# Mostrar la figura
 plt.show()


 plt.figure(figsize=(10, 5))
#-----------------------------------------------------------------------------------
generador=Generator_U_Net().to("cpu")


ruta_imagen = "/content/imagenes/transformed_0002_0.png"
imagen = Image.open(ruta_imagen)

transformaciones = transforms.Compose([
    transforms.Resize((256,256)),
    transforms.ToTensor(),
])

#original iamgen tensor
tensor_imagen = transformaciones(imagen).unsqueeze(0)
tensor_imagen=tensor_imagen.to("cpu")

#imagen generada
imagen_generada=generador(tensor_imagen)
print(imagen_generada.shape)
imagen_numpy = imagen_generada.squeeze().detach().numpy()

# Mostrar la imagen utilizando matplotlib
plt.imshow(imagen_numpy.transpose(1, 2, 0))  # cmap='gray' es para mostrar la imagen en escala de grises
plt.axis('off')  # Ocultar ejes
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-299ebcaddb73> in <cell line: 39>()
#      37
#      38 ruta_imagen = "/content/imagenes/transformed_0002_0.png"
# ---> 39 imagen = Image.open(ruta_imagen)
#      40
#      41 transformaciones = transforms.Compose([
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3225
#    3226     if filename:
# -> 3227         fp = builtins.open(filename, "rb")
#    3228         exclusive_fp = True
#    3229
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/imagenes/transformed_0002_0.png'

# %%
from torchvision import models

#vamos a extraer los feature es decir las caracteisicas imporantes que exiten entre ambas imagnes y compraralas esto se usara par luego hace rel loss contet apartir del contendio

class Feature_Extractor(nn.Module):
    def __init__(self):
        super(Feature_Extractor, self).__init__()
        # Cargar un modelo VGG-19 preentrenado
        vgg19_model = models.vgg16(pretrained=True).features.eval()

        # No actualizar los pesos del modelo VGG durante el entrenamiento
        for param in vgg19_model.parameters():
            param.requires_grad = False

        selected_layers = list(vgg19_model.children())[:31] #AGREGAMOS EL VGG HASTA VERFICAR QUE EL ULITMA CAPA NO TENGA RELU

        self.vgg=nn.Sequential(*selected_layers)

    def forward(self, img):

        # Extraer características de las imágenes generada y real
        feature_img = self.vgg(img)

        return feature_img


# TV Loss se utiliza comúnmente en tareas de generación de imágenes para reducir el ruido y fomentar la suavidad en las imágenes generadas.

class TVLoss(nn.Module):
  def __init__(self, tv_loss_weight=1):
    super(TVLoss, self).__init__()
    self.tv_loss_weight=tv_loss_weight
  def forward(self, x):
    batch_size=x.size()[0]
    h_x = x.size()[2]
    w_x = x.size()[3]

    count_h = self.tensor_size(x[:, :, 1:, :])
    count_w = self.tensor_size(x[:, :, :, 1:])


    h_tv = torch.pow(x[:, :, 1:, :] - x[:, :, :h_x - 1, :], 2).sum()
    w_tv = torch.pow(x[:, :, :, 1:] - x[:, :, :, :w_x - 1], 2).sum()
    return self.tv_loss_weight * 2 * (h_tv / count_h + w_tv / count_w) / batch_size

  # Forgot to implement an important method
  @staticmethod # Must add this
  def tensor_size(t):
    return t.size()[1] * t.size()[2] * t.size()[3]


def psnr(image1, image2):
    mse = torch.mean((image1 - image2) ** 2)
    if mse == 0:
        return float('inf')
    max_pixel = 1
    psnr_value = 10 * torch.log10((max_pixel ** 2) / mse)
    return psnr_value

# %%
vgg=Feature_Extractor()
print(vgg)
tv_loss= TVLoss()
x=torch.randn(18,3,60,60)
tv_loss=tv_loss(x)

print(tv_loss)

# %%
import matplotlib.pyplot as plt
import torch
import numpy as np
import torchvision.utils as vutils
import sklearn
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset
from tqdm import tqdm
# ...

#d=Discriminator(image_dim).to(device)
#g=Generador(dim_vector_ruido,image_dim).to(device)

#d.load_state_dict(torch.load("/content/modelo_gatos_d.pt"))
#g.load_state_dict(torch.load("/content/modelo_gatos_g.pt"))

#d=d.to(device)
#g=g.to(device)


# Supongamos que ya has definido las instancias de los modelos Generador (g) y Discriminador (d),
# y has configurado los optimizadores (g_optimizer y d_optimizer) y la función de pérdida (criterio).



def GAN(discriminador, generador, data_loader, num_epochs, batch_size, criterio_g,criterio_d, d_optimizador, g_optimizador, device):

    discriminador=discriminador.to(device)
    generador=generador.to(device)
    feature_extractor=Feature_Extractor().to(device)
    tv_loss= TVLoss().to(device)
    L1=nn.L1Loss()

    for epoch in range(num_epochs):

        resultados = { 'd_loss':[],"g_loss":[], "d_score":[], "psnr":[]}
        data_loader = tqdm(data_loader)

        for  (l, ab) in (data_loader):

            l=l.float().to(device)
            ab=ab.float().to(device)

            generador.eval()
            discriminador.train()

            # Entrenar el discriminador con imágenes reales
            d_optimizador.zero_grad()

            prediction_real = discriminador(l.float(),ab)

            real_loss = criterio_d(prediction_real, torch.ones_like(prediction_real).to(device))


            # Entrenar el discriminador con imágenes generadas

            fake_ab = generador(l)

            prediction_fake = discriminador(l,fake_ab.float().detach())

            fake_loss = criterio_d(prediction_fake, torch.zeros_like(prediction_fake).to(device)).to(device)
            discriminator_loss = (real_loss + fake_loss)/2

            discriminator_loss.backward()

            d_optimizador.step()

            # Entrenar el generador
            generador.train()
            discriminador.eval()
            g_optimizador.zero_grad()

            generated_ab = generador(l.detach())

            d_fake=discriminador(l,generated_ab)

            loss_gan=criterio_g(d_fake,torch.ones_like(d_fake).to(device)) #loss del generador aparitr del disicmirnador que dice si es o no una imagen falsa
            loss_g=L1(ab,generated_ab)

            generator_loss = (100*loss_g)+loss_gan
            generator_loss.backward()
            g_optimizador.step()


            #resultados por batch:
            resultados["d_loss"].append(discriminator_loss.item())
            resultados["g_loss"].append(generator_loss.item())


            data_loader.set_description(desc="[%d/%d] Loss_D: %.4f Loss_G: %.4f psnr: %.4f" % (
            epoch, num_epochs, np.mean(resultados['d_loss']),
            np.mean(resultados['g_loss']) ,
            np.mean( resultados['psnr']) ,

              ))

        # Imprimir estadísticas y visualizar imágenes generadas al final de cada época
        print(f'Época [{epoch}/{num_epochs}] '
                      f'Pérdida del Discriminador: {np.mean(resultados["d_loss"]):.4f}, '
                      f'Pérdida del Generador: {np.mean(resultados["g_loss"]):.4f}',f'psnr:{np.mean(resultados["psnr"]):.4f}')
        with torch.no_grad():
            generador.eval()

            ab_test = generador(l).detach()

            generado_ab=ab_test[0].squeeze().cpu().detach().permute(1, 2, 0).numpy().transpose(1, 2, 0)
            l_test = l[0].squeeze().cpu().numpy()


            img_rgb = np.zeros((256, 256, 3))  # crea un array de ceros para la imagen RGB
            img_rgb[:,:,0]=l_test
            img_rgb[:,:,1:] =np.transpose(generado_ab, (0, 2, 1))
            plt.imshow(lab2rgb(img_rgb))
            plt.title('rgb')


#--------------------------------------------------------------------------------------------



num_epochs=15





d=Discriminator()
g=Generator_U_Net(1)

d.load_state_dict(torch.load("/content/srgan_d.pt"))
g.load_state_dict(torch.load("/content/srgan_g.pt"))

lr_g = 0.000008
lr_d = 0.0000008
d_optimizer=optim.Adam(d.parameters(),lr=lr_d)
g_optimizer=optim.Adam(g.parameters(),lr=lr_g)

criterio_d=nn.BCELoss()
criterio_g=nn.BCELoss()


print(f"learning rate discrimiador:{lr_d}")
print(f"learning rate generador:{lr_g}")

GAN(d,g,data_loader,num_epochs,batch_size,criterio_g,criterio_d,d_optimizer,g_optimizer,device)
# Out:
# learning rate discrimiador:8e-07
# learning rate generador:8e-06
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#   0%|          | 0/57 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [0/15] Loss_D: 0.0003 Loss_G: 1042.6016 psnr: nan: 100%|██████████| 57/57 [00:51<00:00,  1.11it/s]
# Época [0/15] Pérdida del Discriminador: 0.0003, Pérdida del Generador: 1042.6016 psnr:nan
# [1/15] Loss_D: 0.0003 Loss_G: 1042.4816 psnr: nan: 100%|██████████| 57/57 [00:49<00:00,  1.14it/s]
# Época [1/15] Pérdida del Discriminador: 0.0003, Pérdida del Generador: 1042.4816 psnr:nan
# [2/15] Loss_D: 0.0003 Loss_G: 1041.1307 psnr: nan:  61%|██████▏   | 35/57 [00:31<00:19,  1.15it/s]

# %%
torch.save(g.state_dict(), 'srgan_g.pt')
torch.save(d.state_dict(), 'srgan_d.pt')

# %%
data = []
while(1):
  data.append('1234')

# %%
torch.cuda.empty_cache()

# %%
d.load_state_dict(torch.load("/content/srgan_d.pt"))
# Out:
# <All keys matched successfully>

# %%
from PIL import Image
# Suponiendo que "Generador" es la clase de tu generador y "ruta_modelo" es la ruta del modelo guardado
generador = Generador(2)  # creando generado
generador.load_state_dict(torch.load("/content/srgan_g.pt"))
generador.to(device)
generador.eval()

ruta_imagen = "/content/baboon.png"
imagen_pil = Image.open(ruta_imagen)

transformaciones = transforms.Compose([
    transforms.ToTensor(),  # Convierte la imagen a un tensor

])

imagen_transformada = transformaciones(imagen_pil)
imagen_transformada=imagen_transformada.to(device)
with torch.no_grad():
    generador.eval()

    generated_image = generador(imagen_transformada.unsqueeze(0)).detach().cpu()

# Convertir la imagen al rango [0, 1]
# generated_image = (generated_image + 1) / 2.0

generated_image_np = generated_image.squeeze().permute(1, 2, 0).numpy()

print(generated_image.shape)
# Visualizar la imagen generada
plt.imshow(generated_image_np)
plt.axis('off')
plt.show()


# Convertir el tensor a una imagen
tensor_a_imagen = transforms.ToPILImage()(generated_image.squeeze())

# Guardar la imagen
tensor_a_imagen.save("imagen_guardadahd.jpg")
# Out:
# 64
# 64
# torch.Size([1, 3, 480, 500])
