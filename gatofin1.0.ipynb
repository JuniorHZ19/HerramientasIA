# %% [markdown]
# <a href="https://colab.research.google.com/github/JuniorHZ19/HerramientasIA/blob/main/gatofin1.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@markdown # *0) ** Instalando libreria(OBLIGATORIO)

# !pip install torch torchvision torchaudio
# !pip install google_images_download
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.16.0+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Collecting google_images_download
#   Downloading google_images_download-2.8.0.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Collecting selenium (from google_images_download)
#   Downloading selenium-4.16.0-py3-none-any.whl (10.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 24.9 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium->google_images_download) (2.0.7)
# Collecting trio~=0.17 (from selenium->google_images_download)
#   Downloading trio-0.23.2-py3-none-any.whl (461 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 461.6/461.6 kB 9.0 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium->google_images_download)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium->google_images_download) (2023.11.17)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium->google_images_download) (23.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium->google_images_download) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium->google_images_download) (3.6)
# Collecting outcome (from trio~=0.17->selenium->google_images_download)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium->google_images_download) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium->google_images_download) (1.2.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium->google_images_download)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium->google_images_download) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium->google_images_download)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.0 MB/s eta 0:00:00
# Building wheels for collected packages: google_images_download
#   Building wheel for google_images_download (setup.py) ... done
#   Created wheel for google_images_download: filename=google_images_download-2.8.0-py2.py3-none-any.whl size=14533 sha256=03ce7064b67f7521882742d8b19d5439d7e8b831068ae7ff39c8b3887e255a29
#   Stored in directory: /root/.cache/pip/wheels/5b/f2/64/0eecb22fee5cbc0321d332492ddcc45b03c6373b5616ee95c8
# Successfully built google_images_download
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium, google_images_download
# Successfully installed google_images_download-2.8.0 h11-0.14.0 outcome-1.3.0.post0 selenium-4.16.0 trio-0.23.2 trio-websocket-0.11.1 wsproto-1.2.0

# %%
#@markdown # *1) ** Descargando DataSet  caras gatos(OBLIGATORIO)
import zipfile

nombre_zip="data_set_gatos.zip"

directorio_destino="/content/"

# !gdown --id 1EK7H_QJqxDy0wBssMEi2_gWdo3zE2pmQ -O {nombre_zip}

with zipfile.ZipFile(nombre_zip, 'r') as zip_ref:
    zip_ref.extractall(directorio_destino)
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1EK7H_QJqxDy0wBssMEi2_gWdo3zE2pmQ
# To: /content/data_set_gatos.zip
# 100% 284M/284M [00:05<00:00, 47.9MB/s]

# %%
#@markdown # *1) ** Clase Para manejo de directorios de datasets de imagenes


import os
import cv2
import pandas as pd
from PIL import Image
# Recorre el directorio  y elmiina los archvios que no tiene las extensioens permitidas

class DataSetManage:

 def comprobar_ext_directorios(self,directorios):

  for clase,[directorio,etiquetas] in(directorios.items()):
   lista_directorio=os.listdir(directorio)
   self.validarExt(directorio)



 def  validarExt(self,directorio):
  print(directorio)
   # Extensiones permitidas
  extensiones_permitidas = {".jpg", ".jpeg", ".png"}
  for root, dirs, files in os.walk(directorio):

    for file in files:
        # Obtiene la extensión del archivo
        _, extension = os.path.splitext(file)

        # Verifica si la extensión no está en la lista de extensiones permitidas y elimina el archivo
        if extension.lower() not in extensiones_permitidas:
            archivo_a_eliminar = os.path.join(root, file)
            os.remove(archivo_a_eliminar)
            print(f"Se eliminó: {archivo_a_eliminar}")


# Cambia nombre de cada archivo dentro del directorio a un valor secuencial

 def cambiar_nombres_directorios(self,directorios):
   for clase,[directorio,etiquetas] in(directorios.items()):
     lista_directorio=os.listdir(directorio)
     self.cambiarNombre(directorio,clase)


 def cambiarNombre(self,directorio,subfijo):
  archivos_en_directorio = os.listdir(directorio)
  for i, archivo in enumerate(archivos_en_directorio, start=1):
    # Construir el nuevo nombre del archivo
    nuevo_nombre = f"{subfijo}{i}{os.path.splitext(archivo)[1]}"

    # Ruta completa del archivo antiguo y nuevo
    ruta_antigua = os.path.join(directorio, archivo)
    ruta_nueva = os.path.join(directorio, nuevo_nombre)

    # Cambiar el nombre del archivo
    os.rename(ruta_antigua, ruta_nueva)
    print(f"Se cambió el nombre de {ruta_antigua} a {ruta_nueva}")


#Obtiene la cantidad de elemntos que tiene la carpeta

 def len_directorio(self,directorio):
    cantidad_elementos = sum(1 for elemento in os.listdir(directorio) if os.path.isfile(os.path.join(directorio, elemento)))
    return cantidad_elementos


#----------------------------------------------------------------------------------------------

#Valida si la imagen se puede leer usando  pill o cv2 si no se puede leer se elimina

 def validar_Img_Pill(self,directorios,):
  for etiqueta,[directorio,clase] in(directorios.items()):

    lista_paths=os.listdir(directorio)
    self.validarLecturaImgPill(directorio,lista_paths)
  print(f"Se ah validado todas las imagenes")

 def validar_Img_cv2(self,directorios):
  for etiqueta,[directorio,clase] in(directorios.items()):

    lista_paths=os.listdir(directorio)
    self.validarLecturaImg(directorio,lista_paths)
  print(f"Se ah validado todas las imagenes")


 def validarLecturaImg(self,directorio,lista):

  for ruta in(lista):
   imagen=cv2.imread(directorio+ruta)
   if  imagen is None:
     os.remove(directorio+ruta)
     print(f"No se pudo leer y se elimino archivo:{directorio+ruta}")

 def validarLecturaImgPill(self,directorio,lista):
    for ruta in(lista):
     try:
      imagen=Image.open(directorio+ruta)
     except Exception as e:
      os.remove(directorio+ruta)
      print(f"Archivo '{directorio+ruta}' eliminado.")



#vamos a recorrer el dicionario y validar ruta por ruta si se puede leer sino se elminara
#vamos guaradno al mismo tiempo 3 listas, los directorios , listas de paths de los directiros y de las clases ,para usarlo luego usarlo al crear el csv

 def separar_datos_directorios(self,directorios):
  listas_directorios=[]
  listas_listas_directorios=[]
  listas_clases=[]

  for etiqueta,[directorio,clase] in(directorios.items()):

       lista_paths=os.listdir(directorio)
       listas_directorios.append(directorio)
       listas_listas_directorios.append(lista_paths)
       listas_clases.append(clase)

  return listas_directorios,listas_listas_directorios,listas_clases

 def emparejar_listas_paths(self,lista_listas):

   #Tomamos el minimo tamaño dentro de las lista de cada clase
   tamaño_minimo = min(len(arr) for arr in lista_listas)

   #Vamos a emparejar todas las listas con un tamaño igual que sea la del minimo tamaño de todas,esto para tener un set de datos parejo por cada clase
   Reducido_lista_paths=[]

   #Reduce cada lista de los paths a la cantidad minimo para que todos tenga iaugal cantidad
   for listas in(lista_listas):
    Reducido_lista_paths.append(listas[:tamaño_minimo])

   return Reducido_lista_paths
#---------------------------------------------------------------------------------


 def crear_paths_csv(self,directorio_base,lista_paths,clases,nombre_archivo):

   columnas=["path","etiqueta"]
   datos_csv=[]

   for dir_base,dir_path,clase in  zip(directorio_base,lista_paths,clases):

    for path  in (dir_path):

     datos_csv.append([dir_base+path ,clase])


   df_lista=pd.DataFrame(datos_csv,columns=columnas)
   df_lista.to_csv(nombre_archivo,index=False)
   print("Csv Creado")
#---------------------------------------------------------------------------------

#devuelve cuatnos elemtnos tiene cada clase
 def total_elementos(self,directorios,csv_path):
    df=pd.read_csv(csv_path)
    for clase,[directorio,etiqueta] in (directorios.items()):
     tamaño_etiqueta=(df["etiqueta"] == etiqueta).sum()
     print(f"la clase {clase} tiene :{tamaño_etiqueta} elementos")

# %%
dmg=DataSetManage()

directorios={
     "gato":["/content/Cat-faces-dataset-master/dataset-part1/dataset-part1/",1],
     "gato":["/content/Cat-faces-dataset-master/dataset-part2/dataset-part2/",1],
     "gato":["/content/Cat-faces-dataset-master/dataset-part3/dataset-part3/",1]


}


dmg.comprobar_ext_directorios(directorios)

dmg.cambiar_nombres_directorios(directorios)

dmg.validar_Img_Pill(directorios)

listas_directorios,listas_paths_directorios,listas_clases=dmg.separar_datos_directorios(directorios)

Reducido_lista_paths=dmg.emparejar_listas_paths(listas_paths_directorios)
#validamos que todas las iamgnes en nuestro direcotrios puedan abrirse con openia cv2



#La funcion que creamos para podre crear nuestro csv , con los parametros antes calucaldos que son 3 listas y el nombre del csv

Dataset_csv="Data_set.csv" #nombre que tendla nuestlo csv
dmg.crear_paths_csv(listas_directorios,Reducido_lista_paths,listas_clases,Dataset_csv)

#imprime total de elemtnos por clase
dmg.total_elementos(directorios,"/content/Data_set.csv")
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9536.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4847.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4388.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4848.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7282.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4849.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8823.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4850.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6706.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4851.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2228.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4852.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7565.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4853.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2457.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4854.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3445.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4855.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2717.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4856.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8277.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4857.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5758.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4858.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato67.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4859.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4619.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4860.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9064.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4861.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6167.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4862.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6101.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4863.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2496.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4864.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4411.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4865.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2409.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4866.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1911.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4867.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7216.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4868.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8599.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4869.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2932.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4870.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1850.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4871.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4933.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4872.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3796.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4873.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1327.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4874.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4988.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4875.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8032.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4876.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8119.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4877.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4975.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4878.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato715.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4879.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8584.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4880.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5124.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4881.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6797.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4882.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9257.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4883.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7805.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4884.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4758.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4885.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2152.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4886.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2198.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4887.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5231.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4888.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6172.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4889.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1411.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4890.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9773.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4891.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7463.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4892.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5137.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4893.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato242.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4894.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2808.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4895.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7389.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4896.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4299.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4897.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1498.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4898.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5824.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4899.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9508.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4900.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1063.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4901.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2998.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4902.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato848.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4903.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato213.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4904.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8719.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4905.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8452.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4906.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1166.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4907.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3556.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4908.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3312.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4909.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8779.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4910.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6252.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4911.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5018.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4912.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato986.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4913.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5601.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4914.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato347.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4915.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4864.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4916.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1733.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4917.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8233.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4918.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1689.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4919.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4232.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4920.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5253.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4921.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2868.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4922.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8819.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4923.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3457.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4924.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3315.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4925.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6047.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4926.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3623.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4927.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8127.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4928.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8844.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4929.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5882.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4930.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3741.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4931.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7801.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4932.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3389.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4933.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9794.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4934.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6647.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4935.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4903.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4936.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato528.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4937.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato124.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4938.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4739.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4939.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7021.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4940.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4841.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4941.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6062.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4942.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9329.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4943.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2310.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4944.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4740.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4945.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7620.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4946.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8090.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4947.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2376.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4948.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3914.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4949.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato153.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4950.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1889.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4951.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9802.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4952.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2822.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4953.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9501.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4954.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7381.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4955.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7726.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4956.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato951.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4957.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6943.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4958.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6602.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4959.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9572.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4960.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7094.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4961.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1491.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4962.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8804.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4963.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5376.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4964.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5929.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4965.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3913.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4966.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1627.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4967.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8193.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4968.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato686.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4969.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6563.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4970.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2989.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4971.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2827.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4972.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2117.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4973.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9504.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4974.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato949.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4975.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5493.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4976.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6102.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4977.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4012.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4978.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1645.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4979.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2968.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4980.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7109.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4981.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4767.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4982.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1607.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4983.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9258.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4984.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3140.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4985.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6506.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4986.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3614.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4987.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6608.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4988.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1160.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4989.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4721.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4990.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7697.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4991.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8304.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4992.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8685.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4993.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9770.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4994.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4826.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4995.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6409.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4996.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9342.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4997.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato651.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4998.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4600.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4999.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7053.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5000.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3808.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5001.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato341.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5002.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4300.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5003.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2607.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5004.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1530.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5005.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6489.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5006.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8382.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5007.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato322.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5008.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6783.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5009.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1070.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5010.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1089.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5011.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7549.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5012.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5825.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5013.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3141.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5014.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5986.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5015.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3275.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5016.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7645.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5017.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5200.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5018.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6605.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5019.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5574.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5020.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2709.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5021.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4111.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5022.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3351.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5023.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9834.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5024.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8136.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5025.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6013.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5026.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6779.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5027.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5806.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5028.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2443.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5029.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6880.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5030.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8057.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5031.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8257.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5032.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4498.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5033.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4549.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5034.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6288.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5035.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6897.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5036.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2727.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5037.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2688.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5038.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5163.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5039.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8500.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5040.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9114.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5041.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5277.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5042.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8030.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5043.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5416.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5044.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3713.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5045.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1399.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5046.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6400.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5047.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7966.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5048.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5535.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5049.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5598.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5050.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1729.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5051.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato133.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5052.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6043.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5053.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3850.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5054.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1699.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5055.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato277.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5056.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3674.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5057.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2495.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5058.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1505.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5059.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5545.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5060.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2908.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5061.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato909.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5062.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2252.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5063.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5971.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5064.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato668.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5065.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5908.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5066.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4593.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5067.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3988.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5068.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5729.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5069.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato639.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5070.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6606.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5071.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2265.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5072.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7572.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5073.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9581.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5074.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5746.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5075.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato310.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5076.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5242.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5077.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7609.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5078.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7125.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5079.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1848.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5080.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4070.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5081.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6222.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5082.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato355.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5083.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato500.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5084.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2216.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5085.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5690.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5086.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2226.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5087.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2814.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5088.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4174.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5089.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4384.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5090.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9616.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5091.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7234.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5092.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4876.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5093.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato332.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5094.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1280.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5095.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7517.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5096.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5595.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5097.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3603.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5098.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9476.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5099.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9729.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5100.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1643.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5101.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8794.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5102.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9285.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5103.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5016.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5104.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7818.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5105.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2213.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5106.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6697.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5107.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3327.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5108.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato901.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5109.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4801.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5110.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5803.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5111.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6921.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5112.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato490.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5113.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9687.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5114.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato350.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5115.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2652.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5116.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7772.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5117.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato544.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5118.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2770.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5119.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1599.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5120.png
# ...
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2209.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9753.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4069.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9754.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2760.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9755.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1256.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9756.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato427.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9757.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5426.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9758.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2072.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9759.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7719.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9760.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9201.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9761.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato31.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9762.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9554.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9763.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4298.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9764.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato39.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9765.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4817.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9766.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8554.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9767.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8792.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9768.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2251.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9769.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9154.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9770.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5050.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9771.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3833.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9772.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6058.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9773.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9243.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9774.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6564.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9775.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7838.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9776.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1833.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9777.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1379.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9778.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato7634.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9779.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1413.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9780.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5372.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9781.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5230.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9782.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9465.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9783.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2616.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9784.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4605.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9785.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3989.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9786.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1572.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9787.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1368.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9788.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6132.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9789.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9500.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9790.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6344.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9791.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1676.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9792.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2598.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9793.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4184.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9794.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato899.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9795.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2668.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9796.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2249.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9797.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3039.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9798.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2830.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9799.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5039.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9800.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4952.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9801.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1964.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9802.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8865.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9803.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6277.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9804.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6327.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9805.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4990.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9806.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8528.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9807.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato612.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9808.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3476.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9809.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9787.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9810.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8265.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9811.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2406.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9812.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8084.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9813.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3819.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9814.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8512.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9815.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8840.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9816.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato4378.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9817.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8300.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9818.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato599.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9819.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6485.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9820.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6179.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9821.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3809.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9822.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2183.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9823.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5657.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9824.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato1984.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9825.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9184.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9826.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato827.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9827.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8433.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9828.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9271.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9829.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2556.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9830.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6174.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9831.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3370.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9832.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6236.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9833.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6874.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9834.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato288.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9835.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato5784.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9836.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3926.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9837.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato8079.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9838.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3509.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9839.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato6718.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9840.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2104.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9841.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato2504.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9842.png
# Se cambió el nombre de /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato3102.png a /content/Cat-faces-dataset-master/dataset-part3/dataset-part3/gato9843.png
# Se ah validado todas las imagenes
# Csv Creado
# la clase gato tiene :4927 elementos

# %%
#@markdown # *2) ** Creacion de clase DATASET(OBLIGATORIO)
import torch
from torch.utils.data import Dataset,DataLoader
import pandas as pd
import numpy as np
import cv2
from PIL import Image


class MiDataSet(Dataset):

  def __init__(self,csv_file, transform=None):


     self.data=pd.read_csv(csv_file)

     self.x=self.data["path"]
     self.y=self.data["etiqueta"]

     self.transform=transform

     self.samples=self.data["path"].shape[0]

  def __getitem__(self,id):

    rut_imagen=self.x[id]
    imagen=cv2.imread(rut_imagen)
    etiqueta=self.y[id]


    if imagen is None:
      pillow_image = Image.open(rut_imagen)
      numpy_image = np.array(pillow_image)
      imagen=cv2.cvtColor(numpy_image, cv2.COLOR_RGB2BGR)


    imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)


    if self.transform:
      imagen_rgb = self.transform(imagen_rgb)

    return imagen_rgb,etiqueta


  def __len__(self):
   return self.samples

# %%
#@markdown # *0) ** Creando clase Discriminadora y Geneaadora:

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
from torch.utils.data import Dataset,DataLoader
import torchvision.transforms as transforms
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as F

class Discriminator (nn.Module):
  def __init__(self,input_size):
   super(Discriminator,self).__init__()

   self.conv1=nn.Conv2d(3,24,kernel_size=3,stride=1, bias=False)


   self.conv2=nn.Conv2d(24,48,kernel_size=3,stride=1, bias=False)


   self.maxpol1=nn.MaxPool2d(kernel_size=2)
   self.maxpol2=nn.MaxPool2d(kernel_size=3)
   self.flatt=nn.Flatten()
   self.linal1=nn.Linear(9*9*48,500)
   self.salida=nn.Linear(500,1)


  def forward(self,x):

    x=self.conv1(x)

    x= nn.LeakyReLU(0.1)(x)

    x=self.conv2(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.maxpol1(x)
    x=self.maxpol2(x)
    x=self.flatt(x)

    x=self.linal1(x)
    x=F.relu(x)

    x=self.salida(x)

    out=torch.sigmoid(x)

    return out

#------------------------------------------------------------------------
class Generador(nn.Module):

  def __init__(self,z_dim,output_size):
   super(Generador,self).__init__()

   self.lineal1=nn.Linear(z_dim,7*7*256)

   self.tconv1=nn.ConvTranspose2d(256,128,kernel_size=3,stride=2, bias=False)


   self.tconv2=nn.ConvTranspose2d(128,64,kernel_size=3,stride=2, bias=False)


   self.tconv3=nn.ConvTranspose2d(64,3,kernel_size=3,stride=2, bias=False)


  def forward(self,x):

    x=self.lineal1(x)
    x=x.view(-1, 256, 7, 7)

    x= F.relu(x)

    x= self.tconv1(x)

    x= F.relu(x)

    x= self.tconv2(x)

    x= F.relu(x)

    x= self.tconv3(x)
    out= torch.tanh(x)

    return out

# %%
import sklearn
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset


if torch.cuda.is_available():
    print("CUDA está disponible.")
    device = torch.device("cuda")
else:
    print("CUDA no está disponible. Se utilizará la CPU.")
    device = torch.device("cpu")

transformaciones = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
    transforms.Resize((63, 63),antialias=True)

])


lr=0.001
batch_size=32
dim_vector_ruido =100
image_dim=63*63*3 #dimensiones de la imagen que entrara al discrimiador
num_epochs=300


Dataset=MiDataSet("/content/Data_set.csv",transform=transformaciones)
data_loader=DataLoader(Dataset,batch_size=batch_size,shuffle=True)


d=Discriminator(image_dim).to(device)
g=Generador(dim_vector_ruido,image_dim).to(device)

fixed_noise=torch.randn((batch_size,dim_vector_ruido)).to(device)


d_optimizer=optim.Adam(d.parameters(),lr=lr)
g_optimizer=optim.Adam(g.parameters(),lr=lr)

criterio=nn.BCELoss()
# Out:
# CUDA está disponible.

# %%
import matplotlib.pyplot as plt
import torchvision.utils as vutils

# ...

# Supongamos que ya has definido las instancias de los modelos Generador (g) y Discriminador (d),
# y has configurado los optimizadores (g_optimizer y d_optimizer) y la función de pérdida (criterio).

for epoch in range(num_epochs):
    for i, (x, y) in enumerate(data_loader):
        g.eval()
        d.train()

        batch_size = x.size(0)  # Se cambió de y a x para ser consistente con el uso de las imágenes reales
        real_images = x.to(device)
        real_labels = y.view(-1, 1).float().to(device)

        # Entrenar el discriminador con imágenes reales
        d_optimizer.zero_grad()
        prediction_real = d(real_images)
        real_loss = criterio(prediction_real, real_labels)
        real_loss.backward()

        # Entrenar el discriminador con imágenes generadas
        noise = torch.randn(batch_size, dim_vector_ruido).to(device)
        fake_images = g(noise)
        fake_labels = torch.zeros(batch_size, 1).to(device)
        prediction_fake = d(fake_images.detach())
        fake_loss = criterio(prediction_fake, fake_labels)
        fake_loss.backward()

        discriminator_loss = real_loss + fake_loss
        d_optimizer.step()

        # Entrenar el generador
        g.train()
        d.eval()

        g_optimizer.zero_grad()
        generated_images = g(noise).view(-1,3,63,63).to(device)
        generator_loss = criterio(d(generated_images), real_labels)
        generator_loss.backward()
        g_optimizer.step()

        if i % 100 == 0:
            print(f'Epoch [{epoch}/{num_epochs}], Step [{i}/{len(data_loader)}], '
                  f'Discriminator Loss: {discriminator_loss.item():.4f}, '
                  f'Generator Loss: {generator_loss.item():.4f}')

    # Imprimir estadísticas y visualizar imágenes generadas al final de cada época
    with torch.no_grad():
        g.eval()
        noise = torch.randn(12, dim_vector_ruido).to(device)
        generated_images = g(noise).detach().cpu()

        # Convertir las imágenes al rango [0, 1]
        generated_images = (generated_images + 1) / 2.0

        # Visualizar las imágenes generadas
        plt.figure(figsize=(8, 8))
        plt.axis("off")
        plt.title(f"Generated Images - Epoch {epoch + 1}")
        plt.imshow(vutils.make_grid(generated_images, nrow=4).permute(1, 2, 0).numpy())
        plt.show()
# Out:
# Epoch [0/300], Step [0/154], Discriminator Loss: 1.3966, Generator Loss: 0.5941

# %%
torch.save(g.state_dict(), 'modelo_gatos_g.pt')
torch.save(d.state_dict(), 'modelo_gatos_d.pt')

# %%
# Suponiendo que "Generador" es la clase de tu generador y "ruta_modelo" es la ruta del modelo guardado
generador = Generador(80, 63*63*3)  # Ajusta input_size y output_size según tu implementación
generador.load_state_dict(torch.load("modelo_gatos_g.pt"))
generador.to(device)
generador.eval()

with torch.no_grad():
    generador.eval()
    noise = torch.randn(1, dim_vector_ruido).to(device)
    generated_image = generador(noise).detach().cpu()

# Convertir la imagen al rango [0, 1]
generated_image = (generated_image + 1) / 2.0

generated_image_np = generated_image.squeeze().permute(1, 2, 0).numpy()

print(generated_image.shape)
# Visualizar la imagen generada
plt.imshow(generated_image_np)
plt.axis('off')
plt.show()
