# %% [markdown]
# <a href="https://colab.research.google.com/github/JuniorHZ19/HerramientasIA/blob/main/srganx2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# !unzip DIV2K_train_HR.zip # This is our dataset link. I will include this command in the description

# %%
#@markdown # *0) ** Instalando libreria(OBLIGATORIO)

# !pip install torch torchvision torchaudio

# %%
#@markdown # *1) ** Clase Para manejo de directorios de datasets de imagenes


import os
import cv2
import pandas as pd
from PIL import Image
import torch
from torchvision import transforms
# Recorre el directorio  y elmiina los archvios que no tiene las extensioens permitidas

class DataSetManage:




 def comprobar_ext_directorios(self,directorio):

  for clase,[directorio,etiquetas] in(directorio.items()):
   lista_directorio=os.listdir(directorio)
   self._validarExt(directorio)



 def  _validarExt(self,directorio):
  print(directorio)
   # Extensiones permitidas
  extensiones_permitidas = {".jpg", ".jpeg", ".png"}
  for root, dirs, files in os.walk(directorio):

    for file in files:
        # Obtiene la extensión del archivo
        _, extension = os.path.splitext(file)

        # Verifica si la extensión no está en la lista de extensiones permitidas y elimina el archivo
        if extension.lower() not in extensiones_permitidas:
            archivo_a_eliminar = os.path.join(root, file)
            os.remove(archivo_a_eliminar)
            print(f"Se eliminó: {archivo_a_eliminar}")


# Cambia nombre de cada archivo dentro del directorio a un valor secuencial

 def cambiar_nombres_directorios(self,directorio):
   for clase,[directorio,etiquetas] in(directorio.items()):
     lista_directorio=os.listdir(directorio)
     self._cambiarNombre(directorio,clase)
     print(directorio)


 def _cambiarNombre(self,directorios,subfijo):
  archivos_en_directorio = os.listdir(directorios)
  for i, archivo in enumerate(archivos_en_directorio, start=1):
    # Construir el nuevo nombre del archivo
    nuevo_nombre = f"{subfijo}{i}{os.path.splitext(archivo)[1]}"

    # Ruta completa del archivo antiguo y nuevo
    ruta_antigua = os.path.join(directorios, archivo)
    ruta_nueva = os.path.join(directorios, nuevo_nombre)

    # Cambiar el nombre del archivo
    os.rename(ruta_antigua, ruta_nueva)
    print(f"Se cambió el nombre de {ruta_antigua} a {ruta_nueva}")


#Obtiene la cantidad de elemntos que tiene la carpeta

 def len_directorio(self,directorio):
    cantidad_elementos = sum(1 for elemento in os.listdir(directorio) if os.path.isfile(os.path.join(directorio, elemento)))
    return cantidad_elementos


#----------------------------------------------------------------------------------------------

#Valida si la imagen se puede leer usando  pill o cv2 si no se puede leer se elimina

 def validar_Img_Pill(self,directorio,):
  for etiqueta,[directorio,clase] in(directorio.items()):

    lista_paths=os.listdir(directorio)
    self._validarLecturaImgPill(directorio,lista_paths)
  print(f"Se ah validado todas las imagenes")

 def validar_Img_cv2(self,directorio):
  for etiqueta,[directorio,clase] in(directorio.items()):

    lista_paths=os.listdir(directorio)
    self._validarLecturaImg(directorio,lista_paths)
  print(f"Se ah validado todas las imagenes")

 def _validarLecturaImg(self,directorio,lista):

  for ruta in(lista):
   imagen=cv2.imread(directorio+ruta)
   if  imagen is None:
     os.remove(directorio+ruta)
     print(f"No se pudo leer y se elimino archivo:{directorio+ruta}")

 def _validarLecturaImgPill(self,directorio,lista):
    for ruta in(lista):
     try:
      imagen=Image.open(directorio+ruta)
     except Exception as e:
      os.remove(directorio+ruta)
      print(f"Archivo '{directorio+ruta}' eliminado.")



#vamos a recorrer el dicionario y validar ruta por ruta si se puede leer sino se elminara
#vamos guaradno al mismo tiempo 3 listas, los directorios , listas de paths de los directiros y de las clases ,para usarlo luego usarlo al crear el csv

 def separar_datos_directorios(self,directorios):
  listas_directorios=[]
  listas_listas_directorios=[]
  listas_clases=[]

  for etiqueta,[directorio,clase] in(directorios.items()):

       lista_paths=os.listdir(directorio)
       listas_directorios.append(directorio)
       listas_listas_directorios.append(lista_paths)
       listas_clases.append(clase)

  return listas_directorios,listas_listas_directorios,listas_clases

 def emparejar_listas_paths(self,lista_listas):

   #Tomamos el minimo tamaño dentro de las lista de cada clase
   tamaño_minimo = min(len(arr) for arr in lista_listas)

   #Vamos a emparejar todas las listas con un tamaño igual que sea la del minimo tamaño de todas,esto para tener un set de datos parejo por cada clase
   Reducido_lista_paths=[]

   #Reduce cada lista de los paths a la cantidad minimo para que todos tenga iaugal cantidad
   for listas in(lista_listas):
    Reducido_lista_paths.append(listas[:tamaño_minimo])

   return Reducido_lista_paths
#---------------------------------------------------------------------------------


 def crear_paths_csv(self,directorio_base,lista_paths,clases,nombre_archivo):

   columnas=["path","etiqueta"]
   datos_csv=[]

   for dir_base,dir_path,clase in  zip(directorio_base,lista_paths,clases):

    for path  in (dir_path):

     datos_csv.append([dir_base+path ,clase])


   df_lista=pd.DataFrame(datos_csv,columns=columnas)
   df_lista=df_lista.sort_values(by='path')
   df_lista.to_csv(nombre_archivo,index=False)
   print("Csv Creado")
#---------------------------------------------------------------------------------

#devuelve cuatnos elemtnos tiene cada clase
 def total_elementos(self,directorio,csv_path):
    df=pd.read_csv(csv_path)
    for clase,[directorio,etiqueta] in (directorio.items()):
     tamaño_etiqueta=(df["etiqueta"] == etiqueta).sum()
     print(f"la clase {clase} tiene :{tamaño_etiqueta} elementos")


#-------------------------------------------------------------------------------------------------

  #Funciones para data aumentation
 def   data_aumentation_conjunto(self,input_imagen_folder,output_path_folder,iteraciones,transformaciones):  #ingresa trnasformacioens como compose donde se aplicara las trasnfomracioens conjutnos pero se repteira un numero de veces por cada imagen

   for filename in os.listdir(input_imagen_folder):

    if filename.endswith('.jpg') or filename.endswith('.png'):

        input_path = os.path.join(input_imagen_folder, filename)
        output_path = os.path.join(output_path_folder, f'transformed_{filename}')
        # Aplica las transformaciones
        print(output_path)
        self._apply_transfomaciones_conjunto_it(input_path,output_path,int(iteraciones),transformaciones)


 def   data_aumentation_individual(self,input_imagen_folder,output_path_folder,transformaciones):  #las trnasfomaciones solo pasaremos la lista ya que ira aplicando la transformacion una por una por cada imagen

  for filename in os.listdir(input_imagen_folder):

    if filename.endswith('.jpg') or filename.endswith('.png'):
        input_path = os.path.join(input_imagen_folder, filename)
        output_path = os.path.join(output_path_folder, f'transformed_{filename}')

        # Aplica las transformaciones
        self._apply_transfomaciones_conjunto(input_path,output_path,transformaciones)



 def _apply_transfomaciones_conjunto_it(self,input_imagen_path,output_iamgen_path,iteraciones,transformations=None,): #aplica las transfomracioens  conjutas por iteracion y se guarda las iamgenes

   imagen=Image.open(input_imagen_path)


   for i in range(iteraciones):
      imagen_trasformada=transformations(imagen)

      out_root, out_extension = os.path.splitext(output_iamgen_path)
      imagen_trasformada.save(f"{out_root}_{i}{out_extension}")


 def _apply_transfomaciones_conjunto(self,input_imagen_path,output_iamgen_path,transformations=None): #aplica las transfomracioens individuales  y se guarda las iamgenes

  imagen=Image.open(input_imagen_path)

  for i,transformacion in enumerate(transformations):
   imagen_transformada=transformacion(imagen)
   out_root, out_extension = os.path.splitext(output_iamgen_path)
   imagen_transformada.save(f"{out_root}_{i}{out_extension}")

# %%
#Creamos las carpetas con las imagenes en hr y lw

#Creamos los arhcivo baja resolucion aparitr de imangenes alta resoulcion en hr , estos archios iran a carpaeta lw
directorio_in="/content/DIV2K_train_HR"
directorio_out_lw="/content/lw/"
directorio_out_hr="/content/hr/"

#antes de otrogar mediads de hr y lw , chekea como el generador va votando las resolucioens hr_fake segun la resolucion lw que especifics tiene qeu conicidr
#ya que el discriminador necsita la misma medidades tanto para el hr y el hr_fake que genera el generador

transformaciones_hr=transforms.Compose([
transforms.RandomCrop(size=(240, 240)),

])


transformaciones_lw=transforms.Compose([
transforms.Resize((60,60),interpolation=transforms.InterpolationMode.BICUBIC),
])



datasetmanage=DataSetManage()
datasetmanage.data_aumentation_conjunto(directorio_in,directorio_out_hr,3,transformaciones_hr)
datasetmanage.data_aumentation_conjunto(directorio_out_hr,directorio_out_lw,1,transformaciones_lw)
sorted(directorio_out_hr)
sorted(directorio_out_lw)
# Out:
# /content/hr/transformed_0006.png
# /content/hr/transformed_0067.png
# /content/hr/transformed_0001.png
# /content/hr/transformed_0114.png
# /content/hr/transformed_0326.png
# /content/hr/transformed_0231.png
# /content/hr/transformed_0646.png
# /content/hr/transformed_0294.png
# /content/hr/transformed_0416.png
# /content/hr/transformed_0726.png
# /content/hr/transformed_0429.png
# /content/hr/transformed_0081.png
# /content/hr/transformed_0051.png
# /content/hr/transformed_0587.png
# /content/hr/transformed_0228.png
# /content/hr/transformed_0705.png
# /content/hr/transformed_0676.png
# /content/hr/transformed_0486.png
# /content/hr/transformed_0241.png
# /content/hr/transformed_0514.png
# /content/hr/transformed_0240.png
# /content/hr/transformed_0637.png
# /content/hr/transformed_0474.png
# /content/hr/transformed_0098.png
# /content/hr/transformed_0082.png
# /content/hr/transformed_0108.png
# /content/hr/transformed_0097.png
# /content/hr/transformed_0210.png
# /content/hr/transformed_0013.png
# /content/hr/transformed_0306.png
# /content/hr/transformed_0623.png
# /content/hr/transformed_0444.png
# /content/hr/transformed_0526.png
# /content/hr/transformed_0396.png
# /content/hr/transformed_0485.png
# /content/hr/transformed_0054.png
# /content/hr/transformed_0367.png
# /content/hr/transformed_0681.png
# /content/hr/transformed_0541.png
# /content/hr/transformed_0012.png
# /content/hr/transformed_0640.png
# /content/hr/transformed_0496.png
# /content/hr/transformed_0773.png
# /content/hr/transformed_0503.png
# /content/hr/transformed_0530.png
# /content/hr/transformed_0094.png
# /content/hr/transformed_0695.png
# /content/hr/transformed_0030.png
# /content/hr/transformed_0137.png
# /content/hr/transformed_0666.png
# /content/hr/transformed_0669.png
# /content/hr/transformed_0633.png
# /content/hr/transformed_0359.png
# /content/hr/transformed_0185.png
# /content/hr/transformed_0528.png
# /content/hr/transformed_0324.png
# /content/hr/transformed_0023.png
# /content/hr/transformed_0007.png
# /content/hr/transformed_0656.png
# /content/hr/transformed_0774.png
# /content/hr/transformed_0036.png
# /content/hr/transformed_0195.png
# /content/hr/transformed_0064.png
# /content/hr/transformed_0611.png
# /content/hr/transformed_0612.png
# /content/hr/transformed_0262.png
# /content/hr/transformed_0062.png
# /content/hr/transformed_0059.png
# /content/hr/transformed_0476.png
# /content/hr/transformed_0607.png
# /content/hr/transformed_0469.png
# /content/hr/transformed_0249.png
# /content/hr/transformed_0101.png
# /content/hr/transformed_0330.png
# /content/hr/transformed_0606.png
# /content/hr/transformed_0379.png
# /content/hr/transformed_0456.png
# /content/hr/transformed_0159.png
# /content/hr/transformed_0362.png
# /content/hr/transformed_0335.png
# /content/hr/transformed_0219.png
# /content/hr/transformed_0056.png
# /content/hr/transformed_0684.png
# /content/hr/transformed_0555.png
# /content/hr/transformed_0230.png
# /content/hr/transformed_0218.png
# /content/hr/transformed_0769.png
# /content/hr/transformed_0459.png
# /content/hr/transformed_0116.png
# /content/hr/transformed_0685.png
# /content/hr/transformed_0589.png
# /content/hr/transformed_0406.png
# /content/hr/transformed_0414.png
# /content/hr/transformed_0152.png
# /content/hr/transformed_0184.png
# /content/hr/transformed_0578.png
# /content/hr/transformed_0252.png
# /content/hr/transformed_0293.png
# /content/hr/transformed_0291.png
# /content/hr/transformed_0357.png
# /content/hr/transformed_0778.png
# /content/hr/transformed_0296.png
# /content/hr/transformed_0170.png
# /content/hr/transformed_0428.png
# /content/hr/transformed_0698.png
# /content/hr/transformed_0388.png
# /content/hr/transformed_0481.png
# /content/hr/transformed_0271.png
# /content/hr/transformed_0194.png
# /content/hr/transformed_0652.png
# /content/hr/transformed_0100.png
# /content/hr/transformed_0196.png
# /content/hr/transformed_0672.png
# /content/hr/transformed_0653.png
# /content/hr/transformed_0174.png
# /content/hr/transformed_0483.png
# /content/hr/transformed_0546.png
# /content/hr/transformed_0238.png
# /content/hr/transformed_0489.png
# /content/hr/transformed_0551.png
# /content/hr/transformed_0089.png
# /content/hr/transformed_0449.png
# /content/hr/transformed_0274.png
# /content/hr/transformed_0239.png
# /content/hr/transformed_0457.png
# /content/hr/transformed_0697.png
# /content/hr/transformed_0232.png
# /content/hr/transformed_0163.png
# /content/hr/transformed_0511.png
# /content/hr/transformed_0328.png
# /content/hr/transformed_0488.png
# /content/hr/transformed_0217.png
# /content/hr/transformed_0016.png
# /content/hr/transformed_0524.png
# /content/hr/transformed_0183.png
# /content/hr/transformed_0032.png
# /content/hr/transformed_0411.png
# /content/hr/transformed_0267.png
# /content/hr/transformed_0055.png
# /content/hr/transformed_0192.png
# /content/hr/transformed_0399.png
# /content/hr/transformed_0068.png
# /content/hr/transformed_0579.png
# /content/hr/transformed_0254.png
# /content/hr/transformed_0642.png
# /content/hr/transformed_0800.png
# /content/hr/transformed_0688.png
# /content/hr/transformed_0321.png
# /content/hr/transformed_0490.png
# /content/hr/transformed_0559.png
# /content/hr/transformed_0491.png
# /content/hr/transformed_0156.png
# /content/hr/transformed_0734.png
# /content/hr/transformed_0655.png
# /content/hr/transformed_0282.png
# /content/hr/transformed_0270.png
# /content/hr/transformed_0660.png
# /content/hr/transformed_0516.png
# /content/hr/transformed_0390.png
# /content/hr/transformed_0724.png
# /content/hr/transformed_0782.png
# /content/hr/transformed_0450.png
# /content/hr/transformed_0033.png
# /content/hr/transformed_0402.png
# /content/hr/transformed_0403.png
# /content/hr/transformed_0382.png
# /content/hr/transformed_0598.png
# /content/hr/transformed_0337.png
# /content/hr/transformed_0765.png
# /content/hr/transformed_0229.png
# /content/hr/transformed_0629.png
# /content/hr/transformed_0048.png
# /content/hr/transformed_0461.png
# /content/hr/transformed_0683.png
# /content/hr/transformed_0047.png
# /content/hr/transformed_0375.png
# /content/hr/transformed_0497.png
# /content/hr/transformed_0458.png
# /content/hr/transformed_0641.png
# /content/hr/transformed_0657.png
# /content/hr/transformed_0639.png
# /content/hr/transformed_0538.png
# /content/hr/transformed_0017.png
# /content/hr/transformed_0049.png
# /content/hr/transformed_0090.png
# /content/hr/transformed_0722.png
# /content/hr/transformed_0451.png
# /content/hr/transformed_0725.png
# /content/hr/transformed_0085.png
# /content/hr/transformed_0264.png
# /content/hr/transformed_0743.png
# /content/hr/transformed_0305.png
# /content/hr/transformed_0052.png
# /content/hr/transformed_0710.png
# /content/hr/transformed_0329.png
# /content/hr/transformed_0659.png
# /content/hr/transformed_0289.png
# /content/hr/transformed_0298.png
# /content/hr/transformed_0038.png
# /content/hr/transformed_0480.png
# /content/hr/transformed_0752.png
# /content/hr/transformed_0129.png
# /content/hr/transformed_0665.png
# /content/hr/transformed_0754.png
# /content/hr/transformed_0345.png
# /content/hr/transformed_0719.png
# /content/hr/transformed_0492.png
# /content/hr/transformed_0110.png
# /content/hr/transformed_0540.png
# /content/hr/transformed_0512.png
# /content/hr/transformed_0468.png
# /content/hr/transformed_0590.png
# /content/hr/transformed_0733.png
# /content/hr/transformed_0706.png
# /content/hr/transformed_0173.png
# /content/hr/transformed_0723.png
# /content/hr/transformed_0368.png
# /content/hr/transformed_0628.png
# /content/hr/transformed_0438.png
# /content/hr/transformed_0193.png
# /content/hr/transformed_0610.png
# /content/hr/transformed_0717.png
# /content/hr/transformed_0635.png
# /content/hr/transformed_0304.png
# /content/hr/transformed_0177.png
# /content/hr/transformed_0584.png
# /content/hr/transformed_0645.png
# /content/hr/transformed_0477.png
# /content/hr/transformed_0650.png
# /content/hr/transformed_0745.png
# /content/hr/transformed_0585.png
# /content/hr/transformed_0460.png
# /content/hr/transformed_0281.png
# /content/hr/transformed_0119.png
# /content/hr/transformed_0412.png
# /content/hr/transformed_0568.png
# /content/hr/transformed_0566.png
# /content/hr/transformed_0576.png
# /content/hr/transformed_0445.png
# /content/hr/transformed_0687.png
# /content/hr/transformed_0312.png
# /content/hr/transformed_0529.png
# /content/hr/transformed_0680.png
# /content/hr/transformed_0021.png
# /content/hr/transformed_0181.png
# /content/hr/transformed_0419.png
# /content/hr/transformed_0692.png
# /content/hr/transformed_0691.png
# /content/hr/transformed_0405.png
# /content/hr/transformed_0356.png
# /content/hr/transformed_0409.png
# /content/hr/transformed_0275.png
# /content/hr/transformed_0096.png
# /content/hr/transformed_0272.png
# /content/hr/transformed_0265.png
# /content/hr/transformed_0034.png
# /content/hr/transformed_0572.png
# /content/hr/transformed_0342.png
# /content/hr/transformed_0191.png
# /content/hr/transformed_0370.png
# /content/hr/transformed_0309.png
# /content/hr/transformed_0128.png
# /content/hr/transformed_0216.png
# /content/hr/transformed_0535.png
# /content/hr/transformed_0350.png
# /content/hr/transformed_0741.png
# /content/hr/transformed_0221.png
# /content/hr/transformed_0630.png
# /content/hr/transformed_0605.png
# /content/hr/transformed_0258.png
# /content/hr/transformed_0784.png
# /content/hr/transformed_0731.png
# /content/hr/transformed_0138.png
# /content/hr/transformed_0756.png
# /content/hr/transformed_0748.png
# /content/hr/transformed_0707.png
# /content/hr/transformed_0377.png
# /content/hr/transformed_0454.png
# /content/hr/transformed_0372.png
# /content/hr/transformed_0095.png
# /content/hr/transformed_0035.png
# /content/hr/transformed_0073.png
# /content/hr/transformed_0212.png
# /content/hr/transformed_0385.png
# /content/hr/transformed_0794.png
# /content/hr/transformed_0758.png
# /content/hr/transformed_0534.png
# /content/hr/transformed_0178.png
# /content/hr/transformed_0279.png
# /content/hr/transformed_0455.png
# /content/hr/transformed_0220.png
# /content/hr/transformed_0574.png
# /content/hr/transformed_0553.png
# /content/hr/transformed_0682.png
# /content/hr/transformed_0532.png
# /content/hr/transformed_0041.png
# /content/hr/transformed_0029.png
# /content/hr/transformed_0487.png
# /content/hr/transformed_0418.png
# /content/hr/transformed_0164.png
# /content/hr/transformed_0658.png
# /content/hr/transformed_0322.png
# /content/hr/transformed_0253.png
# /content/hr/transformed_0226.png
# /content/hr/transformed_0246.png
# /content/hr/transformed_0009.png
# /content/hr/transformed_0686.png
# /content/hr/transformed_0154.png
# /content/hr/transformed_0160.png
# /content/hr/transformed_0339.png
# /content/hr/transformed_0614.png
# /content/hr/transformed_0075.png
# /content/hr/transformed_0020.png
# /content/hr/transformed_0583.png
# /content/hr/transformed_0234.png
# /content/hr/transformed_0224.png
# /content/hr/transformed_0621.png
# /content/hr/transformed_0441.png
# /content/hr/transformed_0791.png
# /content/hr/transformed_0365.png
# /content/hr/transformed_0143.png
# /content/hr/transformed_0619.png
# /content/hr/transformed_0086.png
# /content/hr/transformed_0346.png
# /content/hr/transformed_0627.png
# /content/hr/transformed_0302.png
# /content/hr/transformed_0422.png
# /content/hr/transformed_0749.png
# /content/hr/transformed_0387.png
# /content/hr/transformed_0465.png
# /content/hr/transformed_0247.png
# /content/hr/transformed_0506.png
# /content/hr/transformed_0251.png
# /content/hr/transformed_0586.png
# /content/hr/transformed_0556.png
# /content/hr/transformed_0712.png
# /content/hr/transformed_0558.png
# /content/hr/transformed_0150.png
# /content/hr/transformed_0761.png
# /content/hr/transformed_0028.png
# /content/hr/transformed_0783.png
# /content/hr/transformed_0046.png
# /content/hr/transformed_0771.png
# /content/hr/transformed_0378.png
# /content/hr/transformed_0651.png
# /content/hr/transformed_0702.png
# /content/hr/transformed_0434.png
# /content/hr/transformed_0537.png
# /content/hr/transformed_0117.png
# /content/hr/transformed_0148.png
# /content/hr/transformed_0799.png
# /content/hr/transformed_0677.png
# /content/hr/transformed_0003.png
# /content/hr/transformed_0333.png
# /content/hr/transformed_0730.png
# /content/hr/transformed_0644.png
# /content/hr/transformed_0714.png
# /content/hr/transformed_0093.png
# /content/hr/transformed_0762.png
# /content/hr/transformed_0018.png
# /content/hr/transformed_0622.png
# /content/hr/transformed_0255.png
# /content/hr/transformed_0369.png
# /content/hr/transformed_0482.png
# /content/hr/transformed_0569.png
# /content/hr/transformed_0354.png
# /content/hr/transformed_0057.png
# /content/hr/transformed_0499.png
# /content/hr/transformed_0781.png
# /content/hr/transformed_0508.png
# /content/hr/transformed_0025.png
# /content/hr/transformed_0501.png
# /content/hr/transformed_0600.png
# /content/hr/transformed_0131.png
# /content/hr/transformed_0065.png
# /content/hr/transformed_0373.png
# /content/hr/transformed_0269.png
# /content/hr/transformed_0201.png
# /content/hr/transformed_0727.png
# /content/hr/transformed_0708.png
# /content/hr/transformed_0165.png
# /content/hr/transformed_0581.png
# /content/hr/transformed_0259.png
# /content/hr/transformed_0263.png
# /content/hr/transformed_0292.png
# /content/hr/transformed_0374.png
# /content/hr/transformed_0176.png
# /content/hr/transformed_0780.png
# /content/hr/transformed_0310.png
# /content/hr/transformed_0332.png
# /content/hr/transformed_0400.png
# /content/hr/transformed_0140.png
# /content/hr/transformed_0288.png
# /content/hr/transformed_0410.png
# /content/hr/transformed_0189.png
# /content/hr/transformed_0284.png
# /content/hr/transformed_0484.png
# /content/hr/transformed_0207.png
# /content/hr/transformed_0392.png
# /content/hr/transformed_0104.png
# /content/hr/transformed_0647.png
# /content/hr/transformed_0371.png
# /content/hr/transformed_0796.png
# /content/hr/transformed_0266.png
# /content/hr/transformed_0256.png
# /content/hr/transformed_0024.png
# /content/hr/transformed_0550.png
# /content/hr/transformed_0515.png
# /content/hr/transformed_0155.png
# /content/hr/transformed_0394.png
# /content/hr/transformed_0283.png
# /content/hr/transformed_0668.png
# /content/hr/transformed_0327.png
# /content/hr/transformed_0775.png
# /content/hr/transformed_0242.png
# /content/hr/transformed_0563.png
# /content/hr/transformed_0513.png
# /content/hr/transformed_0139.png
# /content/hr/transformed_0039.png
# /content/hr/transformed_0415.png
# /content/hr/transformed_0631.png
# /content/hr/transformed_0413.png
# /content/hr/transformed_0570.png
# /content/hr/transformed_0604.png
# /content/hr/transformed_0545.png
# /content/hr/transformed_0211.png
# /content/hr/transformed_0125.png
# /content/hr/transformed_0638.png
# /content/hr/transformed_0319.png
# /content/hr/transformed_0471.png
# /content/hr/transformed_0785.png
# /content/hr/transformed_0213.png
# /content/hr/transformed_0531.png
# /content/hr/transformed_0135.png
# /content/hr/transformed_0381.png
# /content/hr/transformed_0467.png
# /content/hr/transformed_0495.png
# /content/hr/transformed_0792.png
# /content/hr/transformed_0040.png
# /content/hr/transformed_0732.png
# /content/hr/transformed_0437.png
# /content/hr/transformed_0787.png
# /content/hr/transformed_0244.png
# /content/hr/transformed_0507.png
# /content/hr/transformed_0186.png
# /content/hr/transformed_0772.png
# /content/hr/transformed_0696.png
# /content/hr/transformed_0341.png
# /content/hr/transformed_0424.png
# /content/hr/transformed_0208.png
# /content/hr/transformed_0045.png
# /content/hr/transformed_0439.png
# /content/hr/transformed_0591.png
# /content/hr/transformed_0547.png
# /content/hr/transformed_0593.png
# /content/hr/transformed_0770.png
# /content/hr/transformed_0180.png
# /content/hr/transformed_0106.png
# /content/hr/transformed_0599.png
# /content/hr/transformed_0278.png
# /content/hr/transformed_0776.png
# /content/hr/transformed_0351.png
# /content/hr/transformed_0179.png
# /content/hr/transformed_0716.png
# /content/hr/transformed_0671.png
# /content/hr/transformed_0084.png
# /content/hr/transformed_0344.png
# /content/hr/transformed_0188.png
# /content/hr/transformed_0260.png
# /content/hr/transformed_0190.png
# /content/hr/transformed_0215.png
# /content/hr/transformed_0703.png
# /content/hr/transformed_0203.png
# /content/hr/transformed_0316.png
# /content/hr/transformed_0069.png
# /content/hr/transformed_0423.png
# /content/hr/transformed_0169.png
# /content/hr/transformed_0287.png
# /content/hr/transformed_0233.png
# /content/hr/transformed_0648.png
# /content/hr/transformed_0380.png
# /content/hr/transformed_0689.png
# /content/hr/transformed_0383.png
# /content/hr/transformed_0431.png
# /content/hr/transformed_0318.png
# /content/hr/transformed_0277.png
# /content/hr/transformed_0493.png
# /content/hr/transformed_0026.png
# /content/hr/transformed_0235.png
# /content/hr/transformed_0301.png
# /content/hr/transformed_0502.png
# /content/hr/transformed_0070.png
# /content/hr/transformed_0527.png
# /content/hr/transformed_0313.png
# /content/hr/transformed_0187.png
# /content/hr/transformed_0112.png
# /content/hr/transformed_0533.png
# /content/hr/transformed_0636.png
# /content/hr/transformed_0643.png
# /content/hr/transformed_0147.png
# /content/hr/transformed_0504.png
# /content/hr/transformed_0236.png
# /content/hr/transformed_0609.png
# /content/hr/transformed_0340.png
# /content/hr/transformed_0790.png
# /content/hr/transformed_0797.png
# /content/hr/transformed_0464.png
# /content/hr/transformed_0462.png
# /content/hr/transformed_0157.png
# /content/hr/transformed_0539.png
# /content/hr/transformed_0735.png
# /content/hr/transformed_0588.png
# /content/hr/transformed_0561.png
# /content/hr/transformed_0795.png
# /content/hr/transformed_0715.png
# /content/hr/transformed_0571.png
# /content/hr/transformed_0122.png
# /content/hr/transformed_0760.png
# /content/hr/transformed_0398.png
# /content/hr/transformed_0426.png
# /content/hr/transformed_0136.png
# /content/hr/transformed_0053.png
# /content/hr/transformed_0494.png
# /content/hr/transformed_0004.png
# /content/hr/transformed_0519.png
# /content/hr/transformed_0740.png
# /content/hr/transformed_0517.png
# /content/hr/transformed_0577.png
# /content/hr/transformed_0452.png
# /content/hr/transformed_0317.png
# /content/hr/transformed_0543.png
# /content/hr/transformed_0798.png
# /content/hr/transformed_0755.png
# /content/hr/transformed_0597.png
# /content/hr/transformed_0747.png
# /content/hr/transformed_0753.png
# /content/hr/transformed_0575.png
# /content/hr/transformed_0525.png
# /content/hr/transformed_0453.png
# /content/hr/transformed_0425.png
# /content/hr/transformed_0404.png
# /content/hr/transformed_0166.png
# /content/hr/transformed_0118.png
# /content/hr/transformed_0149.png
# /content/hr/transformed_0675.png
# /content/hr/transformed_0699.png
# /content/hr/transformed_0286.png
# /content/hr/transformed_0620.png
# /content/hr/transformed_0440.png
# /content/hr/transformed_0105.png
# /content/hr/transformed_0061.png
# /content/hr/transformed_0626.png
# /content/hr/transformed_0222.png
# /content/hr/transformed_0209.png
# /content/hr/transformed_0087.png
# /content/hr/transformed_0736.png
# /content/hr/transformed_0205.png
# /content/hr/transformed_0197.png
# /content/hr/transformed_0786.png
# /content/hr/transformed_0649.png
# /content/hr/transformed_0037.png
# /content/hr/transformed_0167.png
# /content/hr/transformed_0044.png
# /content/hr/transformed_0225.png
# /content/hr/transformed_0050.png
# /content/hr/transformed_0750.png
# /content/hr/transformed_0227.png
# /content/hr/transformed_0245.png
# /content/hr/transformed_0315.png
# /content/hr/transformed_0008.png
# /content/hr/transformed_0134.png
# /content/hr/transformed_0408.png
# /content/hr/transformed_0303.png
# /content/hr/transformed_0510.png
# /content/hr/transformed_0199.png
# /content/hr/transformed_0115.png
# /content/hr/transformed_0158.png
# /content/hr/transformed_0109.png
# /content/hr/transformed_0661.png
# /content/hr/transformed_0757.png
# /content/hr/transformed_0435.png
# /content/hr/transformed_0300.png
# /content/hr/transformed_0549.png
# /content/hr/transformed_0014.png
# /content/hr/transformed_0248.png
# /content/hr/transformed_0142.png
# /content/hr/transformed_0667.png
# /content/hr/transformed_0076.png
# /content/hr/transformed_0567.png
# /content/hr/transformed_0200.png
# /content/hr/transformed_0349.png
# /content/hr/transformed_0308.png
# /content/hr/transformed_0311.png
# /content/hr/transformed_0366.png
# /content/hr/transformed_0473.png
# /content/hr/transformed_0618.png
# /content/hr/transformed_0557.png
# /content/hr/transformed_0632.png
# /content/hr/transformed_0746.png
# /content/hr/transformed_0099.png
# /content/hr/transformed_0121.png
# /content/hr/transformed_0694.png
# /content/hr/transformed_0542.png
# /content/hr/transformed_0130.png
# /content/hr/transformed_0127.png
# /content/hr/transformed_0608.png
# /content/hr/transformed_0401.png
# /content/hr/transformed_0472.png
# /content/hr/transformed_0498.png
# /content/hr/transformed_0520.png
# /content/hr/transformed_0363.png
# /content/hr/transformed_0603.png
# /content/hr/transformed_0617.png
# /content/hr/transformed_0079.png
# /content/hr/transformed_0358.png
# /content/hr/transformed_0243.png
# /content/hr/transformed_0679.png
# /content/hr/transformed_0348.png
# /content/hr/transformed_0022.png
# /content/hr/transformed_0088.png
# /content/hr/transformed_0565.png
# /content/hr/transformed_0536.png
# /content/hr/transformed_0624.png
# /content/hr/transformed_0364.png
# /content/hr/transformed_0693.png
# /content/hr/transformed_0299.png
# /content/hr/transformed_0027.png
# /content/hr/transformed_0594.png
# /content/hr/transformed_0742.png
# /content/hr/transformed_0162.png
# /content/hr/transformed_0268.png
# /content/hr/transformed_0060.png
# /content/hr/transformed_0175.png
# /content/hr/transformed_0202.png
# /content/hr/transformed_0788.png
# /content/hr/transformed_0592.png
# /content/hr/transformed_0010.png
# /content/hr/transformed_0360.png
# /content/hr/transformed_0580.png
# /content/hr/transformed_0407.png
# /content/hr/transformed_0133.png
# /content/hr/transformed_0764.png
# /content/hr/transformed_0777.png
# /content/hr/transformed_0151.png
# /content/hr/transformed_0120.png
# /content/hr/transformed_0767.png
# /content/hr/transformed_0500.png
# /content/hr/transformed_0739.png
# /content/hr/transformed_0601.png
# /content/hr/transformed_0479.png
# /content/hr/transformed_0343.png
# /content/hr/transformed_0634.png
# /content/hr/transformed_0475.png
# /content/hr/transformed_0384.png
# /content/hr/transformed_0320.png
# /content/hr/transformed_0397.png
# /content/hr/transformed_0198.png
# /content/hr/transformed_0766.png
# /content/hr/transformed_0077.png
# /content/hr/transformed_0323.png
# /content/hr/transformed_0295.png
# /content/hr/transformed_0334.png
# /content/hr/transformed_0779.png
# /content/hr/transformed_0751.png
# /content/hr/transformed_0521.png
# /content/hr/transformed_0132.png
# /content/hr/transformed_0421.png
# /content/hr/transformed_0280.png
# /content/hr/transformed_0554.png
# /content/hr/transformed_0314.png
# /content/hr/transformed_0763.png
# /content/hr/transformed_0124.png
# /content/hr/transformed_0257.png
# /content/hr/transformed_0427.png
# /content/hr/transformed_0074.png
# /content/hr/transformed_0237.png
# /content/hr/transformed_0663.png
# /content/hr/transformed_0432.png
# /content/hr/transformed_0737.png
# /content/hr/transformed_0522.png
# /content/hr/transformed_0206.png
# /content/hr/transformed_0442.png
# /content/hr/transformed_0664.png
# /content/hr/transformed_0509.png
# /content/hr/transformed_0389.png
# /content/hr/transformed_0448.png
# /content/hr/transformed_0307.png
# /content/hr/transformed_0276.png
# /content/hr/transformed_0107.png
# /content/hr/transformed_0019.png
# /content/hr/transformed_0701.png
# /content/hr/transformed_0738.png
# /content/hr/transformed_0386.png
# /content/hr/transformed_0031.png
# /content/hr/transformed_0092.png
# /content/hr/transformed_0602.png
# /content/hr/transformed_0613.png
# /content/hr/transformed_0113.png
# /content/hr/transformed_0273.png
# /content/hr/transformed_0391.png
# /content/hr/transformed_0463.png
# /content/hr/transformed_0654.png
# /content/hr/transformed_0552.png
# /content/hr/transformed_0297.png
# /content/hr/transformed_0721.png
# /content/hr/transformed_0446.png
# /content/hr/transformed_0789.png
# /content/hr/transformed_0141.png
# /content/hr/transformed_0111.png
# /content/hr/transformed_0153.png
# /content/hr/transformed_0015.png
# /content/hr/transformed_0091.png
# /content/hr/transformed_0078.png
# /content/hr/transformed_0793.png
# /content/hr/transformed_0066.png
# /content/hr/transformed_0204.png
# /content/hr/transformed_0573.png
# /content/hr/transformed_0393.png
# /content/hr/transformed_0544.png
# /content/hr/transformed_0447.png
# /content/hr/transformed_0011.png
# /content/hr/transformed_0436.png
# /content/hr/transformed_0336.png
# /content/hr/transformed_0172.png
# /content/hr/transformed_0768.png
# /content/hr/transformed_0704.png
# /content/hr/transformed_0080.png
# /content/hr/transformed_0171.png
# /content/hr/transformed_0729.png
# /content/hr/transformed_0063.png
# /content/hr/transformed_0478.png
# /content/hr/transformed_0146.png
# /content/hr/transformed_0376.png
# /content/hr/transformed_0347.png
# /content/hr/transformed_0596.png
# /content/hr/transformed_0470.png
# /content/hr/transformed_0395.png
# /content/hr/transformed_0700.png
# /content/hr/transformed_0002.png
# /content/hr/transformed_0430.png
# /content/hr/transformed_0182.png
# /content/hr/transformed_0214.png
# /content/hr/transformed_0290.png
# /content/hr/transformed_0690.png
# /content/hr/transformed_0728.png
# /content/hr/transformed_0616.png
# /content/hr/transformed_0058.png
# /content/hr/transformed_0678.png
# /content/hr/transformed_0420.png
# /content/hr/transformed_0443.png
# /content/hr/transformed_0250.png
# /content/hr/transformed_0144.png
# /content/hr/transformed_0518.png
# /content/hr/transformed_0355.png
# /content/hr/transformed_0168.png
# /content/hr/transformed_0759.png
# /content/hr/transformed_0083.png
# /content/hr/transformed_0223.png
# /content/hr/transformed_0564.png
# /content/hr/transformed_0352.png
# /content/hr/transformed_0123.png
# /content/hr/transformed_0582.png
# /content/hr/transformed_0713.png
# /content/hr/transformed_0072.png
# /content/hr/transformed_0625.png
# /content/hr/transformed_0548.png
# /content/hr/transformed_0505.png
# /content/hr/transformed_0145.png
# /content/hr/transformed_0433.png
# /content/hr/transformed_0615.png
# /content/hr/transformed_0662.png
# /content/hr/transformed_0331.png
# /content/hr/transformed_0523.png
# /content/hr/transformed_0261.png
# /content/hr/transformed_0353.png
# /content/hr/transformed_0285.png
# /content/hr/transformed_0560.png
# /content/hr/transformed_0005.png
# /content/hr/transformed_0562.png
# /content/hr/transformed_0043.png
# /content/hr/transformed_0325.png
# /content/hr/transformed_0126.png
# /content/hr/transformed_0595.png
# /content/hr/transformed_0720.png
# /content/hr/transformed_0042.png
# /content/hr/transformed_0670.png
# /content/hr/transformed_0417.png
# /content/hr/transformed_0071.png
# /content/hr/transformed_0711.png
# /content/hr/transformed_0361.png
# /content/hr/transformed_0161.png
# /content/hr/transformed_0338.png
# /content/hr/transformed_0103.png
# /content/hr/transformed_0718.png
# /content/hr/transformed_0466.png
# /content/hr/transformed_0673.png
# /content/hr/transformed_0709.png
# /content/hr/transformed_0102.png
# /content/hr/transformed_0744.png
# /content/hr/transformed_0674.png
# /content/lw/transformed_transformed_0047_0.png
# /content/lw/transformed_transformed_0005_0.png
# /content/lw/transformed_transformed_0179_0.png
# /content/lw/transformed_transformed_0624_2.png
# /content/lw/transformed_transformed_0713_1.png
# /content/lw/transformed_transformed_0476_0.png
# /content/lw/transformed_transformed_0118_1.png
# /content/lw/transformed_transformed_0297_0.png
# /content/lw/transformed_transformed_0571_2.png
# /content/lw/transformed_transformed_0734_0.png
# /content/lw/transformed_transformed_0162_1.png
# /content/lw/transformed_transformed_0512_0.png
# /content/lw/transformed_transformed_0058_1.png
# /content/lw/transformed_transformed_0382_1.png
# /content/lw/transformed_transformed_0620_1.png
# /content/lw/transformed_transformed_0395_2.png
# /content/lw/transformed_transformed_0440_0.png
# /content/lw/transformed_transformed_0673_0.png
# /content/lw/transformed_transformed_0629_1.png
# /content/lw/transformed_transformed_0556_0.png
# /content/lw/transformed_transformed_0441_2.png
# /content/lw/transformed_transformed_0641_2.png
# /content/lw/transformed_transformed_0091_0.png
# /content/lw/transformed_transformed_0704_2.png
# /content/lw/transformed_transformed_0190_1.png
# /content/lw/transformed_transformed_0356_0.png
# /content/lw/transformed_transformed_0030_1.png
# /content/lw/transformed_transformed_0790_1.png
# /content/lw/transformed_transformed_0443_0.png
# /content/lw/transformed_transformed_0348_1.png
# /content/lw/transformed_transformed_0352_0.png
# /content/lw/transformed_transformed_0429_1.png
# /content/lw/transformed_transformed_0652_0.png
# /content/lw/transformed_transformed_0338_0.png
# /content/lw/transformed_transformed_0393_2.png
# /content/lw/transformed_transformed_0242_1.png
# /content/lw/transformed_transformed_0604_0.png
# /content/lw/transformed_transformed_0297_1.png
# /content/lw/transformed_transformed_0794_2.png
# /content/lw/transformed_transformed_0106_1.png
# /content/lw/transformed_transformed_0391_2.png
# /content/lw/transformed_transformed_0403_0.png
# /content/lw/transformed_transformed_0323_1.png
# /content/lw/transformed_transformed_0472_2.png
# /content/lw/transformed_transformed_0302_0.png
# /content/lw/transformed_transformed_0658_2.png
# /content/lw/transformed_transformed_0074_0.png
# /content/lw/transformed_transformed_0672_1.png
# /content/lw/transformed_transformed_0689_2.png
# /content/lw/transformed_transformed_0378_2.png
# /content/lw/transformed_transformed_0191_1.png
# /content/lw/transformed_transformed_0396_0.png
# /content/lw/transformed_transformed_0657_1.png
# /content/lw/transformed_transformed_0025_2.png
# /content/lw/transformed_transformed_0082_1.png
# /content/lw/transformed_transformed_0378_0.png
# /content/lw/transformed_transformed_0794_0.png
# /content/lw/transformed_transformed_0386_0.png
# /content/lw/transformed_transformed_0539_1.png
# /content/lw/transformed_transformed_0189_1.png
# /content/lw/transformed_transformed_0373_1.png
# /content/lw/transformed_transformed_0562_0.png
# /content/lw/transformed_transformed_0591_2.png
# /content/lw/transformed_transformed_0391_1.png
# /content/lw/transformed_transformed_0009_2.png
# /content/lw/transformed_transformed_0499_1.png
# /content/lw/transformed_transformed_0018_0.png
# /content/lw/transformed_transformed_0309_1.png
# /content/lw/transformed_transformed_0654_0.png
# /content/lw/transformed_transformed_0016_0.png
# /content/lw/transformed_transformed_0467_1.png
# /content/lw/transformed_transformed_0781_0.png
# /content/lw/transformed_transformed_0627_1.png
# /content/lw/transformed_transformed_0759_0.png
# /content/lw/transformed_transformed_0412_0.png
# /content/lw/transformed_transformed_0688_0.png
# /content/lw/transformed_transformed_0094_1.png
# /content/lw/transformed_transformed_0490_0.png
# /content/lw/transformed_transformed_0642_1.png
# /content/lw/transformed_transformed_0769_0.png
# /content/lw/transformed_transformed_0179_1.png
# /content/lw/transformed_transformed_0683_2.png
# /content/lw/transformed_transformed_0583_1.png
# /content/lw/transformed_transformed_0658_0.png
# /content/lw/transformed_transformed_0317_2.png
# /content/lw/transformed_transformed_0521_1.png
# /content/lw/transformed_transformed_0064_2.png
# /content/lw/transformed_transformed_0764_0.png
# /content/lw/transformed_transformed_0234_2.png
# /content/lw/transformed_transformed_0404_2.png
# /content/lw/transformed_transformed_0574_1.png
# /content/lw/transformed_transformed_0016_1.png
# /content/lw/transformed_transformed_0356_2.png
# /content/lw/transformed_transformed_0751_2.png
# /content/lw/transformed_transformed_0027_2.png
# /content/lw/transformed_transformed_0541_1.png
# /content/lw/transformed_transformed_0566_1.png
# /content/lw/transformed_transformed_0655_1.png
# /content/lw/transformed_transformed_0672_0.png
# /content/lw/transformed_transformed_0314_2.png
# /content/lw/transformed_transformed_0253_1.png
# /content/lw/transformed_transformed_0170_0.png
# /content/lw/transformed_transformed_0505_2.png
# /content/lw/transformed_transformed_0614_1.png
# /content/lw/transformed_transformed_0276_2.png
# /content/lw/transformed_transformed_0038_1.png
# /content/lw/transformed_transformed_0645_1.png
# /content/lw/transformed_transformed_0210_2.png
# /content/lw/transformed_transformed_0617_1.png
# /content/lw/transformed_transformed_0544_2.png
# /content/lw/transformed_transformed_0381_0.png
# /content/lw/transformed_transformed_0548_1.png
# /content/lw/transformed_transformed_0044_2.png
# /content/lw/transformed_transformed_0661_1.png
# /content/lw/transformed_transformed_0431_0.png
# /content/lw/transformed_transformed_0651_0.png
# /content/lw/transformed_transformed_0308_2.png
# /content/lw/transformed_transformed_0248_1.png
# /content/lw/transformed_transformed_0284_0.png
# /content/lw/transformed_transformed_0211_2.png
# /content/lw/transformed_transformed_0120_1.png
# /content/lw/transformed_transformed_0433_2.png
# /content/lw/transformed_transformed_0705_2.png
# /content/lw/transformed_transformed_0570_0.png
# /content/lw/transformed_transformed_0612_0.png
# /content/lw/transformed_transformed_0391_0.png
# /content/lw/transformed_transformed_0487_0.png
# /content/lw/transformed_transformed_0101_2.png
# /content/lw/transformed_transformed_0622_1.png
# /content/lw/transformed_transformed_0307_1.png
# /content/lw/transformed_transformed_0560_0.png
# /content/lw/transformed_transformed_0042_2.png
# /content/lw/transformed_transformed_0273_1.png
# /content/lw/transformed_transformed_0519_1.png
# /content/lw/transformed_transformed_0793_1.png
# /content/lw/transformed_transformed_0387_2.png
# /content/lw/transformed_transformed_0497_1.png
# /content/lw/transformed_transformed_0577_0.png
# /content/lw/transformed_transformed_0134_0.png
# /content/lw/transformed_transformed_0725_1.png
# /content/lw/transformed_transformed_0146_1.png
# /content/lw/transformed_transformed_0176_2.png
# /content/lw/transformed_transformed_0224_0.png
# /content/lw/transformed_transformed_0079_0.png
# /content/lw/transformed_transformed_0640_1.png
# /content/lw/transformed_transformed_0133_2.png
# /content/lw/transformed_transformed_0723_1.png
# /content/lw/transformed_transformed_0368_1.png
# /content/lw/transformed_transformed_0610_1.png
# /content/lw/transformed_transformed_0049_1.png
# /content/lw/transformed_transformed_0627_0.png
# /content/lw/transformed_transformed_0004_2.png
# /content/lw/transformed_transformed_0453_2.png
# /content/lw/transformed_transformed_0744_0.png
# /content/lw/transformed_transformed_0529_1.png
# /content/lw/transformed_transformed_0364_2.png
# /content/lw/transformed_transformed_0634_0.png
# /content/lw/transformed_transformed_0448_2.png
# /content/lw/transformed_transformed_0533_2.png
# /content/lw/transformed_transformed_0698_0.png
# /content/lw/transformed_transformed_0432_1.png
# /content/lw/transformed_transformed_0170_2.png
# /content/lw/transformed_transformed_0337_1.png
# /content/lw/transformed_transformed_0281_1.png
# /content/lw/transformed_transformed_0204_0.png
# /content/lw/transformed_transformed_0664_0.png
# /content/lw/transformed_transformed_0322_1.png
# /content/lw/transformed_transformed_0142_0.png
# /content/lw/transformed_transformed_0311_2.png
# /content/lw/transformed_transformed_0441_1.png
# /content/lw/transformed_transformed_0623_0.png
# /content/lw/transformed_transformed_0030_2.png
# /content/lw/transformed_transformed_0752_0.png
# /content/lw/transformed_transformed_0123_0.png
# /content/lw/transformed_transformed_0196_2.png
# /content/lw/transformed_transformed_0371_2.png
# /content/lw/transformed_transformed_0428_0.png
# /content/lw/transformed_transformed_0444_1.png
# /content/lw/transformed_transformed_0001_1.png
# /content/lw/transformed_transformed_0708_0.png
# /content/lw/transformed_transformed_0174_2.png
# /content/lw/transformed_transformed_0493_0.png
# /content/lw/transformed_transformed_0552_0.png
# /content/lw/transformed_transformed_0732_1.png
# /content/lw/transformed_transformed_0547_0.png
# /content/lw/transformed_transformed_0225_1.png
# /content/lw/transformed_transformed_0450_0.png
# /content/lw/transformed_transformed_0102_0.png
# /content/lw/transformed_transformed_0564_0.png
# /content/lw/transformed_transformed_0075_0.png
# /content/lw/transformed_transformed_0665_2.png
# /content/lw/transformed_transformed_0615_2.png
# /content/lw/transformed_transformed_0284_1.png
# /content/lw/transformed_transformed_0168_2.png
# /content/lw/transformed_transformed_0029_2.png
# /content/lw/transformed_transformed_0271_0.png
# /content/lw/transformed_transformed_0727_2.png
# /content/lw/transformed_transformed_0072_0.png
# /content/lw/transformed_transformed_0244_0.png
# /content/lw/transformed_transformed_0729_1.png
# /content/lw/transformed_transformed_0695_0.png
# /content/lw/transformed_transformed_0502_1.png
# /content/lw/transformed_transformed_0569_0.png
# /content/lw/transformed_transformed_0555_0.png
# /content/lw/transformed_transformed_0770_1.png
# /content/lw/transformed_transformed_0024_0.png
# /content/lw/transformed_transformed_0572_0.png
# /content/lw/transformed_transformed_0649_1.png
# /content/lw/transformed_transformed_0755_0.png
# /content/lw/transformed_transformed_0600_0.png
# /content/lw/transformed_transformed_0049_2.png
# /content/lw/transformed_transformed_0408_1.png
# /content/lw/transformed_transformed_0270_0.png
# /content/lw/transformed_transformed_0593_0.png
# /content/lw/transformed_transformed_0458_1.png
# /content/lw/transformed_transformed_0469_0.png
# /content/lw/transformed_transformed_0767_2.png
# /content/lw/transformed_transformed_0149_0.png
# /content/lw/transformed_transformed_0140_0.png
# /content/lw/transformed_transformed_0165_0.png
# /content/lw/transformed_transformed_0224_1.png
# /content/lw/transformed_transformed_0362_2.png
# /content/lw/transformed_transformed_0636_1.png
# /content/lw/transformed_transformed_0451_2.png
# /content/lw/transformed_transformed_0561_0.png
# /content/lw/transformed_transformed_0002_0.png
# /content/lw/transformed_transformed_0314_0.png
# /content/lw/transformed_transformed_0440_2.png
# /content/lw/transformed_transformed_0589_0.png
# /content/lw/transformed_transformed_0668_1.png
# /content/lw/transformed_transformed_0267_0.png
# /content/lw/transformed_transformed_0336_1.png
# /content/lw/transformed_transformed_0552_1.png
# /content/lw/transformed_transformed_0397_0.png
# /content/lw/transformed_transformed_0473_1.png
# /content/lw/transformed_transformed_0354_2.png
# /content/lw/transformed_transformed_0675_2.png
# /content/lw/transformed_transformed_0678_0.png
# /content/lw/transformed_transformed_0084_0.png
# /content/lw/transformed_transformed_0158_2.png
# /content/lw/transformed_transformed_0349_2.png
# /content/lw/transformed_transformed_0492_2.png
# /content/lw/transformed_transformed_0518_2.png
# /content/lw/transformed_transformed_0419_0.png
# /content/lw/transformed_transformed_0763_1.png
# /content/lw/transformed_transformed_0182_2.png
# /content/lw/transformed_transformed_0202_0.png
# /content/lw/transformed_transformed_0447_2.png
# /content/lw/transformed_transformed_0409_2.png
# /content/lw/transformed_transformed_0717_1.png
# /content/lw/transformed_transformed_0542_1.png
# /content/lw/transformed_transformed_0173_2.png
# /content/lw/transformed_transformed_0741_1.png
# /content/lw/transformed_transformed_0357_0.png
# /content/lw/transformed_transformed_0553_2.png
# /content/lw/transformed_transformed_0379_0.png
# /content/lw/transformed_transformed_0186_1.png
# /content/lw/transformed_transformed_0546_0.png
# /content/lw/transformed_transformed_0436_0.png
# /content/lw/transformed_transformed_0058_0.png
# /content/lw/transformed_transformed_0417_2.png
# /content/lw/transformed_transformed_0718_2.png
# /content/lw/transformed_transformed_0257_1.png
# /content/lw/transformed_transformed_0126_1.png
# /content/lw/transformed_transformed_0213_2.png
# /content/lw/transformed_transformed_0317_0.png
# /content/lw/transformed_transformed_0325_1.png
# /content/lw/transformed_transformed_0125_2.png
# /content/lw/transformed_transformed_0528_1.png
# /content/lw/transformed_transformed_0601_2.png
# /content/lw/transformed_transformed_0275_2.png
# /content/lw/transformed_transformed_0239_2.png
# /content/lw/transformed_transformed_0539_0.png
# /content/lw/transformed_transformed_0078_2.png
# /content/lw/transformed_transformed_0722_0.png
# /content/lw/transformed_transformed_0398_0.png
# /content/lw/transformed_transformed_0178_1.png
# /content/lw/transformed_transformed_0104_1.png
# /content/lw/transformed_transformed_0076_0.png
# /content/lw/transformed_transformed_0026_2.png
# /content/lw/transformed_transformed_0468_1.png
# /content/lw/transformed_transformed_0521_0.png
# /content/lw/transformed_transformed_0701_1.png
# /content/lw/transformed_transformed_0045_1.png
# /content/lw/transformed_transformed_0213_0.png
# /content/lw/transformed_transformed_0218_0.png
# /content/lw/transformed_transformed_0663_1.png
# /content/lw/transformed_transformed_0180_0.png
# /content/lw/transformed_transformed_0327_1.png
# /content/lw/transformed_transformed_0385_2.png
# /content/lw/transformed_transformed_0032_2.png
# /content/lw/transformed_transformed_0460_2.png
# /content/lw/transformed_transformed_0449_0.png
# /content/lw/transformed_transformed_0197_1.png
# /content/lw/transformed_transformed_0481_2.png
# /content/lw/transformed_transformed_0056_0.png
# /content/lw/transformed_transformed_0718_1.png
# /content/lw/transformed_transformed_0289_0.png
# /content/lw/transformed_transformed_0727_1.png
# /content/lw/transformed_transformed_0638_2.png
# /content/lw/transformed_transformed_0254_2.png
# /content/lw/transformed_transformed_0124_0.png
# /content/lw/transformed_transformed_0019_2.png
# /content/lw/transformed_transformed_0365_1.png
# /content/lw/transformed_transformed_0681_0.png
# /content/lw/transformed_transformed_0158_1.png
# /content/lw/transformed_transformed_0336_2.png
# /content/lw/transformed_transformed_0685_0.png
# /content/lw/transformed_transformed_0684_2.png
# /content/lw/transformed_transformed_0313_2.png
# /content/lw/transformed_transformed_0001_0.png
# /content/lw/transformed_transformed_0485_1.png
# /content/lw/transformed_transformed_0293_0.png
# /content/lw/transformed_transformed_0036_0.png
# /content/lw/transformed_transformed_0127_2.png
# /content/lw/transformed_transformed_0535_1.png
# /content/lw/transformed_transformed_0618_1.png
# /content/lw/transformed_transformed_0580_1.png
# /content/lw/transformed_transformed_0564_2.png
# /content/lw/transformed_transformed_0377_1.png
# /content/lw/transformed_transformed_0709_0.png
# /content/lw/transformed_transformed_0787_2.png
# /content/lw/transformed_transformed_0459_2.png
# /content/lw/transformed_transformed_0484_1.png
# /content/lw/transformed_transformed_0377_0.png
# /content/lw/transformed_transformed_0335_2.png
# /content/lw/transformed_transformed_0413_1.png
# /content/lw/transformed_transformed_0756_2.png
# /content/lw/transformed_transformed_0328_2.png
# /content/lw/transformed_transformed_0754_2.png
# /content/lw/transformed_transformed_0138_1.png
# /content/lw/transformed_transformed_0259_1.png
# /content/lw/transformed_transformed_0502_0.png
# /content/lw/transformed_transformed_0721_0.png
# /content/lw/transformed_transformed_0249_1.png
# /content/lw/transformed_transformed_0246_1.png
# /content/lw/transformed_transformed_0330_2.png
# /content/lw/transformed_transformed_0760_1.png
# /content/lw/transformed_transformed_0160_1.png
# /content/lw/transformed_transformed_0108_0.png
# /content/lw/transformed_transformed_0333_2.png
# /content/lw/transformed_transformed_0713_0.png
# /content/lw/transformed_transformed_0117_0.png
# /content/lw/transformed_transformed_0085_0.png
# /content/lw/transformed_transformed_0769_1.png
# /content/lw/transformed_transformed_0017_2.png
# /content/lw/transformed_transformed_0453_0.png
# /content/lw/transformed_transformed_0266_0.png
# /content/lw/transformed_transformed_0590_2.png
# /content/lw/transformed_transformed_0146_2.png
# /content/lw/transformed_transformed_0394_0.png
# /content/lw/transformed_transformed_0282_2.png
# /content/lw/transformed_transformed_0463_1.png
# /content/lw/transformed_transformed_0039_0.png
# /content/lw/transformed_transformed_0648_0.png
# /content/lw/transformed_transformed_0137_1.png
# /content/lw/transformed_transformed_0203_2.png
# /content/lw/transformed_transformed_0743_0.png
# /content/lw/transformed_transformed_0190_0.png
# /content/lw/transformed_transformed_0037_0.png
# /content/lw/transformed_transformed_0589_1.png
# /content/lw/transformed_transformed_0573_2.png
# /content/lw/transformed_transformed_0780_1.png
# /content/lw/transformed_transformed_0267_1.png
# /content/lw/transformed_transformed_0531_0.png
# /content/lw/transformed_transformed_0701_0.png
# /content/lw/transformed_transformed_0292_1.png
# /content/lw/transformed_transformed_0427_1.png
# /content/lw/transformed_transformed_0185_0.png
# /content/lw/transformed_transformed_0265_0.png
# /content/lw/transformed_transformed_0334_1.png
# /content/lw/transformed_transformed_0540_2.png
# /content/lw/transformed_transformed_0649_0.png
# /content/lw/transformed_transformed_0677_0.png
# /content/lw/transformed_transformed_0339_2.png
# /content/lw/transformed_transformed_0637_2.png
# /content/lw/transformed_transformed_0529_2.png
# /content/lw/transformed_transformed_0394_2.png
# /content/lw/transformed_transformed_0203_1.png
# /content/lw/transformed_transformed_0294_0.png
# /content/lw/transformed_transformed_0228_2.png
# /content/lw/transformed_transformed_0288_2.png
# /content/lw/transformed_transformed_0392_2.png
# /content/lw/transformed_transformed_0526_2.png
# /content/lw/transformed_transformed_0527_0.png
# /content/lw/transformed_transformed_0280_1.png
# /content/lw/transformed_transformed_0553_1.png
# /content/lw/transformed_transformed_0253_0.png
# /content/lw/transformed_transformed_0141_1.png
# /content/lw/transformed_transformed_0692_0.png
# /content/lw/transformed_transformed_0587_0.png
# /content/lw/transformed_transformed_0229_0.png
# /content/lw/transformed_transformed_0068_1.png
# /content/lw/transformed_transformed_0443_1.png
# /content/lw/transformed_transformed_0549_1.png
# /content/lw/transformed_transformed_0628_0.png
# /content/lw/transformed_transformed_0613_1.png
# /content/lw/transformed_transformed_0691_1.png
# /content/lw/transformed_transformed_0591_1.png
# /content/lw/transformed_transformed_0684_1.png
# /content/lw/transformed_transformed_0722_2.png
# /content/lw/transformed_transformed_0041_2.png
# /content/lw/transformed_transformed_0064_0.png
# /content/lw/transformed_transformed_0442_0.png
# /content/lw/transformed_transformed_0724_2.png
# /content/lw/transformed_transformed_0496_2.png
# /content/lw/transformed_transformed_0270_1.png
# /content/lw/transformed_transformed_0065_0.png
# /content/lw/transformed_transformed_0050_1.png
# /content/lw/transformed_transformed_0414_2.png
# /content/lw/transformed_transformed_0542_0.png
# /content/lw/transformed_transformed_0043_1.png
# /content/lw/transformed_transformed_0237_2.png
# /content/lw/transformed_transformed_0234_0.png
# /content/lw/transformed_transformed_0579_2.png
# /content/lw/transformed_transformed_0110_0.png
# /content/lw/transformed_transformed_0384_2.png
# /content/lw/transformed_transformed_0579_0.png
# /content/lw/transformed_transformed_0268_2.png
# /content/lw/transformed_transformed_0520_2.png
# /content/lw/transformed_transformed_0429_0.png
# /content/lw/transformed_transformed_0374_2.png
# /content/lw/transformed_transformed_0184_0.png
# /content/lw/transformed_transformed_0469_1.png
# /content/lw/transformed_transformed_0029_0.png
# /content/lw/transformed_transformed_0679_2.png
# /content/lw/transformed_transformed_0613_2.png
# /content/lw/transformed_transformed_0782_0.png
# /content/lw/transformed_transformed_0125_1.png
# /content/lw/transformed_transformed_0575_2.png
# /content/lw/transformed_transformed_0194_0.png
# /content/lw/transformed_transformed_0019_1.png
# /content/lw/transformed_transformed_0065_2.png
# /content/lw/transformed_transformed_0340_2.png
# /content/lw/transformed_transformed_0004_1.png
# /content/lw/transformed_transformed_0207_1.png
# /content/lw/transformed_transformed_0205_0.png
# /content/lw/transformed_transformed_0098_2.png
# /content/lw/transformed_transformed_0407_1.png
# /content/lw/transformed_transformed_0118_2.png
# /content/lw/transformed_transformed_0464_0.png
# /content/lw/transformed_transformed_0271_2.png
# /content/lw/transformed_transformed_0375_0.png
# /content/lw/transformed_transformed_0459_1.png
# /content/lw/transformed_transformed_0301_2.png
# /content/lw/transformed_transformed_0763_2.png
# /content/lw/transformed_transformed_0445_0.png
# /content/lw/transformed_transformed_0042_1.png
# /content/lw/transformed_transformed_0575_1.png
# /content/lw/transformed_transformed_0232_1.png
# /content/lw/transformed_transformed_0749_2.png
# /content/lw/transformed_transformed_0516_0.png
# /content/lw/transformed_transformed_0638_0.png
# /content/lw/transformed_transformed_0398_1.png
# /content/lw/transformed_transformed_0420_1.png
# /content/lw/transformed_transformed_0316_1.png
# /content/lw/transformed_transformed_0627_2.png
# /content/lw/transformed_transformed_0698_2.png
# /content/lw/transformed_transformed_0522_2.png
# ...
# /content/lw/transformed_transformed_0109_0.png
# /content/lw/transformed_transformed_0766_0.png
# /content/lw/transformed_transformed_0090_1.png
# /content/lw/transformed_transformed_0458_0.png
# /content/lw/transformed_transformed_0436_2.png
# /content/lw/transformed_transformed_0403_2.png
# /content/lw/transformed_transformed_0304_1.png
# /content/lw/transformed_transformed_0219_1.png
# /content/lw/transformed_transformed_0768_1.png
# /content/lw/transformed_transformed_0361_0.png
# /content/lw/transformed_transformed_0126_0.png
# /content/lw/transformed_transformed_0768_0.png
# /content/lw/transformed_transformed_0398_2.png
# /content/lw/transformed_transformed_0666_2.png
# /content/lw/transformed_transformed_0247_1.png
# /content/lw/transformed_transformed_0128_2.png
# /content/lw/transformed_transformed_0303_2.png
# /content/lw/transformed_transformed_0484_0.png
# /content/lw/transformed_transformed_0327_0.png
# /content/lw/transformed_transformed_0576_2.png
# /content/lw/transformed_transformed_0121_1.png
# /content/lw/transformed_transformed_0567_1.png
# /content/lw/transformed_transformed_0395_1.png
# /content/lw/transformed_transformed_0683_1.png
# /content/lw/transformed_transformed_0365_0.png
# /content/lw/transformed_transformed_0404_1.png
# /content/lw/transformed_transformed_0669_1.png
# /content/lw/transformed_transformed_0009_0.png
# /content/lw/transformed_transformed_0719_1.png
# /content/lw/transformed_transformed_0545_1.png
# /content/lw/transformed_transformed_0108_2.png
# /content/lw/transformed_transformed_0073_1.png
# /content/lw/transformed_transformed_0135_0.png
# /content/lw/transformed_transformed_0795_2.png
# /content/lw/transformed_transformed_0397_2.png
# /content/lw/transformed_transformed_0240_1.png
# /content/lw/transformed_transformed_0389_2.png
# /content/lw/transformed_transformed_0209_1.png
# /content/lw/transformed_transformed_0383_0.png
# /content/lw/transformed_transformed_0152_0.png
# /content/lw/transformed_transformed_0125_0.png
# /content/lw/transformed_transformed_0694_2.png
# /content/lw/transformed_transformed_0301_0.png
# /content/lw/transformed_transformed_0284_2.png
# /content/lw/transformed_transformed_0512_1.png
# /content/lw/transformed_transformed_0641_1.png
# /content/lw/transformed_transformed_0504_0.png
# /content/lw/transformed_transformed_0510_1.png
# /content/lw/transformed_transformed_0654_1.png
# /content/lw/transformed_transformed_0310_2.png
# /content/lw/transformed_transformed_0635_0.png
# /content/lw/transformed_transformed_0372_0.png
# /content/lw/transformed_transformed_0103_2.png
# /content/lw/transformed_transformed_0061_0.png
# /content/lw/transformed_transformed_0571_1.png
# /content/lw/transformed_transformed_0022_0.png
# /content/lw/transformed_transformed_0789_1.png
# /content/lw/transformed_transformed_0707_1.png
# /content/lw/transformed_transformed_0525_0.png
# /content/lw/transformed_transformed_0413_2.png
# /content/lw/transformed_transformed_0468_2.png
# /content/lw/transformed_transformed_0549_0.png
# /content/lw/transformed_transformed_0594_2.png
# /content/lw/transformed_transformed_0036_2.png
# /content/lw/transformed_transformed_0251_1.png
# /content/lw/transformed_transformed_0681_1.png
# /content/lw/transformed_transformed_0297_2.png
# /content/lw/transformed_transformed_0130_2.png
# /content/lw/transformed_transformed_0052_1.png
# /content/lw/transformed_transformed_0292_0.png
# /content/lw/transformed_transformed_0470_2.png
# /content/lw/transformed_transformed_0283_0.png
# /content/lw/transformed_transformed_0653_0.png
# /content/lw/transformed_transformed_0464_2.png
# /content/lw/transformed_transformed_0229_1.png
# /content/lw/transformed_transformed_0680_2.png
# /content/lw/transformed_transformed_0379_1.png
# /content/lw/transformed_transformed_0238_1.png
# /content/lw/transformed_transformed_0749_0.png
# /content/lw/transformed_transformed_0606_0.png
# /content/lw/transformed_transformed_0750_0.png
# /content/lw/transformed_transformed_0222_1.png
# /content/lw/transformed_transformed_0038_0.png
# /content/lw/transformed_transformed_0510_0.png
# /content/lw/transformed_transformed_0700_0.png
# /content/lw/transformed_transformed_0302_1.png
# /content/lw/transformed_transformed_0626_0.png
# /content/lw/transformed_transformed_0419_1.png
# /content/lw/transformed_transformed_0374_0.png
# /content/lw/transformed_transformed_0041_1.png
# /content/lw/transformed_transformed_0109_2.png
# /content/lw/transformed_transformed_0717_2.png
# /content/lw/transformed_transformed_0702_1.png
# /content/lw/transformed_transformed_0103_1.png
# /content/lw/transformed_transformed_0329_2.png
# /content/lw/transformed_transformed_0141_2.png
# /content/lw/transformed_transformed_0261_1.png
# /content/lw/transformed_transformed_0139_2.png
# /content/lw/transformed_transformed_0152_2.png
# /content/lw/transformed_transformed_0689_1.png
# /content/lw/transformed_transformed_0234_1.png
# /content/lw/transformed_transformed_0314_1.png
# /content/lw/transformed_transformed_0070_2.png
# /content/lw/transformed_transformed_0797_2.png
# /content/lw/transformed_transformed_0791_2.png
# /content/lw/transformed_transformed_0788_2.png
# /content/lw/transformed_transformed_0617_2.png
# /content/lw/transformed_transformed_0431_2.png
# /content/lw/transformed_transformed_0083_2.png
# /content/lw/transformed_transformed_0563_1.png
# /content/lw/transformed_transformed_0626_1.png
# /content/lw/transformed_transformed_0498_2.png
# /content/lw/transformed_transformed_0657_0.png
# /content/lw/transformed_transformed_0678_2.png
# /content/lw/transformed_transformed_0087_0.png
# /content/lw/transformed_transformed_0291_1.png
# /content/lw/transformed_transformed_0254_0.png
# /content/lw/transformed_transformed_0111_0.png
# /content/lw/transformed_transformed_0426_2.png
# /content/lw/transformed_transformed_0093_0.png
# /content/lw/transformed_transformed_0675_0.png
# /content/lw/transformed_transformed_0784_1.png
# /content/lw/transformed_transformed_0506_0.png
# /content/lw/transformed_transformed_0595_1.png
# /content/lw/transformed_transformed_0489_2.png
# /content/lw/transformed_transformed_0580_0.png
# /content/lw/transformed_transformed_0285_2.png
# /content/lw/transformed_transformed_0132_0.png
# /content/lw/transformed_transformed_0730_2.png
# /content/lw/transformed_transformed_0777_1.png
# /content/lw/transformed_transformed_0657_2.png
# /content/lw/transformed_transformed_0538_0.png
# /content/lw/transformed_transformed_0656_1.png
# /content/lw/transformed_transformed_0773_1.png
# /content/lw/transformed_transformed_0335_1.png
# /content/lw/transformed_transformed_0397_1.png
# /content/lw/transformed_transformed_0156_1.png
# /content/lw/transformed_transformed_0703_1.png
# /content/lw/transformed_transformed_0661_2.png
# /content/lw/transformed_transformed_0315_0.png
# /content/lw/transformed_transformed_0019_0.png
# /content/lw/transformed_transformed_0596_2.png
# /content/lw/transformed_transformed_0393_1.png
# /content/lw/transformed_transformed_0648_1.png
# /content/lw/transformed_transformed_0624_0.png
# /content/lw/transformed_transformed_0023_0.png
# /content/lw/transformed_transformed_0288_1.png
# /content/lw/transformed_transformed_0205_2.png
# /content/lw/transformed_transformed_0743_2.png
# /content/lw/transformed_transformed_0687_2.png
# /content/lw/transformed_transformed_0534_2.png
# /content/lw/transformed_transformed_0013_2.png
# /content/lw/transformed_transformed_0707_2.png
# /content/lw/transformed_transformed_0599_1.png
# /content/lw/transformed_transformed_0252_1.png
# /content/lw/transformed_transformed_0171_2.png
# /content/lw/transformed_transformed_0117_2.png
# /content/lw/transformed_transformed_0669_0.png
# /content/lw/transformed_transformed_0605_0.png
# /content/lw/transformed_transformed_0216_0.png
# /content/lw/transformed_transformed_0647_2.png
# /content/lw/transformed_transformed_0263_2.png
# /content/lw/transformed_transformed_0020_0.png
# /content/lw/transformed_transformed_0006_1.png
# /content/lw/transformed_transformed_0093_1.png
# /content/lw/transformed_transformed_0245_0.png
# /content/lw/transformed_transformed_0636_2.png
# /content/lw/transformed_transformed_0605_2.png
# /content/lw/transformed_transformed_0263_1.png
# /content/lw/transformed_transformed_0747_2.png
# /content/lw/transformed_transformed_0644_0.png
# /content/lw/transformed_transformed_0256_2.png
# /content/lw/transformed_transformed_0790_2.png
# /content/lw/transformed_transformed_0228_1.png
# /content/lw/transformed_transformed_0366_2.png
# /content/lw/transformed_transformed_0198_2.png
# /content/lw/transformed_transformed_0445_1.png
# /content/lw/transformed_transformed_0389_1.png
# /content/lw/transformed_transformed_0233_0.png
# /content/lw/transformed_transformed_0560_1.png
# /content/lw/transformed_transformed_0568_0.png
# /content/lw/transformed_transformed_0785_2.png
# /content/lw/transformed_transformed_0748_2.png
# /content/lw/transformed_transformed_0202_1.png
# /content/lw/transformed_transformed_0144_1.png
# /content/lw/transformed_transformed_0616_1.png
# /content/lw/transformed_transformed_0283_2.png
# /content/lw/transformed_transformed_0090_2.png
# /content/lw/transformed_transformed_0753_0.png
# /content/lw/transformed_transformed_0031_2.png
# /content/lw/transformed_transformed_0513_0.png
# /content/lw/transformed_transformed_0335_0.png
# /content/lw/transformed_transformed_0272_0.png
# /content/lw/transformed_transformed_0626_2.png
# /content/lw/transformed_transformed_0517_2.png
# /content/lw/transformed_transformed_0331_1.png
# /content/lw/transformed_transformed_0631_1.png
# /content/lw/transformed_transformed_0099_1.png
# /content/lw/transformed_transformed_0694_1.png
# /content/lw/transformed_transformed_0053_0.png
# /content/lw/transformed_transformed_0734_1.png
# /content/lw/transformed_transformed_0612_2.png
# /content/lw/transformed_transformed_0656_2.png
# /content/lw/transformed_transformed_0130_1.png
# /content/lw/transformed_transformed_0292_2.png
# /content/lw/transformed_transformed_0655_2.png
# /content/lw/transformed_transformed_0466_0.png
# /content/lw/transformed_transformed_0618_0.png
# /content/lw/transformed_transformed_0262_0.png
# /content/lw/transformed_transformed_0321_1.png
# /content/lw/transformed_transformed_0291_0.png
# /content/lw/transformed_transformed_0588_1.png
# /content/lw/transformed_transformed_0042_0.png
# /content/lw/transformed_transformed_0356_1.png
# /content/lw/transformed_transformed_0777_2.png
# /content/lw/transformed_transformed_0676_2.png
# /content/lw/transformed_transformed_0473_0.png
# /content/lw/transformed_transformed_0536_0.png
# /content/lw/transformed_transformed_0339_0.png
# /content/lw/transformed_transformed_0417_0.png
# /content/lw/transformed_transformed_0295_2.png
# /content/lw/transformed_transformed_0590_1.png
# /content/lw/transformed_transformed_0711_0.png
# /content/lw/transformed_transformed_0561_1.png
# /content/lw/transformed_transformed_0363_2.png
# /content/lw/transformed_transformed_0323_0.png
# /content/lw/transformed_transformed_0392_0.png
# /content/lw/transformed_transformed_0692_1.png
# /content/lw/transformed_transformed_0227_1.png
# /content/lw/transformed_transformed_0682_0.png
# /content/lw/transformed_transformed_0550_0.png
# /content/lw/transformed_transformed_0505_1.png
# /content/lw/transformed_transformed_0256_1.png
# /content/lw/transformed_transformed_0280_2.png
# /content/lw/transformed_transformed_0340_1.png
# /content/lw/transformed_transformed_0632_1.png
# /content/lw/transformed_transformed_0548_2.png
# /content/lw/transformed_transformed_0568_2.png
# /content/lw/transformed_transformed_0424_1.png
# /content/lw/transformed_transformed_0800_2.png
# /content/lw/transformed_transformed_0068_0.png
# /content/lw/transformed_transformed_0025_0.png
# /content/lw/transformed_transformed_0100_2.png
# /content/lw/transformed_transformed_0353_1.png
# /content/lw/transformed_transformed_0633_2.png
# /content/lw/transformed_transformed_0230_2.png
# /content/lw/transformed_transformed_0525_2.png
# /content/lw/transformed_transformed_0611_0.png
# /content/lw/transformed_transformed_0241_0.png
# /content/lw/transformed_transformed_0061_1.png
# /content/lw/transformed_transformed_0088_2.png
# /content/lw/transformed_transformed_0679_0.png
# /content/lw/transformed_transformed_0482_2.png
# /content/lw/transformed_transformed_0622_2.png
# /content/lw/transformed_transformed_0369_1.png
# /content/lw/transformed_transformed_0616_0.png
# /content/lw/transformed_transformed_0169_2.png
# /content/lw/transformed_transformed_0530_0.png
# /content/lw/transformed_transformed_0144_0.png
# /content/lw/transformed_transformed_0453_1.png
# /content/lw/transformed_transformed_0667_0.png
# /content/lw/transformed_transformed_0715_1.png
# /content/lw/transformed_transformed_0228_0.png
# /content/lw/transformed_transformed_0333_0.png
# /content/lw/transformed_transformed_0345_1.png
# /content/lw/transformed_transformed_0046_2.png
# /content/lw/transformed_transformed_0493_2.png
# /content/lw/transformed_transformed_0699_2.png
# /content/lw/transformed_transformed_0151_0.png
# /content/lw/transformed_transformed_0428_1.png
# /content/lw/transformed_transformed_0489_1.png
# /content/lw/transformed_transformed_0728_0.png
# /content/lw/transformed_transformed_0761_2.png
# /content/lw/transformed_transformed_0265_2.png
# /content/lw/transformed_transformed_0697_0.png
# /content/lw/transformed_transformed_0197_2.png
# /content/lw/transformed_transformed_0474_1.png
# /content/lw/transformed_transformed_0510_2.png
# /content/lw/transformed_transformed_0193_2.png
# /content/lw/transformed_transformed_0731_0.png
# /content/lw/transformed_transformed_0248_0.png
# /content/lw/transformed_transformed_0138_2.png
# /content/lw/transformed_transformed_0559_0.png
# /content/lw/transformed_transformed_0793_2.png
# /content/lw/transformed_transformed_0611_2.png
# /content/lw/transformed_transformed_0603_1.png
# /content/lw/transformed_transformed_0467_0.png
# /content/lw/transformed_transformed_0240_0.png
# /content/lw/transformed_transformed_0370_1.png
# /content/lw/transformed_transformed_0412_1.png
# /content/lw/transformed_transformed_0341_1.png
# /content/lw/transformed_transformed_0686_0.png
# /content/lw/transformed_transformed_0287_0.png
# /content/lw/transformed_transformed_0235_2.png
# /content/lw/transformed_transformed_0281_0.png
# /content/lw/transformed_transformed_0056_2.png
# /content/lw/transformed_transformed_0355_2.png
# /content/lw/transformed_transformed_0582_0.png
# /content/lw/transformed_transformed_0757_2.png
# /content/lw/transformed_transformed_0505_0.png
# /content/lw/transformed_transformed_0561_2.png
# /content/lw/transformed_transformed_0209_0.png
# /content/lw/transformed_transformed_0303_0.png
# /content/lw/transformed_transformed_0010_1.png
# /content/lw/transformed_transformed_0425_2.png
# /content/lw/transformed_transformed_0588_0.png
# /content/lw/transformed_transformed_0396_1.png
# /content/lw/transformed_transformed_0732_2.png
# /content/lw/transformed_transformed_0058_2.png
# /content/lw/transformed_transformed_0251_0.png
# /content/lw/transformed_transformed_0213_1.png
# /content/lw/transformed_transformed_0059_2.png
# /content/lw/transformed_transformed_0134_1.png
# /content/lw/transformed_transformed_0527_2.png
# /content/lw/transformed_transformed_0369_0.png
# /content/lw/transformed_transformed_0326_2.png
# /content/lw/transformed_transformed_0315_2.png
# /content/lw/transformed_transformed_0051_2.png
# /content/lw/transformed_transformed_0091_1.png
# /content/lw/transformed_transformed_0702_2.png
# /content/lw/transformed_transformed_0051_1.png
# /content/lw/transformed_transformed_0606_2.png
# /content/lw/transformed_transformed_0462_1.png
# /content/lw/transformed_transformed_0341_0.png
# /content/lw/transformed_transformed_0685_1.png
# /content/lw/transformed_transformed_0337_0.png
# /content/lw/transformed_transformed_0432_2.png
# /content/lw/transformed_transformed_0673_1.png
# /content/lw/transformed_transformed_0158_0.png
# /content/lw/transformed_transformed_0123_2.png
# /content/lw/transformed_transformed_0477_2.png
# /content/lw/transformed_transformed_0584_1.png
# /content/lw/transformed_transformed_0466_1.png
# /content/lw/transformed_transformed_0225_0.png
# /content/lw/transformed_transformed_0325_0.png
# /content/lw/transformed_transformed_0324_0.png
# /content/lw/transformed_transformed_0708_1.png
# /content/lw/transformed_transformed_0217_2.png
# /content/lw/transformed_transformed_0573_1.png
# ['/', '/', '/', 'c', 'e', 'l', 'n', 'n', 'o', 't', 't', 'w']

# %%
dmg=DataSetManage()
directoriolw={
     "lw":["/content/lw/",0],
}

directoriohr={
     "hr":["/content/hr/",1],
}




listas_directorios,listas_paths_directorios,listas_clases=dmg.separar_datos_directorios(directoriolw)
Dataset_csv="lw_dataset.csv" #nombre que tenda nuestlo csv
dmg.crear_paths_csv(listas_directorios,listas_paths_directorios,listas_clases,Dataset_csv)


listas_directorios,listas_paths_directorios,listas_clases=dmg.separar_datos_directorios(directoriohr)
Dataset_csv="hr_dataset.csv" #nombre que tendla nuestlo csv
dmg.crear_paths_csv(listas_directorios,listas_paths_directorios,listas_clases,Dataset_csv)
# Out:
# Csv Creado
# Csv Creado

# %%
#DEFNIIR DISPOSITIVO:
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("CUDA está disponible.")
    device = torch.device("cuda")
else:
    print("CUDA no está disponible. Se utilizará la CPU.")
    device = torch.device("cpu")
# Out:
# CUDA está disponible.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@markdown # *2) ** Creacion de clase DATASET(OBLIGATORIO)
import torch
from torch.utils.data import Dataset,DataLoader
import pandas as pd
import numpy as np
import cv2
from PIL import Image


class MiDataSet(Dataset):

  def __init__(self,csv_file, transform=None):


     self.data=pd.read_csv(csv_file)

     self.x=self.data["path"]
     self.y=self.data["etiqueta"]

     self.transform=transform

     self.samples=self.data["path"].shape[0]

  def __getitem__(self,id):

    rut_imagen=self.x[id]
    imagen=cv2.imread(rut_imagen)
    etiqueta=self.y[id]


    if imagen is None:
      pillow_image = Image.open(rut_imagen)
      numpy_image = np.array(pillow_image)
      imagen=cv2.cvtColor(numpy_image, cv2.COLOR_RGB2BGR)


    imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)


    if self.transform:
      imagen_rgb = self.transform(imagen_rgb)

    return imagen_rgb,etiqueta


  def __len__(self):
   return self.samples

# %%
#CREANDO DATASETS Y DATALOADERS:

import numpy as np
import matplotlib.pyplot as plt

transformaciones = transforms.Compose([
    transforms.ToTensor(),

])

batch_size=15

DatasetLw=MiDataSet("/content/lw_dataset.csv",transformaciones)
data_loaderLw=DataLoader(DatasetLw,batch_size=batch_size)

DatasetHr=MiDataSet("/content/hr_dataset.csv",transformaciones)
data_loaderHr=DataLoader(DatasetHr,batch_size=batch_size)

generated_image_hr,etiqueta_hr=DatasetHr.__getitem__(200)
generated_image_lw,etiqueta_lw=DatasetHr.__getitem__(200)
print(generated_image_hr.shape)
generated_image_np_hr = generated_image_hr.squeeze().permute(1, 2, 0).numpy()
generated_image_np_lw = generated_image_lw.squeeze().permute(1, 2, 0).numpy()
# Visualizar la imagen generada
# Subfigura 1
plt.subplot(1, 2, 1)
plt.imshow(generated_image_np_hr)
plt.title('hr')

# Subfigura 2
plt.subplot(1, 2, 2)
plt.imshow(generated_image_np_lw)
plt.title('lw')

# Ajustar diseño
plt.tight_layout()

# Mostrar las imágenes
plt.show()
# Out:
# torch.Size([3, 240, 240])

# %%
#@markdown # *0) ** Creando clase Discriminadora y Geneaadora:

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
from torch.utils.data import Dataset,DataLoader
import torchvision.transforms as transforms
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as F

class Discriminator (nn.Module):
  def __init__(self):
   super(Discriminator,self).__init__()

   self.conv1=nn.Conv2d(3,64,kernel_size=3,stride=1, bias=False)
   self.conv2=nn.Conv2d(64,64,kernel_size=3,stride=2, bias=False)
   self.btchnorm64=nn.BatchNorm2d(64)

   self.conv3=nn.Conv2d(64,128,kernel_size=3,stride=1, bias=False)
   self.conv4=nn.Conv2d(128,128,kernel_size=3,stride=2, bias=False)
   self.btchnorm128=nn.BatchNorm2d(128)

   self.conv5=nn.Conv2d(128,256,kernel_size=3,stride=1, bias=False)
   self.conv6=nn.Conv2d(256,256,kernel_size=3,stride=2, bias=False)
   self.btchnorm256=nn.BatchNorm2d(256)

   self.conv7=nn.Conv2d(256,512,kernel_size=3,stride=1, bias=False)
   self.conv8=nn.Conv2d(512,512,kernel_size=3,stride=2, bias=False)
   self.btchnorm512=nn.BatchNorm2d(512)
   self.flatt=nn.Flatten()

   self.oculta1=nn.LazyLinear(1024)
   self.salida= nn.LazyLinear(1)


  def forward(self,x):

    x=self.conv1(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv2(x)
    x=self.btchnorm64(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv3(x)
    x=self.btchnorm128(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv4(x)
    x=self.btchnorm128(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv5(x)
    x=self.btchnorm256(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv6(x)
    x=self.btchnorm256(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv7(x)
    x=self.btchnorm512(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv8(x)
    x=self.btchnorm512(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.flatt(x)
    x=self.oculta1(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.salida(x)
    out=torch.sigmoid(x)

    return out

# %%
discriminador=Discriminator()
discriminador=discriminador.to(device)
x=torch.randn(20,3,208,208).to(device)

print(discriminador(x))

# %%
#------------------------------------------------------------------------
import torch.nn.functional as F
class Generador(nn.Module):

  def __init__(self,factor_escala):
   super(Generador,self).__init__()

   self.convInicial=nn.Conv2d(3,64,kernel_size=9,stride=1,padding=4)

  #Bloques residuales

   res_blocks = []
   for _ in range(5):
       res_blocks.append(ResidualBlock(64))
   self.res_blocks = nn.Sequential(*res_blocks)

   self.convSalida1=nn.Conv2d(64,64,kernel_size=3,stride=1,padding=1)
   self.btchnorm=nn.BatchNorm2d(64)

  #vamos a obligar que la salida anterior se ajuste a la entrada del bloque umsampling que es 256/factor al cuadrado, asi no tengamos problemas en el bluque

   self.convextra=nn.Conv2d(64,int(256/factor_escala**2),kernel_size=1,stride=1)

  #Bloques upsampling

   upsampling = []
   for out_features in range(1):
        upsampling.append(upsampling_block(256,factor_escala))

   self.upsampling = nn.Sequential(*upsampling)

   self.prelu_layer=nn.PReLU();
   self.convlast=nn.Conv2d(int(256/factor_escala**2),3,kernel_size=9,stride=1,padding=4)



  def forward(self,x):


    x=self.convInicial(x)
    x= self.prelu_layer(x)
    x_inicial=x

    x=self.res_blocks(x)
    x= self.convSalida1(x)

    x=torch.add(x,x_inicial)
    x=self.convextra(x)

    x=self.upsampling(x)



    x=self.convlast(x)
    out= ((torch.tanh(x) + 1) / 2)
    return out


class upsampling_block(nn.Module):
    def __init__(self, out_features,factor):
        super(upsampling_block, self).__init__()
        print(int(out_features/factor**2))
        self.conv_block = nn.Sequential(
                nn.Conv2d(int(out_features/factor**2), out_features, 3, 1, 1),
                nn.BatchNorm2d(out_features),
                nn.PixelShuffle(upscale_factor=factor),
                nn.PReLU(),
        )

    def forward(self, x):
        return self.conv_block(x)


class ResidualBlock(nn.Module):
    def __init__(self, in_features):
        super(ResidualBlock, self).__init__()
        self.conv_block = nn.Sequential(
            nn.Conv2d(in_features, in_features, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(in_features, 0.8),
            nn.PReLU(),
            nn.Conv2d(in_features, in_features, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(in_features, 0.8),
        )

    def forward(self, x):
        return x + self.conv_block(x)

# %%
#VAMOS A VER QUE MEDIADES EL GENERADOR DA COMO RESUTLADO CON LW RESOLUTIONS MEDIDAES:

generador=Generador(2)
generador=generador.to(device)
x=torch.randn(20,3,60,60).to(device)

print(generador(x).shape)
# Out:
# 64
# torch.Size([20, 3, 120, 120])

# %%
#PROBAMOS EL GENERADOR INCIAL:

from PIL import Image
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt


#--------------------------------------------------------------------------------------------------------
def show_comparacion(real,generado): #deben de ingrenar don tennoren de imagen generada y real
 print(generado.shape)
 print(real.shape)
 real=real.detach().squeeze().cpu().numpy().transpose(1, 2, 0)
 generado=generado.squeeze().cpu().detach().numpy().transpose(1, 2, 0)
# Primer subgráfico: imagen original
 plt.subplot(1, 2, 1)
 plt.imshow(generado)  # Convertir a NumPy y transponer dimensiones
 plt.title('Imagen Generada')
 plt.axis('off')

# Segundo subgráfico: imagen transformada
 plt.subplot(1, 2, 2)
 plt.imshow(real)  # Convertir a NumPy y transponer dimensiones
 plt.title('Imagen Real')
 plt.axis('off')

# Ajustar el diseño para evitar superposición de títulos
 plt.tight_layout()

# Mostrar la figura
 plt.show()


 plt.figure(figsize=(10, 5))
#-----------------------------------------------------------------------------------
generador=Generador(2).to("cpu")

ruta_imagen = "/content/hr/transformed_0002_0.png"
imagen = Image.open(ruta_imagen)

transformador = ToTensor()

#original iamgen tensor
tensor_imagen = transformador(imagen).unsqueeze(0)
tensor_imagen=tensor_imagen.to("cpu")
#imagen generada
imagen_generada=generador(tensor_imagen)



show_comparacion(tensor_imagen,imagen_generada)
# Out:
# 64
# 64
# torch.Size([1, 3, 960, 960])
# torch.Size([1, 3, 240, 240])

# %%
from torchvision import models

#vamos a extraer los feature es decir las caracteisicas imporantes que exiten entre ambas imagnes y compraralas esto se usara par luego hace rel loss contet apartir del contendio

class Feature_Extractor(nn.Module):
    def __init__(self):
        super(Feature_Extractor, self).__init__()
        # Cargar un modelo VGG-19 preentrenado
        vgg19_model = models.vgg19(pretrained=True).features.eval()

        # No actualizar los pesos del modelo VGG durante el entrenamiento
        for param in vgg19_model.parameters():
            param.requires_grad = False

        selected_layers = list(vgg19_model.children())[:18]

        self.vgg=nn.Sequential(*selected_layers)

    def forward(self, img):

        # Extraer características de las imágenes generada y real
        feature_img = self.vgg(img)

        return feature_img


# TV Loss se utiliza comúnmente en tareas de generación de imágenes para reducir el ruido y fomentar la suavidad en las imágenes generadas.

class TVLoss(nn.Module):
  def __init__(self, tv_loss_weight=1):
    super(TVLoss, self).__init__()
    self.tv_loss_weight=tv_loss_weight
  def forward(self, x):
    batch_size=x.size()[0]
    h_x = x.size()[2]
    w_x = x.size()[3]

    count_h = self.tensor_size(x[:, :, 1:, :])
    count_w = self.tensor_size(x[:, :, :, 1:])


    h_tv = torch.pow(x[:, :, 1:, :] - x[:, :, :h_x - 1, :], 2).sum()
    w_tv = torch.pow(x[:, :, :, 1:] - x[:, :, :, :w_x - 1], 2).sum()
    return self.tv_loss_weight * 2 * (h_tv / count_h + w_tv / count_w) / batch_size

  # Forgot to implement an important method
  @staticmethod # Must add this
  def tensor_size(t):
    return t.size()[1] * t.size()[2] * t.size()[3]

# %%
tv_loss= TVLoss()
x=torch.randn(18,3,60,60)
tv_loss=tv_loss(x)

print(tv_loss)
# Out:
# pasamos
# tensor(8.0288)

# %%
import matplotlib.pyplot as plt
import torch
import torchvision.utils as vutils
import sklearn
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset
# ...

#d=Discriminator(image_dim).to(device)
#g=Generador(dim_vector_ruido,image_dim).to(device)

#d.load_state_dict(torch.load("/content/modelo_gatos_d.pt"))
#g.load_state_dict(torch.load("/content/modelo_gatos_g.pt"))

#d=d.to(device)
#g=g.to(device)


# Supongamos que ya has definido las instancias de los modelos Generador (g) y Discriminador (d),
# y has configurado los optimizadores (g_optimizer y d_optimizer) y la función de pérdida (criterio).



def GAN(discriminador, generador, data_loader_lw,data_loader_hr, num_epochs, batch_size, criterio_g,criterio_d, d_optimizador, g_optimizador, device):

    discriminador=discriminador.to(device)
    generador=generador.to(device)
    feature_extractor=Feature_Extractor().to(device)
    tv_loss= TVLoss().to(device)

    i=0
    for epoch in range(num_epochs):
        for  (lw, hr) in zip(data_loader_lw,data_loader_hr):

            hr_img,hrlbl=hr
            lw_img,lwlbl=lw

            hr_img=hr_img.to(device)
            lw_img=lw_img.to(device)

            generador.eval()
            discriminador.train()

            real_images = hr_img.float()

            real_labels = hrlbl.view(-1, 1).float().to(device)

            # Entrenar el discriminador con imágenes reales
            d_optimizador.zero_grad()

            prediction_real = discriminador(real_images)

            real_loss = criterio_d(prediction_real, real_labels)


            # Entrenar el discriminador con imágenes generadas

            fake_images = generador(lw_img)
            fake_labels = torch.zeros(lw_img.size(0), 1).to(device)

            prediction_fake = discriminador(fake_images)

            fake_loss = criterio_d(prediction_fake, fake_labels).to(device)
            discriminator_loss = (real_loss + fake_loss)/2

            discriminator_loss.backward(retain_graph=True)

            d_optimizador.step()

            # Entrenar el generador
            generador.train()
            discriminador.eval()
            g_optimizador.zero_grad()

            generated_images = generador(lw_img)
            loss_g=criterio_g(discriminador(generated_images),real_labels) #loss del generador aparitr del disicmirnador que dice si es o no una imagen falsa

            loss_imagen=criterio_g(generated_images,real_images) #loss imagen dircamtetne entre igmagen genrada y real

            generated_features=feature_extractor(generated_images)
            real_features=feature_extractor(real_images)
            content_loss=(criterio_g(generated_features, real_features)) #loss de los features original y generado,esto aparitr de el vgg19

            tv_losss=tv_loss(generated_images)
            generator_loss = loss_imagen+content_loss+(0.001*loss_g)+  2e-5 *tv_losss  #loss total del generador

            torch.autograd.set_detect_anomaly(True)
            generator_loss.backward()
            g_optimizador.step()

            if i % 100 == 0:
                print(f'Época [{epoch}/{num_epochs}], Paso [{i}/{len(data_loader_lw)}], '
                      f'Pérdida del Discriminador: {discriminator_loss.item():.4f}, '
                      f'Pérdida del Generador: {generator_loss.item():.4f}')
            i=i+1
        # Imprimir estadísticas y visualizar imágenes generadas al final de cada época
        with torch.no_grad():
            generador.eval()
            generated_images = generador(lw_img)
            print(hr_img.shape)
            print(generated_images.shape)
            show_comparacion(hr_img[0],generated_images[0])


#--------------------------------------------------------------------------------------------



num_epochs=6





d=Discriminator()
g=Generador(2)

d.load_state_dict(torch.load("/content/srgan_d.pt"))
g.load_state_dict(torch.load("/content/srgan_g.pt"))

lr_g = 0.00008
lr_d = 0.000008
d_optimizer=optim.Adam(d.parameters(),lr=lr_d)
g_optimizer=optim.Adam(g.parameters(),lr=lr_g)

criterio_d=nn.BCELoss()
criterio_g=nn.MSELoss()


print(f"learning rate discrimiador:{lr_d}")
print(f"learning rate generador:{lr_g}")

GAN(d,g,data_loaderLw,data_loaderHr,num_epochs,batch_size,criterio_g,criterio_d,d_optimizer,g_optimizer,device)

# %%
torch.save(g.state_dict(), 'srgan_g.pt')
torch.save(d.state_dict(), 'srgan_d.pt')

# %%
d.load_state_dict(torch.load("/content/srgan_d.pt"))

# %%
from PIL import Image
# Suponiendo que "Generador" es la clase de tu generador y "ruta_modelo" es la ruta del modelo guardado
generador = Generador(2)  # creando generado
generador.load_state_dict(torch.load("/content/srgan_g.pt"))
generador.to(device)
generador.eval()

ruta_imagen = "/content/mono.png"
imagen_pil = Image.open(ruta_imagen)

transformaciones = transforms.Compose([
    transforms.ToTensor(),  # Convierte la imagen a un tensor

])
# Aplicar la interpolación bicúbica sin cambiar las dimensiones


imagen_transformada = transformaciones(imagen_pil)
imagen_transformada=imagen_transformada.to(device)
with torch.no_grad():
    generador.eval()

    generated_image = generador(imagen_transformada.unsqueeze(0)).detach().cpu()

# Convertir la imagen al rango [0, 1]
# generated_image = (generated_image + 1) / 2.0

generated_image_np = generated_image.squeeze().permute(1, 2, 0).numpy()

print(generated_image.shape)
# Visualizar la imagen generada
plt.imshow(generated_image_np)
plt.axis('off')
plt.show()


# Convertir el tensor a una imagen
tensor_a_imagen = transforms.ToPILImage()(generated_image.squeeze())


# Guardar la imagen
tensor_a_imagen.save("imagen_guardadahd.jpg")
