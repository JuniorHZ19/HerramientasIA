# %% [markdown]
# <a href="https://colab.research.google.com/github/JuniorHZ19/HerramientasIA/blob/main/imagetoimageWaveGenerator6.5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing_image_downloader
# Out:
# Collecting bing_image_downloader
#   Downloading bing_image_downloader-1.1.2-py3-none-any.whl (5.9 kB)
# Installing collected packages: bing_image_downloader
# Successfully installed bing_image_downloader-1.1.2

# %%
from bing_image_downloader import downloader


downloader.download("paisajes", limit=200,  output_dir='dataset',
                    adult_filter_off=True, force_replace=False, timeout=60)
# Out:
# [%] Downloading Images to /content/dataset/paisajes
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://s-media-cache-ak0.pinimg.com/originals/e1/00/1e/e1001e86903d5fccba2a7e83a0547bd4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://1.bp.blogspot.com/-ur_mJcStlis/VAc2aa3bbSI/AAAAAAACTYI/gCf_p25rvKI/s1600/paisajes%2Bnaturales%2B-%2Bnaturaleza%2B-%2Bnatural%2Bfree%2Blandscapes%2B-%2Bfotos%2Bde%2Bpaisajes.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://2.bp.blogspot.com/-epneGMSghoM/T7Etq2B4yEI/AAAAAAAAc9U/u7F8lh0GkCw/s1600/Reflexion-Montanas-Lagos_Paisajes-Naturales.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://3.bp.blogspot.com/-DpMGtdirhgU/UkG0od7SvDI/AAAAAAAACas/SCmxU02sx5Y/s1600/im%25C3%25A1genes-gratis-para-fondos-y-wallpapers-de-paisajes-motos-piscinas-y-playas-fotos-libres+%252817%2529.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://3.bp.blogspot.com/-ghOTeIXIwqo/U1q9rHdREUI/AAAAAAACMK8/FZmLP5A0Qw0/s1600/paisajes-naturales-escenarios-del-campo-montañas-y-lagos-landscapes+(2).jpg
# [!] Issue getting: https://3.bp.blogspot.com/-ghOTeIXIwqo/U1q9rHdREUI/AAAAAAACMK8/FZmLP5A0Qw0/s1600/paisajes-naturales-escenarios-del-campo-montañas-y-lagos-landscapes+(2).jpg
# [!] Error:: 'ascii' codec can't encode character '\xf1' in position 105: ordinal not in range(128)
# [%] Downloading Image #5 from http://2.bp.blogspot.com/-eiMwsgM6uAo/T2DZlRrSG6I/AAAAAAAAWhQ/wk_X-n9fCQU/s1600/Paisajes-Naturales-HDR-HD_02.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://1.bp.blogspot.com/-zKX8CREi3QY/T2OMZgW3s6I/AAAAAAAAWzg/5sFH754c6sw/s1600/Los-mas-Hermosos-Paisajes-Naturales_04.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from http://1.bp.blogspot.com/-ZuzPfSyNClE/T6552cUYSbI/AAAAAAAAAA4/m3CY0YRvn24/s1600/ph-117121.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://1.bp.blogspot.com/-Z73bAN3BT6g/VAc2S1ssr8I/AAAAAAACTYA/62G5bH-oAw0/s1600/paisajes%2Bnaturales%2B-%2Bnaturaleza%2B-%2Bnatural%2Bfree%2Blandscapes%2B-%2Bfotos%2Bde%2Bpaisajes%2B(9).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://3.bp.blogspot.com/-Mj8qX2E3I3A/T2OMyEirmAI/AAAAAAAAWzo/fYyR3OHYeTU/s1600/Los-mas-Hermosos-Paisajes-Naturales_05.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://2.bp.blogspot.com/-J6VYU_D_DMs/VCmQxPjrGPI/AAAAAAACUdw/e3EZY7Of1_E/s1600/fotos%2Bde%2Bpaisajes%2Bnaturales%2B(1).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://4.bp.blogspot.com/-BMWJmGaKDxY/VPtB6PVOa3I/AAAAAAACiO4/bBDHl07nDjQ/s1600/paisaje-lago-natural.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://3.bp.blogspot.com/-7Dca5yxjVkk/T0rWPVH-HBI/AAAAAAAAVaE/i3ZA2jVxjsg/s1600/Paisajes_Wallpapers-1080p_05.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from http://2.bp.blogspot.com/-uF-f7U6B9NQ/T2ONK0rKXBI/AAAAAAAAW0I/vTvYSL7sLRM/s1600/Los-mas-Hermosos-Paisajes-Naturales_09.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from http://1.bp.blogspot.com/-50HW0FVADz4/TvyE7gGqeJI/AAAAAAAAH5Q/j72bcqLYjRs/s1600/PAISAJES%2BNATURALES%2BOLEO.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://4.bp.blogspot.com/-cze_EK1_lMA/UtSxstrv4qI/AAAAAAACI20/e2KunXS2wiM/s1600/paisaje+con+terrazas+de+arroz+agricultura+rice+terraces.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from http://2.bp.blogspot.com/_EZ16vWYvHHg/TUB1vE5PpJI/AAAAAAAAWa8/utMu40xqDQk/s1600/www.BancodeImagenesGratuitas.com%2B-Alpine-Pond-Colorado.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from http://1.bp.blogspot.com/-DCSIbvgUQdw/USOyuqbyELI/AAAAAAAAFaM/02AeoDG6GAs/s1600/Los-mas-Hermosos-Paisajes-Naturales_01.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://2.bp.blogspot.com/-0vnPGugKJOE/VAc2OO1tMGI/AAAAAAACTX4/DTbOV2aceok/s1600/paisajes%2Bnaturales%2B-%2Bnaturaleza%2B-%2Bnatural%2Bfree%2Blandscapes%2B-%2Bfotos%2Bde%2Bpaisajes%2B(8).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from http://1.bp.blogspot.com/_1E-ebc1qY5w/TCjppu-wqBI/AAAAAAAAI2I/FM6MBMm3dKM/s1600/5.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from http://2.bp.blogspot.com/-hBNyV9tfsvI/T5tEVXFU5eI/AAAAAAAAa8U/ItByc__Wl4A/s1600/Hermosos-Paisajes-Naturales-HD_09.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from http://2.bp.blogspot.com/-CRauYczhvU8/T2ONAwMDnSI/AAAAAAAAWz4/opvQfUlfRIo/s1600/Los-mas-Hermosos-Paisajes-Naturales_07.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from http://2.bp.blogspot.com/-f8xBnqdbzxE/T5tB4ZVWAVI/AAAAAAAAa7c/_Iv0dMDzlyo/s1600/Hermosos-Paisajes-Naturales-HD_02.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from http://4.bp.blogspot.com/-Ul5jAUi2qi8/USZp86JZprI/AAAAAAAAAC4/ZrV7Z0gaenA/s1600/paisaje-lago-montanas-nevadas-y-flores.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from http://2.bp.blogspot.com/-aGB3_SysAVw/UkIpIAfT0iI/AAAAAAABEx0/rB_Qlr6tuxw/s1600/Wallpaper%2BPaisaje%2BHD%2B(49).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from http://1.bp.blogspot.com/-E1OEAsmmETE/TdMe-10X9UI/AAAAAAAAAAY/nGLLcMm5JYY/s1600/paisajes-155.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from http://3.bp.blogspot.com/--sSJOQ21ZAI/T2OM3EsJBqI/AAAAAAAAWzw/X9wC3pEDjY4/s1600/Los-mas-Hermosos-Paisajes-Naturales_06.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from http://2.bp.blogspot.com/-WibI4MqlR7s/T2OMAMNi_9I/AAAAAAAAWzY/f7AGF2Twuf4/s1600/Los-mas-Hermosos-Paisajes-Naturales_03.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://www.wallpapertip.com/wmimgs/6-64843_wallpaper-hd-nature-flower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from http://2.bp.blogspot.com/_Wv2gjxhmoc8/TQbhZWsPCxI/AAAAAAAAAAQ/IhiwPW_E1Lg/s1600/Webshots_77006.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from http://2.bp.blogspot.com/-KxNgp_J4gDo/T5tDGEYRSiI/AAAAAAAAa78/EJP3CsDxXV0/s1600/Hermosos-Paisajes-Naturales-HD_06.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #31 from https://3.bp.blogspot.com/-RB9k9jg2zf0/T2DaP5PZeNI/AAAAAAAAWiI/PWytGCnwGVY/s1600/Paisajes-Naturales-HDR-HD_09.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #32 from http://3.bp.blogspot.com/_1E-ebc1qY5w/TCjpn9GdpZI/AAAAAAAAI2A/LJugfYLhiaE/s1600/4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #33 from https://1.bp.blogspot.com/-SAJiFq8iCZQ/T2ONFbs3pFI/AAAAAAAAW0A/-xAXaKpV7Ok/s1600/Los-mas-Hermosos-Paisajes-Naturales_08.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #34 from http://2.bp.blogspot.com/-ndRq4XcGI6k/UA4CzlfDaWI/AAAAAAABBJQ/eejAKbMgBVQ/s1600/special-blue-landscape-1920x1200-wallpaper-paisaje-azul.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 35 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #35 from https://i.pinimg.com/originals/d4/15/6c/d4156c5474a44240cec2c283c19b11db.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 4
#
# [%] Indexed 35 Images on Page 4.
#
# ===============================================
#
# [%] Downloading Image #36 from http://3.bp.blogspot.com/-F2EQZ_gcVPA/UWHFLNbHMCI/AAAAAAAAVEk/AuwZqqNLj1A/s1600/paisajes-fotografias.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 5
#
# [%] Indexed 35 Images on Page 5.
#
# ===============================================
#
# [%] Downloading Image #37 from http://4.bp.blogspot.com/-afyP1r6EvSM/TlPU6AdX5dI/AAAAAAAALno/x4WHjHCQBlY/s1600/Paisaje-de-un-atardecer-1600x1200.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 6
#
# [%] Indexed 35 Images on Page 6.
#
# ===============================================
#
# [%] Downloading Image #38 from http://2.bp.blogspot.com/-_aM3HGeF9LE/VAc13tw8tfI/AAAAAAACTXg/G7hT9FDFwTo/s1600/paisajes%2Bnaturales%2B-%2Bnaturaleza%2B-%2Bnatural%2Bfree%2Blandscapes%2B-%2Bfotos%2Bde%2Bpaisajes%2B(5).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #39 from https://data.1freewallpapers.com/download/lake-mountains-forest-landscape-nature-3840x2160.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #40 from https://get.pxhere.com/photo/landscape-tree-water-nature-forest-wilderness-cloud-sky-sunrise-sunset-sunlight-morning-leaf-lake-dawn-dusk-evening-reflection-peaceful-autumn-season-trees-wetland-habitat-natural-environment-atmospheric-phenomenon-woody-plant-computer-wallpaper-1098735.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #41 from http://4.bp.blogspot.com/-_Q6SwV8HFqU/T9oWN85XyTI/AAAAAAAAfOs/NlTZmyBWUz4/s1600/Lagos-Montanas-Piedras-y-Arboles_Imagenes-HD-de-Montanas.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #42 from https://www.wallpaperup.com/uploads/wallpapers/2015/01/23/599137/423ae6e1b93e77ce19c1c81c5982dec6.jpg
# [!] Issue getting: https://www.wallpaperup.com/uploads/wallpapers/2015/01/23/599137/423ae6e1b93e77ce19c1c81c5982dec6.jpg
# [!] Error:: <urlopen error timed out>
# [%] Downloading Image #42 from http://2.bp.blogspot.com/-Zt9Td2g8XGo/VAc2IleKMPI/AAAAAAACTXw/o_El-IsfME8/s1600/paisajes%2Bnaturales%2B-%2Bnaturaleza%2B-%2Bnatural%2Bfree%2Blandscapes%2B-%2Bfotos%2Bde%2Bpaisajes%2B(7).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #43 from https://4.bp.blogspot.com/-E7bPPfQVr0w/T8bOZC8-XpI/AAAAAAAAeYI/lguz3krSlQk/s1600/Bosque-de-Pinos-Paisajes-Naturales-en-HD.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #44 from https://1.bp.blogspot.com/-vBrLlEdlD7w/U7wzFS3zZfI/AAAAAAACPnQ/1SpG5oBP39E/s1600/paisajes+naturales+cascadas+y+playas+-+natural+landscapes,+waterfalls+and+beaches+(6).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #45 from https://2.bp.blogspot.com/-hBNyV9tfsvI/T5tEVXFU5eI/AAAAAAAAa8U/ItByc__Wl4A/s1600/Hermosos-Paisajes-Naturales-HD_09.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #46 from https://get.wallhere.com/photo/trees-landscape-forest-dark-lake-water-nature-reflection-park-clouds-green-morning-river-wilderness-pond-dock-boathouses-wetland-cloud-tree-autumn-leaf-mountain-season-reservoir-loch-habitat-woody-plant-body-of-water-64206.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #47 from http://4.bp.blogspot.com/-Um2o17gncJQ/VE50PENDnGI/AAAAAAACXG0/jgdKfkiQwHA/s1600/1+las+mejores+fotos+de+paisajes+naturales+2014+(2).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #48 from http://3.bp.blogspot.com/-cDHlPZWgGZw/VE50_15YonI/AAAAAAACXHk/NvKhhAbeqnk/s1600/las+mejores+fotos+de+paisajes+naturales+2014+(3).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #49 from https://3.bp.blogspot.com/_EZ16vWYvHHg/S6zgFnQu-sI/AAAAAAAAJWA/G_Uelf5_4GY/s1600/Paisajes+www.BancodeImagenesGratuitas.com+-7.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #50 from https://3.bp.blogspot.com/-mzssXLlJU0s/VGpwyKbekgI/AAAAAAACYac/lVGpOyjds7c/s1600/paisajes%2Bnaturales%2Bde%2Bcolección%2Bmontañas%2Bríos%2Blagos%2Bbosques%2Bnieve%2B(9).jpg
# [!] Issue getting: https://3.bp.blogspot.com/-mzssXLlJU0s/VGpwyKbekgI/AAAAAAACYac/lVGpOyjds7c/s1600/paisajes%2Bnaturales%2Bde%2Bcolección%2Bmontañas%2Bríos%2Blagos%2Bbosques%2Bnieve%2B(9).jpg
# [!] Error:: 'ascii' codec can't encode character '\xf3' in position 95: ordinal not in range(128)
# [%] Downloading Image #50 from https://i.pinimg.com/originals/04/0e/ce/040ece9078b22e7315de96aa620057c5.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #51 from http://4.bp.blogspot.com/-wvNXHxFL4ws/VF5N4-F71BI/AAAAAAAABsI/J4H_ud3xa5M/s1600/green-nature-wallpaper-desktop.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #52 from http://3.bp.blogspot.com/-NzKcOoC35mI/TfiWXcG1d3I/AAAAAAAAACc/o3jo8O6Q8rE/s1600/paisaje_de_montana-1280x1024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #53 from https://i.pinimg.com/originals/7e/86/e3/7e86e32d44e9b29e1fcad0caa654519b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #54 from https://i.pinimg.com/originals/d2/61/47/d2614770d6f3f8a58c202b1508acabf5.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #55 from https://i.pinimg.com/originals/4a/f0/63/4af063edf04a870525f3865e4a1b056d.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #56 from http://www.imagenzone.net/fondos-de-pantalla/Paisajes/001.jpg
# [Error]Invalid image, not saving http://www.imagenzone.net/fondos-de-pantalla/Paisajes/001.jpg
#
# [!] Issue getting: http://www.imagenzone.net/fondos-de-pantalla/Paisajes/001.jpg
# [!] Error:: Invalid image, not saving http://www.imagenzone.net/fondos-de-pantalla/Paisajes/001.jpg
#
# [%] Downloading Image #56 from http://imagenpng.com/wp-content/uploads/2017/01/F6D.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #57 from https://fondosmil.com/fondo/11112.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 7
#
# [%] Indexed 35 Images on Page 7.
#
# ===============================================
#
# [%] Downloading Image #58 from http://4.bp.blogspot.com/-tDZO-EPeAg0/Tn2GRky-4hI/AAAAAAAAOAo/B_BrXbh8czA/s1600/bellos+paisajes+fantasticos+reflejos.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #59 from http://padi87.files.wordpress.com/2008/10/paisajes.jpg
# [Error]Invalid image, not saving http://padi87.files.wordpress.com/2008/10/paisajes.jpg
#
# [!] Issue getting: http://padi87.files.wordpress.com/2008/10/paisajes.jpg
# [!] Error:: Invalid image, not saving http://padi87.files.wordpress.com/2008/10/paisajes.jpg
#
# [%] Downloading Image #59 from https://1.bp.blogspot.com/-XeZKWQFqf24/UBbmjySvYuI/AAAAAAAAABI/y7TbEN_b78Q/s1600/fondos-pantalla-paisajes-flores-1024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #60 from https://1.bp.blogspot.com/-QoAzL9hQ6Hg/T5RDAP8Z_TI/AAAAAAAAEPc/7WFKVxGUJ5k/s1600/DSCN1793.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #61 from https://3.bp.blogspot.com/-Nepf91kt7BI/T5tEhA34MJI/AAAAAAAAa8c/YCNT0bGKCCs/s1600/Hermosos-Paisajes-Naturales-HD_10.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #62 from https://2.bp.blogspot.com/-WibI4MqlR7s/T2OMAMNi_9I/AAAAAAAAWzY/f7AGF2Twuf4/s1600/Los-mas-Hermosos-Paisajes-Naturales_03.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #63 from https://2.bp.blogspot.com/-uF-f7U6B9NQ/T2ONK0rKXBI/AAAAAAAAW0I/vTvYSL7sLRM/s1600/Los-mas-Hermosos-Paisajes-Naturales_09.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #64 from https://3.bp.blogspot.com/-uFKKCOm05H4/T2DZdbF_FNI/AAAAAAAAWhI/qhstNbdePAM/s1600/Paisajes-Naturales-HDR-HD_01.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #65 from https://3.bp.blogspot.com/-CIs82PI6A-8/T0rF19vO-8I/AAAAAAAAVYM/Q6dTcC_MnL8/s1600/Paisajes_HD_01.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #66 from http://3.bp.blogspot.com/-MtSwBdg29VU/UDZ6TrLY0KI/AAAAAAAAKJg/0Mspf0EkUjI/s1600/paisajes+(44).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #67 from https://4.bp.blogspot.com/-0JqhWwtL4lQ/TjUstBftNfI/AAAAAAAAGkk/j13wwM3AIcA/s1600/paisajes+naturales1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #68 from http://2.bp.blogspot.com/-MPgSHns2GRI/TxczXvAaFJI/AAAAAAAABtQ/JvNHZyqObMw/s1600/Foto0083.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #69 from http://1.bp.blogspot.com/-ph8CxIbJ_0Y/UpJGeMQKMOI/AAAAAAAAvpU/ZXTGoCa_Ans/s1600/oleos-de-paisajes-con-montañas.jpg
# [!] Issue getting: http://1.bp.blogspot.com/-ph8CxIbJ_0Y/UpJGeMQKMOI/AAAAAAAAvpU/ZXTGoCa_Ans/s1600/oleos-de-paisajes-con-montañas.jpg
# [!] Error:: 'ascii' codec can't encode character '\xf1' in position 87: ordinal not in range(128)
# [%] Downloading Image #69 from https://3.bp.blogspot.com/_IttMcKXajd0/TNbpD5vGKvI/AAAAAAAAAAQ/fVRyblex5iU/s1600/Paisajes%2520HD%2C%2520wallpapers-37.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #70 from http://www.arqhys.com/wp-content/fotos/2012/08/Pinturas-paisajes.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #71 from http://3.bp.blogspot.com/-U3N7iom8zUo/T6_kYnXZBSI/AAAAAAAAc3Q/4Tau2om1HJc/s1600/Fondos-de-pantalla-de-paisajes-naturales_03.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #72 from http://3.bp.blogspot.com/-6sdcHvyXjVs/T1VkopOy5TI/AAAAAAAAVwY/0LeAsprJFfo/s1600/paisajes-naturaleza-caminos-bosques_03.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #73 from https://4.bp.blogspot.com/-LvFyFg7W2cU/UObtOdBWPaI/AAAAAAAALzw/5GaCOGHuSFw/s1600/paisajes.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #74 from https://2.bp.blogspot.com/-kDJCzQHAndI/T6qaAAzI5aI/AAAAAAAAceY/53bncxc3EKA/s1600/Paisajes-de-la-naturaleza-en-hd.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #75 from https://frasesdelavida.com/wp-content/uploads/2019/08/frases-de-paisajes-1024x612.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 8
#
# [%] Indexed 35 Images on Page 8.
#
# ===============================================
#
#
#
# [!!]Indexing page: 9
#
# [%] Indexed 35 Images on Page 9.
#
# ===============================================
#
# [%] Downloading Image #76 from https://2.bp.blogspot.com/-MPgSHns2GRI/TxczXvAaFJI/AAAAAAAABtQ/JvNHZyqObMw/s1600/Foto0083.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #77 from https://1.bp.blogspot.com/-v3AVwz94ChY/Xp5coo9GciI/AAAAAAAACCI/AdMoJAvitHYvHxuOC0p7FYnZ8o4QxfkXQCLcBGAsYHQ/s1600/paisaje.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #78 from http://3.bp.blogspot.com/_EZ16vWYvHHg/S6zgFnQu-sI/AAAAAAAAJWA/G_Uelf5_4GY/s1600/Paisajes+www.BancodeImagenesGratuitas.com+-7.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #79 from https://1.bp.blogspot.com/-2lgE5j6tj2c/T5tDfVgC5jI/AAAAAAAAa8E/X8s0NHS9lMg/s1600/Hermosos-Paisajes-Naturales-HD_07.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #80 from https://www.jigsawplanet.com/Correcaminos/paisajes?rc=face
# [%] File Downloaded !
#
# [%] Downloading Image #81 from http://2.bp.blogspot.com/-ON_HBXCPKTs/T8Oga_IK_XI/AAAAAAAAeD0/JnCcEaeLD7Y/s1600/Paisaje-Arbol-al-Atardecer.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #82 from https://3.bp.blogspot.com/-ELHXtePt2BI/UWHFKleB7_I/AAAAAAAAVEc/KgIjR2bI520/s1600/paisajes-fotografias-digitales.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 10
#
# [%] Indexed 35 Images on Page 10.
#
# ===============================================
#
# [%] Downloading Image #83 from http://k31.kn3.net/taringa/0/C/1/2/0/0/KonahsFvZ/F6D.jpg
# [!] Issue getting: http://k31.kn3.net/taringa/0/C/1/2/0/0/KonahsFvZ/F6D.jpg
# [!] Error:: HTTP Error 522:
#
#
# [!!]Indexing page: 11
#
# [%] Indexed 35 Images on Page 11.
#
# ===============================================
#
# [%] Downloading Image #83 from http://2.bp.blogspot.com/-lA9ZNMB8Jd4/UmvtfGxE5HI/AAAAAAAB7yE/g5SRSCvgV9s/s1600/2-los-mejores-paisajes-del-mundo-cascadas-agua-ríos-lagos-montañas-animales-aves-otoño-playas-y-bosques+(19).jpg
# [!] Issue getting: http://2.bp.blogspot.com/-lA9ZNMB8Jd4/UmvtfGxE5HI/AAAAAAAB7yE/g5SRSCvgV9s/s1600/2-los-mejores-paisajes-del-mundo-cascadas-agua-ríos-lagos-montañas-animales-aves-otoño-playas-y-bosques+(19).jpg
# [!] Error:: 'ascii' codec can't encode character '\xed' in position 108: ordinal not in range(128)
#
#
# [!!]Indexing page: 12
#
# [%] Indexed 35 Images on Page 12.
#
# ===============================================
#
# [%] Downloading Image #83 from https://i.pinimg.com/originals/9f/4e/c7/9f4ec77473d353bd571ba7bbb686f6fe.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 13
#
# [%] Indexed 35 Images on Page 13.
#
# ===============================================
#
#
#
# [!!]Indexing page: 14
#
# [%] Indexed 35 Images on Page 14.
#
# ===============================================
#
# [%] Downloading Image #84 from http://1.bp.blogspot.com/_9EVC1Jt2fJM/TR37xIcz56I/AAAAAAAAALA/g703qXxGw5k/s1600/wallpaper-paisaje-monta%25C3%25B1as.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 15
#
# [%] Indexed 35 Images on Page 15.
#
# ===============================================
#
# [%] Downloading Image #85 from http://3.bp.blogspot.com/-MS4hgp58ohY/UCMVm3u86BI/AAAAAAAACA4/6pKP0ZLiXQY/s1600/Paisajes-hermosos.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #86 from http://lavidaenpau.files.wordpress.com/2010/04/paisajes-hermosos-025-1024x768.jpg
# [Error]Invalid image, not saving http://lavidaenpau.files.wordpress.com/2010/04/paisajes-hermosos-025-1024x768.jpg
#
# [!] Issue getting: http://lavidaenpau.files.wordpress.com/2010/04/paisajes-hermosos-025-1024x768.jpg
# [!] Error:: Invalid image, not saving http://lavidaenpau.files.wordpress.com/2010/04/paisajes-hermosos-025-1024x768.jpg
#
# [%] Downloading Image #86 from https://2.bp.blogspot.com/-eAbtXMa_Gpo/Uq817asBhiI/AAAAAAAAR4w/Sd6ymD1F4tM/s640/camino-en-el-paisaje.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #87 from http://www.v3wall.com/wallpaper/1440_900/1008/1440_900_201008151034463297606.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 16
#
# [%] Indexed 35 Images on Page 16.
#
# ===============================================
#
# [%] Downloading Image #88 from http://3.bp.blogspot.com/-uFKKCOm05H4/T2DZdbF_FNI/AAAAAAAAWhI/qhstNbdePAM/s1600/Paisajes-Naturales-HDR-HD_01.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #89 from http://4.bp.blogspot.com/-m4RdM13lrmw/TpT0A2VMd_I/AAAAAAAAAFQ/nWSex-i5qZc/s1600/Fondo-de-pantalla-Paisajes-20.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 17
#
# [%] Indexed 35 Images on Page 17.
#
# ===============================================
#
#
#
# [!!]Indexing page: 18
#
# [%] Indexed 35 Images on Page 18.
#
# ===============================================
#
# [%] Downloading Image #90 from http://1.bp.blogspot.com/_6_IyWh3BPlU/TE9QuuN9M8I/AAAAAAAAAwQ/NL6HwAdXqCU/s1600/paisajes.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 19
#
# [%] Indexed 35 Images on Page 19.
#
# ===============================================
#
#
#
# [!!]Indexing page: 20
#
# [%] Indexed 35 Images on Page 20.
#
# ===============================================
#
# [%] Downloading Image #91 from https://2.bp.blogspot.com/_EZ16vWYvHHg/TUNkZuRSnBI/AAAAAAAAWfc/EpC6oXBomdo/s1600/www.BancodeImagenesGratuitas.com%2B-%2Bcanyon-falls.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 21
#
# [%] Indexed 35 Images on Page 21.
#
# ===============================================
#
# [%] Downloading Image #92 from http://1.bp.blogspot.com/-ADQwZmJPYAQ/T5tCiDUNT9I/AAAAAAAAa70/qPfDg_cLzno/s1600/Hermosos-Paisajes-Naturales-HD_05.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #93 from http://1.bp.blogspot.com/-rP8Du9HxAyE/UDZ59ehcHUI/AAAAAAAAKHY/GQuyR88wrvo/s1600/paisajes+(29).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #94 from http://3.bp.blogspot.com/-bh-mYrha1Gs/TmPbjGOxW_I/AAAAAAAALJE/RmpcrFWxexc/s1600/paisajes%2Bcascada%2Bhermoso.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #95 from http://1.bp.blogspot.com/-xUMPrK8VewU/UWHFHjRZYBI/AAAAAAAAVD8/8dX8yrnbTW4/s1600/paisajes-fotografias+(2).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #96 from https://2.bp.blogspot.com/_XWkF4A1lUpU/TTLgNTBihSI/AAAAAAAAAbs/SNoZ9hanXW8/s400/2998852830_52d84ffae6_z.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 22
#
# [%] Indexed 35 Images on Page 22.
#
# ===============================================
#
# [%] Downloading Image #97 from http://2.bp.blogspot.com/-1SZw6oCcfWc/TmPY3GbA5gI/AAAAAAAALIk/6Jgu14Dopuc/s1600/paisajes+naturales.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #98 from https://2.bp.blogspot.com/-6J2JnCgVvas/UgusxrKCE6I/AAAAAAAAmNE/VqeNEGOw3ZY/s1600/imagenes-de-paisajes+(8).jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 23
#
# [%] Indexed 35 Images on Page 23.
#
# ===============================================
#
# [%] Downloading Image #99 from https://fondosmil.com/fondo/11119.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 24
#
# [%] Indexed 35 Images on Page 24.
#
# ===============================================
#
# [%] Downloading Image #100 from https://curiosidadescuriosas.com/wp-content/uploads/2012/12/Fotografia-de-Paisaje-Natural-4.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 25
#
# [%] Indexed 35 Images on Page 25.
#
# ===============================================
#
#
#
# [!!]Indexing page: 26
#
# [%] Indexed 35 Images on Page 26.
#
# ===============================================
#
# [%] Downloading Image #101 from https://bashny.net/uploads/images/00/00/39/2013/08/18/e971c9747c.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #102 from http://3.bp.blogspot.com/-mFb5O-py0k0/U33HezExL1I/AAAAAAAAAeM/Lo47DC2xLvY/s1600/paisajes-hd-naturales.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #103 from http://lavidaenpau.files.wordpress.com/2010/04/fondos-paisajes-1024202.jpg
# [Error]Invalid image, not saving http://lavidaenpau.files.wordpress.com/2010/04/fondos-paisajes-1024202.jpg
#
# [!] Issue getting: http://lavidaenpau.files.wordpress.com/2010/04/fondos-paisajes-1024202.jpg
# [!] Error:: Invalid image, not saving http://lavidaenpau.files.wordpress.com/2010/04/fondos-paisajes-1024202.jpg
#
# [%] Downloading Image #103 from https://1.bp.blogspot.com/-6o7Z4ZXoxDY/Ug_CraETebI/AAAAAAAAma0/PB1U-IlTkXk/s640/paisajes-naturales-paisajes-naturales.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #104 from http://2.bp.blogspot.com/-W71Rb2cKqUM/TmVGQ5iBKwI/AAAAAAAALRE/jN6DL5Z_90M/s1600/jardin-de-colores-paisajes.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 27
#
# [%] Indexed 35 Images on Page 27.
#
# ===============================================
#
# [%] Downloading Image #105 from http://3.bp.blogspot.com/-CAzkWYK1DHw/UHeU4vWLNxI/AAAAAAABLXI/Yc7Z4jzHbZE/s1600/hermoso-paisaje-en-las-playas-tropicales-del-eden-amazing-and-luxury-beaches.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 28
#
# [%] Indexed 35 Images on Page 28.
#
# ===============================================
#
# [%] Downloading Image #106 from https://1.bp.blogspot.com/-_Z_KmNSrDjg/Ug_CrU-GwYI/AAAAAAAAma4/_-8ZtBVZHrA/s1600/paisajes-paisajes-paisajes-paisajes+(2).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #107 from http://4.bp.blogspot.com/-MAt-MWFnF28/TsIF3uy9TvI/AAAAAAAAq5U/EAW4gD4u7rI/s1600/www.FreeAmazingPictures.com-Paisajes.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 29
#
# [%] Indexed 35 Images on Page 29.
#
# ===============================================
#
# [%] Downloading Image #108 from http://1.bp.blogspot.com/-WjdENErO3cU/Uv_1loUrcUI/AAAAAAAA8lo/3tDdjw99_O8/s00/atardecer-en-un-campo-de-flores_paisajes-naturales-hd-1920x1080.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 30
#
# [%] Indexed 35 Images on Page 30.
#
# ===============================================
#
# [%] Downloading Image #109 from https://todastusfrases.com/wp-content/uploads/2019/10/Fondos-de-pantalla-de-paisajes-naturales-4.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 31
#
# [%] Indexed 35 Images on Page 31.
#
# ===============================================
#
#
#
# [!!]Indexing page: 32
#
# [%] Indexed 35 Images on Page 32.
#
# ===============================================
#
#
#
# [!!]Indexing page: 33
#
# [%] Indexed 35 Images on Page 33.
#
# ===============================================
#
# [%] Downloading Image #110 from http://2.bp.blogspot.com/-ZKV60RyWwrU/UDZ52AO5III/AAAAAAAAKGw/Cwg4nE5dqic/s1600/paisajes+(24).jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 34
#
# [%] Indexed 35 Images on Page 34.
#
# ===============================================
#
# [%] Downloading Image #111 from http://1.bp.blogspot.com/-7cx4lKlz80U/UDZ5wx-QsxI/AAAAAAAAKGQ/Rh0OWe-cHv4/s1600/paisajes+(20).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #112 from http://3.bp.blogspot.com/-5pIJjwTRjSE/Tp5FNzdiybI/AAAAAAAAEXk/hSXNqYfKo3k/s1600/paisajes-hermosos-de-la-naturaleza-.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #113 from http://2.bp.blogspot.com/_D3N3TCjQ27Y/TKFBmKujQ8I/AAAAAAAAAHk/agRCZAlcU4Q/s1600/fondos-paisajes-1024202.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #114 from https://2.bp.blogspot.com/-1FX6MWjkFjo/XdQ96CHj38I/AAAAAAAAKrM/NMzkOXsRPhswM6Mgu3Xybw7-B9xFkfJvgCK4BGAYYCw/s1600/Paisaje-de-paisaje.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #115 from http://2.bp.blogspot.com/-_CmzKmQCq38/ToxAvtoDCpI/AAAAAAAAAAk/HGzuxgq1neQ/s1600/imagenes-paisajes-postal.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #116 from http://3.bp.blogspot.com/-ThBoKd-tWXU/TmUN3RopbyI/AAAAAAAALMI/6MfgBLWDw3Q/s1600/luna-paisajes-wallpapers-hd.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #117 from http://1.bp.blogspot.com/-Gy7m8yl-PeI/UDZ5_KgbY0I/AAAAAAAAKHg/j2cjFyJz9SY/s1600/paisajes+(3).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #118 from https://2.bp.blogspot.com/-wDRLyTwUIvo/UfgaNH4ijfI/AAAAAAAAdig/PwtpyDzXkD4/s1600/fotos-de-paisajes-gratis+(2).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #119 from http://3.bp.blogspot.com/-ECRQOe8D5Iw/T6_kT4MC0oI/AAAAAAAAc3I/YA2E6Z-LE2w/s1600/Fondos-de-pantalla-de-paisajes-naturales_02.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #120 from http://1.bp.blogspot.com/-3wdJgIevsPM/T657yzzFo4I/AAAAAAAAACo/lrHvR3aXHzY/s1600/imagenes-paisajes-hermosos-6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #121 from http://1.bp.blogspot.com/-ofSa2DHmXmU/UDZ50zz7aAI/AAAAAAAAKGo/NgnidmMnbag/s1600/paisajes+(23).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #122 from http://3.bp.blogspot.com/-oyBITjGM-Ks/T5RC0EO_O9I/AAAAAAAAEPE/T7jN2q5KxUU/s1600/DSCN1789.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #123 from https://2.bp.blogspot.com/_M3nBcCbetGo/TDUZtlf0L9I/AAAAAAAAAAU/ll54UaZ9oo4/s1600/paisaje-1024-x-768.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 35
#
# [%] Indexed 35 Images on Page 35.
#
# ===============================================
#
# [%] Downloading Image #124 from http://1.bp.blogspot.com/-CiEpv6YJ7OY/VgA8ORcnPKI/AAAAAAABFuk/NKYPjw1oHiQ/s00/paisaje-campo-con-flores-de-colores.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 36
#
# [%] Indexed 35 Images on Page 36.
#
# ===============================================
#
# [%] Downloading Image #125 from https://3.bp.blogspot.com/-tDJ0v38EI_8/UcESoRkSuXI/AAAAAAAB0aQ/WvSJMFhuvbs/s1600/fotos-e-imagenes-gratis-de-paisajes-naturales-y-rios-y-cascadas-1.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 37
#
# [%] Indexed 35 Images on Page 37.
#
# ===============================================
#
# [%] Downloading Image #126 from http://www.v3wall.com/wallpaper/1680_1050/1008/1680_1050_201008131030271263523.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #127 from http://4.bp.blogspot.com/-d1eb7nNBU2Y/UaZw9GtH-EI/AAAAAAAAABo/X6adDWUZXkU/s400/paisajes.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #128 from https://2.bp.blogspot.com/-D727boy5wDk/WNy8aKR9QXI/AAAAAAAACdY/E7yEhEuyDu4YlJLGxi9PlAYDb6XI3cqDQCLcB/s1600/paisaje%2Bsat.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 38
#
# [%] Indexed 35 Images on Page 38.
#
# ===============================================
#
# [%] Downloading Image #129 from http://k42.kn3.net/taringa/1/6/1/5/2/9/51/pedroroa-2/035.jpg?3060
# [!] Issue getting: http://k42.kn3.net/taringa/1/6/1/5/2/9/51/pedroroa-2/035.jpg?3060
# [!] Error:: HTTP Error 522:
# [%] Downloading Image #129 from https://w0.peakpx.com/wallpaper/224/496/HD-wallpaper-mountain-full-paisaje.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 39
#
# [%] Indexed 35 Images on Page 39.
#
# ===============================================
#
# [%] Downloading Image #130 from https://2.bp.blogspot.com/-OeYWOohr-pg/UWHFIROXT5I/AAAAAAAAVEE/5DhGrCVMHv8/s1600/paisajes-en-fotografias.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 40
#
# [%] Indexed 35 Images on Page 40.
#
# ===============================================
#
# [%] Downloading Image #131 from https://s1.1zoom.me/b6231/655/Mountains_Forests_Lake_Austria_Scenery_566149_1920x1080.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #132 from http://i0.wp.com/medioambienteynaturaleza.com/wp-content/uploads/2015/06/Fondos-de-pantalla-de-paisajes-naturales29.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #133 from https://besthqwallpapers.com/Uploads/6-4-2020/127567/guatemala-4k-piers-mountains-sea.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #134 from https://s1.1zoom.me/big3/708/370449-svetik.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #135 from https://4.bp.blogspot.com/-obc8Kv2fkl8/UCG79-RBiHI/AAAAAAABCyA/gcvzZq77HMY/s1600/la-incomprensible-perfeccion-de-la-naturaleza-paisajes-y-escenarios-naturales.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #136 from http://4.bp.blogspot.com/-Lxwd_btMGuw/VC7kqvDqkVI/AAAAAAACUww/-6rE3NfOG2g/s1600/fotos%2Bgratis%2Bde%2Bpaisajes%2Bnaturales%2C%2Bbosques%2C%2Bmontañas%2C%2Bríos%2By%2Blagos%2B(3).jpg
# [!] Issue getting: http://4.bp.blogspot.com/-Lxwd_btMGuw/VC7kqvDqkVI/AAAAAAACUww/-6rE3NfOG2g/s1600/fotos%2Bgratis%2Bde%2Bpaisajes%2Bnaturales%2C%2Bbosques%2C%2Bmontañas%2C%2Bríos%2By%2Blagos%2B(3).jpg
# [!] Error:: 'ascii' codec can't encode character '\xf1' in position 126: ordinal not in range(128)
# [%] Downloading Image #136 from https://i.pinimg.com/originals/ea/d9/e4/ead9e4aaf5b4121a95517dd34b83b597.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #137 from https://1.bp.blogspot.com/-BdPPx-w2k-I/U97RJlTAx8I/AAAAAAACQ2E/2T0AJgcANPc/s1600/paisajes+naturales+de+bosques+y+árboles+verdes+(2).jpg
# [!] Issue getting: https://1.bp.blogspot.com/-BdPPx-w2k-I/U97RJlTAx8I/AAAAAAACQ2E/2T0AJgcANPc/s1600/paisajes+naturales+de+bosques+y+árboles+verdes+(2).jpg
# [!] Error:: 'ascii' codec can't encode character '\xe1' in position 92: ordinal not in range(128)
# [%] Downloading Image #137 from https://2.bp.blogspot.com/-3A0aO9TR0NY/T0j5iztFsSI/AAAAAAAAVDE/TIMNs-QOCuE/s1600/Paisajes-HD_08.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #138 from https://3.bp.blogspot.com/--sSJOQ21ZAI/T2OM3EsJBqI/AAAAAAAAWzw/X9wC3pEDjY4/s1600/Los-mas-Hermosos-Paisajes-Naturales_06.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #139 from https://www.paisajesimagenes.com/wp-content/uploads/ver-paisajes.jpg
# [!] Issue getting: https://www.paisajesimagenes.com/wp-content/uploads/ver-paisajes.jpg
# [!] Error:: <urlopen error [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)>
# [%] Downloading Image #139 from https://i.pinimg.com/originals/51/3c/11/513c11efe5e77102af1a5729cce66e3b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #140 from https://i.pinimg.com/originals/ce/6d/b3/ce6db3d5daadf8aeb037537b88079a35.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #141 from http://2.bp.blogspot.com/-ec7XaKLc8WM/TnQt4675h1I/AAAAAAAANOQ/QXNyKBiC3yk/s1600/atardecer_tropical.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #142 from http://2.bp.blogspot.com/-Hn9pbyCkyiY/UNuW97d15cI/AAAAAAAAyE0/owYtG3qzCwc/s1600/1680x1050+-+Paisaje+Wallpaper+(12).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #143 from https://2.bp.blogspot.com/-q0qwB_e4HDM/Vxy2vRiOYuI/AAAAAAADAQo/mplObZfgG9Me9swREjVY0WmrOlTxLxTOwCLcB/s1600/los%2Bmejores%2Bpaisajes%2Bdel%2Bmundo%2Bbanco%2Bde%2Bimagenes%2Bfotos%2Blindas%2B%25283%2529.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #144 from https://i.pinimg.com/originals/1a/dc/bb/1adcbbb9c63a2eb920e1c5b774251bc2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #145 from https://1.bp.blogspot.com/-V3peLaDChTk/WXOscai0ksI/AAAAAAAAbsY/z3PPV5kSCyE8o2fJv0hwS5_0iG-uOKcpgCLcBGAs/s1600/imagenes-de-paisajes-bonitos-naturales_1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #146 from https://3.bp.blogspot.com/-pzKezxmdIns/ViQXGEzKKoI/AAAAAAAAObk/h8hZ0DBJbSg/s1600/7005130-autumn-landscape.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 41
#
# [%] Indexed 35 Images on Page 41.
#
# ===============================================
#
# [%] Downloading Image #147 from http://1.bp.blogspot.com/-arvZL833Nms/Tdga5zj4WNI/AAAAAAAAAAY/KnDOEooMAvk/s1600/fondos-paisajes.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #148 from http://4.bp.blogspot.com/-ruXXEkDcfI4/T5tBh-wPWgI/AAAAAAAAa7U/L4rIZi1km38/s1600/Hermosos-Paisajes-Naturales-HD_01.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 42
#
# [%] Indexed 35 Images on Page 42.
#
# ===============================================
#
# [%] Downloading Image #149 from http://1.bp.blogspot.com/_wCT2N6yfd1g/TPaHFP935rI/AAAAAAAAAB8/UG6_F8sRTIY/s1600/paisajes02.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 43
#
# [%] Indexed 35 Images on Page 43.
#
# ===============================================
#
# [%] Downloading Image #150 from https://4.bp.blogspot.com/-1794Amzwdjs/VCmSUBztq9I/AAAAAAACUe4/0DCYQMdaLt8/s1600/fotos+de+paisajes+naturales.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 44
#
# [%] Indexed 35 Images on Page 44.
#
# ===============================================
#
# [%] Downloading Image #151 from http://1.bp.blogspot.com/-JyvDYBLH4l4/TnQv3OMBJgI/AAAAAAAANPA/XcpRH3_-tGk/s1600/Atardecer-violeta.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 45
#
# [%] No more images are available
#
#
# [%] Done. Downloaded 151 images.

# %%
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# !unzip DIV2K_train_HR.zip # This is our dataset link. I will include this command in the description

# %%
#@markdown # *0) ** Instalando libreria(OBLIGATORIO)

# !pip install torch torchvision torchaudio

# %%
torch.cuda.empty_cache()

# %%
import shutil

shutil.rmtree("/content/imagenes")

# %%
#@markdown # *1) ** Clase Para manejo de directorios de datasets de imagenes


import os
import cv2
import pandas as pd
from PIL import Image
import torch
from torchvision import transforms
# Recorre el directorio  y elmiina los archvios que no tiene las extensioens permitidas

class DataSetManage:




 def comprobar_ext_directorios(self,directorio):

  for clase,[directorio,etiquetas] in(directorio.items()):
   lista_directorio=os.listdir(directorio)
   self._validarExt(directorio)



 def  _validarExt(self,directorio):
  print(directorio)
   # Extensiones permitidas
  extensiones_permitidas = {".jpg", ".jpeg", ".png"}
  for root, dirs, files in os.walk(directorio):

    for file in files:
        # Obtiene la extensión del archivo
        _, extension = os.path.splitext(file)

        # Verifica si la extensión no está en la lista de extensiones permitidas y elimina el archivo
        if extension.lower() not in extensiones_permitidas:
            archivo_a_eliminar = os.path.join(root, file)
            os.remove(archivo_a_eliminar)
            print(f"Se eliminó: {archivo_a_eliminar}")


# Cambia nombre de cada archivo dentro del directorio a un valor secuencial

 def cambiar_nombres_directorios(self,directorio):
   for clase,[directorio,etiquetas] in(directorio.items()):
     lista_directorio=os.listdir(directorio)
     self._cambiarNombre(directorio,clase)
     print(directorio)


 def _cambiarNombre(self,directorios,subfijo):
  archivos_en_directorio = os.listdir(directorios)
  for i, archivo in enumerate(archivos_en_directorio, start=1):
    # Construir el nuevo nombre del archivo
    nuevo_nombre = f"{subfijo}{i}{os.path.splitext(archivo)[1]}"

    # Ruta completa del archivo antiguo y nuevo
    ruta_antigua = os.path.join(directorios, archivo)
    ruta_nueva = os.path.join(directorios, nuevo_nombre)

    # Cambiar el nombre del archivo
    os.rename(ruta_antigua, ruta_nueva)
    print(f"Se cambió el nombre de {ruta_antigua} a {ruta_nueva}")


#Obtiene la cantidad de elemntos que tiene la carpeta

 def len_directorio(self,directorio):
    cantidad_elementos = sum(1 for elemento in os.listdir(directorio) if os.path.isfile(os.path.join(directorio, elemento)))
    return cantidad_elementos


#----------------------------------------------------------------------------------------------

#Valida si la imagen se puede leer usando  pill o cv2 si no se puede leer se elimina

 def validar_Img_Pill(self,directorio,):
  for etiqueta,[directorio,clase] in(directorio.items()):

    lista_paths=os.listdir(directorio)
    self._validarLecturaImgPill(directorio,lista_paths)
  print(f"Se ah validado todas las imagenes")

 def validar_Img_cv2(self,directorio):
  for etiqueta,[directorio,clase] in(directorio.items()):

    lista_paths=os.listdir(directorio)
    self._validarLecturaImg(directorio,lista_paths)
  print(f"Se ah validado todas las imagenes")

 def _validarLecturaImg(self,directorio,lista):

  for ruta in(lista):
   imagen=cv2.imread(directorio+ruta)
   if  imagen is None:
     os.remove(directorio+ruta)
     print(f"No se pudo leer y se elimino archivo:{directorio+ruta}")

 def _validarLecturaImgPill(self,directorio,lista):
    for ruta in(lista):
     try:
      imagen=Image.open(directorio+ruta)
     except Exception as e:
      os.remove(directorio+ruta)
      print(f"Archivo '{directorio+ruta}' eliminado.")



#vamos a recorrer el dicionario y validar ruta por ruta si se puede leer sino se elminara
#vamos guaradno al mismo tiempo 3 listas, los directorios , listas de paths de los directiros y de las clases ,para usarlo luego usarlo al crear el csv

 def separar_datos_directorios(self,directorios):
  listas_directorios=[]
  listas_listas_directorios=[]
  listas_clases=[]

  for etiqueta,[directorio,clase] in(directorios.items()):

       lista_paths=os.listdir(directorio)
       listas_directorios.append(directorio)
       listas_listas_directorios.append(lista_paths)
       listas_clases.append(clase)

  return listas_directorios,listas_listas_directorios,listas_clases

 def emparejar_listas_paths(self,lista_listas):

   #Tomamos el minimo tamaño dentro de las lista de cada clase
   tamaño_minimo = min(len(arr) for arr in lista_listas)

   #Vamos a emparejar todas las listas con un tamaño igual que sea la del minimo tamaño de todas,esto para tener un set de datos parejo por cada clase
   Reducido_lista_paths=[]

   #Reduce cada lista de los paths a la cantidad minimo para que todos tenga iaugal cantidad
   for listas in(lista_listas):
    Reducido_lista_paths.append(listas[:tamaño_minimo])

   return Reducido_lista_paths
#---------------------------------------------------------------------------------


 def crear_paths_csv(self,directorio_base,lista_paths,clases,nombre_archivo):

   columnas=["path","etiqueta"]
   datos_csv=[]

   for dir_base,dir_path,clase in  zip(directorio_base,lista_paths,clases):

    for path  in (dir_path):

     datos_csv.append([dir_base+path ,clase])


   df_lista=pd.DataFrame(datos_csv,columns=columnas)
   df_lista=df_lista.sort_values(by='path')
   df_lista.to_csv(nombre_archivo,index=False)
   print("Csv Creado")
#---------------------------------------------------------------------------------

#devuelve cuatnos elemtnos tiene cada clase
 def total_elementos(self,directorio,csv_path):
    df=pd.read_csv(csv_path)
    for clase,[directorio,etiqueta] in (directorio.items()):
     tamaño_etiqueta=(df["etiqueta"] == etiqueta).sum()
     print(f"la clase {clase} tiene :{tamaño_etiqueta} elementos")


#-------------------------------------------------------------------------------------------------

  #Funciones para data aumentation
 def   data_aumentation_conjunto(self,input_imagen_folder,output_path_folder,iteraciones,transformaciones,keepname=False):  #ingresa trnasformacioens como compose donde se aplicara las trasnfomracioens conjutnos pero se repteira un numero de veces por cada imagen

   for filename in os.listdir(input_imagen_folder):

    if filename.endswith('.jpg') or filename.endswith('.png'):

        input_path = os.path.join(input_imagen_folder, filename)
        if(keepname==False):
         output_path = os.path.join(output_path_folder, f'transformed_{filename}')
        else:
          output_path = os.path.join(output_path_folder, f'{filename}')
        # Aplica las transformaciones
        print(output_path)
        self._apply_transfomaciones_conjunto_it(input_path,output_path,int(iteraciones),transformaciones,keepname)


 def   data_aumentation_individual(self,input_imagen_folder,output_path_folder,transformaciones,keepname=False):  #las trnasfomaciones solo pasaremos la lista ya que ira aplicando la transformacion una por una por cada imagen

  for filename in os.listdir(input_imagen_folder):

    if filename.endswith('.jpg') or filename.endswith('.png'):
        input_path = os.path.join(input_imagen_folder, filename)
        if(keepname==False):
         output_path = os.path.join(output_path_folder, f'transformed_{filename}')
         print("opasasmos")
        else:
          output_path = os.path.join(output_path_folder, f'{filename}')
        # Aplica las transformaciones
        self._apply_transfomaciones_conjunto(input_path,output_path,transformaciones,keepname)



 def _apply_transfomaciones_conjunto_it(self,input_imagen_path,output_iamgen_path,iteraciones,transformations=None,keepname=False): #aplica las transfomracioens  conjutas por iteracion y se guarda las iamgenes

   imagen=Image.open(input_imagen_path).convert("RGB")


   for i in range(iteraciones):
      imagen_trasformada=transformations(imagen)

      out_root, out_extension = os.path.splitext(output_iamgen_path)
      if(keepname==False):
       imagen_trasformada.save(f"{out_root}_{i}{out_extension}")
      else:
        imagen_trasformada.save(f"{out_root}{out_extension}")

 def _apply_transfomaciones_conjunto(self,input_imagen_path,output_iamgen_path,transformations=None,keepname=False): #aplica las transfomracioens individuales  y se guarda las iamgenes

  imagen=Image.open(input_imagen_path).convert("RGB")

  for i,transformacion in enumerate(transformations):
   imagen_transformada=transformacion(imagen)
   out_root, out_extension = os.path.splitext(output_iamgen_path)
   if(keepname==False):
     imagen_transformada.save(f"{out_root}_{i}{out_extension}")
   else:
      imagen_transformada.save(f"{out_root}{out_extension}")

# %%
#Creamos las carpetas con las imagenes en hr y lw

#Creamos los arhcivo baja resolucion aparitr de imangenes alta resoulcion en hr , estos archios iran a carpaeta lw
directorio_in="/content/dataset/paisajes"
directorio_out="/content/imagenes/"

#antes de otrogar mediads de hr y lw , chekea como el generador va votando las resolucioens hr_fake segun la resolucion lw que especifics tiene qeu conicidr
#ya que el discriminador necsita la misma medidades tanto para el hr y el hr_fake que genera el generador

transformaciones=transforms.Compose([
transforms.Resize((512,512)),

])




datasetmanage=DataSetManage()
datasetmanage.data_aumentation_conjunto(directorio_in,directorio_out,1,transformaciones)
# Out:
# /content/imagenes/transformed_Image_24.jpg
# /content/imagenes/transformed_Image_6.jpg
# /content/imagenes/transformed_Image_138.jpg
# /content/imagenes/transformed_Image_27.jpg
# /content/imagenes/transformed_Image_134.jpg
# /content/imagenes/transformed_Image_110.jpg
# /content/imagenes/transformed_Image_81.jpg
# /content/imagenes/transformed_Image_131.jpg
# /content/imagenes/transformed_Image_118.jpg
# /content/imagenes/transformed_Image_2.jpg
# /content/imagenes/transformed_Image_121.jpg
# /content/imagenes/transformed_Image_126.jpg
# /content/imagenes/transformed_Image_97.jpg
# /content/imagenes/transformed_Image_19.jpg
# /content/imagenes/transformed_Image_149.jpg
# /content/imagenes/transformed_Image_107.jpg
# /content/imagenes/transformed_Image_109.jpg
# /content/imagenes/transformed_Image_89.jpg
# /content/imagenes/transformed_Image_20.jpg
# /content/imagenes/transformed_Image_91.jpg
# /content/imagenes/transformed_Image_31.jpg
# /content/imagenes/transformed_Image_104.jpg
# /content/imagenes/transformed_Image_30.jpg
# /content/imagenes/transformed_Image_120.jpg
# /content/imagenes/transformed_Image_67.jpg
# /content/imagenes/transformed_Image_75.jpg
# /content/imagenes/transformed_Image_127.jpg
# /content/imagenes/transformed_Image_108.jpg
# /content/imagenes/transformed_Image_106.jpg
# /content/imagenes/transformed_Image_87.jpg
# /content/imagenes/transformed_Image_133.jpg
# /content/imagenes/transformed_Image_9.jpg
# /content/imagenes/transformed_Image_78.jpg
# /content/imagenes/transformed_Image_70.jpg
# /content/imagenes/transformed_Image_98.jpg
# /content/imagenes/transformed_Image_105.jpg
# /content/imagenes/transformed_Image_55.jpg
# /content/imagenes/transformed_Image_148.jpg
# /content/imagenes/transformed_Image_141.jpg
# /content/imagenes/transformed_Image_39.jpg
# /content/imagenes/transformed_Image_37.jpg
# /content/imagenes/transformed_Image_22.jpg
# /content/imagenes/transformed_Image_74.jpg
# /content/imagenes/transformed_Image_132.jpg
# /content/imagenes/transformed_Image_129.jpg
# /content/imagenes/transformed_Image_147.jpg
# /content/imagenes/transformed_Image_44.jpg
# /content/imagenes/transformed_Image_94.jpg
# /content/imagenes/transformed_Image_40.jpg
# /content/imagenes/transformed_Image_4.jpg
# /content/imagenes/transformed_Image_45.jpg
# /content/imagenes/transformed_Image_93.jpg
# /content/imagenes/transformed_Image_34.jpg
# /content/imagenes/transformed_Image_32.jpg
# /content/imagenes/transformed_Image_14.jpg
# /content/imagenes/transformed_Image_103.jpg
# /content/imagenes/transformed_Image_57.jpg
# /content/imagenes/transformed_Image_102.jpg
# /content/imagenes/transformed_Image_49.jpg
# /content/imagenes/transformed_Image_12.jpg
# /content/imagenes/transformed_Image_83.jpg
# /content/imagenes/transformed_Image_66.jpg
# /content/imagenes/transformed_Image_35.jpg
# /content/imagenes/transformed_Image_137.jpg
# /content/imagenes/transformed_Image_151.jpg
# /content/imagenes/transformed_Image_54.jpg
# /content/imagenes/transformed_Image_125.jpg
# /content/imagenes/transformed_Image_143.jpg
# /content/imagenes/transformed_Image_10.jpg
# /content/imagenes/transformed_Image_101.jpg
# /content/imagenes/transformed_Image_90.jpg
# /content/imagenes/transformed_Image_113.jpg
# /content/imagenes/transformed_Image_80.jpg
# /content/imagenes/transformed_Image_92.jpg
# /content/imagenes/transformed_Image_41.jpg
# /content/imagenes/transformed_Image_142.jpg
# /content/imagenes/transformed_Image_5.jpg
# /content/imagenes/transformed_Image_128.jpg
# /content/imagenes/transformed_Image_43.jpg
# /content/imagenes/transformed_Image_117.jpg
# /content/imagenes/transformed_Image_114.jpg
# /content/imagenes/transformed_Image_17.jpg
# /content/imagenes/transformed_Image_82.jpg
# /content/imagenes/transformed_Image_64.jpg
# /content/imagenes/transformed_Image_18.jpg
# /content/imagenes/transformed_Image_33.jpg
# /content/imagenes/transformed_Image_48.jpg
# /content/imagenes/transformed_Image_86.jpg
# /content/imagenes/transformed_Image_68.jpg
# /content/imagenes/transformed_Image_77.jpg
# /content/imagenes/transformed_Image_3.jpg
# /content/imagenes/transformed_Image_96.jpg
# /content/imagenes/transformed_Image_130.jpg
# /content/imagenes/transformed_Image_36.jpg
# /content/imagenes/transformed_Image_76.jpg
# /content/imagenes/transformed_Image_100.jpg
# /content/imagenes/transformed_Image_21.jpg
# /content/imagenes/transformed_Image_16.jpg
# /content/imagenes/transformed_Image_140.jpg
# /content/imagenes/transformed_Image_123.jpg
# /content/imagenes/transformed_Image_52.jpg
# /content/imagenes/transformed_Image_28.jpg
# /content/imagenes/transformed_Image_7.jpg
# /content/imagenes/transformed_Image_150.jpg
# /content/imagenes/transformed_Image_47.jpg
# /content/imagenes/transformed_Image_13.jpg
# /content/imagenes/transformed_Image_8.jpg
# /content/imagenes/transformed_Image_99.jpg
# /content/imagenes/transformed_Image_1.jpg
# /content/imagenes/transformed_Image_58.jpg
# /content/imagenes/transformed_Image_61.jpg
# /content/imagenes/transformed_Image_116.jpg
# /content/imagenes/transformed_Image_139.jpg
# /content/imagenes/transformed_Image_51.jpg
# /content/imagenes/transformed_Image_23.jpg
# /content/imagenes/transformed_Image_146.jpg
# /content/imagenes/transformed_Image_11.jpg
# /content/imagenes/transformed_Image_144.jpg
# /content/imagenes/transformed_Image_73.jpg
# /content/imagenes/transformed_Image_136.jpg
# /content/imagenes/transformed_Image_145.jpg
# /content/imagenes/transformed_Image_29.jpg
# /content/imagenes/transformed_Image_71.jpg
# /content/imagenes/transformed_Image_115.jpg
# /content/imagenes/transformed_Image_38.jpg
# /content/imagenes/transformed_Image_53.jpg
# /content/imagenes/transformed_Image_95.jpg
# /content/imagenes/transformed_Image_65.jpg
# /content/imagenes/transformed_Image_119.jpg
# /content/imagenes/transformed_Image_69.jpg
# /content/imagenes/transformed_Image_50.jpg
# /content/imagenes/transformed_Image_72.jpg
# /content/imagenes/transformed_Image_46.jpg
# /content/imagenes/transformed_Image_63.jpg
# /content/imagenes/transformed_Image_25.jpg
# /content/imagenes/transformed_Image_15.jpg
# /content/imagenes/transformed_Image_62.jpg
# /content/imagenes/transformed_Image_26.jpg

# %%
dmg=DataSetManage()
directoriolw={
     "img":["/content/imagenes/",1],
}



listas_directorios,listas_paths_directorios,listas_clases=dmg.separar_datos_directorios(directoriolw)
Dataset_csv="dataset.csv" #nombre que tenda nuestlo csv
dmg.crear_paths_csv(listas_directorios,listas_paths_directorios,listas_clases,Dataset_csv)
# Out:
# Csv Creado

# %%
#DEFNIIR DISPOSITIVO:
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("CUDA está disponible.")
    device = torch.device("cuda")
else:
    print("CUDA no está disponible. Se utilizará la CPU.")
    device = torch.device("cpu")
# Out:
# CUDA no está disponible. Se utilizará la CPU.

# %%
#@markdown # *2) ** Creacion de clase DATASET(OBLIGATORIO)
import torch
from torch.utils.data import Dataset,DataLoader
import pandas as pd
import numpy as np
import cv2
from PIL import Image
from skimage.color import rgb2lab, lab2rgb

class MiDataSet(Dataset):
    def __init__(self, csv, transform=None):
        self.data = pd.read_csv(csv)
        self.path = self.data["path"]
        self.samples = self.data["path"].shape[0]
        self.transform = transform

    def __getitem__(self, idx):
        ruta = self.path[idx]

        # Abrir la imagen
        img = Image.open(ruta).convert("RGB")

        l_channel,ab_channel =self.rgb_a_lab(img)

        #normalizar:
        ab_channel_normalizado=(((ab_channel+ 128) / 255) * 2) - 1  #normalizado ab que va de -128 a 127  a un rango -1 a 1 para que conicida con la salida de generador
        l_channel_normalizado=l_channel/100 #normalizado l que va de 0-100 a un  rango 0-1

        if self.transform:
            l_tensor= self.transform(l_channel_normalizado)
            ab_tensor = self.transform(ab_channel_normalizado)

        return l_tensor, ab_tensor

    def __len__(self):
        return self.samples

    def rgb_a_lab(self,img):

      lab_image=rgb2lab(img)

      # Separa los canales L y AB
      l_channel = lab_image[:,:, 0]
      ab_channel=lab_image[:,:, 1:]


      return l_channel,ab_channel

    def lab_a_rgb(self,l,ab):
      rgb_image=np.zeros((256,256,3))
      rgb_image[:,:,0]=l
      rgb_image[:,:,1:]=ab
      return lab2rgb(rgb_image)

# %%
 from PIL import Image
 img = Image.open("/content/imagenes/transformed_Image_3_0.jpg")
 array_img=np.array(img)

 lab_image=rgb2lab(img)
 l=lab_image[:,:,0]
 ab=lab_image[:,:,1:]


 print(np.max(ab))
# Out:
# 62.35266326525624

# %%
#CREANDO DATASETS Y DATALOADERS:
from skimage.color import lab2rgb
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
import torch
from torchvision import datasets, transforms

transformaciones = transforms.Compose([
    transforms.ToTensor(),

])

batch_size=15




dataset =MiDataSet("/content/dataset.csv",transformaciones)
data_loader=DataLoader(dataset,batch_size=batch_size)

l1,ab=dataset.__getitem__(2)

ab_desnormalizado=((((ab+1)/2)*255))-128

l1_desnormalizado=l1*100

#Estructura imagen sera la variable que usaremos como base donde se pondra cada canal l ab

estructura_imagen=np.zeros((512, 512, 3))

#Visualisando

l1 = l1_desnormalizado.squeeze().numpy()
ab = ab_desnormalizado.squeeze().permute(1, 2, 0).numpy()

# Visualizar la imagen generada
# Subfigura l1
plt.subplot(1, 3, 1)
plt.imshow(l1,cmap='gray')
plt.title('l1')

# Subfigura ab
plt.subplot(1, 3, 2)

img_ab = estructura_imagen # crea un array de ceros para la imagen RGB
img_ab[:,:,1:] = ab
plt.imshow(img_ab)
plt.title('ab')


# Subfigura rgb
plt.subplot(1, 3, 3)

img_rgb = estructura_imagen  # crea un array de ceros para la imagen RGB
img_rgb[:,:,0]=l1
img_rgb[:,:,1:] = ab

plt.imshow(lab2rgb(img_rgb))
plt.title('rgb')

# Ajustar diseño
plt.tight_layout()

# Mostrar las imágenes
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#@markdown # *0) ** Creando clase Discriminadora:

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
from torch.utils.data import Dataset,DataLoader
import torchvision.transforms as transforms
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as F

class cnnBlock(nn.Module):
  def __init__(self,in_channels,out_channels,stride=2):
   super(cnnBlock,self).__init__()
   self.conv=nn.Sequential(
         nn.Conv2d(in_channels,out_channels,4,stride,padding=1),
         nn.BatchNorm2d(out_channels),
         nn.LeakyReLU(0.2),
     )
  def forward(self,x):
    return self.conv(x)

class Discriminator (nn.Module):
  def __init__(self):
   super(Discriminator,self).__init__()

   self.inicial=nn.Sequential(
                           nn.Conv2d(3,64,4,2,1),
                           nn.LeakyReLU(0.2),
                        )

   self.cnnblock1=cnnBlock(64,128)
   self.cnnblock2=cnnBlock(128,256)
   self.cnnblock3=cnnBlock(256,512,stride=1)

   self.lastconv= nn.Conv2d(512,1,4,1,1)


  def forward(self,x,y):

    x=torch.cat([x,y],dim=1)

    x=self.inicial(x)
    x=self.cnnblock1(x)
    x=self.cnnblock2(x)
    x=self.cnnblock3(x)

    x=self.lastconv(x)
    out=torch.sigmoid(x)

    return out

# %%
d=Discriminator()
x = torch.randn(2, 1, 256, 256)  # Ejemplo de tensor x con 3 canales
y = torch.randn(2, 2, 256, 256)  # Ejemplo de tensor y con 5 canales

# Concatenar los tensores x e y a lo largo de la dimensión de los canales
ju=d(x,y)
print(ju.shape)
# Out:
# torch.Size([2, 1, 30, 30])

# %%
discriminador=Discriminator()
discriminador=discriminador.to(device)
x=torch.randn(20,3,256,256).to(device)
y=torch.randn(20,3,256,256).to(device)
print(discriminador(x,y).shape)
# Out:
# torch.Size([20, 1, 30, 30])

# %%
#@markdown # *2) ** GENERADOR U NET SIN SKIPS 256 X256 ENTRA L CANAL SALE 2 CANALES AB(OBLIGATORIO)
import torch.nn.functional as F
import torch.nn as nn
#---------------------GENERADOR BASADO EN U- NET---------------------------------------------------

import torch.nn.functional as F

#input debe ser 256x256 otras dimeneoins  puede que tenega eror al mometno de concat las dimenes reducidas debe de conicidir y este unetblacok se ajsuta a una etnrada 256x256
class U_Net_block(nn.Module):

  def __init__(self,in_channel,out_channel,type,activacion="leakyrelu",dropout_on="False"):
   super(U_Net_block,self).__init__()

   if type=="down" :

    self.block=nn.Conv2d(in_channel,out_channel,kernel_size=4,stride=2,padding=1,bias=False)

   elif type=="up":

    self.block=nn.Conv2d(in_channel,out_channel,kernel_size=3,stride=1,padding=1,bias=False)

   self.batchnorm=nn.BatchNorm2d(out_channel)

   self.activacion=activacion
   self.leakyrelu=nn.LeakyReLU(0.2)
   self.relu=nn.ReLU()

   self.dropout_on=dropout_on # solo si necsitmos usar el dropout

   self.dropout=nn.Dropout(0.5)

  def forward(self,x):

     x=self.block(x)
     x=self.batchnorm(x)

     if(self.activacion=="leakyrelu"):
      out=self.leakyrelu(x)
     else:
      out=self.relu(x)

     if(self.dropout_on==True):
      out=self.dropout(x)

     return out


class Generator_U_Net(nn.Module):

    def __init__(self,in_channel=3):
        super(Generator_U_Net,self).__init__()

        # Encoder Seccion:

        self.inicial=nn.Sequential(
            nn.Conv2d(in_channel,64,kernel_size=4,stride=2,padding=1,bias=False), # primer bloque convolucional down no tiene batchnorm
            nn.LeakyReLU(0.2)
        )


        self.encoder1=U_Net_block(64,128,"down",activacion="leakyrelu")
        self.encoder2=U_Net_block(128,256,"down",activacion="leakyrelu")
        self.encoder3=U_Net_block(256,512,"down",activacion="leakyrelu")
        self.encoder4=U_Net_block(512,512,"down",activacion="leakyrelu")
        self.encoder5=U_Net_block(512,512,"down",activacion="leakyrelu")
        self.encoder6=U_Net_block(512,512,"down",activacion="leakyrelu")
        self.encoder7=U_Net_block(512,512,"down",activacion="leakyrelu")


        # Decoder Seccion:


        self.decoder1=U_Net_block(512,512,"up",activacion="relu")
        self.decoder2=U_Net_block(512,512,"up",activacion="relu")
        self.decoder3=U_Net_block(512,512,"up",activacion="relu")
        self.decoder4=U_Net_block(512,256,"up",activacion="relu")
        self.decoder5=U_Net_block(256,128,"up",activacion="relu")
        self.decoder6=U_Net_block(128,64,"up",activacion="relu")
        self.decoder7=U_Net_block(64,64,"up",activacion="relu")

        # Last
        self.convlast=nn.Conv2d(64,256,kernel_size=3,stride=1,padding=1,bias=False)
        self.extra=nn.Conv2d(256,2,kernel_size=3,stride=1,padding=1,bias=False)

        self.than=nn.Tanh()


    def forward(self,x):

        d1=self.inicial(x) # d1 ->64 out
        d2=self.encoder1(d1) # d2 ->128 out
        d3=self.encoder2(d2) # d3 ->256 out
        d4=self.encoder3(d3) # d4 ->512 out
        d5=self.encoder4(d4) # d5 ->512 out
        d6=self.encoder5(d5) # d6 ->512 out
        d7=self.encoder6(d6) # d7 ->512 out
        d8=self.encoder6(d7) # d7 ->512 out


        e1=self.decoder1(d8) #e1 -> 512 out
        e1=F.interpolate(e1,scale_factor=2, mode='bilinear', align_corners=False)
        e2=self.decoder2(e1) # e2  in ->512+512=1024  out->512
        e2=F.interpolate(e2,scale_factor=2, mode='bilinear', align_corners=False)

        e3=self.decoder3(e2) # e3  in ->512+512=1024   out->512
        e3=F.interpolate(e3,scale_factor=2, mode='bilinear', align_corners=False)

        e4=self.decoder4(e3) # e4 in ->512+512=1024   out->512
        e4=F.interpolate(e4,scale_factor=2, mode='bilinear', align_corners=False)

        e5=self.decoder5(e4)# e5 in ->512+512=1024    out->256
        e5=F.interpolate(e5,scale_factor=2, mode='bilinear', align_corners=False)

        e6=self.decoder6(e5) # e6 in ->256+256=512   out->128
        e6=F.interpolate(e6,scale_factor=2, mode='bilinear', align_corners=False)

        e7=self.decoder7(e6)
        e7=F.interpolate(e7,scale_factor=2, mode='bilinear', align_corners=False)

        out=self.convlast(e7) # last in 64+64  out->3
        out=F.interpolate(out,scale_factor=2, mode='bilinear', align_corners=False)
        out=self.extra(out)
        out=self.than(out)

        return out

# %%
#@markdown # *2) ** GENERADOR 256 X256 ENTRA L CANAL SALE 2 CANALES AB(OBLIGATORIO)

#---------------------GENERADOR BASADO EN U- NET---------------------------------------------------

import torch.nn.functional as F
import torch.nn as nn

#input debe ser 80x80 otras dimeneoins  puede que tenega eror al mometno de concat las dimenes reducidas debe de conicidir y este unetblacok se ajsuta a una etnrada 256x256
class U_Net_block(nn.Module):

  def __init__(self,in_channel,out_channel,type,btchnm=True,activacion="leakyrelu",dropout_on="False"):
   super(U_Net_block,self).__init__()

   self.type=type
   self.blockdown=nn.Conv2d(in_channel,out_channel,kernel_size=4,stride=2,padding=1,bias=False)
   self.blockup=nn.Conv2d(in_channel,out_channel,kernel_size=3,stride=1,padding=1,bias=False)
   self.batchnorm=nn.BatchNorm2d(out_channel)

   self.activacion=activacion
   self.leakyrelu=nn.LeakyReLU(0.2)
   self.relu=nn.ReLU()
   self.btchnm_on=btchnm
   self.btchnorm=nn.BatchNorm2d(out_channel)
   self.dropout_on=dropout_on # solo si necsitmos usar el dropout

   self.dropout=nn.Dropout(0.5)

  def forward(self,x):

    if self.type=="down" :
     x=self.blockdown(x)

    elif self.type=="up":
     x=self.blockup(x)
     x=F.interpolate(x,scale_factor=2, mode='bilinear', align_corners=False)


    if self.btchnm_on==True:
     x=self.btchnorm(x)

    if(self.activacion=="leakyrelu"):
      out=self.leakyrelu(x)
    else:
      out=self.relu(x)

    if(self.dropout_on==True):
      out=self.dropout(x)

    return out


class Generator_U_Net(nn.Module):

    def __init__(self,in_channel=3):
        super(Generator_U_Net,self).__init__()

        # Encoder Seccion:

        self.inicial=U_Net_block(1,64,"down",btchnm=False,activacion="leakyrelu")


        self.encoder1=U_Net_block(64,128,"down",btchnm=True,activacion="leakyrelu")
        self.encoder2=U_Net_block(128,256,"down",btchnm=True,activacion="leakyrelu")
        self.encoder3=U_Net_block(256,512,"down",btchnm=True,activacion="leakyrelu")
        self.encoder4=U_Net_block(512,512,"down",btchnm=True,activacion="leakyrelu")
        self.encoder5=U_Net_block(512,512,"down",btchnm=True,activacion="leakyrelu")
        self.encoder6=U_Net_block(512,512,"down",btchnm=True,activacion="leakyrelu")

        self.bottleneck=U_Net_block(512,512,"down",btchnm=False,activacion="relu")

        # Decoder Seccion:


        self.decoder1=U_Net_block(512,512,"up",btchnm=True,activacion="relu")
        self.decoder2=U_Net_block(1024,512,"up",btchnm=True,activacion="relu")
        self.decoder3=U_Net_block(1024,512,"up",btchnm=True,activacion="relu")
        self.decoder4=U_Net_block(1024,512,"up",btchnm=True,activacion="relu")
        self.decoder5=U_Net_block(1024,256,"up",btchnm=True,activacion="relu")
        self.decoder6=U_Net_block(512,128,"up",btchnm=True,activacion="relu")
        self.decoder7=U_Net_block(256,64,"up",btchnm=True,activacion="relu")


        # Last
        self.convlast=U_Net_block(128,2,"up",btchnm=False,activacion="relu")

        self.than=nn.Tanh()


    def forward(self,x):

        d1=self.inicial(x) # d1 ->64 out
        d2=self.encoder1(d1) # d2 ->128 out
        d3=self.encoder2(d2) # d3 ->256 out
        d4=self.encoder3(d3) # d4 ->512 out
        d5=self.encoder4(d4) # d5 ->512 out
        d6=self.encoder5(d5) # d6 ->512 out
        d7=self.encoder6(d6) # d7 ->512 out

        bneck=self.bottleneck(d7)  #bneck -> 512 out

        e1=self.decoder1(bneck) #e1 -> 512 out

        e2=self.decoder2(torch.cat([e1,d7],1)) # e2  in ->512+512=1024  out->512

        e3=self.decoder3(torch.cat([e2,d6],1)) # e3  in ->512+512=1024   out->512

        e4=self.decoder4(torch.cat([e3,d5],1)) # e4 in ->512+512=1024   out->512

        e5=self.decoder5(torch.cat([e4,d4],1)) # e5 in ->512+512=1024    out->256

        e6=self.decoder6(torch.cat([e5,d3],1)) # e6 in ->256+256=512   out->128

        e7=self.decoder7(torch.cat([e6,d2],1)) # e7 in ->128+128=256  out->64

        out=self.convlast(torch.cat([e7,d1],1)) # last in 64+64  out->3

        out=self.than(out)

        return out

# %%
#@markdown # *2) ** GENERADOR 512 X512 ENTRA L CANAL SALE 2 CANALES AB(OBLIGATORIO)

#---------------------GENERADOR BASADO EN U- NET---------------------------------------------------

import torch.nn.functional as F
import torch.nn as nn

#input debe ser 80x80 otras dimeneoins  puede que tenega eror al mometno de concat las dimenes reducidas debe de conicidir y este unetblacok se ajsuta a una etnrada 256x256
class U_Net_block(nn.Module):

  def __init__(self,in_channel,out_channel,type,btchnm=True,activacion="leakyrelu",dropout_on="False"):
   super(U_Net_block,self).__init__()

   self.type=type
   self.blockdown=nn.Conv2d(in_channel,out_channel,kernel_size=4,stride=2,padding=1,bias=False)
   self.blockup=nn.Conv2d(in_channel,out_channel,kernel_size=3,stride=1,padding=1,bias=False)
   self.batchnorm=nn.BatchNorm2d(out_channel)

   self.activacion=activacion
   self.leakyrelu=nn.LeakyReLU(0.2)
   self.relu=nn.ReLU()
   self.btchnm_on=btchnm
   self.btchnorm=nn.BatchNorm2d(out_channel)
   self.dropout_on=dropout_on # solo si necsitmos usar el dropout

   self.dropout=nn.Dropout(0.5)

  def forward(self,x):

    if self.type=="down" :
     x=self.blockdown(x)

    elif self.type=="up":
     x=self.blockup(x)
     x=F.interpolate(x,scale_factor=2, mode='bilinear', align_corners=False)


    if self.btchnm_on==True:
     x=self.btchnorm(x)

    if(self.activacion=="leakyrelu"):
      out=self.leakyrelu(x)
    else:
      out=self.relu(x)

    if(self.dropout_on==True):
      out=self.dropout(x)

    return out


class Generator_U_Net(nn.Module):

    def __init__(self,in_channel=3):
        super(Generator_U_Net,self).__init__()

        # Encoder Seccion:

        self.inicial=U_Net_block(1,32,"down",btchnm=False,activacion="leakyrelu")
        self.segundo=U_Net_block(32,32,"down",btchnm=True,activacion="leakyrelu")
        self.encoder1=U_Net_block(32,128,"down",btchnm=True,activacion="leakyrelu")
        self.encoder2=U_Net_block(128,256,"down",btchnm=True,activacion="leakyrelu")
        self.encoder3=U_Net_block(256,512,"down",btchnm=True,activacion="leakyrelu")
        self.encoder4=U_Net_block(512,512,"down",btchnm=True,activacion="leakyrelu")
        self.encoder5=U_Net_block(512,512,"down",btchnm=True,activacion="leakyrelu")
        self.encoder6=U_Net_block(512,512,"down",btchnm=True,activacion="leakyrelu")
        self.encoder7=U_Net_block(512,512,"down",btchnm=True,activacion="leakyrelu")

        self.bottleneck=U_Net_block(512,512,"down",btchnm=False,activacion="relu")

        # Decoder Seccion:


        self.decoder1=U_Net_block(512,512,"up",btchnm=True,activacion="relu")
        self.decoder2=U_Net_block(1024,512,"up",btchnm=True,activacion="relu")
        self.decoder3=U_Net_block(1024,512,"up",btchnm=True,activacion="relu")
        self.decoder4=U_Net_block(1024,512,"up",btchnm=True,activacion="relu")
        self.decoder5=U_Net_block(1024,256,"up",btchnm=True,activacion="relu")
        self.decoder6=U_Net_block(512,128,"up",btchnm=True,activacion="relu")
        self.decoder7=U_Net_block(256,64,"up",btchnm=True,activacion="relu")
        self.decoder8=U_Net_block(96,32,"up",btchnm=True,activacion="relu")

        # Last
        self.convlast=U_Net_block(64,2,"up",btchnm=False,activacion="relu")

        self.than=nn.Tanh()


    def forward(self,x):

        d0=self.inicial(x) # d1 ->64 out
        d1=self.segundo(d0) # d1 ->64 out

        d2=self.encoder1(d1) # d2 ->128 out
        d3=self.encoder2(d2) # d3 ->256 out
        d4=self.encoder3(d3) # d4 ->512 out
        d5=self.encoder4(d4) # d5 ->512 out
        d6=self.encoder5(d5) # d6 ->512 out
        d7=self.encoder6(d6) # d7 ->512 out

        bneck=self.bottleneck(d7)  #bneck -> 512 out

        e1=self.decoder1(bneck) #e1 -> 512 out

        e2=self.decoder2(torch.cat([e1,d7],1)) # e2  in ->512+512=1024  out->512

        e3=self.decoder3(torch.cat([e2,d6],1)) # e3  in ->512+512=1024   out->512

        e4=self.decoder4(torch.cat([e3,d5],1)) # e4 in ->512+512=1024   out->512

        e5=self.decoder5(torch.cat([e4,d4],1)) # e5 in ->512+512=1024    out->256

        e6=self.decoder6(torch.cat([e5,d3],1)) # e6 in ->256+256=512   out->128

        e7=self.decoder7(torch.cat([e6,d2],1)) # e7 in ->128+128=256  out->64
        e8=self.decoder8(torch.cat([e7,d1],1)) # e7 in ->128+128=256  out->64

        out=self.convlast(torch.cat([e8,d0],1)) # last in 64+64  out->3

        out=self.than(out)

        return out

# %%
#@markdown # *2) ** Prototipo WaveNet GENERADOR 256x256 ENTRA L CANAL SALE 2 CANALES AB(OBLIGATORIO)

#---------------------GENERADOR BASADO EN U- NET---------------------------------------------------

import torch.nn.functional as F
import torch.nn as nn

#input debe ser 80x80 otras dimeneoins  puede que tenega eror al mometno de concat las dimenes reducidas debe de conicidir y este unetblacok se ajsuta a una etnrada 256x256
class U_Net_block(nn.Module):

  def __init__(self,in_channel,out_channel,type,btchnm=True,activacion="leakyrelu",dropout_on="False"):
   super(U_Net_block,self).__init__()

   self.type=type
   self.blockdown=nn.Conv2d(in_channel,out_channel,kernel_size=4,stride=2,padding=1,bias=False)
   self.blockup=nn.Conv2d(in_channel,out_channel,kernel_size=3,stride=1,padding=1,bias=False)
   self.batchnorm=nn.BatchNorm2d(out_channel)

   self.activacion=activacion
   self.leakyrelu=nn.LeakyReLU(0.2)
   self.relu=nn.ReLU()
   self.batch_on=btchnm
   self.batchnorm=nn.BatchNorm2d(out_channel)
   self.dropout_on=dropout_on # solo si necsitmos usar el dropout

   self.dropout=nn.Dropout(0.5)

  def forward(self,x):

    if self.type=="down" :
     x=self.blockdown(x)

    elif self.type=="up":
     x=self.blockup(x)
     x=F.interpolate(x,scale_factor=2, mode='bilinear', align_corners=False)


    if self.batch_on==True:
     x=self.batchnorm(x)

    if(self.activacion=="leakyrelu"):
      out=self.leakyrelu(x)
    else:
      out=self.relu(x)

    if(self.dropout_on==True):
      out=self.dropout(x)

    return out


class Generator_U_Net(nn.Module):

    def __init__(self,in_channel=3):
        super(Generator_U_Net,self).__init__()


        # Encoder Seccion:
        self.encoderInicial=U_Net_block(1,128,"down",btchnm=False,activacion="leakyrelu")

        self.decoder1=U_Net_block(128,64,"up",btchnm=True,activacion="relu")#matiene con le f.interpole luego se aumetara las dimiensionesx2
        self.encoder1=U_Net_block(64,128,"down",btchnm=True,activacion="leakyrelu") #128x128
        self.encoder2=U_Net_block(128,256,"down",btchnm=True,activacion="leakyrelu")#64x64

        self.decoder2=U_Net_block(256,128,"up",btchnm=True,activacion="relu")#128x128


        # Last
        self.decoderFinal=U_Net_block(128,2,"up",btchnm=False,activacion="relu")#matiene con le f.interpole luego se aumetara las dimiensionesx2

        self.than=nn.Tanh()


    def forward(self,x):

        inicial=self.encoderInicial(x)

        d1=self.decoder1(inicial)
        e1=self.encoder1(d1)
        e2=self.encoder2(e1)
        d2=self.decoder2(e2)

        out=self.decoderFinal(d2)
        out=self.than(out)

        return out

# %%
#@markdown # *2) ** Prototipo WaveNet GENERADOR 256x256 CON SKIP CONECTION ENTRA L CANAL SALE 2 CANALES AB(OBLIGATORIO)

#---------------------GENERADOR BASADO EN U- NET---------------------------------------------------

import torch.nn.functional as F
import torch.nn as nn

#input debe ser 80x80 otras dimeneoins  puede que tenega eror al mometno de concat las dimenes reducidas debe de conicidir y este unetblacok se ajsuta a una etnrada 256x256
class U_Net_block(nn.Module):

  def __init__(self,in_channel,out_channel,type,btchnm=True,activacion="leakyrelu",dropout_on="False"):
   super(U_Net_block,self).__init__()

   self.type=type
   self.blockdown=nn.Conv2d(in_channel,out_channel,kernel_size=4,stride=2,padding=1,bias=False)
   self.blockup=nn.Conv2d(in_channel,out_channel,kernel_size=3,stride=1,padding=1,bias=False)
   self.batchnorm=nn.BatchNorm2d(out_channel)

   self.activacion=activacion
   self.leakyrelu=nn.LeakyReLU(0.2)
   self.relu=nn.ReLU()
   self.batch_on=btchnm
   self.btchnorm=nn.BatchNorm2d(out_channel)
   self.dropout_on=dropout_on # solo si necsitmos usar el dropout

   self.dropout=nn.Dropout(0.5)

  def forward(self,x):

    if self.type=="down" :
     x=self.blockdown(x)

    elif self.type=="up":
     x=self.blockup(x)
     x=F.interpolate(x,scale_factor=2, mode='bilinear', align_corners=False)


    if self.batch_on==True:
     x=self.btchnorm(x)

    if(self.activacion=="leakyrelu"):
      out=self.leakyrelu(x)
    else:
      out=self.relu(x)

    if(self.dropout_on==True):
      out=self.dropout(x)

    return out


class Generator_U_Net(nn.Module):

    def __init__(self,in_channel=3):
        super(Generator_U_Net,self).__init__()


        # Encoder Seccion:
        self.encoderInicial=U_Net_block(1,128,"down",btchnm=False,activacion="leakyrelu")

        self.decoder1=U_Net_block(128,64,"up",btchnm=True,activacion="relu")#matiene con le f.interpole luego se aumetara las dimiensionesx2
        self.encoder1=U_Net_block(64,128,"down",btchnm=False,activacion="leakyrelu") #128x128
        self.encoder2=U_Net_block(256,256,"down",btchnm=False,activacion="leakyrelu")#64x64

        self.decoder2=U_Net_block(256,128,"up",btchnm=True,activacion="relu")#128x128


        # Last
        self.decoderFinal=U_Net_block(256,2,"up",btchnm=False,activacion="relu")#matiene con le f.interpole luego se aumetara las dimiensionesx2

        self.than=nn.Tanh()


    def forward(self,x):


        inicial=self.encoderInicial(x)

        d1=self.decoder1(inicial)
        e1=self.encoder1(d1)
        e2=self.encoder2(torch.cat([inicial,e1],1))
        d2=self.decoder2(e2)

        out=self.decoderFinal(torch.cat([inicial,d2],1))
        out=self.than(out)

        return out

# %%
#VAMOS A VER QUE MEDIADES EL GENERADOR DA COMO RESUTLADO CON LW RESOLUTIONS MEDIDAES:

generador=Generator_U_Net(1)
generador=generador.to(device)
x=torch.randn(20,1,512,512).to(device)

print(generador(x).shape)
# Out:
# torch.Size([20, 2, 512, 512])

# %%
#PROBAMOS EL GENERADOR INCIAL:

from PIL import Image
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt


#--------------------------------------------------------------------------------------------------------
def show_comparacion(real,generado): #deben de ingrenar don tennoren de imagen generada y real
 print(generado.shape)
 print(real.shape)
 real=real.detach().squeeze().cpu().numpy().transpose(1, 2, 0)
 generado=generado.squeeze().cpu().detach().numpy().transpose(1, 2, 0)
# Primer subgráfico: imagen original
 plt.subplot(1, 2, 1)
 plt.imshow(generado)  # Convertir a NumPy y transponer dimensiones
 plt.title('Imagen Generada')
 plt.axis('off')

# Segundo subgráfico: imagen transformada
 plt.subplot(1, 2, 2)
 plt.imshow(real)  # Convertir a NumPy y transponer dimensiones
 plt.title('Imagen Real')
 plt.axis('off')

# Ajustar el diseño para evitar superposición de títulos
 plt.tight_layout()

# Mostrar la figura
 plt.show()


 plt.figure(figsize=(10, 5))
#-----------------------------------------------------------------------------------
generador=Generator_U_Net().to("cpu")


ruta_imagen = "/content/imagenes/transformed_0002_0.png"
imagen = Image.open(ruta_imagen)

transformaciones = transforms.Compose([
    transforms.Resize((256,256)),
    transforms.ToTensor(),
])

#original iamgen tensor
tensor_imagen = transformaciones(imagen).unsqueeze(0)
tensor_imagen=tensor_imagen.to("cpu")

#imagen generada
imagen_generada=generador(tensor_imagen)
print(imagen_generada.shape)
imagen_numpy = imagen_generada.squeeze().detach().numpy()

# Mostrar la imagen utilizando matplotlib
plt.imshow(imagen_numpy.transpose(1, 2, 0))  # cmap='gray' es para mostrar la imagen en escala de grises
plt.axis('off')  # Ocultar ejes
plt.show()

# %%
from torchvision import models

#vamos a extraer los feature es decir las caracteisicas imporantes que exiten entre ambas imagnes y compraralas esto se usara par luego hace rel loss contet apartir del contendio

class Feature_Extractor(nn.Module):
    def __init__(self):
        super(Feature_Extractor, self).__init__()
        # Cargar un modelo VGG-19 preentrenado
        vgg19_model = models.vgg16(pretrained=True).features.eval()

        # No actualizar los pesos del modelo VGG durante el entrenamiento
        for param in vgg19_model.parameters():
            param.requires_grad = False

        selected_layers = list(vgg19_model.children())[:31] #AGREGAMOS EL VGG HASTA VERFICAR QUE EL ULITMA CAPA NO TENGA RELU

        self.vgg=nn.Sequential(*selected_layers)

    def forward(self, img):

        # Extraer características de las imágenes generada y real
        feature_img = self.vgg(img)

        return feature_img


# TV Loss se utiliza comúnmente en tareas de generación de imágenes para reducir el ruido y fomentar la suavidad en las imágenes generadas.

class TVLoss(nn.Module):
  def __init__(self, tv_loss_weight=1):
    super(TVLoss, self).__init__()
    self.tv_loss_weight=tv_loss_weight
  def forward(self, x):
    batch_size=x.size()[0]
    h_x = x.size()[2]
    w_x = x.size()[3]

    count_h = self.tensor_size(x[:, :, 1:, :])
    count_w = self.tensor_size(x[:, :, :, 1:])


    h_tv = torch.pow(x[:, :, 1:, :] - x[:, :, :h_x - 1, :], 2).sum()
    w_tv = torch.pow(x[:, :, :, 1:] - x[:, :, :, :w_x - 1], 2).sum()
    return self.tv_loss_weight * 2 * (h_tv / count_h + w_tv / count_w) / batch_size

  # Forgot to implement an important method
  @staticmethod # Must add this
  def tensor_size(t):
    return t.size()[1] * t.size()[2] * t.size()[3]


def psnr(image1, image2):
    mse = torch.mean((image1 - image2) ** 2)
    if mse == 0:
        return float('inf')
    max_pixel = 1
    psnr_value = 10 * torch.log10((max_pixel ** 2) / mse)
    return psnr_value

# %%
vgg=Feature_Extractor()
print(vgg)
tv_loss= TVLoss()
x=torch.randn(18,3,60,60)
tv_loss=tv_loss(x)

print(tv_loss)

# %%
import matplotlib.pyplot as plt
import torch
import numpy as np
import torchvision.utils as vutils
import sklearn
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset
from tqdm import tqdm
# ...

#d=Discriminator(image_dim).to(device)
#g=Generador(dim_vector_ruido,image_dim).to(device)

#d.load_state_dict(torch.load("/content/modelo_gatos_d.pt"))
#g.load_state_dict(torch.load("/content/modelo_gatos_g.pt"))

#d=d.to(device)
#g=g.to(device)


# Supongamos que ya has definido las instancias de los modelos Generador (g) y Discriminador (d),
# y has configurado los optimizadores (g_optimizer y d_optimizer) y la función de pérdida (criterio).



def GAN(discriminador, generador, data_loader, num_epochs, batch_size, criterio_g,criterio_d, d_optimizador, g_optimizador, device):

    discriminador=discriminador.to(device)
    generador=generador.to(device)
    feature_extractor=Feature_Extractor().to(device)
    tv_loss= TVLoss().to(device)
    L1=nn.L1Loss()

    for epoch in range(num_epochs):

        resultados = { 'd_loss':[],"g_loss":[], "d_score":[], "psnr":[]}
        data_loader = tqdm(data_loader)

        for  (l, ab) in (data_loader):

            l=l.float().to(device)
            ab=ab.float().to(device)

            generador.eval()
            discriminador.train()

            # Entrenar el discriminador con imágenes reales
            d_optimizador.zero_grad()

            prediction_real = discriminador(l.float(),ab)

            real_loss = criterio_d(prediction_real, torch.ones_like(prediction_real).to(device))


            # Entrenar el discriminador con imágenes generadas

            fake_ab = generador(l)

            prediction_fake = discriminador(l,fake_ab.float().detach())

            fake_loss = criterio_d(prediction_fake, torch.zeros_like(prediction_fake).to(device)).to(device)
            discriminator_loss = (real_loss + fake_loss)/2

            discriminator_loss.backward()

            d_optimizador.step()

            # Entrenar el generador
            generador.train()
            discriminador.eval()
            g_optimizador.zero_grad()

            generated_ab = generador(l.detach())

            d_fake=discriminador(l,generated_ab)

            loss_gan=criterio_g(d_fake,torch.ones_like(d_fake).to(device)) #loss del generador aparitr del disicmirnador que dice si es o no una imagen falsa
            loss_g=L1(ab,generated_ab)

            generator_loss = (100*loss_g)+loss_gan
            generator_loss.backward()
            g_optimizador.step()


            #resultados por batch:
            resultados["d_loss"].append(discriminator_loss.item())
            resultados["g_loss"].append(generator_loss.item())


            data_loader.set_description(desc="[%d/%d] Loss_D: %.4f Loss_G: %.4f psnr: %.4f" % (
            epoch, num_epochs, np.mean(resultados['d_loss']),
            np.mean(resultados['g_loss']) ,
            np.mean( resultados['psnr']) ,

              ))

        # Imprimir estadísticas y visualizar imágenes generadas al final de cada época
        print(f'Época [{epoch}/{num_epochs}] '
                      f'Pérdida del Discriminador: {np.mean(resultados["d_loss"]):.4f}, '
                      f'Pérdida del Generador: {np.mean(resultados["g_loss"]):.4f}',f'psnr:{np.mean(resultados["psnr"]):.4f}')
        with torch.no_grad():

            generador.eval()

            ab_test = generador(l).detach()

            generado_ab=ab_test[0].squeeze().cpu().detach().numpy().transpose(1, 2, 0)
            l_test = l[0].squeeze().cpu().numpy()
            ab_test=ab[0].squeeze().cpu().numpy().transpose(1, 2, 0)

            ab_test_desnormalizado=((((ab_test+1)/2)*255))-128
            ab_desnormalizado=((((generado_ab+1)/2)*255))-128
            l1_desnormalizado=l_test*100

            plt.figure(figsize=(20, 5))
            # Subfigura generada ab
            plt.subplot(1, 4, 1)
            img_rgb = estructura_imagen  # crea un array de ceros para la imagen RGB

            img_rgb[:,:,1:] =ab_desnormalizado
            plt.imshow(img_rgb)
            plt.title('imagen generada')

            # Subfigura generada rgb
            plt.subplot(1, 4, 2)
            img_rgb = estructura_imagen  # crea un array de ceros para la imagen RGB
            img_rgb[:,:,0]=l1_desnormalizado
            img_rgb[:,:,1:] =ab_desnormalizado
            plt.imshow(lab2rgb(img_rgb))
            plt.title('imagen generada')


            # Subfigura real ab
            plt.subplot(1, 4, 3)
            img_rgb2 = estructura_imagen  # crea un array de ceros para la imagen RGB
            #img_rgb2[:,:,0]=l1_desnormalizado
            img_rgb2[:,:,1:] = ab_test_desnormalizado
            plt.imshow(img_rgb2)
            plt.title('imagen real')

            # Subfigura real rgb
            plt.subplot(1, 4, 4)
            img_rgb2 = estructura_imagen  # crea un array de ceros para la imagen RGB
            img_rgb2[:,:,0]=l1_desnormalizado
            img_rgb2[:,:,1:] = ab_test_desnormalizado
            plt.imshow(lab2rgb(img_rgb2))
            plt.title('imagen real')

           # Ajustar diseño
            plt.tight_layout()

          # Mostrar las imágenes
            plt.show()



#--------------------------------------------------------------------------------------------



num_epochs=80





d=Discriminator()
g=Generator_U_Net(1)

#d.load_state_dict(torch.load("/content/colorgan_d.pt"))
#g.load_state_dict(torch.load("/content/colorgan_g.pt"))

lr_g = 0.000008
lr_d = 0.000008
d_optimizer=optim.Adam(d.parameters(),lr=lr_d, betas=(0.5, 0.999))
g_optimizer=optim.Adam(g.parameters(),lr=lr_g, betas=(0.5, 0.999))

criterio_d=nn.BCELoss()
criterio_g=nn.BCELoss()


print(f"learning rate discrimiador:{lr_d}")
print(f"learning rate generador:{lr_g}")

GAN(d,g,data_loader,num_epochs,batch_size,criterio_g,criterio_d,d_optimizer,g_optimizer,device)

# %%
torch.save(g.state_dict(), 'colorgan_g.pt')
torch.save(d.state_dict(), 'colorgan_d.pt')

# %%
data = []
while(1):
  data.append('1234')

# %%
torch.cuda.empty_cache()

# %%
d.load_state_dict(torch.load("/content/srgan_d.pt"))
# Out:
# <All keys matched successfully>

# %%
from PIL import Image
import skimage.io
# Suponiendo que "Generador" es la clase de tu generador y "ruta_modelo" es la ruta del modelo guardado
generador = Generator_U_Net(1)  # creando generado
generador.load_state_dict(torch.load("/content/colorgan_g.pt"))
generador.to(device)
generador.eval()

ruta_imagen = "/content/imagenes/transformed_Image_117_0.jpg"
imagen_pil = Image.open(ruta_imagen).convert("RGB")


lab_image=rgb2lab(imagen_pil)

# Separa los canales L y AB
l_channel = lab_image[:,:, 0]

l_channel=l_channel/100 #normalizar l1

transformaciones = transforms.Compose([
    transforms.ToTensor(),  # Convierte la imagen a un tensor
    transforms.Resize((512,512),interpolation=transforms.InterpolationMode.BICUBIC),
])

l_tensor = transformaciones(l_channel)
l_tensor=l_tensor.to(device)

with torch.no_grad():
    generador.eval()

    generated_ab = generador(l_tensor.detach().float().unsqueeze(0)).squeeze().cpu().numpy().transpose(1, 2, 0)
    ab_desnormalizado=((((generated_ab+1)/2)*255))-128

    img_rgb = np.zeros((512, 512, 3), dtype=np.float64)  # crea un array de ceros para la imagen RGB
    img_rgb[:,:,0]=l_tensor.squeeze().detach().cpu().numpy()*100
    img_rgb[:,:,1:] = ab_desnormalizado

    img_rgb=lab2rgb(img_rgb)


# Visualizar la imagen generada
plt.imshow(img_rgb)
plt.axis('off')
plt.show()


imagen_scaled = (img_rgb / np.max(img_rgb))*255 # como esta en float pil necsit valores rango 0-255

# Convertir la imagen a tipo uint8

imagen_uint8 = imagen_scaled.astype(np.uint8)

# Crear una imagen PIL a partir del arreglo uint8
imagen_pil = Image.fromarray(imagen_uint8)

imagen_bicubic = imagen_pil.resize((imagen_pil.width , imagen_pil.height), resample=Image.BICUBIC)
# Guardar la imagen en disco
imagen_bicubic.save("imagen_pil.png")
# Out:
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 6 pixels
#   return func(*args, **kwargs)
