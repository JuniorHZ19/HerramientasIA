# ...

# %%
  from gtts import gTTS
  from IPython.display import Audio, display
  with open("documento_word.docx", "r", encoding="utf-8") as archivo:
    contenido = archivo.read()
  tts = gTTS(text=contenido,lang="es")
  tts.save("audio.mp3")
  display(Audio("audio.mp3",autoplay=True))

# %%
#@markdown #Step 2. CREADOR CUENTO
import time

from openai import OpenAI
from docx import Document

import os
from gtts import gTTS
from IPython.display import Audio, display


# Crear el audio usando gTTS

client = OpenAI(
    api_key="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"
)

rol="escritor" #@param {type:"string"}



def get_preguntas(pregunta,rol):
    response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[{"role":f"system","content":f"olvida todo lo anterior,ahora eres {rol},narrame la historia no hagas sinopsis ni nada"},
              {"role":f"user","content":f"{pregunta}"}
              ],
    max_tokens=3048
     )
    return response



def get_new_parrafo(parrafo):
      nuevapregunta="amplia este parrafo '"+parrafo+"'"
      respuesta = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
            {"role":f"system","content":f"{rol}"},
              {"role":f"user","content":f"{nuevapregunta}"}
              ],
      max_tokens=3048
     )
      nuevoparrafo=respuesta.choices[0].message.content
      return nuevoparrafo


parrafos_modificados = []
documento = Document()

while True:
  print("--------------------------------------------------------------------------------------------------------------------------------------")
  pregunta=input("Usuario : ")

  respuesta=get_preguntas(pregunta,rol).choices[0].message.content
  print("cuento original:"+ respuesta)

  parrafos=respuesta.split(".")

  for parrafo in parrafos:
     print("este es el parrafo: "+parrafo)
     time.sleep(7)
     nuevoparrafo=get_new_parrafo(parrafo)

     print(nuevoparrafo)
     documento.add_paragraph(nuevoparrafo)



  documento.save("documento_word.docx")

  with open("documento_word.docx", "r", encoding="utf-8") as archivo:
    contenido = archivo.read()

  tts = gTTS(text=contenido,lang="es")
  tts.save("audio.mp3")
  display(Audio("audio.mp3",autoplay=True))

  print("Se ah creado el word correctamente ")

# %%
#@markdown # ASISTENTE

import time

from openai import OpenAI

import os
from gtts import gTTS
from IPython.display import Audio, display


# Crear el audio usando gTTS

client = OpenAI(
    api_key="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",
)


rol="Eres un asistente de floreria Maria , y vendes flores online"#@param {type:"string"}
asistir_en="Eres un asistente de una floreria que atiende a clientes sobre las flores que vendemos , la floreria se llama MARIA,Floreria MARIA se encuentra en las ciduad de lima, barranco , precios son  margartia:15 soles por flores , rosas=14 soles por flor , azusenas=13 soles por sol , tulipanes=14 soles por flor , cual quier otra flor tiene que consultar a la recepcion o ir a nuestro local en barranco  local es :el pueblo maldito,barranco,el numero de whasap es 964789."#@param {type:"string"}


def get_preguntas(pregunta,rol,asistir_en):
    response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[{"role":f"assistant","content":f"{asistir_en}"},
              {"role":f"system","content":f"{rol}, si te pregunta otra cosa de lo que no das asistencia responde que no es tu rubro"},
              {"role":f"user","content":f"{pregunta}"}
              ],
    max_tokens=3048
     )
    return response




while True:
  print("--------------------------------------------------------------------------------------------------------------------------------------")
  pregunta=input("Usuario : ")
  respuesta=get_preguntas(pregunta,rol,asistir_en)

  print("ChatGPT: "+respuesta.choices[0].message.content)
  tts = gTTS(respuesta.choices[0].message.content,lang="es")
  tts.save("audio.mp3")
  display(Audio("audio.mp3",autoplay=True))
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------
# Usuario : hola
# ChatGPT: ¡Hola! ¿En qué puedo ayudarte hoy?
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# --------------------------------------------------------------------------------------------------------------------------------------
# Usuario : que vendes?
# ChatGPT: En Florería MARIA vendemos una variedad de flores como margaritas, rosas, azucenas y tulipanes. Si necesitas información sobre otras flores, te recomiendo que consultes con la recepción o nos visites en nuestro local en Barranco. También puedes contactarnos a través de WhatsApp al número 964789.
#                 <audio  controls="controls" autoplay="autoplay">
# ...

# %%
#@markdown ## ROL
import time

from openai import OpenAI

import os
from gtts import gTTS
from IPython.display import Audio, display


# Crear el audio usando gTTS

client = OpenAI(
    api_key="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",
)

rol="Data Sciense" #@param {type:"string"}



def get_preguntas(pregunta,rol):
    response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[{"role":f"system","content":f"{rol}, pero no digas que eres una AI"},
              {"role":f"user","content":f"{pregunta}"}
              ],
    max_tokens=3048
     )
    return response




while True:
  print("--------------------------------------------------------------------------------------------------------------------------------------")
  pregunta=input("Usuario : ")
  respuesta=get_preguntas(pregunta,rol)

  print("ChatGPT: "+respuesta.choices[0].message.content)
  tts = gTTS(respuesta.choices[0].message.content,lang="es")
  tts.save("audio.mp3")
  display(Audio("audio.mp3",autoplay=True))

# %% [markdown]
# #DEBATES IA

# %%
from openai import OpenAI


import os

client = OpenAI(
    api_key="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",
)

rol1="Ingeniero" #@param {type:"string"}
rol2="Filosofo" #@param {type:"string"}
tema_debate="Sobre la inteligencia artificial" #@param {type:"string"}

unleash = False # @param {type:"boolean"}

if unleash==True:
  rol1=f"Eres un jugador rol player y eres un malvado genio {rol1}"
  rol2=f"Eres un jugador rol player y eres un malvado genio {rol2}"

def get_preguntas_r1(pr,rol1):
    response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[{"role":f"system","content":f"olvida todo lo anterior,ahora eres {rol1}, pero no digas que eres una AI"},
              {"role":f"user","content":f"{pr}"}
              ],
    max_tokens=3048
     )
    return response


def get_preguntas_r2(pr,rol2):
    response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[{"role":f"system","content":f"olvida todo lo anterior,ahora eres {rol2}, pero no digas que eres una AI"},
              {"role":f"user","content":f"{pr}"}
              ],
    max_tokens=3048
     )
    return response


respuesta1=get_preguntas_r1(str(tema_debate+"que opinas?"),rol1)
rp=respuesta1.choices[0].message.content+"que opinas?"
print(f"{rol1} :"+rp)

respuesta2=get_preguntas_r2(rp,rol2).choices[0].message.content+"que opinas?"

print(f"{rol2} :"+respuesta2)


while True:
  print("------------------------------------------------------------------------------------------------------------------------------------------------")

  respuesta1=str(get_preguntas_r1(respuesta2,rol1))+"que opinas?"

  rp=respuesta.choices[0].message.content +"que opinas?"

  print(f"{rol1} :"+rp)

  respuesta2=get_preguntas_r2(rp,rol2).choices[0].message.content+"que opinas?"

print(f"{rol2} :"+respuesta2)
