# %% [markdown]
# <a href="https://colab.research.google.com/github/JuniorHZ19/HerramientasIA/blob/main/imagetoimage1.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# !unzip DIV2K_train_HR.zip # This is our dataset link. I will include this command in the description

# %%
#@markdown # *0) ** Instalando libreria(OBLIGATORIO)

# !pip install torch torchvision torchaudio

# %%
#@markdown # *1) ** Clase Para manejo de directorios de datasets de imagenes


import os
import cv2
import pandas as pd
from PIL import Image
import torch
from torchvision import transforms
# Recorre el directorio  y elmiina los archvios que no tiene las extensioens permitidas

class DataSetManage:




 def comprobar_ext_directorios(self,directorio):

  for clase,[directorio,etiquetas] in(directorio.items()):
   lista_directorio=os.listdir(directorio)
   self._validarExt(directorio)



 def  _validarExt(self,directorio):
  print(directorio)
   # Extensiones permitidas
  extensiones_permitidas = {".jpg", ".jpeg", ".png"}
  for root, dirs, files in os.walk(directorio):

    for file in files:
        # Obtiene la extensión del archivo
        _, extension = os.path.splitext(file)

        # Verifica si la extensión no está en la lista de extensiones permitidas y elimina el archivo
        if extension.lower() not in extensiones_permitidas:
            archivo_a_eliminar = os.path.join(root, file)
            os.remove(archivo_a_eliminar)
            print(f"Se eliminó: {archivo_a_eliminar}")


# Cambia nombre de cada archivo dentro del directorio a un valor secuencial

 def cambiar_nombres_directorios(self,directorio):
   for clase,[directorio,etiquetas] in(directorio.items()):
     lista_directorio=os.listdir(directorio)
     self._cambiarNombre(directorio,clase)
     print(directorio)


 def _cambiarNombre(self,directorios,subfijo):
  archivos_en_directorio = os.listdir(directorios)
  for i, archivo in enumerate(archivos_en_directorio, start=1):
    # Construir el nuevo nombre del archivo
    nuevo_nombre = f"{subfijo}{i}{os.path.splitext(archivo)[1]}"

    # Ruta completa del archivo antiguo y nuevo
    ruta_antigua = os.path.join(directorios, archivo)
    ruta_nueva = os.path.join(directorios, nuevo_nombre)

    # Cambiar el nombre del archivo
    os.rename(ruta_antigua, ruta_nueva)
    print(f"Se cambió el nombre de {ruta_antigua} a {ruta_nueva}")


#Obtiene la cantidad de elemntos que tiene la carpeta

 def len_directorio(self,directorio):
    cantidad_elementos = sum(1 for elemento in os.listdir(directorio) if os.path.isfile(os.path.join(directorio, elemento)))
    return cantidad_elementos


#----------------------------------------------------------------------------------------------

#Valida si la imagen se puede leer usando  pill o cv2 si no se puede leer se elimina

 def validar_Img_Pill(self,directorio,):
  for etiqueta,[directorio,clase] in(directorio.items()):

    lista_paths=os.listdir(directorio)
    self._validarLecturaImgPill(directorio,lista_paths)
  print(f"Se ah validado todas las imagenes")

 def validar_Img_cv2(self,directorio):
  for etiqueta,[directorio,clase] in(directorio.items()):

    lista_paths=os.listdir(directorio)
    self._validarLecturaImg(directorio,lista_paths)
  print(f"Se ah validado todas las imagenes")

 def _validarLecturaImg(self,directorio,lista):

  for ruta in(lista):
   imagen=cv2.imread(directorio+ruta)
   if  imagen is None:
     os.remove(directorio+ruta)
     print(f"No se pudo leer y se elimino archivo:{directorio+ruta}")

 def _validarLecturaImgPill(self,directorio,lista):
    for ruta in(lista):
     try:
      imagen=Image.open(directorio+ruta)
     except Exception as e:
      os.remove(directorio+ruta)
      print(f"Archivo '{directorio+ruta}' eliminado.")



#vamos a recorrer el dicionario y validar ruta por ruta si se puede leer sino se elminara
#vamos guaradno al mismo tiempo 3 listas, los directorios , listas de paths de los directiros y de las clases ,para usarlo luego usarlo al crear el csv

 def separar_datos_directorios(self,directorios):
  listas_directorios=[]
  listas_listas_directorios=[]
  listas_clases=[]

  for etiqueta,[directorio,clase] in(directorios.items()):

       lista_paths=os.listdir(directorio)
       listas_directorios.append(directorio)
       listas_listas_directorios.append(lista_paths)
       listas_clases.append(clase)

  return listas_directorios,listas_listas_directorios,listas_clases

 def emparejar_listas_paths(self,lista_listas):

   #Tomamos el minimo tamaño dentro de las lista de cada clase
   tamaño_minimo = min(len(arr) for arr in lista_listas)

   #Vamos a emparejar todas las listas con un tamaño igual que sea la del minimo tamaño de todas,esto para tener un set de datos parejo por cada clase
   Reducido_lista_paths=[]

   #Reduce cada lista de los paths a la cantidad minimo para que todos tenga iaugal cantidad
   for listas in(lista_listas):
    Reducido_lista_paths.append(listas[:tamaño_minimo])

   return Reducido_lista_paths
#---------------------------------------------------------------------------------


 def crear_paths_csv(self,directorio_base,lista_paths,clases,nombre_archivo):

   columnas=["path","etiqueta"]
   datos_csv=[]

   for dir_base,dir_path,clase in  zip(directorio_base,lista_paths,clases):

    for path  in (dir_path):

     datos_csv.append([dir_base+path ,clase])


   df_lista=pd.DataFrame(datos_csv,columns=columnas)
   df_lista=df_lista.sort_values(by='path')
   df_lista.to_csv(nombre_archivo,index=False)
   print("Csv Creado")
#---------------------------------------------------------------------------------

#devuelve cuatnos elemtnos tiene cada clase
 def total_elementos(self,directorio,csv_path):
    df=pd.read_csv(csv_path)
    for clase,[directorio,etiqueta] in (directorio.items()):
     tamaño_etiqueta=(df["etiqueta"] == etiqueta).sum()
     print(f"la clase {clase} tiene :{tamaño_etiqueta} elementos")


#-------------------------------------------------------------------------------------------------

  #Funciones para data aumentation
 def   data_aumentation_conjunto(self,input_imagen_folder,output_path_folder,iteraciones,transformaciones,keepname=False):  #ingresa trnasformacioens como compose donde se aplicara las trasnfomracioens conjutnos pero se repteira un numero de veces por cada imagen

   for filename in os.listdir(input_imagen_folder):

    if filename.endswith('.jpg') or filename.endswith('.png'):

        input_path = os.path.join(input_imagen_folder, filename)
        if(keepname==False):
         output_path = os.path.join(output_path_folder, f'transformed_{filename}')
        else:
          output_path = os.path.join(output_path_folder, f'{filename}')
        # Aplica las transformaciones
        print(output_path)
        self._apply_transfomaciones_conjunto_it(input_path,output_path,int(iteraciones),transformaciones,keepname)


 def   data_aumentation_individual(self,input_imagen_folder,output_path_folder,transformaciones,keepname=False):  #las trnasfomaciones solo pasaremos la lista ya que ira aplicando la transformacion una por una por cada imagen

  for filename in os.listdir(input_imagen_folder):

    if filename.endswith('.jpg') or filename.endswith('.png'):
        input_path = os.path.join(input_imagen_folder, filename)
        if(keepname==False):
         output_path = os.path.join(output_path_folder, f'transformed_{filename}')
         print("opasasmos")
        else:
          output_path = os.path.join(output_path_folder, f'{filename}')
        # Aplica las transformaciones
        self._apply_transfomaciones_conjunto(input_path,output_path,transformaciones,keepname)



 def _apply_transfomaciones_conjunto_it(self,input_imagen_path,output_iamgen_path,iteraciones,transformations=None,keepname=False): #aplica las transfomracioens  conjutas por iteracion y se guarda las iamgenes

   imagen=Image.open(input_imagen_path)


   for i in range(iteraciones):
      imagen_trasformada=transformations(imagen)

      out_root, out_extension = os.path.splitext(output_iamgen_path)
      if(keepname==False):
       imagen_trasformada.save(f"{out_root}_{i}{out_extension}")
      else:
        imagen_trasformada.save(f"{out_root}{out_extension}")

 def _apply_transfomaciones_conjunto(self,input_imagen_path,output_iamgen_path,transformations=None,keepname=False): #aplica las transfomracioens individuales  y se guarda las iamgenes

  imagen=Image.open(input_imagen_path)

  for i,transformacion in enumerate(transformations):
   imagen_transformada=transformacion(imagen)
   out_root, out_extension = os.path.splitext(output_iamgen_path)
   if(keepname==False):
     imagen_transformada.save(f"{out_root}_{i}{out_extension}")
   else:
      imagen_transformada.save(f"{out_root}{out_extension}")

# %%
#Creamos las carpetas con las imagenes en hr y lw

#Creamos los arhcivo baja resolucion aparitr de imangenes alta resoulcion en hr , estos archios iran a carpaeta lw
directorio_in="/content/DIV2K_train_HR"
directorio_out="/content/Imagenes/img/"

#antes de otrogar mediads de hr y lw , chekea como el generador va votando las resolucioens hr_fake segun la resolucion lw que especifics tiene qeu conicidr
#ya que el discriminador necsita la misma medidades tanto para el hr y el hr_fake que genera el generador

transformaciones=transforms.Compose([
transforms.Resize((256, 256)),

])




datasetmanage=DataSetManage()
datasetmanage.data_aumentation_conjunto(directorio_in,directorio_out,1,transformaciones)
# Out:
# /content/Imagenes/img/transformed_0002.png
# /content/Imagenes/img/transformed_0253.png
# /content/Imagenes/img/transformed_0505.png
# /content/Imagenes/img/transformed_0734.png
# /content/Imagenes/img/transformed_0232.png
# /content/Imagenes/img/transformed_0790.png
# /content/Imagenes/img/transformed_0412.png
# /content/Imagenes/img/transformed_0396.png
# /content/Imagenes/img/transformed_0728.png
# /content/Imagenes/img/transformed_0778.png
# /content/Imagenes/img/transformed_0797.png
# /content/Imagenes/img/transformed_0017.png
# /content/Imagenes/img/transformed_0319.png
# /content/Imagenes/img/transformed_0722.png
# /content/Imagenes/img/transformed_0476.png
# /content/Imagenes/img/transformed_0050.png
# /content/Imagenes/img/transformed_0752.png
# /content/Imagenes/img/transformed_0563.png
# /content/Imagenes/img/transformed_0598.png
# /content/Imagenes/img/transformed_0456.png
# /content/Imagenes/img/transformed_0117.png
# /content/Imagenes/img/transformed_0781.png
# /content/Imagenes/img/transformed_0724.png
# /content/Imagenes/img/transformed_0267.png
# /content/Imagenes/img/transformed_0310.png
# /content/Imagenes/img/transformed_0606.png
# /content/Imagenes/img/transformed_0417.png
# /content/Imagenes/img/transformed_0361.png
# /content/Imagenes/img/transformed_0597.png
# /content/Imagenes/img/transformed_0118.png
# /content/Imagenes/img/transformed_0638.png
# /content/Imagenes/img/transformed_0265.png
# /content/Imagenes/img/transformed_0245.png
# /content/Imagenes/img/transformed_0124.png
# /content/Imagenes/img/transformed_0246.png
# /content/Imagenes/img/transformed_0596.png
# /content/Imagenes/img/transformed_0241.png
# /content/Imagenes/img/transformed_0092.png
# /content/Imagenes/img/transformed_0502.png
# /content/Imagenes/img/transformed_0154.png
# /content/Imagenes/img/transformed_0219.png
# /content/Imagenes/img/transformed_0108.png
# /content/Imagenes/img/transformed_0134.png
# /content/Imagenes/img/transformed_0350.png
# /content/Imagenes/img/transformed_0605.png
# /content/Imagenes/img/transformed_0739.png
# /content/Imagenes/img/transformed_0624.png
# /content/Imagenes/img/transformed_0628.png
# /content/Imagenes/img/transformed_0743.png
# /content/Imagenes/img/transformed_0181.png
# /content/Imagenes/img/transformed_0509.png
# /content/Imagenes/img/transformed_0316.png
# /content/Imagenes/img/transformed_0715.png
# /content/Imagenes/img/transformed_0282.png
# /content/Imagenes/img/transformed_0753.png
# /content/Imagenes/img/transformed_0029.png
# /content/Imagenes/img/transformed_0337.png
# /content/Imagenes/img/transformed_0076.png
# /content/Imagenes/img/transformed_0738.png
# /content/Imagenes/img/transformed_0625.png
# /content/Imagenes/img/transformed_0281.png
# /content/Imagenes/img/transformed_0770.png
# /content/Imagenes/img/transformed_0761.png
# /content/Imagenes/img/transformed_0390.png
# /content/Imagenes/img/transformed_0221.png
# /content/Imagenes/img/transformed_0290.png
# /content/Imagenes/img/transformed_0184.png
# /content/Imagenes/img/transformed_0687.png
# /content/Imagenes/img/transformed_0445.png
# /content/Imagenes/img/transformed_0293.png
# /content/Imagenes/img/transformed_0336.png
# /content/Imagenes/img/transformed_0074.png
# /content/Imagenes/img/transformed_0448.png
# /content/Imagenes/img/transformed_0328.png
# /content/Imagenes/img/transformed_0676.png
# /content/Imagenes/img/transformed_0433.png
# /content/Imagenes/img/transformed_0616.png
# /content/Imagenes/img/transformed_0553.png
# /content/Imagenes/img/transformed_0539.png
# /content/Imagenes/img/transformed_0481.png
# /content/Imagenes/img/transformed_0022.png
# /content/Imagenes/img/transformed_0058.png
# /content/Imagenes/img/transformed_0480.png
# /content/Imagenes/img/transformed_0613.png
# /content/Imagenes/img/transformed_0637.png
# /content/Imagenes/img/transformed_0142.png
# /content/Imagenes/img/transformed_0511.png
# /content/Imagenes/img/transformed_0383.png
# /content/Imagenes/img/transformed_0003.png
# /content/Imagenes/img/transformed_0498.png
# /content/Imagenes/img/transformed_0477.png
# /content/Imagenes/img/transformed_0780.png
# /content/Imagenes/img/transformed_0355.png
# /content/Imagenes/img/transformed_0668.png
# /content/Imagenes/img/transformed_0128.png
# /content/Imagenes/img/transformed_0143.png
# /content/Imagenes/img/transformed_0301.png
# /content/Imagenes/img/transformed_0413.png
# /content/Imagenes/img/transformed_0351.png
# /content/Imagenes/img/transformed_0796.png
# /content/Imagenes/img/transformed_0707.png
# /content/Imagenes/img/transformed_0709.png
# /content/Imagenes/img/transformed_0429.png
# /content/Imagenes/img/transformed_0762.png
# /content/Imagenes/img/transformed_0735.png
# /content/Imagenes/img/transformed_0335.png
# /content/Imagenes/img/transformed_0731.png
# /content/Imagenes/img/transformed_0600.png
# /content/Imagenes/img/transformed_0195.png
# /content/Imagenes/img/transformed_0466.png
# /content/Imagenes/img/transformed_0569.png
# /content/Imagenes/img/transformed_0710.png
# /content/Imagenes/img/transformed_0720.png
# /content/Imagenes/img/transformed_0626.png
# /content/Imagenes/img/transformed_0393.png
# /content/Imagenes/img/transformed_0773.png
# /content/Imagenes/img/transformed_0519.png
# /content/Imagenes/img/transformed_0446.png
# /content/Imagenes/img/transformed_0610.png
# /content/Imagenes/img/transformed_0729.png
# /content/Imagenes/img/transformed_0516.png
# /content/Imagenes/img/transformed_0166.png
# /content/Imagenes/img/transformed_0258.png
# /content/Imagenes/img/transformed_0454.png
# /content/Imagenes/img/transformed_0381.png
# /content/Imagenes/img/transformed_0422.png
# /content/Imagenes/img/transformed_0073.png
# /content/Imagenes/img/transformed_0027.png
# /content/Imagenes/img/transformed_0296.png
# /content/Imagenes/img/transformed_0554.png
# /content/Imagenes/img/transformed_0323.png
# /content/Imagenes/img/transformed_0391.png
# /content/Imagenes/img/transformed_0152.png
# /content/Imagenes/img/transformed_0137.png
# /content/Imagenes/img/transformed_0139.png
# /content/Imagenes/img/transformed_0346.png
# /content/Imagenes/img/transformed_0235.png
# /content/Imagenes/img/transformed_0019.png
# /content/Imagenes/img/transformed_0529.png
# /content/Imagenes/img/transformed_0458.png
# /content/Imagenes/img/transformed_0312.png
# /content/Imagenes/img/transformed_0535.png
# /content/Imagenes/img/transformed_0468.png
# /content/Imagenes/img/transformed_0298.png
# /content/Imagenes/img/transformed_0371.png
# /content/Imagenes/img/transformed_0192.png
# /content/Imagenes/img/transformed_0399.png
# /content/Imagenes/img/transformed_0787.png
# /content/Imagenes/img/transformed_0500.png
# /content/Imagenes/img/transformed_0373.png
# /content/Imagenes/img/transformed_0387.png
# /content/Imagenes/img/transformed_0167.png
# /content/Imagenes/img/transformed_0375.png
# /content/Imagenes/img/transformed_0210.png
# /content/Imagenes/img/transformed_0287.png
# /content/Imagenes/img/transformed_0617.png
# /content/Imagenes/img/transformed_0581.png
# /content/Imagenes/img/transformed_0150.png
# /content/Imagenes/img/transformed_0209.png
# /content/Imagenes/img/transformed_0060.png
# /content/Imagenes/img/transformed_0489.png
# /content/Imagenes/img/transformed_0486.png
# /content/Imagenes/img/transformed_0727.png
# /content/Imagenes/img/transformed_0549.png
# /content/Imagenes/img/transformed_0737.png
# /content/Imagenes/img/transformed_0655.png
# /content/Imagenes/img/transformed_0012.png
# /content/Imagenes/img/transformed_0430.png
# /content/Imagenes/img/transformed_0460.png
# /content/Imagenes/img/transformed_0144.png
# /content/Imagenes/img/transformed_0662.png
# /content/Imagenes/img/transformed_0525.png
# /content/Imagenes/img/transformed_0306.png
# /content/Imagenes/img/transformed_0688.png
# /content/Imagenes/img/transformed_0224.png
# /content/Imagenes/img/transformed_0656.png
# /content/Imagenes/img/transformed_0595.png
# /content/Imagenes/img/transformed_0615.png
# /content/Imagenes/img/transformed_0120.png
# /content/Imagenes/img/transformed_0255.png
# /content/Imagenes/img/transformed_0757.png
# /content/Imagenes/img/transformed_0044.png
# /content/Imagenes/img/transformed_0343.png
# /content/Imagenes/img/transformed_0534.png
# /content/Imagenes/img/transformed_0291.png
# /content/Imagenes/img/transformed_0564.png
# /content/Imagenes/img/transformed_0231.png
# /content/Imagenes/img/transformed_0198.png
# /content/Imagenes/img/transformed_0229.png
# /content/Imagenes/img/transformed_0141.png
# /content/Imagenes/img/transformed_0200.png
# /content/Imagenes/img/transformed_0243.png
# /content/Imagenes/img/transformed_0204.png
# /content/Imagenes/img/transformed_0025.png
# /content/Imagenes/img/transformed_0685.png
# /content/Imagenes/img/transformed_0700.png
# /content/Imagenes/img/transformed_0007.png
# /content/Imagenes/img/transformed_0116.png
# /content/Imagenes/img/transformed_0499.png
# /content/Imagenes/img/transformed_0415.png
# /content/Imagenes/img/transformed_0274.png
# /content/Imagenes/img/transformed_0558.png
# /content/Imagenes/img/transformed_0703.png
# /content/Imagenes/img/transformed_0332.png
# /content/Imagenes/img/transformed_0020.png
# /content/Imagenes/img/transformed_0440.png
# /content/Imagenes/img/transformed_0349.png
# /content/Imagenes/img/transformed_0636.png
# /content/Imagenes/img/transformed_0746.png
# /content/Imagenes/img/transformed_0314.png
# /content/Imagenes/img/transformed_0789.png
# /content/Imagenes/img/transformed_0103.png
# /content/Imagenes/img/transformed_0719.png
# /content/Imagenes/img/transformed_0225.png
# /content/Imagenes/img/transformed_0294.png
# /content/Imagenes/img/transformed_0590.png
# /content/Imagenes/img/transformed_0527.png
# /content/Imagenes/img/transformed_0104.png
# /content/Imagenes/img/transformed_0627.png
# /content/Imagenes/img/transformed_0159.png
# /content/Imagenes/img/transformed_0082.png
# /content/Imagenes/img/transformed_0545.png
# /content/Imagenes/img/transformed_0640.png
# /content/Imagenes/img/transformed_0464.png
# /content/Imagenes/img/transformed_0582.png
# /content/Imagenes/img/transformed_0191.png
# /content/Imagenes/img/transformed_0112.png
# /content/Imagenes/img/transformed_0679.png
# /content/Imagenes/img/transformed_0272.png
# /content/Imagenes/img/transformed_0449.png
# /content/Imagenes/img/transformed_0334.png
# /content/Imagenes/img/transformed_0016.png
# /content/Imagenes/img/transformed_0186.png
# /content/Imagenes/img/transformed_0697.png
# /content/Imagenes/img/transformed_0521.png
# /content/Imagenes/img/transformed_0194.png
# /content/Imagenes/img/transformed_0061.png
# /content/Imagenes/img/transformed_0567.png
# /content/Imagenes/img/transformed_0443.png
# /content/Imagenes/img/transformed_0785.png
# /content/Imagenes/img/transformed_0723.png
# /content/Imagenes/img/transformed_0691.png
# /content/Imagenes/img/transformed_0621.png
# /content/Imagenes/img/transformed_0484.png
# /content/Imagenes/img/transformed_0123.png
# /content/Imagenes/img/transformed_0573.png
# /content/Imagenes/img/transformed_0211.png
# /content/Imagenes/img/transformed_0450.png
# /content/Imagenes/img/transformed_0098.png
# /content/Imagenes/img/transformed_0672.png
# /content/Imagenes/img/transformed_0506.png
# /content/Imagenes/img/transformed_0101.png
# /content/Imagenes/img/transformed_0283.png
# /content/Imagenes/img/transformed_0023.png
# /content/Imagenes/img/transformed_0333.png
# /content/Imagenes/img/transformed_0311.png
# /content/Imagenes/img/transformed_0543.png
# /content/Imagenes/img/transformed_0090.png
# /content/Imagenes/img/transformed_0587.png
# /content/Imagenes/img/transformed_0398.png
# /content/Imagenes/img/transformed_0318.png
# /content/Imagenes/img/transformed_0444.png
# /content/Imagenes/img/transformed_0402.png
# /content/Imagenes/img/transformed_0380.png
# /content/Imagenes/img/transformed_0365.png
# /content/Imagenes/img/transformed_0239.png
# /content/Imagenes/img/transformed_0327.png
# /content/Imagenes/img/transformed_0555.png
# /content/Imagenes/img/transformed_0661.png
# /content/Imagenes/img/transformed_0706.png
# /content/Imagenes/img/transformed_0297.png
# /content/Imagenes/img/transformed_0288.png
# /content/Imagenes/img/transformed_0160.png
# /content/Imagenes/img/transformed_0701.png
# /content/Imagenes/img/transformed_0614.png
# /content/Imagenes/img/transformed_0100.png
# /content/Imagenes/img/transformed_0544.png
# /content/Imagenes/img/transformed_0071.png
# /content/Imagenes/img/transformed_0584.png
# /content/Imagenes/img/transformed_0431.png
# /content/Imagenes/img/transformed_0386.png
# /content/Imagenes/img/transformed_0530.png
# /content/Imagenes/img/transformed_0079.png
# /content/Imagenes/img/transformed_0602.png
# /content/Imagenes/img/transformed_0714.png
# /content/Imagenes/img/transformed_0754.png
# /content/Imagenes/img/transformed_0279.png
# /content/Imagenes/img/transformed_0037.png
# /content/Imagenes/img/transformed_0136.png
# /content/Imagenes/img/transformed_0607.png
# /content/Imagenes/img/transformed_0690.png
# /content/Imagenes/img/transformed_0414.png
# /content/Imagenes/img/transformed_0482.png
# /content/Imagenes/img/transformed_0378.png
# /content/Imagenes/img/transformed_0190.png
# /content/Imagenes/img/transformed_0562.png
# /content/Imagenes/img/transformed_0115.png
# /content/Imagenes/img/transformed_0644.png
# /content/Imagenes/img/transformed_0603.png
# /content/Imagenes/img/transformed_0064.png
# /content/Imagenes/img/transformed_0657.png
# /content/Imagenes/img/transformed_0039.png
# /content/Imagenes/img/transformed_0105.png
# /content/Imagenes/img/transformed_0164.png
# /content/Imagenes/img/transformed_0740.png
# /content/Imagenes/img/transformed_0339.png
# /content/Imagenes/img/transformed_0550.png
# /content/Imagenes/img/transformed_0240.png
# /content/Imagenes/img/transformed_0264.png
# /content/Imagenes/img/transformed_0111.png
# /content/Imagenes/img/transformed_0604.png
# /content/Imagenes/img/transformed_0693.png
# /content/Imagenes/img/transformed_0401.png
# /content/Imagenes/img/transformed_0097.png
# /content/Imagenes/img/transformed_0252.png
# /content/Imagenes/img/transformed_0032.png
# /content/Imagenes/img/transformed_0315.png
# /content/Imagenes/img/transformed_0218.png
# /content/Imagenes/img/transformed_0013.png
# /content/Imagenes/img/transformed_0376.png
# /content/Imagenes/img/transformed_0488.png
# /content/Imagenes/img/transformed_0338.png
# /content/Imagenes/img/transformed_0420.png
# /content/Imagenes/img/transformed_0359.png
# /content/Imagenes/img/transformed_0179.png
# /content/Imagenes/img/transformed_0305.png
# /content/Imagenes/img/transformed_0492.png
# /content/Imagenes/img/transformed_0140.png
# /content/Imagenes/img/transformed_0760.png
# /content/Imagenes/img/transformed_0286.png
# /content/Imagenes/img/transformed_0487.png
# /content/Imagenes/img/transformed_0517.png
# /content/Imagenes/img/transformed_0048.png
# /content/Imagenes/img/transformed_0407.png
# /content/Imagenes/img/transformed_0410.png
# /content/Imagenes/img/transformed_0018.png
# /content/Imagenes/img/transformed_0665.png
# /content/Imagenes/img/transformed_0088.png
# /content/Imagenes/img/transformed_0226.png
# /content/Imagenes/img/transformed_0262.png
# /content/Imagenes/img/transformed_0174.png
# /content/Imagenes/img/transformed_0353.png
# /content/Imagenes/img/transformed_0591.png
# /content/Imagenes/img/transformed_0388.png
# /content/Imagenes/img/transformed_0736.png
# /content/Imagenes/img/transformed_0442.png
# /content/Imagenes/img/transformed_0329.png
# /content/Imagenes/img/transformed_0126.png
# /content/Imagenes/img/transformed_0483.png
# /content/Imagenes/img/transformed_0206.png
# /content/Imagenes/img/transformed_0237.png
# /content/Imagenes/img/transformed_0330.png
# /content/Imagenes/img/transformed_0006.png
# /content/Imagenes/img/transformed_0161.png
# /content/Imagenes/img/transformed_0254.png
# /content/Imagenes/img/transformed_0320.png
# /content/Imagenes/img/transformed_0575.png
# /content/Imagenes/img/transformed_0507.png
# /content/Imagenes/img/transformed_0081.png
# /content/Imagenes/img/transformed_0432.png
# /content/Imagenes/img/transformed_0490.png
# /content/Imagenes/img/transformed_0114.png
# /content/Imagenes/img/transformed_0485.png
# /content/Imagenes/img/transformed_0541.png
# /content/Imagenes/img/transformed_0182.png
# /content/Imagenes/img/transformed_0589.png
# /content/Imagenes/img/transformed_0276.png
# /content/Imagenes/img/transformed_0409.png
# /content/Imagenes/img/transformed_0357.png
# /content/Imagenes/img/transformed_0217.png
# /content/Imagenes/img/transformed_0178.png
# /content/Imagenes/img/transformed_0726.png
# /content/Imagenes/img/transformed_0669.png
# /content/Imagenes/img/transformed_0340.png
# /content/Imagenes/img/transformed_0189.png
# /content/Imagenes/img/transformed_0725.png
# /content/Imagenes/img/transformed_0531.png
# /content/Imagenes/img/transformed_0547.png
# /content/Imagenes/img/transformed_0366.png
# /content/Imagenes/img/transformed_0495.png
# /content/Imagenes/img/transformed_0145.png
# /content/Imagenes/img/transformed_0425.png
# /content/Imagenes/img/transformed_0473.png
# /content/Imagenes/img/transformed_0358.png
# /content/Imagenes/img/transformed_0713.png
# /content/Imagenes/img/transformed_0234.png
# /content/Imagenes/img/transformed_0791.png
# /content/Imagenes/img/transformed_0129.png
# /content/Imagenes/img/transformed_0578.png
# /content/Imagenes/img/transformed_0493.png
# /content/Imagenes/img/transformed_0362.png
# /content/Imagenes/img/transformed_0125.png
# /content/Imagenes/img/transformed_0372.png
# /content/Imagenes/img/transformed_0084.png
# /content/Imagenes/img/transformed_0503.png
# /content/Imagenes/img/transformed_0067.png
# /content/Imagenes/img/transformed_0057.png
# /content/Imagenes/img/transformed_0653.png
# /content/Imagenes/img/transformed_0538.png
# /content/Imagenes/img/transformed_0102.png
# /content/Imagenes/img/transformed_0395.png
# /content/Imagenes/img/transformed_0065.png
# /content/Imagenes/img/transformed_0256.png
# /content/Imagenes/img/transformed_0292.png
# /content/Imagenes/img/transformed_0756.png
# /content/Imagenes/img/transformed_0767.png
# /content/Imagenes/img/transformed_0131.png
# /content/Imagenes/img/transformed_0677.png
# /content/Imagenes/img/transformed_0586.png
# /content/Imagenes/img/transformed_0570.png
# /content/Imagenes/img/transformed_0404.png
# /content/Imagenes/img/transformed_0028.png
# /content/Imagenes/img/transformed_0223.png
# /content/Imagenes/img/transformed_0799.png
# /content/Imagenes/img/transformed_0031.png
# /content/Imagenes/img/transformed_0170.png
# /content/Imagenes/img/transformed_0646.png
# /content/Imagenes/img/transformed_0127.png
# /content/Imagenes/img/transformed_0475.png
# /content/Imagenes/img/transformed_0515.png
# /content/Imagenes/img/transformed_0047.png
# /content/Imagenes/img/transformed_0462.png
# /content/Imagenes/img/transformed_0772.png
# /content/Imagenes/img/transformed_0684.png
# /content/Imagenes/img/transformed_0699.png
# /content/Imagenes/img/transformed_0437.png
# /content/Imagenes/img/transformed_0793.png
# /content/Imagenes/img/transformed_0536.png
# /content/Imagenes/img/transformed_0721.png
# /content/Imagenes/img/transformed_0436.png
# /content/Imagenes/img/transformed_0324.png
# /content/Imagenes/img/transformed_0749.png
# /content/Imagenes/img/transformed_0087.png
# /content/Imagenes/img/transformed_0634.png
# /content/Imagenes/img/transformed_0236.png
# /content/Imagenes/img/transformed_0321.png
# /content/Imagenes/img/transformed_0463.png
# /content/Imagenes/img/transformed_0510.png
# /content/Imagenes/img/transformed_0056.png
# /content/Imagenes/img/transformed_0686.png
# /content/Imagenes/img/transformed_0599.png
# /content/Imagenes/img/transformed_0289.png
# /content/Imagenes/img/transformed_0268.png
# /content/Imagenes/img/transformed_0421.png
# /content/Imagenes/img/transformed_0275.png
# /content/Imagenes/img/transformed_0030.png
# /content/Imagenes/img/transformed_0080.png
# /content/Imagenes/img/transformed_0089.png
# /content/Imagenes/img/transformed_0741.png
# /content/Imagenes/img/transformed_0113.png
# /content/Imagenes/img/transformed_0526.png
# /content/Imagenes/img/transformed_0352.png
# /content/Imagenes/img/transformed_0651.png
# /content/Imagenes/img/transformed_0369.png
# /content/Imagenes/img/transformed_0664.png
# /content/Imagenes/img/transformed_0096.png
# /content/Imagenes/img/transformed_0747.png
# /content/Imagenes/img/transformed_0046.png
# /content/Imagenes/img/transformed_0630.png
# /content/Imagenes/img/transformed_0043.png
# /content/Imagenes/img/transformed_0648.png
# /content/Imagenes/img/transformed_0180.png
# /content/Imagenes/img/transformed_0779.png
# /content/Imagenes/img/transformed_0075.png
# /content/Imagenes/img/transformed_0620.png
# /content/Imagenes/img/transformed_0382.png
# /content/Imagenes/img/transformed_0639.png
# /content/Imagenes/img/transformed_0776.png
# /content/Imagenes/img/transformed_0230.png
# /content/Imagenes/img/transformed_0379.png
# /content/Imagenes/img/transformed_0643.png
# /content/Imagenes/img/transformed_0771.png
# /content/Imagenes/img/transformed_0049.png
# /content/Imagenes/img/transformed_0162.png
# /content/Imagenes/img/transformed_0748.png
# /content/Imagenes/img/transformed_0494.png
# /content/Imagenes/img/transformed_0163.png
# /content/Imagenes/img/transformed_0660.png
# /content/Imagenes/img/transformed_0764.png
# /content/Imagenes/img/transformed_0427.png
# /content/Imagenes/img/transformed_0658.png
# /content/Imagenes/img/transformed_0670.png
# /content/Imagenes/img/transformed_0556.png
# /content/Imagenes/img/transformed_0680.png
# /content/Imagenes/img/transformed_0560.png
# /content/Imagenes/img/transformed_0611.png
# /content/Imagenes/img/transformed_0156.png
# /content/Imagenes/img/transformed_0121.png
# /content/Imagenes/img/transformed_0585.png
# /content/Imagenes/img/transformed_0146.png
# /content/Imagenes/img/transformed_0187.png
# /content/Imagenes/img/transformed_0172.png
# /content/Imagenes/img/transformed_0406.png
# /content/Imagenes/img/transformed_0439.png
# /content/Imagenes/img/transformed_0792.png
# /content/Imagenes/img/transformed_0453.png
# /content/Imagenes/img/transformed_0356.png
# /content/Imagenes/img/transformed_0322.png
# /content/Imagenes/img/transformed_0673.png
# /content/Imagenes/img/transformed_0138.png
# /content/Imagenes/img/transformed_0654.png
# /content/Imagenes/img/transformed_0641.png
# /content/Imagenes/img/transformed_0394.png
# /content/Imagenes/img/transformed_0548.png
# /content/Imagenes/img/transformed_0213.png
# /content/Imagenes/img/transformed_0659.png
# /content/Imagenes/img/transformed_0063.png
# /content/Imagenes/img/transformed_0758.png
# /content/Imagenes/img/transformed_0130.png
# /content/Imagenes/img/transformed_0416.png
# /content/Imagenes/img/transformed_0512.png
# /content/Imagenes/img/transformed_0565.png
# /content/Imagenes/img/transformed_0451.png
# /content/Imagenes/img/transformed_0478.png
# /content/Imagenes/img/transformed_0364.png
# /content/Imagenes/img/transformed_0609.png
# /content/Imagenes/img/transformed_0623.png
# /content/Imagenes/img/transformed_0642.png
# /content/Imagenes/img/transformed_0248.png
# /content/Imagenes/img/transformed_0360.png
# /content/Imagenes/img/transformed_0788.png
# /content/Imagenes/img/transformed_0202.png
# /content/Imagenes/img/transformed_0133.png
# /content/Imagenes/img/transformed_0504.png
# /content/Imagenes/img/transformed_0467.png
# /content/Imagenes/img/transformed_0175.png
# /content/Imagenes/img/transformed_0307.png
# /content/Imagenes/img/transformed_0742.png
# /content/Imagenes/img/transformed_0571.png
# /content/Imagenes/img/transformed_0149.png
# /content/Imagenes/img/transformed_0010.png
# /content/Imagenes/img/transformed_0629.png
# /content/Imagenes/img/transformed_0207.png
# /content/Imagenes/img/transformed_0392.png
# /content/Imagenes/img/transformed_0592.png
# /content/Imagenes/img/transformed_0577.png
# /content/Imagenes/img/transformed_0270.png
# /content/Imagenes/img/transformed_0203.png
# /content/Imagenes/img/transformed_0173.png
# /content/Imagenes/img/transformed_0091.png
# /content/Imagenes/img/transformed_0704.png
# /content/Imagenes/img/transformed_0408.png
# /content/Imagenes/img/transformed_0325.png
# /content/Imagenes/img/transformed_0165.png
# /content/Imagenes/img/transformed_0750.png
# /content/Imagenes/img/transformed_0168.png
# /content/Imagenes/img/transformed_0783.png
# /content/Imagenes/img/transformed_0647.png
# /content/Imagenes/img/transformed_0034.png
# /content/Imagenes/img/transformed_0377.png
# /content/Imagenes/img/transformed_0062.png
# /content/Imagenes/img/transformed_0169.png
# /content/Imagenes/img/transformed_0666.png
# /content/Imagenes/img/transformed_0472.png
# /content/Imagenes/img/transformed_0326.png
# /content/Imagenes/img/transformed_0188.png
# /content/Imagenes/img/transformed_0220.png
# /content/Imagenes/img/transformed_0109.png
# /content/Imagenes/img/transformed_0041.png
# /content/Imagenes/img/transformed_0214.png
# /content/Imagenes/img/transformed_0572.png
# /content/Imagenes/img/transformed_0479.png
# /content/Imagenes/img/transformed_0261.png
# /content/Imagenes/img/transformed_0474.png
# /content/Imagenes/img/transformed_0153.png
# /content/Imagenes/img/transformed_0618.png
# /content/Imagenes/img/transformed_0537.png
# /content/Imagenes/img/transformed_0667.png
# /content/Imagenes/img/transformed_0438.png
# /content/Imagenes/img/transformed_0212.png
# /content/Imagenes/img/transformed_0250.png
# /content/Imagenes/img/transformed_0708.png
# /content/Imagenes/img/transformed_0496.png
# /content/Imagenes/img/transformed_0622.png
# /content/Imagenes/img/transformed_0331.png
# /content/Imagenes/img/transformed_0491.png
# /content/Imagenes/img/transformed_0532.png
# /content/Imagenes/img/transformed_0273.png
# /content/Imagenes/img/transformed_0795.png
# /content/Imagenes/img/transformed_0201.png
# /content/Imagenes/img/transformed_0744.png
# /content/Imagenes/img/transformed_0698.png
# /content/Imagenes/img/transformed_0263.png
# /content/Imagenes/img/transformed_0447.png
# /content/Imagenes/img/transformed_0015.png
# /content/Imagenes/img/transformed_0069.png
# /content/Imagenes/img/transformed_0711.png
# /content/Imagenes/img/transformed_0026.png
# /content/Imagenes/img/transformed_0342.png
# /content/Imagenes/img/transformed_0208.png
# /content/Imagenes/img/transformed_0694.png
# /content/Imagenes/img/transformed_0005.png
# /content/Imagenes/img/transformed_0054.png
# /content/Imagenes/img/transformed_0675.png
# /content/Imagenes/img/transformed_0751.png
# /content/Imagenes/img/transformed_0099.png
# /content/Imagenes/img/transformed_0755.png
# /content/Imagenes/img/transformed_0344.png
# /content/Imagenes/img/transformed_0520.png
# /content/Imagenes/img/transformed_0608.png
# /content/Imagenes/img/transformed_0546.png
# /content/Imagenes/img/transformed_0619.png
# /content/Imagenes/img/transformed_0072.png
# /content/Imagenes/img/transformed_0418.png
# /content/Imagenes/img/transformed_0652.png
# /content/Imagenes/img/transformed_0426.png
# /content/Imagenes/img/transformed_0552.png
# /content/Imagenes/img/transformed_0518.png
# /content/Imagenes/img/transformed_0251.png
# /content/Imagenes/img/transformed_0045.png
# /content/Imagenes/img/transformed_0095.png
# /content/Imagenes/img/transformed_0645.png
# /content/Imagenes/img/transformed_0227.png
# /content/Imagenes/img/transformed_0260.png
# /content/Imagenes/img/transformed_0285.png
# /content/Imagenes/img/transformed_0183.png
# /content/Imagenes/img/transformed_0196.png
# /content/Imagenes/img/transformed_0304.png
# /content/Imagenes/img/transformed_0514.png
# /content/Imagenes/img/transformed_0271.png
# /content/Imagenes/img/transformed_0093.png
# /content/Imagenes/img/transformed_0588.png
# /content/Imagenes/img/transformed_0176.png
# /content/Imagenes/img/transformed_0247.png
# /content/Imagenes/img/transformed_0284.png
# /content/Imagenes/img/transformed_0317.png
# /content/Imagenes/img/transformed_0308.png
# /content/Imagenes/img/transformed_0068.png
# /content/Imagenes/img/transformed_0574.png
# /content/Imagenes/img/transformed_0042.png
# /content/Imagenes/img/transformed_0008.png
# /content/Imagenes/img/transformed_0014.png
# /content/Imagenes/img/transformed_0094.png
# /content/Imagenes/img/transformed_0205.png
# /content/Imagenes/img/transformed_0717.png
# /content/Imagenes/img/transformed_0148.png
# /content/Imagenes/img/transformed_0733.png
# /content/Imagenes/img/transformed_0033.png
# /content/Imagenes/img/transformed_0798.png
# /content/Imagenes/img/transformed_0551.png
# /content/Imagenes/img/transformed_0122.png
# /content/Imagenes/img/transformed_0696.png
# /content/Imagenes/img/transformed_0086.png
# /content/Imagenes/img/transformed_0055.png
# /content/Imagenes/img/transformed_0368.png
# /content/Imagenes/img/transformed_0434.png
# /content/Imagenes/img/transformed_0513.png
# /content/Imagenes/img/transformed_0763.png
# /content/Imagenes/img/transformed_0051.png
# /content/Imagenes/img/transformed_0009.png
# /content/Imagenes/img/transformed_0522.png
# /content/Imagenes/img/transformed_0650.png
# /content/Imagenes/img/transformed_0341.png
# /content/Imagenes/img/transformed_0303.png
# /content/Imagenes/img/transformed_0782.png
# /content/Imagenes/img/transformed_0465.png
# /content/Imagenes/img/transformed_0557.png
# /content/Imagenes/img/transformed_0533.png
# /content/Imagenes/img/transformed_0682.png
# /content/Imagenes/img/transformed_0501.png
# /content/Imagenes/img/transformed_0299.png
# /content/Imagenes/img/transformed_0635.png
# /content/Imagenes/img/transformed_0389.png
# /content/Imagenes/img/transformed_0345.png
# /content/Imagenes/img/transformed_0216.png
# /content/Imagenes/img/transformed_0428.png
# /content/Imagenes/img/transformed_0705.png
# /content/Imagenes/img/transformed_0309.png
# /content/Imagenes/img/transformed_0508.png
# /content/Imagenes/img/transformed_0712.png
# /content/Imagenes/img/transformed_0053.png
# /content/Imagenes/img/transformed_0633.png
# /content/Imagenes/img/transformed_0257.png
# /content/Imagenes/img/transformed_0423.png
# /content/Imagenes/img/transformed_0215.png
# /content/Imagenes/img/transformed_0059.png
# /content/Imagenes/img/transformed_0732.png
# /content/Imagenes/img/transformed_0576.png
# /content/Imagenes/img/transformed_0561.png

# %%
dmg=DataSetManage()
directoriolw={
     "lw":["/content/Imagenes/clas1/",1],
}





listas_directorios,listas_paths_directorios,listas_clases=dmg.separar_datos_directorios(directoriolw)
Dataset_csv="dataset.csv" #nombre que tenda nuestlo csv
dmg.crear_paths_csv(listas_directorios,listas_paths_directorios,listas_clases,Dataset_csv)
# Out:
# Csv Creado

# %%
#DEFNIIR DISPOSITIVO:
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("CUDA está disponible.")
    device = torch.device("cuda")
else:
    print("CUDA no está disponible. Se utilizará la CPU.")
    device = torch.device("cpu")
# Out:
# CUDA está disponible.

# %%
#@markdown # *2) ** Creacion de clase DATASET(OBLIGATORIO)
import torch
from torch.utils.data import Dataset,DataLoader
import pandas as pd
import numpy as np
import cv2
from PIL import Image


class MiDataSet(Dataset):
    def __init__(self, csv, transform=None):
        self.data = pd.read_csv(csv)
        self.path = self.data["path"]
        self.samples = self.data["path"].shape[0]
        self.transform = transform

    def __getitem__(self, idx):
        ruta = self.path[idx]

        # Abrir la imagen
        img = Image.open(ruta).convert('RGB')

        # Convertir la imagen a modo LAB
        lab_img = img.convert('LAB')

        # Separar los canales LAB
        l_channel, a_channel, b_channel = lab_img.split()

        # Convertir los canales a arrays numpy
        l_arr = np.array(l_channel)
        ab_arr = np.array([a_channel, b_channel])

        if self.transform:
            l_arr = self.transform(l_channel)
            ab_arr = self.transform(np.concatenate((np.expand_dims(a_channel,axis=2), np.expand_dims(b_channel,axis=2)), axis=2))

        return l_arr, ab_arr

    def __len__(self):
        return self.samples

# %%
#CREANDO DATASETS Y DATALOADERS:

import numpy as np
import matplotlib.pyplot as plt
import torch
from torchvision import datasets, transforms

transformaciones = transforms.Compose([
    transforms.ToTensor(),

])

batch_size=15




dataset =MiDataSet("/content/dataset.csv",transformaciones)
data_loader=DataLoader(dataset,batch_size=batch_size)

l1,ab=dataset.__getitem__(10)

print(l1.shape)
print(ab.shape)
l1 = l1.squeeze().numpy()
ab = ab.squeeze().numpy()
# Visualizar la imagen generada
# Subfigura l1
plt.subplot(1, 2, 1)
plt.imshow(l1)
plt.title('l1')

# Subfigura ab
plt.subplot(1, 2, 1)
plt.imshow(ab)
plt.title('ab')

# Ajustar diseño
plt.tight_layout()

# Mostrar las imágenes
plt.show()

# %%
#@markdown # *0) ** Creando clase Discriminadora:

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
from torch.utils.data import Dataset,DataLoader
import torchvision.transforms as transforms
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as F

class cnnBlock(nn.Module):
  def __init__(self,in_channels,out_channels,stride=2):
   super(cnnBlock,self).__init__()
   self.conv=nn.Sequential(
         nn.Conv2d(in_channels,out_channels,4,stride,padding=1),
         nn.BatchNorm2d(out_channels),
         nn.LeakyReLU(0.2),
     )
  def forward(self,x):
    return self.conv(x)

class Discriminator (nn.Module):
  def __init__(self):
   super(Discriminator,self).__init__()

   self.inicial=nn.Sequential(
                           nn.Conv2d(3*2,64,4,2,1),
                           nn.LeakyReLU(0.2),
                        )

   self.cnnblock1=cnnBlock(64,128)
   self.cnnblock2=cnnBlock(128,256)
   self.cnnblock3=cnnBlock(256,512,stride=1)

   self.lastconv= nn.Conv2d(512,1,4,1,1)


  def forward(self,x,y):

    x=torch.cat([x,y],dim=1)

    x=self.inicial(x)
    x=self.cnnblock1(x)
    x=self.cnnblock2(x)
    x=self.cnnblock3(x)

    x=self.lastconv(x)
    out=torch.sigmoid(x)

    return out

# %%
discriminador=Discriminator()
discriminador=discriminador.to(device)
x=torch.randn(20,3,256,256).to(device)
y=torch.randn(20,3,256,256).to(device)
print(discriminador(x,y).shape)
# Out:
# torch.Size([20, 1, 30, 30])

# %%
#---------------------GENERADOR BASADO EN U- NET---------------------------------------------------

import torch.nn.functional as F

#input debe ser 256x256 otras dimeneoins  puede que tenega eror al mometno de concat las dimenes reducidas debe de conicidir y este unetblacok se ajsuta a una etnrada 256x256
class U_Net_block(nn.Module):

  def __init__(self,in_channel,out_channel,type,activacion="leakyrelu",dropout_on="False"):
   super(U_Net_block,self).__init__()

   if type=="down" :

    self.block=nn.Conv2d(in_channel,out_channel,kernel_size=4,stride=2,padding=1)

   elif type=="up":

    self.block=nn.ConvTranspose2d(in_channel,out_channel,kernel_size=4,stride=2,padding=1)

   self.batchnorm=nn.BatchNorm2d(out_channel)

   self.activacion=activacion
   self.leakyrelu=nn.LeakyReLU(0.2)
   self.relu=nn.ReLU()

   self.dropout_on=dropout_on # solo si necsitmos usar el dropout

   self.dropout=nn.Dropout(0.5)

  def forward(self,x):

     x=self.block(x)
     x=self.batchnorm(x)

     if(self.activacion=="leakyrelu"):
      out=self.leakyrelu(x)
     else:
      out=self.relu(x)

     if(self.dropout_on==True):
      out=self.dropout(x)

     return out


class Generator_U_Net(nn.Module):

    def __init__(self,in_channel=3):
        super(Generator_U_Net,self).__init__()

        # Encoder Seccion:

        self.inicial=nn.Sequential(
            nn.Conv2d(in_channel,64,kernel_size=4,stride=2,padding=1), # primer bloque convolucional down no tiene batchnorm
            nn.LeakyReLU(0.2)
        )


        self.encoder1=U_Net_block(64,128,"down",activacion="leakyrelu")
        self.encoder2=U_Net_block(128,256,"down",activacion="leakyrelu")
        self.encoder3=U_Net_block(256,512,"down",activacion="leakyrelu")
        self.encoder4=U_Net_block(512,512,"down",activacion="leakyrelu")
        self.encoder5=U_Net_block(512,512,"down",activacion="leakyrelu")
        self.encoder6=U_Net_block(512,512,"down",activacion="leakyrelu")

        self.bottleneck=nn.Sequential( nn.Conv2d(512,512,4,2,1),
                                       nn.ReLU())

        # Decoder Seccion:


        self.decoder1=U_Net_block(512,512,"up",activacion="relu")
        self.decoder2=U_Net_block(1024,512,"up",activacion="relu")
        self.decoder3=U_Net_block(1024,512,"up",activacion="relu")
        self.decoder4=U_Net_block(1024,512,"up",activacion="relu")
        self.decoder5=U_Net_block(1024,256,"up",activacion="relu")
        self.decoder6=U_Net_block(512,128,"up",activacion="relu")
        self.decoder7=U_Net_block(256,64,"up",activacion="relu")


        # Last

        self.lastup=nn.Sequential(
            nn.ConvTranspose2d(128,in_channel,kernel_size=4,stride=2,padding=1),
            nn.Tanh(),
        )

    def forward(self,x):

        d1=self.inicial(x) # d1 ->64 out
        d2=self.encoder1(d1) # d2 ->128 out
        d3=self.encoder2(d2) # d3 ->256 out
        d4=self.encoder3(d3) # d4 ->512 out
        d5=self.encoder4(d4) # d5 ->512 out
        d6=self.encoder5(d5) # d6 ->512 out
        d7=self.encoder6(d6) # d7 ->512 out

        bneck=self.bottleneck(d7)  #bneck -> 512 out

        e1=self.decoder1(bneck) #e1 -> 512 out
        e2=self.decoder2(torch.cat([e1,d7],1)) # e2  in ->512+512=1024  out->512
        e3=self.decoder3(torch.cat([e2,d6],1)) # e3  in ->512+512=1024   out->512
        e4=self.decoder4(torch.cat([e3,d5],1)) # e4 in ->512+512=1024   out->512
        e5=self.decoder5(torch.cat([e4,d4],1)) # e5 in ->512+512=1024    out->256

        e6=self.decoder6(torch.cat([e5,d3],1)) # e6 in ->256+256=512   out->128
        e7=self.decoder7(torch.cat([e6,d2],1)) # e7 in ->128+128=256  out->64
        print("pasamos")

        out=self.lastup(torch.cat([e7,d1],1)) # last in 64+64  out->3

        return out

# %%
#VAMOS A VER QUE MEDIADES EL GENERADOR DA COMO RESUTLADO CON LW RESOLUTIONS MEDIDAES:

generador=Generator_U_Net()
generador=generador.to(device)
x=torch.randn(20,3,256,512).to(device)

print(generador(x).shape)
# Out:
# pasamos
# torch.Size([20, 3, 256, 512])

# %%
#PROBAMOS EL GENERADOR INCIAL:

from PIL import Image
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt


#--------------------------------------------------------------------------------------------------------
def show_comparacion(real,generado): #deben de ingrenar don tennoren de imagen generada y real
 print(generado.shape)
 print(real.shape)
 real=real.detach().squeeze().cpu().numpy().transpose(1, 2, 0)
 generado=generado.squeeze().cpu().detach().numpy().transpose(1, 2, 0)
# Primer subgráfico: imagen original
 plt.subplot(1, 2, 1)
 plt.imshow(generado)  # Convertir a NumPy y transponer dimensiones
 plt.title('Imagen Generada')
 plt.axis('off')

# Segundo subgráfico: imagen transformada
 plt.subplot(1, 2, 2)
 plt.imshow(real)  # Convertir a NumPy y transponer dimensiones
 plt.title('Imagen Real')
 plt.axis('off')

# Ajustar el diseño para evitar superposición de títulos
 plt.tight_layout()

# Mostrar la figura
 plt.show()


 plt.figure(figsize=(10, 5))
#-----------------------------------------------------------------------------------
generador=Generator_U_Net().to("cpu")


ruta_imagen = "/content/baboon.png"
imagen = Image.open(ruta_imagen)

transformaciones = transforms.Compose([
    transforms.Resize((256,256)),
    transforms.ToTensor(),
])

#original iamgen tensor
tensor_imagen = transformaciones(imagen).unsqueeze(0)
tensor_imagen=tensor_imagen.to("cpu")

#imagen generada
imagen_generada=generador(tensor_imagen)
print(imagen_generada.shape)
imagen_numpy = imagen_generada.squeeze().detach().numpy()

# Mostrar la imagen utilizando matplotlib
plt.imshow(imagen_numpy.transpose(1, 2, 0))  # cmap='gray' es para mostrar la imagen en escala de grises
plt.axis('off')  # Ocultar ejes
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# pasamos
# torch.Size([1, 3, 256, 256])

# %%
from torchvision import models

#vamos a extraer los feature es decir las caracteisicas imporantes que exiten entre ambas imagnes y compraralas esto se usara par luego hace rel loss contet apartir del contendio

class Feature_Extractor(nn.Module):
    def __init__(self):
        super(Feature_Extractor, self).__init__()
        # Cargar un modelo VGG-19 preentrenado
        vgg19_model = models.vgg16(pretrained=True).features.eval()

        # No actualizar los pesos del modelo VGG durante el entrenamiento
        for param in vgg19_model.parameters():
            param.requires_grad = False

        selected_layers = list(vgg19_model.children())[:31] #AGREGAMOS EL VGG HASTA VERFICAR QUE EL ULITMA CAPA NO TENGA RELU

        self.vgg=nn.Sequential(*selected_layers)

    def forward(self, img):

        # Extraer características de las imágenes generada y real
        feature_img = self.vgg(img)

        return feature_img


# TV Loss se utiliza comúnmente en tareas de generación de imágenes para reducir el ruido y fomentar la suavidad en las imágenes generadas.

class TVLoss(nn.Module):
  def __init__(self, tv_loss_weight=1):
    super(TVLoss, self).__init__()
    self.tv_loss_weight=tv_loss_weight
  def forward(self, x):
    batch_size=x.size()[0]
    h_x = x.size()[2]
    w_x = x.size()[3]

    count_h = self.tensor_size(x[:, :, 1:, :])
    count_w = self.tensor_size(x[:, :, :, 1:])


    h_tv = torch.pow(x[:, :, 1:, :] - x[:, :, :h_x - 1, :], 2).sum()
    w_tv = torch.pow(x[:, :, :, 1:] - x[:, :, :, :w_x - 1], 2).sum()
    return self.tv_loss_weight * 2 * (h_tv / count_h + w_tv / count_w) / batch_size

  # Forgot to implement an important method
  @staticmethod # Must add this
  def tensor_size(t):
    return t.size()[1] * t.size()[2] * t.size()[3]


def psnr(image1, image2):
    mse = torch.mean((image1 - image2) ** 2)
    if mse == 0:
        return float('inf')
    max_pixel = 1
    psnr_value = 10 * torch.log10((max_pixel ** 2) / mse)
    return psnr_value

# %%
vgg=Feature_Extractor()
print(vgg)
tv_loss= TVLoss()
x=torch.randn(18,3,60,60)
tv_loss=tv_loss(x)

print(tv_loss)

# %%
import matplotlib.pyplot as plt
import torch
import numpy as np
import torchvision.utils as vutils
import sklearn
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset
from tqdm import tqdm
# ...

#d=Discriminator(image_dim).to(device)
#g=Generador(dim_vector_ruido,image_dim).to(device)

#d.load_state_dict(torch.load("/content/modelo_gatos_d.pt"))
#g.load_state_dict(torch.load("/content/modelo_gatos_g.pt"))

#d=d.to(device)
#g=g.to(device)


# Supongamos que ya has definido las instancias de los modelos Generador (g) y Discriminador (d),
# y has configurado los optimizadores (g_optimizer y d_optimizer) y la función de pérdida (criterio).



def GAN(discriminador, generador, data_loader_lw,data_loader_hr, num_epochs, batch_size, criterio_g,criterio_d, d_optimizador, g_optimizador, device):

    discriminador=discriminador.to(device)
    generador=generador.to(device)
    feature_extractor=Feature_Extractor().to(device)
    tv_loss= TVLoss().to(device)


    for epoch in range(num_epochs):

        resultados = { 'd_loss':[],"g_loss":[], "d_score":[], "psnr":[]}
        train_bar = tqdm(data_loader_hr)

        for  (lw, hr) in zip(data_loader_lw,data_loader_hr):

            hr_img,hrlbl=hr
            lw_img,lwlbl=lw

            hr_img=hr_img.to(device)
            lw_img=lw_img.to(device)

            generador.eval()
            discriminador.train()

            real_images = hr_img.float()

            real_labels = hrlbl.view(-1, 1).float().to(device)

            # Entrenar el discriminador con imágenes reales
            d_optimizador.zero_grad()

            prediction_real = discriminador(real_images)

            real_loss = criterio_d(prediction_real, real_labels)


            # Entrenar el discriminador con imágenes generadas

            fake_images = generador(lw_img)
            fake_labels = torch.zeros(lw_img.size(0), 1).to(device)

            prediction_fake = discriminador(fake_images)

            fake_loss = criterio_d(prediction_fake, fake_labels).to(device)
            discriminator_loss = (real_loss + fake_loss)/2

            discriminator_loss.backward(retain_graph=True)

            d_optimizador.step()

            # Entrenar el generador
            generador.train()
            discriminador.eval()
            g_optimizador.zero_grad()

            generated_images = generador(lw_img)
            loss_g=criterio_g(discriminador(generated_images),real_labels) #loss del generador aparitr del disicmirnador que dice si es o no una imagen falsa

            loss_imagen=criterio_g(generated_images,real_images) #loss imagen dircamtetne entre igmagen genrada y real

            generated_features=feature_extractor(generated_images)
            real_features=feature_extractor(real_images)

            content_loss=(criterio_g(generated_features, real_features)) #loss de los features original y generado,esto aparitr de el vgg19

            psnr_batch=psnr(generated_images,real_images).to(device)
            psnr_promedio=psnr_batch.mean()

            tv_losss=tv_loss(generated_images)
            generator_loss = loss_imagen+(torch.abs(0.39-(0.01*psnr_promedio)))+0.006*content_loss+(0.001*loss_g)+  2e-8 *tv_losss  #loss total del generador

            torch.autograd.set_detect_anomaly(True)
            generator_loss.backward()
            g_optimizador.step()


            #resultados por batch:
            resultados["d_loss"].append(discriminator_loss.item())
            resultados["g_loss"].append(generator_loss.item())
            resultados["psnr"].append(psnr_promedio).cpu()

            train_bar.set_description(desc="[%d/%d] Loss_D: %.4f Loss_G: %.4f D(x): %.4f D(G(z)): %.4f" % (
            epoch, num_epochs, np.mean(resultados['d_loss']),
            np.mean(resultados['g_loss']) ,
            np.mean( resultados['psnr']) ,

    ))

        # Imprimir estadísticas y visualizar imágenes generadas al final de cada época
        print(f'Época [{epoch}/{num_epochs}] '
                      f'Pérdida del Discriminador: {np.mean(resultados["d_loss"]):.4f}, '
                      f'Pérdida del Generador: {np.mean(resultados["g_loss"]):.4f}',f'psnr:{np.mean(resultados["psnr"]):.4f}')
        with torch.no_grad():
            generador.eval()
            generated_images = generador(lw_img)

            print(hr_img.shape)
            print(hrlbl[0])
            print(lwlbl[0])
            show_comparacion(hr_img[0],generated_images[0])


#--------------------------------------------------------------------------------------------



num_epochs=10





d=Discriminator()
g=Generador(2)

#d.load_state_dict(torch.load("/content/srgan_d.pt"))
#g.load_state_dict(torch.load("/content/srgan_g.pt"))

lr_g = 0.00008
lr_d = 0.000008
d_optimizer=optim.Adam(d.parameters(),lr=lr_d)
g_optimizer=optim.Adam(g.parameters(),lr=lr_g)

criterio_d=nn.BCELoss()
criterio_g=nn.MSELoss()


print(f"learning rate discrimiador:{lr_d}")
print(f"learning rate generador:{lr_g}")

GAN(d,g,data_loaderLw,data_loaderHr,num_epochs,batch_size,criterio_g,criterio_d,d_optimizer,g_optimizer,device)

# %%
torch.save(g.state_dict(), 'srgan_g.pt')
torch.save(d.state_dict(), 'srgan_d.pt')

# %%
d.load_state_dict(torch.load("/content/srgan_d.pt"))
# Out:
# <All keys matched successfully>

# %%
from PIL import Image
# Suponiendo que "Generador" es la clase de tu generador y "ruta_modelo" es la ruta del modelo guardado
generador = Generador(2)  # creando generado
generador.load_state_dict(torch.load("/content/srgan_g.pt"))
generador.to(device)
generador.eval()

ruta_imagen = "/content/baboon.png"
imagen_pil = Image.open(ruta_imagen)

transformaciones = transforms.Compose([
    transforms.ToTensor(),  # Convierte la imagen a un tensor

])

imagen_transformada = transformaciones(imagen_pil)
imagen_transformada=imagen_transformada.to(device)
with torch.no_grad():
    generador.eval()

    generated_image = generador(imagen_transformada.unsqueeze(0)).detach().cpu()

# Convertir la imagen al rango [0, 1]
# generated_image = (generated_image + 1) / 2.0

generated_image_np = generated_image.squeeze().permute(1, 2, 0).numpy()

print(generated_image.shape)
# Visualizar la imagen generada
plt.imshow(generated_image_np)
plt.axis('off')
plt.show()


# Convertir el tensor a una imagen
tensor_a_imagen = transforms.ToPILImage()(generated_image.squeeze())

# Guardar la imagen
tensor_a_imagen.save("imagen_guardadahd.jpg")
# Out:
# 64
# 64
# torch.Size([1, 3, 480, 500])
