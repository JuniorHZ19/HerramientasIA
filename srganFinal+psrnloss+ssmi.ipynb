# %% [markdown]
# <a href="https://colab.research.google.com/github/JuniorHZ19/HerramientasIA/blob/main/srganFinal%2Bpsrnloss%2Bssmi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# !unzip DIV2K_train_HR.zip # This is our dataset link. I will include this command in the description

# %%
#@markdown # *0) ** Instalando libreria(OBLIGATORIO)

# !pip install torch torchvision torchaudio

# %%
#@markdown # *1) ** Clase Para manejo de directorios de datasets de imagenes


import os
import cv2
import pandas as pd
from PIL import Image
import torch
from torchvision import transforms
# Recorre el directorio  y elmiina los archvios que no tiene las extensioens permitidas

class DataSetManage:




 def comprobar_ext_directorios(self,directorio):

  for clase,[directorio,etiquetas] in(directorio.items()):
   lista_directorio=os.listdir(directorio)
   self._validarExt(directorio)



 def  _validarExt(self,directorio):
  print(directorio)
   # Extensiones permitidas
  extensiones_permitidas = {".jpg", ".jpeg", ".png"}
  for root, dirs, files in os.walk(directorio):

    for file in files:
        # Obtiene la extensión del archivo
        _, extension = os.path.splitext(file)

        # Verifica si la extensión no está en la lista de extensiones permitidas y elimina el archivo
        if extension.lower() not in extensiones_permitidas:
            archivo_a_eliminar = os.path.join(root, file)
            os.remove(archivo_a_eliminar)
            print(f"Se eliminó: {archivo_a_eliminar}")


# Cambia nombre de cada archivo dentro del directorio a un valor secuencial

 def cambiar_nombres_directorios(self,directorio):
   for clase,[directorio,etiquetas] in(directorio.items()):
     lista_directorio=os.listdir(directorio)
     self._cambiarNombre(directorio,clase)
     print(directorio)


 def _cambiarNombre(self,directorios,subfijo):
  archivos_en_directorio = os.listdir(directorios)
  for i, archivo in enumerate(archivos_en_directorio, start=1):
    # Construir el nuevo nombre del archivo
    nuevo_nombre = f"{subfijo}{i}{os.path.splitext(archivo)[1]}"

    # Ruta completa del archivo antiguo y nuevo
    ruta_antigua = os.path.join(directorios, archivo)
    ruta_nueva = os.path.join(directorios, nuevo_nombre)

    # Cambiar el nombre del archivo
    os.rename(ruta_antigua, ruta_nueva)
    print(f"Se cambió el nombre de {ruta_antigua} a {ruta_nueva}")


#Obtiene la cantidad de elemntos que tiene la carpeta

 def len_directorio(self,directorio):
    cantidad_elementos = sum(1 for elemento in os.listdir(directorio) if os.path.isfile(os.path.join(directorio, elemento)))
    return cantidad_elementos


#----------------------------------------------------------------------------------------------

#Valida si la imagen se puede leer usando  pill o cv2 si no se puede leer se elimina

 def validar_Img_Pill(self,directorio,):
  for etiqueta,[directorio,clase] in(directorio.items()):

    lista_paths=os.listdir(directorio)
    self._validarLecturaImgPill(directorio,lista_paths)
  print(f"Se ah validado todas las imagenes")

 def validar_Img_cv2(self,directorio):
  for etiqueta,[directorio,clase] in(directorio.items()):

    lista_paths=os.listdir(directorio)
    self._validarLecturaImg(directorio,lista_paths)
  print(f"Se ah validado todas las imagenes")

 def _validarLecturaImg(self,directorio,lista):

  for ruta in(lista):
   imagen=cv2.imread(directorio+ruta)
   if  imagen is None:
     os.remove(directorio+ruta)
     print(f"No se pudo leer y se elimino archivo:{directorio+ruta}")

 def _validarLecturaImgPill(self,directorio,lista):
    for ruta in(lista):
     try:
      imagen=Image.open(directorio+ruta)
     except Exception as e:
      os.remove(directorio+ruta)
      print(f"Archivo '{directorio+ruta}' eliminado.")



#vamos a recorrer el dicionario y validar ruta por ruta si se puede leer sino se elminara
#vamos guaradno al mismo tiempo 3 listas, los directorios , listas de paths de los directiros y de las clases ,para usarlo luego usarlo al crear el csv

 def separar_datos_directorios(self,directorios):
  listas_directorios=[]
  listas_listas_directorios=[]
  listas_clases=[]

  for etiqueta,[directorio,clase] in(directorios.items()):

       lista_paths=os.listdir(directorio)
       listas_directorios.append(directorio)
       listas_listas_directorios.append(lista_paths)
       listas_clases.append(clase)

  return listas_directorios,listas_listas_directorios,listas_clases

 def emparejar_listas_paths(self,lista_listas):

   #Tomamos el minimo tamaño dentro de las lista de cada clase
   tamaño_minimo = min(len(arr) for arr in lista_listas)

   #Vamos a emparejar todas las listas con un tamaño igual que sea la del minimo tamaño de todas,esto para tener un set de datos parejo por cada clase
   Reducido_lista_paths=[]

   #Reduce cada lista de los paths a la cantidad minimo para que todos tenga iaugal cantidad
   for listas in(lista_listas):
    Reducido_lista_paths.append(listas[:tamaño_minimo])

   return Reducido_lista_paths
#---------------------------------------------------------------------------------


 def crear_paths_csv(self,directorio_base,lista_paths,clases,nombre_archivo):

   columnas=["path","etiqueta"]
   datos_csv=[]

   for dir_base,dir_path,clase in  zip(directorio_base,lista_paths,clases):

    for path  in (dir_path):

     datos_csv.append([dir_base+path ,clase])


   df_lista=pd.DataFrame(datos_csv,columns=columnas)
   df_lista=df_lista.sort_values(by='path')
   df_lista.to_csv(nombre_archivo,index=False)
   print("Csv Creado")
#---------------------------------------------------------------------------------

#devuelve cuatnos elemtnos tiene cada clase
 def total_elementos(self,directorio,csv_path):
    df=pd.read_csv(csv_path)
    for clase,[directorio,etiqueta] in (directorio.items()):
     tamaño_etiqueta=(df["etiqueta"] == etiqueta).sum()
     print(f"la clase {clase} tiene :{tamaño_etiqueta} elementos")


#-------------------------------------------------------------------------------------------------

  #Funciones para data aumentation
 def   data_aumentation_conjunto(self,input_imagen_folder,output_path_folder,iteraciones,transformaciones,keepname=False):  #ingresa trnasformacioens como compose donde se aplicara las trasnfomracioens conjutnos pero se repteira un numero de veces por cada imagen

   for filename in os.listdir(input_imagen_folder):

    if filename.endswith('.jpg') or filename.endswith('.png'):

        input_path = os.path.join(input_imagen_folder, filename)
        if(keepname==False):
         output_path = os.path.join(output_path_folder, f'transformed_{filename}')
        else:
          output_path = os.path.join(output_path_folder, f'{filename}')
        # Aplica las transformaciones
        print(output_path)
        self._apply_transfomaciones_conjunto_it(input_path,output_path,int(iteraciones),transformaciones,keepname)


 def   data_aumentation_individual(self,input_imagen_folder,output_path_folder,transformaciones,keepname=False):  #las trnasfomaciones solo pasaremos la lista ya que ira aplicando la transformacion una por una por cada imagen

  for filename in os.listdir(input_imagen_folder):

    if filename.endswith('.jpg') or filename.endswith('.png'):
        input_path = os.path.join(input_imagen_folder, filename)
        if(keepname==False):
         output_path = os.path.join(output_path_folder, f'transformed_{filename}')
         print("opasasmos")
        else:
          output_path = os.path.join(output_path_folder, f'{filename}')
        # Aplica las transformaciones
        self._apply_transfomaciones_conjunto(input_path,output_path,transformaciones,keepname)



 def _apply_transfomaciones_conjunto_it(self,input_imagen_path,output_iamgen_path,iteraciones,transformations=None,keepname=False): #aplica las transfomracioens  conjutas por iteracion y se guarda las iamgenes

   imagen=Image.open(input_imagen_path)


   for i in range(iteraciones):
      imagen_trasformada=transformations(imagen)

      out_root, out_extension = os.path.splitext(output_iamgen_path)
      if(keepname==False):
       imagen_trasformada.save(f"{out_root}_{i}{out_extension}")
      else:
        imagen_trasformada.save(f"{out_root}{out_extension}")

 def _apply_transfomaciones_conjunto(self,input_imagen_path,output_iamgen_path,transformations=None,keepname=False): #aplica las transfomracioens individuales  y se guarda las iamgenes

  imagen=Image.open(input_imagen_path)

  for i,transformacion in enumerate(transformations):
   imagen_transformada=transformacion(imagen)
   out_root, out_extension = os.path.splitext(output_iamgen_path)
   if(keepname==False):
     imagen_transformada.save(f"{out_root}_{i}{out_extension}")
   else:
      imagen_transformada.save(f"{out_root}{out_extension}")

# %%
#Creamos las carpetas con las imagenes en hr y lw

#Creamos los arhcivo baja resolucion aparitr de imangenes alta resoulcion en hr , estos archios iran a carpaeta lw
directorio_in="/content/DIV2K_train_HR"
directorio_out_lw="/content/lw/"
directorio_out_hr="/content/hr/"

#antes de otrogar mediads de hr y lw , chekea como el generador va votando las resolucioens hr_fake segun la resolucion lw que especifics tiene qeu conicidr
#ya que el discriminador necsita la misma medidades tanto para el hr y el hr_fake que genera el generador

transformaciones_hr=transforms.Compose([
transforms.RandomCrop(size=(80, 80)),

])


transformaciones_lw=transforms.Compose([
transforms.Resize((20,20),interpolation=transforms.InterpolationMode.BICUBIC),
])



datasetmanage=DataSetManage()
datasetmanage.data_aumentation_conjunto(directorio_in,directorio_out_hr,4,transformaciones_hr)
datasetmanage.data_aumentation_conjunto(directorio_out_hr,directorio_out_lw,1,transformaciones_lw,keepname=True)
sorted(directorio_out_hr)
sorted(directorio_out_lw)
# Out:
# /content/hr/transformed_0745.png
# /content/hr/transformed_0739.png
# /content/hr/transformed_0679.png
# /content/hr/transformed_0054.png
# /content/hr/transformed_0133.png
# /content/hr/transformed_0118.png
# /content/hr/transformed_0602.png
# /content/hr/transformed_0670.png
# /content/hr/transformed_0061.png
# /content/hr/transformed_0030.png
# /content/hr/transformed_0622.png
# /content/hr/transformed_0556.png
# /content/hr/transformed_0070.png
# /content/hr/transformed_0409.png
# /content/hr/transformed_0453.png
# /content/hr/transformed_0264.png
# /content/hr/transformed_0461.png
# /content/hr/transformed_0582.png
# /content/hr/transformed_0758.png
# /content/hr/transformed_0036.png
# /content/hr/transformed_0216.png
# /content/hr/transformed_0138.png
# /content/hr/transformed_0772.png
# /content/hr/transformed_0755.png
# /content/hr/transformed_0697.png
# /content/hr/transformed_0548.png
# /content/hr/transformed_0422.png
# /content/hr/transformed_0253.png
# /content/hr/transformed_0435.png
# /content/hr/transformed_0459.png
# /content/hr/transformed_0183.png
# /content/hr/transformed_0275.png
# /content/hr/transformed_0198.png
# /content/hr/transformed_0490.png
# /content/hr/transformed_0531.png
# /content/hr/transformed_0620.png
# /content/hr/transformed_0221.png
# /content/hr/transformed_0460.png
# /content/hr/transformed_0284.png
# /content/hr/transformed_0269.png
# /content/hr/transformed_0710.png
# /content/hr/transformed_0098.png
# /content/hr/transformed_0047.png
# /content/hr/transformed_0730.png
# /content/hr/transformed_0782.png
# /content/hr/transformed_0164.png
# /content/hr/transformed_0131.png
# /content/hr/transformed_0116.png
# /content/hr/transformed_0063.png
# /content/hr/transformed_0188.png
# /content/hr/transformed_0744.png
# /content/hr/transformed_0267.png
# /content/hr/transformed_0616.png
# /content/hr/transformed_0608.png
# /content/hr/transformed_0364.png
# /content/hr/transformed_0553.png
# /content/hr/transformed_0325.png
# /content/hr/transformed_0299.png
# /content/hr/transformed_0747.png
# /content/hr/transformed_0667.png
# /content/hr/transformed_0305.png
# /content/hr/transformed_0052.png
# /content/hr/transformed_0756.png
# /content/hr/transformed_0748.png
# /content/hr/transformed_0711.png
# /content/hr/transformed_0538.png
# /content/hr/transformed_0507.png
# /content/hr/transformed_0004.png
# /content/hr/transformed_0463.png
# /content/hr/transformed_0017.png
# /content/hr/transformed_0641.png
# /content/hr/transformed_0363.png
# /content/hr/transformed_0572.png
# /content/hr/transformed_0472.png
# /content/hr/transformed_0791.png
# /content/hr/transformed_0281.png
# /content/hr/transformed_0219.png
# /content/hr/transformed_0023.png
# /content/hr/transformed_0350.png
# /content/hr/transformed_0228.png
# /content/hr/transformed_0735.png
# /content/hr/transformed_0778.png
# /content/hr/transformed_0311.png
# /content/hr/transformed_0245.png
# /content/hr/transformed_0766.png
# /content/hr/transformed_0733.png
# /content/hr/transformed_0425.png
# /content/hr/transformed_0546.png
# /content/hr/transformed_0089.png
# /content/hr/transformed_0402.png
# /content/hr/transformed_0727.png
# /content/hr/transformed_0776.png
# /content/hr/transformed_0356.png
# /content/hr/transformed_0706.png
# /content/hr/transformed_0012.png
# /content/hr/transformed_0225.png
# /content/hr/transformed_0268.png
# /content/hr/transformed_0684.png
# /content/hr/transformed_0028.png
# /content/hr/transformed_0065.png
# /content/hr/transformed_0580.png
# /content/hr/transformed_0438.png
# /content/hr/transformed_0200.png
# /content/hr/transformed_0084.png
# /content/hr/transformed_0038.png
# /content/hr/transformed_0581.png
# /content/hr/transformed_0451.png
# /content/hr/transformed_0551.png
# /content/hr/transformed_0135.png
# /content/hr/transformed_0447.png
# /content/hr/transformed_0117.png
# /content/hr/transformed_0309.png
# /content/hr/transformed_0591.png
# /content/hr/transformed_0229.png
# /content/hr/transformed_0789.png
# /content/hr/transformed_0767.png
# /content/hr/transformed_0493.png
# /content/hr/transformed_0698.png
# /content/hr/transformed_0009.png
# /content/hr/transformed_0738.png
# /content/hr/transformed_0227.png
# /content/hr/transformed_0354.png
# /content/hr/transformed_0794.png
# /content/hr/transformed_0619.png
# /content/hr/transformed_0334.png
# /content/hr/transformed_0319.png
# /content/hr/transformed_0488.png
# /content/hr/transformed_0764.png
# /content/hr/transformed_0653.png
# /content/hr/transformed_0173.png
# /content/hr/transformed_0474.png
# /content/hr/transformed_0314.png
# /content/hr/transformed_0508.png
# /content/hr/transformed_0215.png
# /content/hr/transformed_0633.png
# /content/hr/transformed_0156.png
# /content/hr/transformed_0457.png
# /content/hr/transformed_0111.png
# /content/hr/transformed_0617.png
# /content/hr/transformed_0783.png
# /content/hr/transformed_0177.png
# /content/hr/transformed_0683.png
# /content/hr/transformed_0283.png
# /content/hr/transformed_0650.png
# /content/hr/transformed_0598.png
# /content/hr/transformed_0007.png
# /content/hr/transformed_0400.png
# /content/hr/transformed_0404.png
# /content/hr/transformed_0621.png
# /content/hr/transformed_0083.png
# /content/hr/transformed_0478.png
# /content/hr/transformed_0153.png
# /content/hr/transformed_0318.png
# /content/hr/transformed_0471.png
# /content/hr/transformed_0501.png
# /content/hr/transformed_0167.png
# /content/hr/transformed_0528.png
# /content/hr/transformed_0623.png
# /content/hr/transformed_0519.png
# /content/hr/transformed_0359.png
# /content/hr/transformed_0750.png
# /content/hr/transformed_0666.png
# /content/hr/transformed_0060.png
# /content/hr/transformed_0469.png
# /content/hr/transformed_0053.png
# /content/hr/transformed_0709.png
# /content/hr/transformed_0344.png
# /content/hr/transformed_0722.png
# /content/hr/transformed_0040.png
# /content/hr/transformed_0477.png
# /content/hr/transformed_0090.png
# /content/hr/transformed_0751.png
# /content/hr/transformed_0412.png
# /content/hr/transformed_0693.png
# /content/hr/transformed_0558.png
# /content/hr/transformed_0455.png
# /content/hr/transformed_0395.png
# /content/hr/transformed_0574.png
# /content/hr/transformed_0289.png
# /content/hr/transformed_0405.png
# /content/hr/transformed_0428.png
# /content/hr/transformed_0466.png
# /content/hr/transformed_0385.png
# /content/hr/transformed_0545.png
# /content/hr/transformed_0473.png
# /content/hr/transformed_0724.png
# /content/hr/transformed_0559.png
# /content/hr/transformed_0257.png
# /content/hr/transformed_0380.png
# /content/hr/transformed_0392.png
# /content/hr/transformed_0150.png
# /content/hr/transformed_0536.png
# /content/hr/transformed_0715.png
# /content/hr/transformed_0494.png
# /content/hr/transformed_0328.png
# /content/hr/transformed_0389.png
# /content/hr/transformed_0396.png
# /content/hr/transformed_0399.png
# /content/hr/transformed_0072.png
# /content/hr/transformed_0286.png
# /content/hr/transformed_0233.png
# /content/hr/transformed_0204.png
# /content/hr/transformed_0291.png
# /content/hr/transformed_0408.png
# /content/hr/transformed_0492.png
# /content/hr/transformed_0719.png
# /content/hr/transformed_0475.png
# /content/hr/transformed_0237.png
# /content/hr/transformed_0600.png
# /content/hr/transformed_0557.png
# /content/hr/transformed_0418.png
# /content/hr/transformed_0583.png
# /content/hr/transformed_0276.png
# /content/hr/transformed_0179.png
# /content/hr/transformed_0696.png
# /content/hr/transformed_0429.png
# /content/hr/transformed_0712.png
# /content/hr/transformed_0518.png
# /content/hr/transformed_0511.png
# /content/hr/transformed_0045.png
# /content/hr/transformed_0195.png
# /content/hr/transformed_0634.png
# /content/hr/transformed_0287.png
# /content/hr/transformed_0378.png
# /content/hr/transformed_0458.png
# /content/hr/transformed_0601.png
# /content/hr/transformed_0105.png
# /content/hr/transformed_0407.png
# /content/hr/transformed_0749.png
# /content/hr/transformed_0110.png
# /content/hr/transformed_0273.png
# /content/hr/transformed_0108.png
# /content/hr/transformed_0584.png
# /content/hr/transformed_0657.png
# /content/hr/transformed_0661.png
# /content/hr/transformed_0338.png
# /content/hr/transformed_0798.png
# /content/hr/transformed_0517.png
# /content/hr/transformed_0230.png
# /content/hr/transformed_0575.png
# /content/hr/transformed_0092.png
# /content/hr/transformed_0565.png
# /content/hr/transformed_0168.png
# /content/hr/transformed_0265.png
# /content/hr/transformed_0786.png
# /content/hr/transformed_0351.png
# /content/hr/transformed_0603.png
# /content/hr/transformed_0211.png
# /content/hr/transformed_0662.png
# /content/hr/transformed_0403.png
# /content/hr/transformed_0647.png
# /content/hr/transformed_0357.png
# /content/hr/transformed_0129.png
# /content/hr/transformed_0042.png
# /content/hr/transformed_0763.png
# /content/hr/transformed_0658.png
# /content/hr/transformed_0308.png
# /content/hr/transformed_0773.png
# /content/hr/transformed_0143.png
# /content/hr/transformed_0170.png
# /content/hr/transformed_0504.png
# /content/hr/transformed_0002.png
# /content/hr/transformed_0240.png
# /content/hr/transformed_0797.png
# /content/hr/transformed_0592.png
# /content/hr/transformed_0700.png
# /content/hr/transformed_0021.png
# /content/hr/transformed_0690.png
# /content/hr/transformed_0686.png
# /content/hr/transformed_0599.png
# /content/hr/transformed_0201.png
# /content/hr/transformed_0765.png
# /content/hr/transformed_0266.png
# /content/hr/transformed_0371.png
# /content/hr/transformed_0081.png
# /content/hr/transformed_0578.png
# /content/hr/transformed_0413.png
# /content/hr/transformed_0615.png
# /content/hr/transformed_0343.png
# /content/hr/transformed_0391.png
# /content/hr/transformed_0197.png
# /content/hr/transformed_0260.png
# /content/hr/transformed_0327.png
# /content/hr/transformed_0419.png
# /content/hr/transformed_0331.png
# /content/hr/transformed_0057.png
# /content/hr/transformed_0725.png
# /content/hr/transformed_0321.png
# /content/hr/transformed_0540.png
# /content/hr/transformed_0250.png
# /content/hr/transformed_0640.png
# /content/hr/transformed_0218.png
# /content/hr/transformed_0039.png
# /content/hr/transformed_0075.png
# /content/hr/transformed_0205.png
# /content/hr/transformed_0611.png
# /content/hr/transformed_0178.png
# /content/hr/transformed_0345.png
# /content/hr/transformed_0479.png
# /content/hr/transformed_0760.png
# /content/hr/transformed_0172.png
# /content/hr/transformed_0312.png
# /content/hr/transformed_0134.png
# /content/hr/transformed_0445.png
# /content/hr/transformed_0721.png
# /content/hr/transformed_0386.png
# /content/hr/transformed_0332.png
# /content/hr/transformed_0293.png
# /content/hr/transformed_0440.png
# /content/hr/transformed_0144.png
# /content/hr/transformed_0320.png
# /content/hr/transformed_0731.png
# /content/hr/transformed_0169.png
# /content/hr/transformed_0685.png
# /content/hr/transformed_0610.png
# /content/hr/transformed_0340.png
# /content/hr/transformed_0468.png
# /content/hr/transformed_0226.png
# /content/hr/transformed_0587.png
# /content/hr/transformed_0674.png
# /content/hr/transformed_0018.png
# /content/hr/transformed_0607.png
# /content/hr/transformed_0757.png
# /content/hr/transformed_0784.png
# /content/hr/transformed_0231.png
# /content/hr/transformed_0410.png
# /content/hr/transformed_0417.png
# /content/hr/transformed_0421.png
# /content/hr/transformed_0248.png
# /content/hr/transformed_0056.png
# /content/hr/transformed_0746.png
# /content/hr/transformed_0605.png
# /content/hr/transformed_0398.png
# /content/hr/transformed_0677.png
# /content/hr/transformed_0533.png
# /content/hr/transformed_0232.png
# /content/hr/transformed_0035.png
# /content/hr/transformed_0059.png
# /content/hr/transformed_0481.png
# /content/hr/transformed_0127.png
# /content/hr/transformed_0031.png
# /content/hr/transformed_0203.png
# /content/hr/transformed_0376.png
# /content/hr/transformed_0106.png
# /content/hr/transformed_0720.png
# /content/hr/transformed_0753.png
# /content/hr/transformed_0393.png
# /content/hr/transformed_0612.png
# /content/hr/transformed_0125.png
# /content/hr/transformed_0270.png
# /content/hr/transformed_0676.png
# /content/hr/transformed_0379.png
# /content/hr/transformed_0304.png
# /content/hr/transformed_0252.png
# /content/hr/transformed_0011.png
# /content/hr/transformed_0593.png
# /content/hr/transformed_0644.png
# /content/hr/transformed_0223.png
# /content/hr/transformed_0114.png
# /content/hr/transformed_0535.png
# /content/hr/transformed_0516.png
# /content/hr/transformed_0606.png
# /content/hr/transformed_0449.png
# /content/hr/transformed_0433.png
# /content/hr/transformed_0665.png
# /content/hr/transformed_0224.png
# /content/hr/transformed_0080.png
# /content/hr/transformed_0112.png
# /content/hr/transformed_0058.png
# /content/hr/transformed_0147.png
# /content/hr/transformed_0707.png
# /content/hr/transformed_0723.png
# /content/hr/transformed_0024.png
# /content/hr/transformed_0530.png
# /content/hr/transformed_0074.png
# /content/hr/transformed_0103.png
# /content/hr/transformed_0702.png
# /content/hr/transformed_0062.png
# /content/hr/transformed_0181.png
# /content/hr/transformed_0759.png
# /content/hr/transformed_0768.png
# /content/hr/transformed_0775.png
# /content/hr/transformed_0704.png
# /content/hr/transformed_0637.png
# /content/hr/transformed_0573.png
# /content/hr/transformed_0754.png
# /content/hr/transformed_0140.png
# /content/hr/transformed_0716.png
# /content/hr/transformed_0115.png
# /content/hr/transformed_0382.png
# /content/hr/transformed_0781.png
# /content/hr/transformed_0033.png
# /content/hr/transformed_0437.png
# /content/hr/transformed_0415.png
# /content/hr/transformed_0541.png
# /content/hr/transformed_0322.png
# /content/hr/transformed_0124.png
# /content/hr/transformed_0337.png
# /content/hr/transformed_0044.png
# /content/hr/transformed_0190.png
# /content/hr/transformed_0397.png
# /content/hr/transformed_0691.png
# /content/hr/transformed_0258.png
# /content/hr/transformed_0630.png
# /content/hr/transformed_0414.png
# /content/hr/transformed_0199.png
# /content/hr/transformed_0091.png
# /content/hr/transformed_0639.png
# /content/hr/transformed_0664.png
# /content/hr/transformed_0771.png
# /content/hr/transformed_0050.png
# /content/hr/transformed_0793.png
# /content/hr/transformed_0005.png
# /content/hr/transformed_0372.png
# /content/hr/transformed_0777.png
# /content/hr/transformed_0523.png
# /content/hr/transformed_0374.png
# /content/hr/transformed_0627.png
# /content/hr/transformed_0537.png
# /content/hr/transformed_0078.png
# /content/hr/transformed_0514.png
# /content/hr/transformed_0554.png
# /content/hr/transformed_0562.png
# /content/hr/transformed_0180.png
# /content/hr/transformed_0236.png
# /content/hr/transformed_0427.png
# /content/hr/transformed_0388.png
# /content/hr/transformed_0093.png
# /content/hr/transformed_0717.png
# /content/hr/transformed_0645.png
# /content/hr/transformed_0576.png
# /content/hr/transformed_0594.png
# /content/hr/transformed_0660.png
# /content/hr/transformed_0064.png
# /content/hr/transformed_0086.png
# /content/hr/transformed_0333.png
# /content/hr/transformed_0769.png
# /content/hr/transformed_0502.png
# /content/hr/transformed_0285.png
# /content/hr/transformed_0067.png
# /content/hr/transformed_0353.png
# /content/hr/transformed_0163.png
# /content/hr/transformed_0193.png
# /content/hr/transformed_0109.png
# /content/hr/transformed_0157.png
# /content/hr/transformed_0010.png
# /content/hr/transformed_0041.png
# /content/hr/transformed_0515.png
# /content/hr/transformed_0306.png
# /content/hr/transformed_0088.png
# /content/hr/transformed_0369.png
# /content/hr/transformed_0434.png
# /content/hr/transformed_0037.png
# /content/hr/transformed_0189.png
# /content/hr/transformed_0249.png
# /content/hr/transformed_0165.png
# /content/hr/transformed_0008.png
# /content/hr/transformed_0426.png
# /content/hr/transformed_0446.png
# /content/hr/transformed_0302.png
# /content/hr/transformed_0235.png
# /content/hr/transformed_0073.png
# /content/hr/transformed_0659.png
# /content/hr/transformed_0544.png
# /content/hr/transformed_0141.png
# /content/hr/transformed_0625.png
# /content/hr/transformed_0669.png
# /content/hr/transformed_0770.png
# /content/hr/transformed_0255.png
# /content/hr/transformed_0307.png
# /content/hr/transformed_0681.png
# /content/hr/transformed_0761.png
# /content/hr/transformed_0526.png
# /content/hr/transformed_0238.png
# /content/hr/transformed_0737.png
# /content/hr/transformed_0579.png
# /content/hr/transformed_0099.png
# /content/hr/transformed_0154.png
# /content/hr/transformed_0342.png
# /content/hr/transformed_0496.png
# /content/hr/transformed_0774.png
# /content/hr/transformed_0718.png
# /content/hr/transformed_0243.png
# /content/hr/transformed_0522.png
# /content/hr/transformed_0278.png
# /content/hr/transformed_0348.png
# /content/hr/transformed_0213.png
# /content/hr/transformed_0486.png
# /content/hr/transformed_0323.png
# /content/hr/transformed_0295.png
# /content/hr/transformed_0510.png
# /content/hr/transformed_0095.png
# /content/hr/transformed_0377.png
# /content/hr/transformed_0182.png
# /content/hr/transformed_0210.png
# /content/hr/transformed_0656.png
# /content/hr/transformed_0480.png
# /content/hr/transformed_0788.png
# /content/hr/transformed_0552.png
# /content/hr/transformed_0568.png
# /content/hr/transformed_0456.png
# /content/hr/transformed_0375.png
# /content/hr/transformed_0015.png
# /content/hr/transformed_0384.png
# /content/hr/transformed_0534.png
# /content/hr/transformed_0550.png
# /content/hr/transformed_0217.png
# /content/hr/transformed_0569.png
# /content/hr/transformed_0694.png
# /content/hr/transformed_0671.png
# /content/hr/transformed_0439.png
# /content/hr/transformed_0176.png
# /content/hr/transformed_0547.png
# /content/hr/transformed_0626.png
# /content/hr/transformed_0555.png
# /content/hr/transformed_0589.png
# /content/hr/transformed_0202.png
# /content/hr/transformed_0367.png
# /content/hr/transformed_0529.png
# /content/hr/transformed_0003.png
# /content/hr/transformed_0383.png
# /content/hr/transformed_0442.png
# /content/hr/transformed_0368.png
# /content/hr/transformed_0443.png
# /content/hr/transformed_0026.png
# /content/hr/transformed_0207.png
# /content/hr/transformed_0424.png
# /content/hr/transformed_0678.png
# /content/hr/transformed_0208.png
# /content/hr/transformed_0499.png
# /content/hr/transformed_0646.png
# /content/hr/transformed_0324.png
# /content/hr/transformed_0139.png
# /content/hr/transformed_0171.png
# /content/hr/transformed_0087.png
# /content/hr/transformed_0705.png
# /content/hr/transformed_0701.png
# /content/hr/transformed_0618.png
# /content/hr/transformed_0500.png
# /content/hr/transformed_0489.png
# /content/hr/transformed_0366.png
# /content/hr/transformed_0296.png
# /content/hr/transformed_0097.png
# /content/hr/transformed_0019.png
# /content/hr/transformed_0631.png
# /content/hr/transformed_0300.png
# /content/hr/transformed_0166.png
# /content/hr/transformed_0315.png
# /content/hr/transformed_0159.png
# /content/hr/transformed_0454.png
# /content/hr/transformed_0085.png
# /content/hr/transformed_0563.png
# /content/hr/transformed_0186.png
# /content/hr/transformed_0411.png
# /content/hr/transformed_0194.png
# /content/hr/transformed_0162.png
# /content/hr/transformed_0734.png
# /content/hr/transformed_0137.png
# /content/hr/transformed_0155.png
# /content/hr/transformed_0251.png
# /content/hr/transformed_0732.png
# /content/hr/transformed_0316.png
# /content/hr/transformed_0539.png
# /content/hr/transformed_0282.png
# /content/hr/transformed_0560.png
# /content/hr/transformed_0365.png
# /content/hr/transformed_0703.png
# /content/hr/transformed_0145.png
# /content/hr/transformed_0673.png
# /content/hr/transformed_0046.png
# /content/hr/transformed_0648.png
# /content/hr/transformed_0034.png
# /content/hr/transformed_0708.png
# /content/hr/transformed_0509.png
# /content/hr/transformed_0590.png
# /content/hr/transformed_0101.png
# /content/hr/transformed_0055.png
# /content/hr/transformed_0254.png
# /content/hr/transformed_0261.png
# /content/hr/transformed_0370.png
# /content/hr/transformed_0785.png
# /content/hr/transformed_0450.png
# /content/hr/transformed_0174.png
# /content/hr/transformed_0242.png
# /content/hr/transformed_0571.png
# /content/hr/transformed_0736.png
# /content/hr/transformed_0280.png
# /content/hr/transformed_0126.png
# /content/hr/transformed_0158.png
# /content/hr/transformed_0524.png
# /content/hr/transformed_0130.png
# /content/hr/transformed_0689.png
# /content/hr/transformed_0543.png
# /content/hr/transformed_0762.png
# /content/hr/transformed_0292.png
# /content/hr/transformed_0239.png
# /content/hr/transformed_0373.png
# /content/hr/transformed_0566.png
# /content/hr/transformed_0482.png
# /content/hr/transformed_0498.png
# /content/hr/transformed_0567.png
# /content/hr/transformed_0303.png
# /content/hr/transformed_0222.png
# /content/hr/transformed_0714.png
# /content/hr/transformed_0632.png
# /content/hr/transformed_0687.png
# /content/hr/transformed_0740.png
# /content/hr/transformed_0564.png
# /content/hr/transformed_0043.png
# /content/hr/transformed_0272.png
# /content/hr/transformed_0355.png
# /content/hr/transformed_0175.png
# /content/hr/transformed_0692.png
# /content/hr/transformed_0362.png
# /content/hr/transformed_0128.png
# /content/hr/transformed_0352.png
# /content/hr/transformed_0800.png
# /content/hr/transformed_0675.png
# /content/hr/transformed_0241.png
# /content/hr/transformed_0132.png
# /content/hr/transformed_0596.png
# /content/hr/transformed_0102.png
# /content/hr/transformed_0014.png
# /content/hr/transformed_0082.png
# /content/hr/transformed_0688.png
# /content/hr/transformed_0247.png
# /content/hr/transformed_0027.png
# /content/hr/transformed_0436.png
# /content/hr/transformed_0532.png
# /content/hr/transformed_0420.png
# /content/hr/transformed_0113.png
# /content/hr/transformed_0310.png
# /content/hr/transformed_0277.png
# /content/hr/transformed_0161.png
# /content/hr/transformed_0506.png
# /content/hr/transformed_0643.png
# /content/hr/transformed_0294.png
# /content/hr/transformed_0121.png
# /content/hr/transformed_0741.png
# /content/hr/transformed_0013.png
# /content/hr/transformed_0209.png
# /content/hr/transformed_0628.png
# /content/hr/transformed_0149.png
# /content/hr/transformed_0642.png
# /content/hr/transformed_0485.png
# /content/hr/transformed_0244.png
# /content/hr/transformed_0160.png
# /content/hr/transformed_0077.png
# /content/hr/transformed_0652.png
# /content/hr/transformed_0142.png
# /content/hr/transformed_0726.png
# /content/hr/transformed_0728.png
# /content/hr/transformed_0290.png
# /content/hr/transformed_0104.png
# /content/hr/transformed_0192.png
# /content/hr/transformed_0361.png
# /content/hr/transformed_0349.png
# /content/hr/transformed_0503.png
# /content/hr/transformed_0465.png
# /content/hr/transformed_0301.png
# /content/hr/transformed_0317.png
# /content/hr/transformed_0588.png
# /content/hr/transformed_0604.png
# /content/hr/transformed_0381.png
# /content/hr/transformed_0799.png
# /content/hr/transformed_0049.png
# /content/hr/transformed_0649.png
# /content/hr/transformed_0699.png
# /content/hr/transformed_0394.png
# /content/hr/transformed_0441.png
# /content/hr/transformed_0595.png
# /content/hr/transformed_0346.png
# /content/hr/transformed_0016.png
# /content/hr/transformed_0527.png
# /content/hr/transformed_0094.png
# /content/hr/transformed_0487.png
# /content/hr/transformed_0119.png
# /content/hr/transformed_0654.png
# /content/hr/transformed_0638.png
# /content/hr/transformed_0672.png
# /content/hr/transformed_0577.png
# /content/hr/transformed_0071.png
# /content/hr/transformed_0467.png
# /content/hr/transformed_0100.png
# /content/hr/transformed_0076.png
# /content/hr/transformed_0032.png
# /content/hr/transformed_0525.png
# /content/hr/transformed_0470.png
# /content/hr/transformed_0448.png
# /content/hr/transformed_0330.png
# /content/hr/transformed_0624.png
# /content/hr/transformed_0136.png
# /content/hr/transformed_0464.png
# /content/hr/transformed_0234.png
# /content/hr/transformed_0742.png
# /content/hr/transformed_0476.png
# /content/hr/transformed_0520.png
# /content/hr/transformed_0790.png
# /content/hr/transformed_0358.png
# /content/hr/transformed_0151.png
# /content/hr/transformed_0663.png
# /content/hr/transformed_0214.png
# /content/hr/transformed_0505.png
# /content/hr/transformed_0432.png
# /content/hr/transformed_0629.png
# /content/hr/transformed_0298.png
# /content/hr/transformed_0020.png
# /content/hr/transformed_0462.png
# /content/hr/transformed_0401.png
# /content/hr/transformed_0152.png
# /content/hr/transformed_0066.png
# /content/hr/transformed_0029.png
# /content/hr/transformed_0148.png
# /content/hr/transformed_0416.png
# /content/hr/transformed_0297.png
# /content/hr/transformed_0387.png
# /content/hr/transformed_0680.png
# /content/hr/transformed_0146.png
# /content/hr/transformed_0274.png
# /content/hr/transformed_0212.png
# /content/hr/transformed_0246.png
# /content/hr/transformed_0484.png
# /content/hr/transformed_0585.png
# /content/hr/transformed_0743.png
# /content/hr/transformed_0780.png
# /content/hr/transformed_0279.png
# /content/hr/transformed_0022.png
# /content/hr/transformed_0495.png
# /content/hr/transformed_0184.png
# /content/hr/transformed_0521.png
# /content/hr/transformed_0191.png
# /content/hr/transformed_0068.png
# /content/hr/transformed_0430.png
# /content/hr/transformed_0048.png
# /content/hr/transformed_0347.png
# /content/hr/transformed_0792.png
# /content/hr/transformed_0006.png
# /content/hr/transformed_0570.png
# /content/hr/transformed_0668.png
# /content/hr/transformed_0483.png
# /content/hr/transformed_0069.png
# /content/hr/transformed_0491.png
# /content/hr/transformed_0512.png
# /content/hr/transformed_0752.png
# /content/hr/transformed_0196.png
# /content/hr/transformed_0107.png
# /content/hr/transformed_0609.png
# /content/hr/transformed_0423.png
# /content/hr/transformed_0220.png
# /content/hr/transformed_0025.png
# /content/hr/transformed_0360.png
# /content/hr/transformed_0549.png
# /content/hr/transformed_0796.png
# /content/hr/transformed_0122.png
# /content/hr/transformed_0779.png
# /content/hr/transformed_0001.png
# /content/hr/transformed_0513.png
# /content/hr/transformed_0185.png
# /content/hr/transformed_0120.png
# /content/hr/transformed_0263.png
# /content/hr/transformed_0329.png
# /content/hr/transformed_0271.png
# /content/hr/transformed_0336.png
# /content/hr/transformed_0123.png
# /content/hr/transformed_0326.png
# /content/hr/transformed_0682.png
# /content/hr/transformed_0636.png
# /content/hr/transformed_0256.png
# /content/hr/transformed_0339.png
# /content/hr/transformed_0452.png
# /content/hr/transformed_0051.png
# /content/hr/transformed_0597.png
# /content/hr/transformed_0787.png
# /content/hr/transformed_0335.png
# /content/hr/transformed_0651.png
# /content/hr/transformed_0288.png
# /content/hr/transformed_0313.png
# /content/hr/transformed_0431.png
# /content/hr/transformed_0729.png
# /content/hr/transformed_0444.png
# /content/hr/transformed_0406.png
# /content/hr/transformed_0341.png
# /content/hr/transformed_0497.png
# /content/hr/transformed_0655.png
# /content/hr/transformed_0259.png
# /content/hr/transformed_0713.png
# /content/hr/transformed_0614.png
# /content/hr/transformed_0187.png
# /content/hr/transformed_0635.png
# /content/hr/transformed_0542.png
# /content/hr/transformed_0695.png
# /content/hr/transformed_0206.png
# /content/hr/transformed_0795.png
# /content/hr/transformed_0262.png
# /content/hr/transformed_0390.png
# /content/hr/transformed_0613.png
# /content/hr/transformed_0586.png
# /content/hr/transformed_0561.png
# /content/hr/transformed_0096.png
# /content/hr/transformed_0079.png
# /content/lw/transformed_0441_0.png
# /content/lw/transformed_0548_2.png
# /content/lw/transformed_0413_0.png
# /content/lw/transformed_0674_0.png
# /content/lw/transformed_0726_1.png
# /content/lw/transformed_0047_1.png
# /content/lw/transformed_0087_1.png
# /content/lw/transformed_0004_3.png
# /content/lw/transformed_0494_2.png
# /content/lw/transformed_0251_2.png
# /content/lw/transformed_0449_3.png
# /content/lw/transformed_0260_3.png
# /content/lw/transformed_0119_2.png
# /content/lw/transformed_0076_3.png
# /content/lw/transformed_0394_3.png
# /content/lw/transformed_0489_0.png
# /content/lw/transformed_0668_1.png
# /content/lw/transformed_0174_1.png
# /content/lw/transformed_0412_2.png
# /content/lw/transformed_0382_3.png
# /content/lw/transformed_0757_1.png
# /content/lw/transformed_0727_1.png
# /content/lw/transformed_0665_3.png
# /content/lw/transformed_0514_1.png
# /content/lw/transformed_0304_1.png
# /content/lw/transformed_0287_1.png
# /content/lw/transformed_0422_3.png
# /content/lw/transformed_0352_3.png
# /content/lw/transformed_0008_1.png
# /content/lw/transformed_0436_2.png
# /content/lw/transformed_0583_3.png
# /content/lw/transformed_0470_1.png
# /content/lw/transformed_0302_3.png
# /content/lw/transformed_0113_2.png
# /content/lw/transformed_0731_1.png
# /content/lw/transformed_0361_2.png
# /content/lw/transformed_0492_1.png
# /content/lw/transformed_0631_3.png
# /content/lw/transformed_0016_2.png
# /content/lw/transformed_0173_1.png
# /content/lw/transformed_0368_3.png
# /content/lw/transformed_0489_1.png
# /content/lw/transformed_0320_0.png
# /content/lw/transformed_0662_0.png
# /content/lw/transformed_0767_3.png
# /content/lw/transformed_0031_2.png
# /content/lw/transformed_0752_1.png
# /content/lw/transformed_0361_1.png
# /content/lw/transformed_0143_0.png
# /content/lw/transformed_0530_1.png
# /content/lw/transformed_0575_3.png
# /content/lw/transformed_0424_0.png
# /content/lw/transformed_0689_3.png
# /content/lw/transformed_0256_2.png
# /content/lw/transformed_0093_1.png
# /content/lw/transformed_0385_2.png
# /content/lw/transformed_0432_1.png
# /content/lw/transformed_0306_0.png
# /content/lw/transformed_0046_1.png
# /content/lw/transformed_0466_1.png
# /content/lw/transformed_0736_0.png
# /content/lw/transformed_0609_3.png
# /content/lw/transformed_0455_3.png
# /content/lw/transformed_0271_1.png
# /content/lw/transformed_0137_3.png
# /content/lw/transformed_0326_1.png
# /content/lw/transformed_0067_0.png
# /content/lw/transformed_0229_3.png
# /content/lw/transformed_0611_1.png
# /content/lw/transformed_0311_2.png
# /content/lw/transformed_0183_1.png
# /content/lw/transformed_0685_2.png
# /content/lw/transformed_0182_1.png
# /content/lw/transformed_0105_1.png
# /content/lw/transformed_0744_0.png
# /content/lw/transformed_0205_3.png
# /content/lw/transformed_0040_0.png
# /content/lw/transformed_0365_0.png
# /content/lw/transformed_0728_3.png
# /content/lw/transformed_0380_0.png
# /content/lw/transformed_0464_1.png
# /content/lw/transformed_0740_3.png
# /content/lw/transformed_0515_1.png
# /content/lw/transformed_0415_1.png
# /content/lw/transformed_0316_0.png
# /content/lw/transformed_0675_2.png
# /content/lw/transformed_0329_3.png
# /content/lw/transformed_0254_2.png
# /content/lw/transformed_0257_3.png
# /content/lw/transformed_0646_2.png
# /content/lw/transformed_0582_1.png
# /content/lw/transformed_0274_0.png
# /content/lw/transformed_0275_2.png
# /content/lw/transformed_0596_3.png
# /content/lw/transformed_0297_3.png
# /content/lw/transformed_0648_3.png
# /content/lw/transformed_0505_1.png
# /content/lw/transformed_0751_1.png
# /content/lw/transformed_0563_2.png
# /content/lw/transformed_0035_3.png
# /content/lw/transformed_0615_2.png
# /content/lw/transformed_0355_1.png
# /content/lw/transformed_0041_3.png
# /content/lw/transformed_0295_2.png
# /content/lw/transformed_0206_3.png
# /content/lw/transformed_0102_3.png
# /content/lw/transformed_0149_1.png
# /content/lw/transformed_0246_3.png
# /content/lw/transformed_0422_1.png
# /content/lw/transformed_0315_3.png
# /content/lw/transformed_0561_1.png
# /content/lw/transformed_0764_2.png
# /content/lw/transformed_0329_1.png
# /content/lw/transformed_0178_3.png
# /content/lw/transformed_0137_1.png
# /content/lw/transformed_0283_3.png
# /content/lw/transformed_0751_3.png
# /content/lw/transformed_0506_1.png
# /content/lw/transformed_0007_2.png
# /content/lw/transformed_0452_2.png
# /content/lw/transformed_0381_2.png
# /content/lw/transformed_0508_2.png
# /content/lw/transformed_0001_3.png
# /content/lw/transformed_0020_3.png
# /content/lw/transformed_0129_2.png
# /content/lw/transformed_0206_0.png
# /content/lw/transformed_0109_0.png
# /content/lw/transformed_0300_2.png
# /content/lw/transformed_0751_2.png
# /content/lw/transformed_0728_1.png
# /content/lw/transformed_0371_3.png
# /content/lw/transformed_0247_1.png
# /content/lw/transformed_0387_1.png
# /content/lw/transformed_0044_0.png
# /content/lw/transformed_0237_2.png
# /content/lw/transformed_0110_1.png
# /content/lw/transformed_0666_0.png
# /content/lw/transformed_0335_0.png
# /content/lw/transformed_0121_1.png
# /content/lw/transformed_0409_2.png
# /content/lw/transformed_0266_2.png
# /content/lw/transformed_0167_2.png
# /content/lw/transformed_0086_0.png
# /content/lw/transformed_0142_2.png
# /content/lw/transformed_0092_2.png
# /content/lw/transformed_0791_0.png
# /content/lw/transformed_0154_2.png
# /content/lw/transformed_0749_1.png
# /content/lw/transformed_0670_0.png
# /content/lw/transformed_0493_0.png
# /content/lw/transformed_0705_3.png
# /content/lw/transformed_0554_0.png
# /content/lw/transformed_0278_0.png
# /content/lw/transformed_0034_2.png
# /content/lw/transformed_0174_0.png
# /content/lw/transformed_0478_3.png
# /content/lw/transformed_0115_1.png
# /content/lw/transformed_0636_1.png
# /content/lw/transformed_0354_2.png
# /content/lw/transformed_0511_3.png
# /content/lw/transformed_0251_3.png
# /content/lw/transformed_0742_3.png
# /content/lw/transformed_0754_0.png
# /content/lw/transformed_0656_2.png
# /content/lw/transformed_0563_3.png
# /content/lw/transformed_0778_3.png
# /content/lw/transformed_0765_2.png
# /content/lw/transformed_0171_1.png
# /content/lw/transformed_0421_3.png
# /content/lw/transformed_0710_1.png
# /content/lw/transformed_0667_1.png
# /content/lw/transformed_0392_2.png
# /content/lw/transformed_0010_3.png
# /content/lw/transformed_0716_0.png
# /content/lw/transformed_0486_0.png
# /content/lw/transformed_0606_3.png
# /content/lw/transformed_0791_2.png
# /content/lw/transformed_0183_2.png
# /content/lw/transformed_0106_2.png
# /content/lw/transformed_0588_0.png
# /content/lw/transformed_0369_1.png
# /content/lw/transformed_0402_2.png
# /content/lw/transformed_0769_3.png
# /content/lw/transformed_0229_2.png
# /content/lw/transformed_0163_1.png
# /content/lw/transformed_0200_3.png
# /content/lw/transformed_0425_2.png
# /content/lw/transformed_0522_0.png
# /content/lw/transformed_0030_3.png
# /content/lw/transformed_0447_1.png
# /content/lw/transformed_0459_2.png
# /content/lw/transformed_0745_2.png
# /content/lw/transformed_0038_2.png
# /content/lw/transformed_0037_0.png
# /content/lw/transformed_0181_0.png
# /content/lw/transformed_0236_1.png
# /content/lw/transformed_0354_3.png
# /content/lw/transformed_0634_3.png
# /content/lw/transformed_0508_0.png
# /content/lw/transformed_0102_0.png
# /content/lw/transformed_0768_0.png
# /content/lw/transformed_0732_1.png
# /content/lw/transformed_0069_3.png
# /content/lw/transformed_0395_0.png
# /content/lw/transformed_0164_0.png
# /content/lw/transformed_0763_1.png
# /content/lw/transformed_0268_3.png
# /content/lw/transformed_0590_0.png
# /content/lw/transformed_0204_2.png
# /content/lw/transformed_0472_1.png
# /content/lw/transformed_0473_1.png
# /content/lw/transformed_0538_3.png
# /content/lw/transformed_0729_1.png
# /content/lw/transformed_0179_2.png
# /content/lw/transformed_0101_2.png
# /content/lw/transformed_0524_2.png
# /content/lw/transformed_0008_3.png
# /content/lw/transformed_0509_1.png
# /content/lw/transformed_0704_1.png
# /content/lw/transformed_0759_2.png
# /content/lw/transformed_0192_2.png
# /content/lw/transformed_0784_3.png
# /content/lw/transformed_0722_1.png
# /content/lw/transformed_0454_1.png
# /content/lw/transformed_0787_3.png
# /content/lw/transformed_0377_1.png
# /content/lw/transformed_0416_1.png
# /content/lw/transformed_0090_3.png
# /content/lw/transformed_0166_3.png
# /content/lw/transformed_0370_1.png
# /content/lw/transformed_0687_2.png
# /content/lw/transformed_0686_0.png
# /content/lw/transformed_0434_2.png
# /content/lw/transformed_0066_1.png
# /content/lw/transformed_0414_1.png
# /content/lw/transformed_0081_3.png
# /content/lw/transformed_0724_1.png
# /content/lw/transformed_0671_0.png
# /content/lw/transformed_0407_1.png
# /content/lw/transformed_0452_0.png
# /content/lw/transformed_0597_3.png
# /content/lw/transformed_0546_2.png
# /content/lw/transformed_0054_1.png
# /content/lw/transformed_0362_1.png
# /content/lw/transformed_0284_0.png
# /content/lw/transformed_0357_1.png
# /content/lw/transformed_0497_0.png
# /content/lw/transformed_0372_1.png
# /content/lw/transformed_0091_1.png
# /content/lw/transformed_0287_3.png
# /content/lw/transformed_0651_2.png
# /content/lw/transformed_0542_2.png
# /content/lw/transformed_0260_0.png
# /content/lw/transformed_0772_0.png
# /content/lw/transformed_0346_0.png
# /content/lw/transformed_0053_1.png
# /content/lw/transformed_0741_3.png
# /content/lw/transformed_0310_3.png
# /content/lw/transformed_0514_3.png
# /content/lw/transformed_0485_0.png
# /content/lw/transformed_0273_3.png
# /content/lw/transformed_0629_3.png
# /content/lw/transformed_0472_0.png
# /content/lw/transformed_0682_1.png
# /content/lw/transformed_0345_2.png
# /content/lw/transformed_0410_1.png
# /content/lw/transformed_0094_0.png
# /content/lw/transformed_0321_0.png
# /content/lw/transformed_0192_3.png
# /content/lw/transformed_0562_0.png
# /content/lw/transformed_0755_2.png
# /content/lw/transformed_0480_3.png
# /content/lw/transformed_0708_0.png
# /content/lw/transformed_0484_1.png
# /content/lw/transformed_0516_3.png
# /content/lw/transformed_0637_0.png
# /content/lw/transformed_0072_1.png
# /content/lw/transformed_0084_2.png
# /content/lw/transformed_0787_0.png
# /content/lw/transformed_0294_1.png
# /content/lw/transformed_0242_0.png
# /content/lw/transformed_0285_0.png
# /content/lw/transformed_0649_3.png
# /content/lw/transformed_0138_3.png
# /content/lw/transformed_0109_1.png
# /content/lw/transformed_0722_2.png
# /content/lw/transformed_0564_0.png
# /content/lw/transformed_0732_2.png
# /content/lw/transformed_0099_2.png
# /content/lw/transformed_0438_3.png
# /content/lw/transformed_0662_2.png
# /content/lw/transformed_0560_3.png
# /content/lw/transformed_0048_2.png
# /content/lw/transformed_0590_3.png
# /content/lw/transformed_0297_1.png
# /content/lw/transformed_0357_3.png
# /content/lw/transformed_0376_0.png
# /content/lw/transformed_0751_0.png
# /content/lw/transformed_0436_1.png
# /content/lw/transformed_0351_0.png
# /content/lw/transformed_0594_2.png
# /content/lw/transformed_0321_3.png
# /content/lw/transformed_0346_2.png
# /content/lw/transformed_0283_2.png
# /content/lw/transformed_0411_1.png
# /content/lw/transformed_0170_3.png
# /content/lw/transformed_0258_1.png
# /content/lw/transformed_0452_1.png
# /content/lw/transformed_0099_0.png
# /content/lw/transformed_0610_3.png
# /content/lw/transformed_0057_1.png
# /content/lw/transformed_0141_0.png
# /content/lw/transformed_0188_1.png
# /content/lw/transformed_0182_3.png
# /content/lw/transformed_0377_0.png
# /content/lw/transformed_0422_2.png
# /content/lw/transformed_0025_3.png
# /content/lw/transformed_0507_0.png
# /content/lw/transformed_0692_1.png
# /content/lw/transformed_0747_2.png
# /content/lw/transformed_0089_2.png
# /content/lw/transformed_0618_0.png
# /content/lw/transformed_0616_2.png
# /content/lw/transformed_0103_0.png
# /content/lw/transformed_0293_1.png
# /content/lw/transformed_0721_3.png
# /content/lw/transformed_0387_2.png
# /content/lw/transformed_0207_2.png
# /content/lw/transformed_0017_0.png
# /content/lw/transformed_0666_1.png
# /content/lw/transformed_0277_2.png
# /content/lw/transformed_0334_0.png
# /content/lw/transformed_0647_0.png
# /content/lw/transformed_0251_1.png
# /content/lw/transformed_0644_3.png
# /content/lw/transformed_0150_2.png
# /content/lw/transformed_0705_0.png
# /content/lw/transformed_0720_3.png
# /content/lw/transformed_0626_3.png
# /content/lw/transformed_0409_1.png
# /content/lw/transformed_0307_3.png
# /content/lw/transformed_0057_2.png
# /content/lw/transformed_0153_2.png
# /content/lw/transformed_0476_1.png
# /content/lw/transformed_0515_2.png
# /content/lw/transformed_0124_0.png
# /content/lw/transformed_0260_1.png
# /content/lw/transformed_0750_2.png
# /content/lw/transformed_0122_2.png
# /content/lw/transformed_0344_3.png
# /content/lw/transformed_0046_2.png
# /content/lw/transformed_0164_2.png
# /content/lw/transformed_0536_2.png
# /content/lw/transformed_0477_2.png
# /content/lw/transformed_0585_2.png
# /content/lw/transformed_0096_2.png
# /content/lw/transformed_0227_1.png
# /content/lw/transformed_0324_2.png
# /content/lw/transformed_0539_0.png
# /content/lw/transformed_0448_2.png
# /content/lw/transformed_0194_2.png
# /content/lw/transformed_0707_0.png
# /content/lw/transformed_0618_1.png
# /content/lw/transformed_0286_2.png
# /content/lw/transformed_0464_2.png
# /content/lw/transformed_0568_1.png
# /content/lw/transformed_0744_2.png
# /content/lw/transformed_0429_3.png
# /content/lw/transformed_0234_3.png
# /content/lw/transformed_0376_3.png
# /content/lw/transformed_0034_3.png
# /content/lw/transformed_0799_3.png
# /content/lw/transformed_0713_1.png
# /content/lw/transformed_0495_0.png
# /content/lw/transformed_0112_1.png
# /content/lw/transformed_0417_0.png
# /content/lw/transformed_0397_1.png
# /content/lw/transformed_0364_2.png
# /content/lw/transformed_0788_0.png
# /content/lw/transformed_0581_2.png
# /content/lw/transformed_0794_3.png
# /content/lw/transformed_0730_0.png
# /content/lw/transformed_0315_1.png
# /content/lw/transformed_0698_3.png
# /content/lw/transformed_0728_2.png
# /content/lw/transformed_0096_3.png
# /content/lw/transformed_0777_2.png
# /content/lw/transformed_0534_3.png
# /content/lw/transformed_0107_3.png
# /content/lw/transformed_0258_2.png
# /content/lw/transformed_0730_1.png
# /content/lw/transformed_0622_1.png
# /content/lw/transformed_0225_2.png
# /content/lw/transformed_0599_2.png
# /content/lw/transformed_0650_2.png
# /content/lw/transformed_0738_0.png
# /content/lw/transformed_0596_0.png
# /content/lw/transformed_0380_3.png
# /content/lw/transformed_0774_3.png
# /content/lw/transformed_0500_1.png
# /content/lw/transformed_0305_2.png
# /content/lw/transformed_0366_1.png
# /content/lw/transformed_0578_0.png
# /content/lw/transformed_0757_2.png
# /content/lw/transformed_0626_2.png
# /content/lw/transformed_0669_1.png
# /content/lw/transformed_0574_1.png
# /content/lw/transformed_0243_3.png
# /content/lw/transformed_0748_2.png
# /content/lw/transformed_0243_0.png
# /content/lw/transformed_0467_3.png
# /content/lw/transformed_0129_1.png
# /content/lw/transformed_0381_3.png
# /content/lw/transformed_0448_1.png
# /content/lw/transformed_0777_3.png
# /content/lw/transformed_0628_3.png
# /content/lw/transformed_0477_1.png
# /content/lw/transformed_0603_3.png
# /content/lw/transformed_0153_3.png
# /content/lw/transformed_0416_2.png
# /content/lw/transformed_0090_2.png
# /content/lw/transformed_0563_0.png
# /content/lw/transformed_0135_3.png
# /content/lw/transformed_0122_0.png
# /content/lw/transformed_0727_3.png
# /content/lw/transformed_0088_0.png
# /content/lw/transformed_0417_3.png
# /content/lw/transformed_0395_3.png
# /content/lw/transformed_0448_0.png
# /content/lw/transformed_0769_1.png
# /content/lw/transformed_0517_3.png
# /content/lw/transformed_0319_0.png
# /content/lw/transformed_0393_2.png
# /content/lw/transformed_0350_1.png
# /content/lw/transformed_0416_3.png
# /content/lw/transformed_0545_0.png
# /content/lw/transformed_0203_3.png
# /content/lw/transformed_0707_1.png
# /content/lw/transformed_0383_2.png
# /content/lw/transformed_0613_2.png
# /content/lw/transformed_0177_0.png
# /content/lw/transformed_0527_2.png
# /content/lw/transformed_0042_0.png
# /content/lw/transformed_0542_0.png
# /content/lw/transformed_0739_1.png
# /content/lw/transformed_0060_0.png
# /content/lw/transformed_0579_2.png
# /content/lw/transformed_0513_0.png
# /content/lw/transformed_0685_1.png
# /content/lw/transformed_0422_0.png
# /content/lw/transformed_0752_2.png
# /content/lw/transformed_0434_3.png
# /content/lw/transformed_0547_0.png
# /content/lw/transformed_0356_0.png
# /content/lw/transformed_0222_0.png
# /content/lw/transformed_0330_0.png
# /content/lw/transformed_0310_0.png
# /content/lw/transformed_0209_0.png
# /content/lw/transformed_0286_1.png
# /content/lw/transformed_0268_2.png
# /content/lw/transformed_0318_1.png
# /content/lw/transformed_0028_3.png
# /content/lw/transformed_0550_0.png
# /content/lw/transformed_0623_2.png
# /content/lw/transformed_0789_0.png
# /content/lw/transformed_0302_2.png
# /content/lw/transformed_0757_3.png
# /content/lw/transformed_0012_2.png
# /content/lw/transformed_0796_3.png
# /content/lw/transformed_0709_1.png
# /content/lw/transformed_0634_1.png
# /content/lw/transformed_0074_0.png
# /content/lw/transformed_0157_3.png
# /content/lw/transformed_0471_1.png
# /content/lw/transformed_0764_0.png
# /content/lw/transformed_0635_1.png
# /content/lw/transformed_0748_1.png
# /content/lw/transformed_0145_0.png
# /content/lw/transformed_0267_2.png
# /content/lw/transformed_0155_3.png
# /content/lw/transformed_0189_2.png
# /content/lw/transformed_0732_0.png
# /content/lw/transformed_0794_2.png
# /content/lw/transformed_0099_3.png
# /content/lw/transformed_0417_2.png
# /content/lw/transformed_0074_3.png
# /content/lw/transformed_0482_3.png
# /content/lw/transformed_0733_2.png
# /content/lw/transformed_0463_2.png
# /content/lw/transformed_0486_2.png
# /content/lw/transformed_0218_1.png
# /content/lw/transformed_0126_3.png
# /content/lw/transformed_0193_1.png
# /content/lw/transformed_0011_3.png
# /content/lw/transformed_0036_1.png
# /content/lw/transformed_0645_2.png
# /content/lw/transformed_0070_1.png
# /content/lw/transformed_0562_1.png
# /content/lw/transformed_0065_0.png
# /content/lw/transformed_0703_1.png
# /content/lw/transformed_0473_2.png
# /content/lw/transformed_0118_2.png
# /content/lw/transformed_0224_0.png
# /content/lw/transformed_0611_3.png
# /content/lw/transformed_0236_2.png
# /content/lw/transformed_0152_1.png
# /content/lw/transformed_0726_0.png
# /content/lw/transformed_0066_0.png
# /content/lw/transformed_0551_2.png
# /content/lw/transformed_0473_3.png
# /content/lw/transformed_0197_3.png
# /content/lw/transformed_0785_2.png
# /content/lw/transformed_0020_2.png
# /content/lw/transformed_0213_1.png
# /content/lw/transformed_0712_3.png
# /content/lw/transformed_0413_1.png
# /content/lw/transformed_0366_2.png
# /content/lw/transformed_0185_1.png
# /content/lw/transformed_0180_1.png
# /content/lw/transformed_0205_2.png
# /content/lw/transformed_0362_0.png
# /content/lw/transformed_0607_2.png
# /content/lw/transformed_0786_3.png
# /content/lw/transformed_0405_0.png
# /content/lw/transformed_0386_0.png
# /content/lw/transformed_0318_2.png
# /content/lw/transformed_0089_1.png
# /content/lw/transformed_0471_2.png
# /content/lw/transformed_0384_0.png
# /content/lw/transformed_0775_2.png
# /content/lw/transformed_0176_2.png
# /content/lw/transformed_0662_3.png
# /content/lw/transformed_0112_0.png
# /content/lw/transformed_0502_0.png
# /content/lw/transformed_0562_3.png
# /content/lw/transformed_0127_3.png
# /content/lw/transformed_0257_2.png
# /content/lw/transformed_0426_3.png
# /content/lw/transformed_0773_0.png
# /content/lw/transformed_0706_1.png
# /content/lw/transformed_0259_0.png
# /content/lw/transformed_0505_3.png
# /content/lw/transformed_0036_2.png
# /content/lw/transformed_0184_3.png
# /content/lw/transformed_0103_1.png
# /content/lw/transformed_0063_0.png
# /content/lw/transformed_0302_0.png
# /content/lw/transformed_0496_2.png
# /content/lw/transformed_0373_3.png
# /content/lw/transformed_0364_0.png
# /content/lw/transformed_0248_1.png
# /content/lw/transformed_0554_1.png
# /content/lw/transformed_0353_3.png
# /content/lw/transformed_0367_1.png
# /content/lw/transformed_0201_0.png
# /content/lw/transformed_0511_1.png
# /content/lw/transformed_0510_3.png
# /content/lw/transformed_0558_2.png
# /content/lw/transformed_0600_0.png
# /content/lw/transformed_0421_1.png
# /content/lw/transformed_0246_1.png
# /content/lw/transformed_0087_3.png
# /content/lw/transformed_0698_1.png
# /content/lw/transformed_0633_3.png
# /content/lw/transformed_0700_1.png
# /content/lw/transformed_0415_3.png
# /content/lw/transformed_0381_1.png
# /content/lw/transformed_0659_1.png
# /content/lw/transformed_0450_0.png
# /content/lw/transformed_0006_2.png
# /content/lw/transformed_0096_0.png
# /content/lw/transformed_0656_0.png
# /content/lw/transformed_0259_1.png
# /content/lw/transformed_0022_2.png
# /content/lw/transformed_0302_1.png
# /content/lw/transformed_0159_0.png
# /content/lw/transformed_0567_1.png
# /content/lw/transformed_0630_1.png
# /content/lw/transformed_0437_1.png
# /content/lw/transformed_0444_0.png
# /content/lw/transformed_0371_2.png
# /content/lw/transformed_0361_3.png
# /content/lw/transformed_0587_2.png
# /content/lw/transformed_0439_1.png
# /content/lw/transformed_0503_0.png
# /content/lw/transformed_0253_3.png
# /content/lw/transformed_0443_3.png
# /content/lw/transformed_0210_0.png
# /content/lw/transformed_0663_2.png
# /content/lw/transformed_0770_3.png
# /content/lw/transformed_0709_3.png
# /content/lw/transformed_0372_2.png
# /content/lw/transformed_0045_1.png
# /content/lw/transformed_0550_2.png
# /content/lw/transformed_0091_3.png
# /content/lw/transformed_0089_0.png
# /content/lw/transformed_0586_2.png
# /content/lw/transformed_0714_0.png
# /content/lw/transformed_0695_0.png
# /content/lw/transformed_0508_1.png
# /content/lw/transformed_0020_1.png
# /content/lw/transformed_0512_0.png
# /content/lw/transformed_0380_1.png
# /content/lw/transformed_0475_0.png
# /content/lw/transformed_0079_0.png
# /content/lw/transformed_0033_0.png
# /content/lw/transformed_0403_0.png
# /content/lw/transformed_0290_1.png
# /content/lw/transformed_0543_0.png
# /content/lw/transformed_0646_1.png
# /content/lw/transformed_0220_3.png
# /content/lw/transformed_0161_3.png
# /content/lw/transformed_0749_3.png
# /content/lw/transformed_0269_1.png
# /content/lw/transformed_0489_3.png
# /content/lw/transformed_0651_0.png
# /content/lw/transformed_0147_1.png
# ...
# /content/lw/transformed_0072_0.png
# /content/lw/transformed_0523_0.png
# /content/lw/transformed_0723_3.png
# /content/lw/transformed_0724_0.png
# /content/lw/transformed_0544_0.png
# /content/lw/transformed_0413_2.png
# /content/lw/transformed_0789_2.png
# /content/lw/transformed_0406_0.png
# /content/lw/transformed_0570_2.png
# /content/lw/transformed_0791_3.png
# /content/lw/transformed_0047_2.png
# /content/lw/transformed_0055_3.png
# /content/lw/transformed_0517_0.png
# /content/lw/transformed_0280_3.png
# /content/lw/transformed_0559_1.png
# /content/lw/transformed_0398_2.png
# /content/lw/transformed_0571_1.png
# /content/lw/transformed_0792_0.png
# /content/lw/transformed_0569_3.png
# /content/lw/transformed_0740_2.png
# /content/lw/transformed_0075_1.png
# /content/lw/transformed_0112_3.png
# /content/lw/transformed_0697_3.png
# /content/lw/transformed_0012_0.png
# /content/lw/transformed_0341_3.png
# /content/lw/transformed_0660_0.png
# /content/lw/transformed_0665_2.png
# /content/lw/transformed_0548_1.png
# /content/lw/transformed_0375_2.png
# /content/lw/transformed_0453_3.png
# /content/lw/transformed_0559_0.png
# /content/lw/transformed_0708_2.png
# /content/lw/transformed_0332_1.png
# /content/lw/transformed_0644_1.png
# /content/lw/transformed_0439_2.png
# /content/lw/transformed_0780_1.png
# /content/lw/transformed_0298_2.png
# /content/lw/transformed_0617_0.png
# /content/lw/transformed_0176_3.png
# /content/lw/transformed_0323_3.png
# /content/lw/transformed_0061_3.png
# /content/lw/transformed_0383_0.png
# /content/lw/transformed_0242_1.png
# /content/lw/transformed_0388_0.png
# /content/lw/transformed_0326_3.png
# /content/lw/transformed_0476_3.png
# /content/lw/transformed_0653_3.png
# /content/lw/transformed_0604_1.png
# /content/lw/transformed_0754_3.png
# /content/lw/transformed_0370_2.png
# /content/lw/transformed_0355_0.png
# /content/lw/transformed_0483_0.png
# /content/lw/transformed_0043_0.png
# /content/lw/transformed_0415_2.png
# /content/lw/transformed_0755_3.png
# /content/lw/transformed_0638_1.png
# /content/lw/transformed_0482_1.png
# /content/lw/transformed_0714_3.png
# /content/lw/transformed_0562_2.png
# /content/lw/transformed_0425_1.png
# /content/lw/transformed_0528_3.png
# /content/lw/transformed_0294_2.png
# /content/lw/transformed_0349_1.png
# /content/lw/transformed_0098_1.png
# /content/lw/transformed_0009_0.png
# /content/lw/transformed_0507_2.png
# /content/lw/transformed_0248_0.png
# /content/lw/transformed_0467_1.png
# /content/lw/transformed_0578_2.png
# /content/lw/transformed_0025_0.png
# /content/lw/transformed_0764_3.png
# /content/lw/transformed_0672_1.png
# /content/lw/transformed_0316_3.png
# /content/lw/transformed_0322_2.png
# /content/lw/transformed_0430_2.png
# /content/lw/transformed_0347_1.png
# /content/lw/transformed_0749_0.png
# /content/lw/transformed_0199_1.png
# /content/lw/transformed_0164_3.png
# /content/lw/transformed_0209_1.png
# /content/lw/transformed_0743_3.png
# /content/lw/transformed_0553_3.png
# /content/lw/transformed_0033_3.png
# /content/lw/transformed_0076_1.png
# /content/lw/transformed_0752_3.png
# /content/lw/transformed_0120_3.png
# /content/lw/transformed_0763_3.png
# /content/lw/transformed_0433_0.png
# /content/lw/transformed_0690_1.png
# /content/lw/transformed_0710_3.png
# /content/lw/transformed_0385_3.png
# /content/lw/transformed_0137_0.png
# /content/lw/transformed_0545_2.png
# /content/lw/transformed_0623_0.png
# /content/lw/transformed_0350_2.png
# /content/lw/transformed_0227_0.png
# /content/lw/transformed_0224_2.png
# /content/lw/transformed_0154_0.png
# /content/lw/transformed_0492_2.png
# /content/lw/transformed_0457_1.png
# /content/lw/transformed_0484_2.png
# /content/lw/transformed_0619_2.png
# /content/lw/transformed_0121_0.png
# /content/lw/transformed_0117_3.png
# /content/lw/transformed_0771_1.png
# /content/lw/transformed_0357_2.png
# /content/lw/transformed_0266_3.png
# /content/lw/transformed_0461_3.png
# /content/lw/transformed_0071_0.png
# /content/lw/transformed_0457_3.png
# /content/lw/transformed_0352_0.png
# /content/lw/transformed_0004_0.png
# /content/lw/transformed_0198_0.png
# /content/lw/transformed_0233_3.png
# /content/lw/transformed_0800_1.png
# /content/lw/transformed_0600_2.png
# /content/lw/transformed_0505_0.png
# /content/lw/transformed_0116_3.png
# /content/lw/transformed_0773_2.png
# /content/lw/transformed_0443_2.png
# /content/lw/transformed_0663_3.png
# /content/lw/transformed_0093_3.png
# /content/lw/transformed_0582_2.png
# /content/lw/transformed_0041_2.png
# /content/lw/transformed_0196_3.png
# /content/lw/transformed_0796_0.png
# /content/lw/transformed_0558_3.png
# /content/lw/transformed_0614_2.png
# /content/lw/transformed_0506_0.png
# /content/lw/transformed_0232_0.png
# /content/lw/transformed_0739_0.png
# /content/lw/transformed_0440_3.png
# /content/lw/transformed_0051_2.png
# /content/lw/transformed_0077_0.png
# /content/lw/transformed_0256_1.png
# /content/lw/transformed_0776_2.png
# /content/lw/transformed_0790_3.png
# /content/lw/transformed_0202_3.png
# /content/lw/transformed_0282_0.png
# /content/lw/transformed_0094_3.png
# /content/lw/transformed_0501_3.png
# /content/lw/transformed_0053_0.png
# /content/lw/transformed_0144_1.png
# /content/lw/transformed_0162_0.png
# /content/lw/transformed_0358_0.png
# /content/lw/transformed_0034_1.png
# /content/lw/transformed_0378_1.png
# /content/lw/transformed_0122_3.png
# /content/lw/transformed_0011_0.png
# /content/lw/transformed_0326_2.png
# /content/lw/transformed_0689_2.png
# /content/lw/transformed_0454_2.png
# /content/lw/transformed_0631_1.png
# /content/lw/transformed_0281_2.png
# /content/lw/transformed_0778_2.png
# /content/lw/transformed_0215_1.png
# /content/lw/transformed_0747_3.png
# /content/lw/transformed_0133_0.png
# /content/lw/transformed_0051_0.png
# /content/lw/transformed_0041_1.png
# /content/lw/transformed_0199_3.png
# /content/lw/transformed_0591_3.png
# /content/lw/transformed_0414_2.png
# /content/lw/transformed_0083_0.png
# /content/lw/transformed_0172_3.png
# /content/lw/transformed_0027_1.png
# /content/lw/transformed_0400_3.png
# /content/lw/transformed_0639_3.png
# /content/lw/transformed_0719_1.png
# /content/lw/transformed_0002_0.png
# /content/lw/transformed_0165_2.png
# /content/lw/transformed_0612_2.png
# /content/lw/transformed_0064_3.png
# /content/lw/transformed_0017_2.png
# /content/lw/transformed_0391_2.png
# /content/lw/transformed_0746_3.png
# /content/lw/transformed_0559_2.png
# /content/lw/transformed_0701_2.png
# /content/lw/transformed_0459_1.png
# /content/lw/transformed_0207_0.png
# /content/lw/transformed_0520_1.png
# /content/lw/transformed_0060_3.png
# /content/lw/transformed_0648_1.png
# /content/lw/transformed_0480_2.png
# /content/lw/transformed_0063_1.png
# /content/lw/transformed_0506_3.png
# /content/lw/transformed_0706_3.png
# /content/lw/transformed_0005_2.png
# /content/lw/transformed_0675_1.png
# /content/lw/transformed_0094_1.png
# /content/lw/transformed_0109_2.png
# /content/lw/transformed_0080_3.png
# /content/lw/transformed_0398_3.png
# /content/lw/transformed_0577_2.png
# /content/lw/transformed_0106_3.png
# /content/lw/transformed_0461_2.png
# /content/lw/transformed_0501_2.png
# /content/lw/transformed_0614_3.png
# /content/lw/transformed_0528_2.png
# /content/lw/transformed_0643_3.png
# /content/lw/transformed_0688_0.png
# /content/lw/transformed_0235_3.png
# /content/lw/transformed_0264_2.png
# /content/lw/transformed_0669_3.png
# /content/lw/transformed_0761_3.png
# /content/lw/transformed_0273_2.png
# /content/lw/transformed_0028_1.png
# /content/lw/transformed_0417_1.png
# /content/lw/transformed_0245_0.png
# /content/lw/transformed_0138_2.png
# /content/lw/transformed_0791_1.png
# /content/lw/transformed_0670_3.png
# /content/lw/transformed_0400_0.png
# /content/lw/transformed_0054_2.png
# /content/lw/transformed_0753_2.png
# /content/lw/transformed_0353_2.png
# /content/lw/transformed_0419_0.png
# /content/lw/transformed_0469_3.png
# /content/lw/transformed_0249_3.png
# /content/lw/transformed_0073_2.png
# /content/lw/transformed_0766_3.png
# /content/lw/transformed_0537_1.png
# /content/lw/transformed_0068_2.png
# /content/lw/transformed_0078_1.png
# /content/lw/transformed_0396_2.png
# /content/lw/transformed_0784_2.png
# /content/lw/transformed_0716_2.png
# /content/lw/transformed_0598_1.png
# /content/lw/transformed_0631_2.png
# /content/lw/transformed_0211_3.png
# /content/lw/transformed_0591_1.png
# /content/lw/transformed_0342_2.png
# /content/lw/transformed_0799_1.png
# /content/lw/transformed_0183_3.png
# /content/lw/transformed_0551_1.png
# /content/lw/transformed_0342_1.png
# /content/lw/transformed_0735_3.png
# /content/lw/transformed_0795_3.png
# /content/lw/transformed_0125_0.png
# /content/lw/transformed_0352_2.png
# /content/lw/transformed_0110_0.png
# /content/lw/transformed_0289_3.png
# /content/lw/transformed_0296_0.png
# /content/lw/transformed_0075_0.png
# /content/lw/transformed_0627_2.png
# /content/lw/transformed_0187_2.png
# /content/lw/transformed_0157_1.png
# /content/lw/transformed_0442_3.png
# /content/lw/transformed_0332_2.png
# /content/lw/transformed_0053_2.png
# /content/lw/transformed_0314_0.png
# /content/lw/transformed_0793_0.png
# /content/lw/transformed_0134_1.png
# /content/lw/transformed_0329_2.png
# /content/lw/transformed_0795_1.png
# /content/lw/transformed_0718_1.png
# /content/lw/transformed_0042_2.png
# /content/lw/transformed_0487_1.png
# /content/lw/transformed_0059_2.png
# /content/lw/transformed_0038_0.png
# /content/lw/transformed_0609_1.png
# /content/lw/transformed_0101_0.png
# /content/lw/transformed_0555_0.png
# /content/lw/transformed_0771_2.png
# /content/lw/transformed_0782_2.png
# /content/lw/transformed_0654_1.png
# /content/lw/transformed_0033_2.png
# /content/lw/transformed_0654_2.png
# /content/lw/transformed_0228_2.png
# /content/lw/transformed_0219_1.png
# /content/lw/transformed_0339_1.png
# /content/lw/transformed_0657_3.png
# /content/lw/transformed_0697_0.png
# /content/lw/transformed_0286_3.png
# /content/lw/transformed_0439_0.png
# /content/lw/transformed_0387_0.png
# /content/lw/transformed_0735_2.png
# /content/lw/transformed_0729_2.png
# /content/lw/transformed_0104_1.png
# /content/lw/transformed_0711_0.png
# /content/lw/transformed_0707_2.png
# /content/lw/transformed_0700_3.png
# /content/lw/transformed_0161_0.png
# /content/lw/transformed_0071_1.png
# /content/lw/transformed_0533_1.png
# /content/lw/transformed_0458_2.png
# /content/lw/transformed_0279_0.png
# /content/lw/transformed_0581_1.png
# /content/lw/transformed_0039_3.png
# /content/lw/transformed_0024_2.png
# /content/lw/transformed_0464_0.png
# /content/lw/transformed_0587_3.png
# /content/lw/transformed_0401_2.png
# /content/lw/transformed_0410_2.png
# /content/lw/transformed_0303_3.png
# /content/lw/transformed_0141_3.png
# /content/lw/transformed_0173_0.png
# /content/lw/transformed_0625_3.png
# /content/lw/transformed_0110_3.png
# /content/lw/transformed_0778_0.png
# /content/lw/transformed_0271_3.png
# /content/lw/transformed_0304_2.png
# /content/lw/transformed_0299_2.png
# /content/lw/transformed_0617_3.png
# /content/lw/transformed_0173_2.png
# /content/lw/transformed_0297_0.png
# /content/lw/transformed_0346_1.png
# /content/lw/transformed_0623_1.png
# /content/lw/transformed_0242_2.png
# /content/lw/transformed_0717_0.png
# /content/lw/transformed_0375_3.png
# /content/lw/transformed_0535_3.png
# /content/lw/transformed_0358_2.png
# /content/lw/transformed_0740_0.png
# /content/lw/transformed_0586_1.png
# /content/lw/transformed_0514_2.png
# /content/lw/transformed_0132_1.png
# /content/lw/transformed_0442_2.png
# /content/lw/transformed_0403_1.png
# /content/lw/transformed_0685_0.png
# /content/lw/transformed_0702_0.png
# /content/lw/transformed_0187_1.png
# /content/lw/transformed_0533_2.png
# /content/lw/transformed_0636_3.png
# /content/lw/transformed_0156_2.png
# /content/lw/transformed_0182_2.png
# /content/lw/transformed_0096_1.png
# /content/lw/transformed_0368_0.png
# /content/lw/transformed_0463_0.png
# /content/lw/transformed_0128_2.png
# /content/lw/transformed_0146_3.png
# /content/lw/transformed_0114_3.png
# /content/lw/transformed_0548_0.png
# /content/lw/transformed_0327_2.png
# /content/lw/transformed_0218_2.png
# /content/lw/transformed_0229_1.png
# /content/lw/transformed_0419_3.png
# /content/lw/transformed_0327_0.png
# /content/lw/transformed_0492_3.png
# /content/lw/transformed_0145_2.png
# /content/lw/transformed_0262_3.png
# /content/lw/transformed_0123_2.png
# /content/lw/transformed_0084_0.png
# /content/lw/transformed_0367_0.png
# /content/lw/transformed_0106_1.png
# /content/lw/transformed_0590_1.png
# /content/lw/transformed_0196_2.png
# /content/lw/transformed_0701_1.png
# /content/lw/transformed_0250_0.png
# /content/lw/transformed_0708_1.png
# /content/lw/transformed_0475_3.png
# /content/lw/transformed_0475_2.png
# /content/lw/transformed_0609_0.png
# /content/lw/transformed_0125_2.png
# /content/lw/transformed_0704_0.png
# /content/lw/transformed_0280_2.png
# /content/lw/transformed_0007_0.png
# /content/lw/transformed_0393_1.png
# /content/lw/transformed_0679_0.png
# /content/lw/transformed_0424_2.png
# /content/lw/transformed_0468_1.png
# /content/lw/transformed_0369_2.png
# /content/lw/transformed_0609_2.png
# /content/lw/transformed_0483_1.png
# /content/lw/transformed_0139_0.png
# /content/lw/transformed_0567_0.png
# /content/lw/transformed_0594_3.png
# /content/lw/transformed_0726_3.png
# /content/lw/transformed_0223_3.png
# /content/lw/transformed_0457_2.png
# /content/lw/transformed_0493_1.png
# /content/lw/transformed_0168_2.png
# /content/lw/transformed_0624_1.png
# /content/lw/transformed_0510_2.png
# /content/lw/transformed_0485_1.png
# /content/lw/transformed_0276_1.png
# /content/lw/transformed_0583_2.png
# /content/lw/transformed_0082_2.png
# /content/lw/transformed_0437_0.png
# /content/lw/transformed_0395_2.png
# /content/lw/transformed_0595_3.png
# /content/lw/transformed_0274_2.png
# /content/lw/transformed_0635_3.png
# /content/lw/transformed_0081_1.png
# /content/lw/transformed_0461_1.png
# /content/lw/transformed_0667_0.png
# /content/lw/transformed_0718_0.png
# /content/lw/transformed_0777_1.png
# /content/lw/transformed_0203_2.png
# /content/lw/transformed_0382_1.png
# /content/lw/transformed_0304_0.png
# /content/lw/transformed_0310_1.png
# /content/lw/transformed_0335_2.png
# /content/lw/transformed_0607_1.png
# /content/lw/transformed_0405_2.png
# /content/lw/transformed_0035_1.png
# /content/lw/transformed_0159_3.png
# /content/lw/transformed_0758_1.png
# /content/lw/transformed_0013_3.png
# /content/lw/transformed_0604_0.png
# /content/lw/transformed_0139_2.png
# /content/lw/transformed_0576_0.png
# /content/lw/transformed_0758_3.png
# /content/lw/transformed_0270_3.png
# /content/lw/transformed_0667_3.png
# /content/lw/transformed_0496_0.png
# /content/lw/transformed_0271_0.png
# /content/lw/transformed_0205_1.png
# /content/lw/transformed_0323_0.png
# /content/lw/transformed_0373_0.png
# /content/lw/transformed_0295_3.png
# /content/lw/transformed_0445_0.png
# /content/lw/transformed_0749_2.png
# /content/lw/transformed_0657_2.png
# /content/lw/transformed_0434_1.png
# /content/lw/transformed_0336_0.png
# /content/lw/transformed_0215_3.png
# /content/lw/transformed_0142_0.png
# /content/lw/transformed_0380_2.png
# /content/lw/transformed_0282_1.png
# /content/lw/transformed_0201_1.png
# /content/lw/transformed_0050_3.png
# /content/lw/transformed_0439_3.png
# /content/lw/transformed_0248_2.png
# /content/lw/transformed_0451_0.png
# /content/lw/transformed_0540_1.png
# /content/lw/transformed_0085_1.png
# /content/lw/transformed_0023_1.png
# /content/lw/transformed_0239_2.png
# /content/lw/transformed_0406_2.png
# /content/lw/transformed_0058_3.png
# /content/lw/transformed_0148_1.png
# /content/lw/transformed_0460_3.png
# /content/lw/transformed_0172_1.png
# /content/lw/transformed_0026_1.png
# /content/lw/transformed_0551_0.png
# /content/lw/transformed_0344_2.png
# /content/lw/transformed_0664_0.png
# /content/lw/transformed_0309_3.png
# /content/lw/transformed_0731_2.png
# /content/lw/transformed_0691_1.png
# /content/lw/transformed_0396_1.png
# /content/lw/transformed_0560_0.png
# /content/lw/transformed_0272_3.png
# /content/lw/transformed_0050_1.png
# /content/lw/transformed_0435_2.png
# /content/lw/transformed_0565_1.png
# /content/lw/transformed_0129_0.png
# /content/lw/transformed_0003_0.png
# /content/lw/transformed_0197_0.png
# /content/lw/transformed_0741_0.png
# /content/lw/transformed_0263_1.png
# /content/lw/transformed_0456_0.png
# /content/lw/transformed_0793_1.png
# /content/lw/transformed_0522_3.png
# ['/', '/', '/', 'c', 'e', 'l', 'n', 'n', 'o', 't', 't', 'w']

# %%
dmg=DataSetManage()
directoriolw={
     "lw":["/content/lw/",0],
}

directoriohr={
     "hr":["/content/hr/",1],
}




listas_directorios,listas_paths_directorios,listas_clases=dmg.separar_datos_directorios(directoriolw)
Dataset_csv="lw_dataset.csv" #nombre que tenda nuestlo csv
dmg.crear_paths_csv(listas_directorios,listas_paths_directorios,listas_clases,Dataset_csv)


listas_directorios,listas_paths_directorios,listas_clases=dmg.separar_datos_directorios(directoriohr)
Dataset_csv="hr_dataset.csv" #nombre que tendla nuestlo csv
dmg.crear_paths_csv(listas_directorios,listas_paths_directorios,listas_clases,Dataset_csv)
# Out:
# Csv Creado
# Csv Creado

# %%
#DEFNIIR DISPOSITIVO:
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("CUDA está disponible.")
    device = torch.device("cuda")
else:
    print("CUDA no está disponible. Se utilizará la CPU.")
    device = torch.device("cpu")
# Out:
# CUDA está disponible.

# %%
#@markdown # *2) ** Creacion de clase DATASET(OBLIGATORIO)
import torch
from torch.utils.data import Dataset,DataLoader
import pandas as pd
import numpy as np
import cv2
from PIL import Image


class MiDataSet(Dataset):

  def __init__(self,csv_file, transform=None):


     self.data=pd.read_csv(csv_file)

     self.x=self.data["path"]
     self.y=self.data["etiqueta"]

     self.transform=transform

     self.samples=self.data["path"].shape[0]

  def __getitem__(self,id):

    rut_imagen=self.x[id]
    imagen=cv2.imread(rut_imagen)
    etiqueta=self.y[id]


    if imagen is None:
      pillow_image = Image.open(rut_imagen)
      numpy_image = np.array(pillow_image)
      imagen=cv2.cvtColor(numpy_image, cv2.COLOR_RGB2BGR)


    imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)


    if self.transform:
      imagen_rgb = self.transform(imagen_rgb)

    return imagen_rgb,etiqueta


  def __len__(self):
   return self.samples

# %%
#CREANDO DATASETS Y DATALOADERS:

import numpy as np
import matplotlib.pyplot as plt

transformaciones = transforms.Compose([
    transforms.ToTensor(),

])

batch_size=15

DatasetLw=MiDataSet("/content/lw_dataset.csv",transformaciones)
data_loaderLw=DataLoader(DatasetLw,batch_size=batch_size)

DatasetHr=MiDataSet("/content/hr_dataset.csv",transformaciones)
data_loaderHr=DataLoader(DatasetHr,batch_size=batch_size)

generated_image_hr,etiqueta_hr=DatasetHr.__getitem__(200)
generated_image_lw,etiqueta_lw=DatasetHr.__getitem__(200)
print(generated_image_hr.shape)
generated_image_np_hr = generated_image_hr.squeeze().permute(1, 2, 0).numpy()
generated_image_np_lw = generated_image_lw.squeeze().permute(1, 2, 0).numpy()
# Visualizar la imagen generada
# Subfigura 1
plt.subplot(1, 2, 1)
plt.imshow(generated_image_np_hr)
plt.title('hr')

# Subfigura 2
plt.subplot(1, 2, 2)
plt.imshow(generated_image_np_lw)
plt.title('lw')

# Ajustar diseño
plt.tight_layout()

# Mostrar las imágenes
plt.show()
# Out:
# torch.Size([3, 80, 80])

# %%
#@markdown # *0) ** Creando clase Discriminadora y Geneaadora:

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
from torch.utils.data import Dataset,DataLoader
import torchvision.transforms as transforms
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as F

class Discriminator (nn.Module):
  def __init__(self):
   super(Discriminator,self).__init__()

   self.conv1=nn.Conv2d(3,64,kernel_size=3,stride=1, bias=False)
   self.conv2=nn.Conv2d(64,64,kernel_size=3,stride=2, bias=False)
   self.btchnorm64=nn.BatchNorm2d(64)

   self.conv3=nn.Conv2d(64,128,kernel_size=3,stride=1, bias=False)
   self.conv4=nn.Conv2d(128,128,kernel_size=3,stride=2, bias=False)
   self.btchnorm128=nn.BatchNorm2d(128)

   self.conv5=nn.Conv2d(128,256,kernel_size=3,stride=1, bias=False)
   self.conv6=nn.Conv2d(256,256,kernel_size=3,stride=2, bias=False)
   self.btchnorm256=nn.BatchNorm2d(256)

   self.conv7=nn.Conv2d(256,512,kernel_size=3,stride=1, bias=False)
   self.conv8=nn.Conv2d(512,512,kernel_size=3,stride=2, bias=False)
   self.btchnorm512=nn.BatchNorm2d(512)
   self.flatt=nn.Flatten()

   self.oculta1=nn.LazyLinear(1024)
   self.salida= nn.LazyLinear(1)


  def forward(self,x):

    x=self.conv1(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv2(x)
    x=self.btchnorm64(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv3(x)
    x=self.btchnorm128(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv4(x)
    x=self.btchnorm128(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv5(x)
    x=self.btchnorm256(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv6(x)
    x=self.btchnorm256(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv7(x)
    x=self.btchnorm512(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv8(x)
    x=self.btchnorm512(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.flatt(x)
    x=self.oculta1(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.salida(x)
    out=torch.sigmoid(x)

    return out

# %%
discriminador=Discriminator()
discriminador=discriminador.to(device)
x=torch.randn(20,3,208,208).to(device)

print(discriminador(x))
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# tensor([[0.4905],
#         [0.4856],
#         [0.5014],
#         [0.5070],
#         [0.4486],
#         [0.4512],
#         [0.4351],
#         [0.4713],
#         [0.4997],
#         [0.4377],
#         [0.4173],
#         [0.5353],
#         [0.4843],
#         [0.5077],
#         [0.4307],
#         [0.4333],
#         [0.5312],
#         [0.4669],
#         [0.4440],
#         [0.4472]], device='cuda:0', grad_fn=<SigmoidBackward0>)

# %%
#------------------------------------------------------------------------
import torch.nn.functional as F
class Generador(nn.Module):

  def __init__(self,factor_escala):
   super(Generador,self).__init__()

   self.convInicial=nn.Conv2d(3,64,kernel_size=9,stride=1,padding=4)

  #Bloques residuales

   res_blocks = []
   for _ in range(5):
       res_blocks.append(ResidualBlock(64))
   self.res_blocks = nn.Sequential(*res_blocks)

   self.convSalida1=nn.Conv2d(64,64,kernel_size=3,stride=1,padding=1)
   self.btchnorm=nn.BatchNorm2d(64)

  #vamos a obligar que la salida anterior se ajuste a la entrada del bloque umsampling que es 256/factor al cuadrado, asi no tengamos problemas en el bluque

   self.convextra=nn.Conv2d(64,int(256/factor_escala**2),kernel_size=1,stride=1)

  #Bloques upsampling

   upsampling = []
   for out_features in range(2):
        upsampling.append(upsampling_block(256,factor_escala))

   self.upsampling = nn.Sequential(*upsampling)

   self.prelu_layer=nn.PReLU();
   self.convlast=nn.Conv2d(int(256/factor_escala**2),3,kernel_size=9,stride=1,padding=4)



  def forward(self,x):


    x=self.convInicial(x)
    x= self.prelu_layer(x)
    x_inicial=x

    x=self.res_blocks(x)
    x= self.convSalida1(x)

    x=torch.add(x,x_inicial)
    x=self.convextra(x)

    x=self.upsampling(x)



    x=self.convlast(x)
    out= ((torch.tanh(x) + 1) / 2)
    return out


class upsampling_block(nn.Module):
    def __init__(self, out_features,factor):
        super(upsampling_block, self).__init__()
        print(int(out_features/factor**2))
        self.conv_block = nn.Sequential(
                nn.Conv2d(int(out_features/factor**2), out_features, 3, 1, 1),
                nn.BatchNorm2d(out_features),
                nn.PixelShuffle(upscale_factor=factor),
                nn.PReLU(),
        )

    def forward(self, x):
        return self.conv_block(x)


class ResidualBlock(nn.Module):
    def __init__(self, in_features):
        super(ResidualBlock, self).__init__()
        self.conv_block = nn.Sequential(
            nn.Conv2d(in_features, in_features, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(in_features, 0.8),
            nn.PReLU(),
            nn.Conv2d(in_features, in_features, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(in_features, 0.8),
        )

    def forward(self, x):
        return x + self.conv_block(x)

# %%
#VAMOS A VER QUE MEDIADES EL GENERADOR DA COMO RESUTLADO CON LW RESOLUTIONS MEDIDAES:

generador=Generador(2)
generador=generador.to(device)
x=torch.randn(20,3,20,20).to(device)

print(generador(x).shape)
# Out:
# 64
# 64
# torch.Size([20, 3, 80, 80])

# %%
#PROBAMOS EL GENERADOR INCIAL:

from PIL import Image
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt


#--------------------------------------------------------------------------------------------------------
def show_comparacion(real,generado): #deben de ingrenar don tennoren de imagen generada y real
 print(generado.shape)
 print(real.shape)
 real=real.detach().squeeze().cpu().numpy().transpose(1, 2, 0)
 generado=generado.squeeze().cpu().detach().numpy().transpose(1, 2, 0)
# Primer subgráfico: imagen original
 plt.subplot(1, 2, 1)
 plt.imshow(generado)  # Convertir a NumPy y transponer dimensiones
 plt.title('Imagen Generada')
 plt.axis('off')

# Segundo subgráfico: imagen transformada
 plt.subplot(1, 2, 2)
 plt.imshow(real)  # Convertir a NumPy y transponer dimensiones
 plt.title('Imagen Real')
 plt.axis('off')

# Ajustar el diseño para evitar superposición de títulos
 plt.tight_layout()

# Mostrar la figura
 plt.show()


 plt.figure(figsize=(10, 5))
#-----------------------------------------------------------------------------------
generador=Generador(2).to("cpu")

ruta_imagen = "/content/hr/transformed_0002_1.png"
imagen = Image.open(ruta_imagen)

transformador = ToTensor()

#original iamgen tensor
tensor_imagen = transformador(imagen).unsqueeze(0)
tensor_imagen=tensor_imagen.to("cpu")
#imagen generada
imagen_generada=generador(tensor_imagen)



show_comparacion(tensor_imagen,imagen_generada)
# Out:
# 64
# 64
# torch.Size([1, 3, 320, 320])
# torch.Size([1, 3, 80, 80])

# %%
import torch.nn.functional as F
import math

#Funciones especiales para hallar metricas entre imagnes:
#Usaremos psnr como metrica para comparar dos imagenes que tan iguales son este resultado dara pro desibeles (db) el ragno es de 0-40 donde 40db mas optimo


def psnr(image1, image2):
    mse = torch.mean((image1 - image2) ** 2)
    if mse == 0:
        return float('inf')
    max_pixel = 1
    psnr_value = 10 * torch.log10((max_pixel ** 2) / mse)
    return psnr_value


#Otra metrica es el ssmi, este parametro compara tanto el contraste,brillo y Similitud de estructura, el rango es [-1,1]


def ssim_score(y_pred, y_true, w_size=11,sigma=1.5 ,size_average=True, full=False):

    # Value range can be different from 255. Other common ranges are 1 (sigmoid) and 2 (tanh).
    if torch.max(y_pred) > 128:
        max_val = 255
    else:
        max_val = 1

    if torch.min(y_pred) < -0.5:
        min_val = -1
    else:
        min_val = 0
    L = max_val - min_val

    padd = 0
    (_, channel, height, width) = y_pred.size()

    # Gaussian filter
    gauss = torch.Tensor([math.exp(-(x - w_size//2)**2/float(2*sigma**2)) for x in range(w_size)]).to(device)
    window = gauss/gauss.sum().to(device)

    # Create 2D window
    _1D_window = window.unsqueeze(1)
    _2D_window = _1D_window.mm(_1D_window.t()).float().unsqueeze(0).unsqueeze(0)
    window = _2D_window.expand(channel, 1, w_size, w_size).contiguous().to(device)

    # Convolution
    mu1 = F.conv2d(y_pred, window, padding=padd, groups=channel)
    mu2 = F.conv2d(y_true, window, padding=padd, groups=channel)
    mu1_sq = mu1.pow(2)
    mu2_sq = mu2.pow(2)
    mu1_mu2 = mu1 * mu2

    sigma1_sq = F.conv2d(y_pred * y_pred, window, padding=padd, groups=channel) - mu1_sq
    sigma2_sq = F.conv2d(y_true * y_true, window, padding=padd, groups=channel) - mu2_sq
    sigma12 = F.conv2d(y_pred * y_true, window, padding=padd, groups=channel) - mu1_mu2

    C1 = (0.01 * L) ** 2
    C2 = (0.03 * L) ** 2

    v1 = 2.0 * sigma12 + C2
    v2 = sigma1_sq + sigma2_sq + C2
    cs = torch.mean(v1 / v2)  # contrast sensitivity

    ssim_map = ((2 * mu1_mu2 + C1) * v1) / ((mu1_sq + mu2_sq + C1) * v2)

    if size_average:
        ret = ssim_map.mean()
    else:
        ret = ssim_map.mean(1).mean(1).mean(1)

    if full:
        return ret, cs
    return ret

# %%
img1 = torch.rand(1, 3, 11, 11).to(device)
img2 = torch.rand(1, 3, 11, 11).to(device)

ss=SSIM()

ssim_value = ssim_score(img1, img2).to("cuda")
psnr_value = psnr(img1, img2)
print("SSIM:", ssim_value.item())
print("psrn:", psnr_value.item())
# Out:
# SSIM: 0.10368409007787704
# psrn: 7.960908889770508

# %%
from torchvision import models

#vamos a extraer los feature es decir las caracteisicas imporantes que exiten entre ambas imagnes y compraralas esto se usara par luego hace rel loss contet apartir del contendio

class Feature_Extractor(nn.Module):
    def __init__(self):
        super(Feature_Extractor, self).__init__()
        # Cargar un modelo VGG-19 preentrenado
        vgg19_model = models.vgg19(pretrained=True).features.eval()

        # No actualizar los pesos del modelo VGG durante el entrenamiento
        for param in vgg19_model.parameters():
            param.requires_grad = False

        selected_layers = list(vgg19_model.children())[:35] #AGREGAMOS EL VGG HASTA VERFICAR QUE EL ULITMA CAPA NO TENGA RELU

        self.vgg=nn.Sequential(*selected_layers)

    def forward(self, img):

        # Extraer características de las imágenes generada y real
        feature_img = self.vgg(img)

        return feature_img


# TV Loss se utiliza comúnmente en tareas de generación de imágenes para reducir el ruido y fomentar la suavidad en las imágenes generadas.

class TVLoss(nn.Module):
  def __init__(self, tv_loss_weight=1):
    super(TVLoss, self).__init__()
    self.tv_loss_weight=tv_loss_weight
  def forward(self, x):
    batch_size=x.size()[0]
    h_x = x.size()[2]
    w_x = x.size()[3]

    count_h = self.tensor_size(x[:, :, 1:, :])
    count_w = self.tensor_size(x[:, :, :, 1:])


    h_tv = torch.pow(x[:, :, 1:, :] - x[:, :, :h_x - 1, :], 2).sum()
    w_tv = torch.pow(x[:, :, :, 1:] - x[:, :, :, :w_x - 1], 2).sum()
    return self.tv_loss_weight * 2 * (h_tv / count_h + w_tv / count_w) / batch_size

  # Forgot to implement an important method
  @staticmethod # Must add this
  def tensor_size(t):
    return t.size()[1] * t.size()[2] * t.size()[3]

# %%
vgg=Feature_Extractor()
print(vgg)
tv_loss= TVLoss()
x=torch.randn(18,3,60,60)
tv_loss=tv_loss(x)

print(tv_loss)

# %%
import matplotlib.pyplot as plt
import torch
import numpy as np
import torchvision.utils as vutils
import sklearn
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset
from tqdm import tqdm
# ...

#d=Discriminator(image_dim).to(device)
#g=Generador(dim_vector_ruido,image_dim).to(device)

#d.load_state_dict(torch.load("/content/modelo_gatos_d.pt"))
#g.load_state_dict(torch.load("/content/modelo_gatos_g.pt"))

#d=d.to(device)
#g=g.to(device)


# Supongamos que ya has definido las instancias de los modelos Generador (g) y Discriminador (d),
# y has configurado los optimizadores (g_optimizer y d_optimizer) y la función de pérdida (criterio).



def GAN(discriminador, generador, data_loader_lw,data_loader_hr, num_epochs, batch_size, criterio_g,criterio_d, d_optimizador, g_optimizador, device):

    discriminador=discriminador.to(device)
    generador=generador.to(device)
    feature_extractor=Feature_Extractor().to(device)
    tv_loss= TVLoss().to(device)
    l1_loss=nn.L1Loss()

    for epoch in range(num_epochs):

        resultados = { 'd_loss':[],"g_loss":[], "d_score":[], "psnr":[],"ssmi":[] }
        data_loader_hr = tqdm(data_loader_hr)

        for  (lw, hr) in zip(data_loader_lw,data_loader_hr):

            hr_img,hrlbl=hr
            lw_img,lwlbl=lw

            hr_img=hr_img.to(device)
            lw_img=lw_img.to(device)

            generador.eval()
            discriminador.train()

            real_images = hr_img.float()

            real_labels = hrlbl.view(-1, 1).float().to(device)

            # Entrenar el discriminador con imágenes reales
            d_optimizador.zero_grad()

            prediction_real = discriminador(real_images)

            real_loss = criterio_d(prediction_real, real_labels)


            # Entrenar el discriminador con imágenes generadas

            fake_images = generador(lw_img)
            fake_labels = torch.zeros(lw_img.size(0), 1).to(device)

            prediction_fake = discriminador(fake_images)

            fake_loss = criterio_d(prediction_fake, fake_labels).to(device)
            discriminator_loss = (real_loss + fake_loss)

            discriminator_loss.backward(retain_graph=True)

            d_optimizador.step()

            # Entrenar el generador
            generador.train()
            discriminador.eval()
            g_optimizador.zero_grad()

            generated_images = generador(lw_img)
            loss_g=criterio_g(discriminador(generated_images),real_labels) #loss del generador aparitr del disicmirnador que dice si es o no una imagen falsa

            content_loss=criterio_g(generated_images,real_images) #loss imagen dircamtetne entre igmagen genrada y real

            generated_features=feature_extractor(generated_images)
            real_features=feature_extractor(real_images)

            content_loss_vgg=(criterio_g(real_features,generated_features)) #loss de los features original y generado,esto aparitr de el vgg19

           #calculando metricas opcional
            psnr_batch=psnr(generated_images,real_images).to(device)
            ssmi_batch=ssim_score(generated_images,real_images).to(device)

            psnr_promedio=psnr_batch.mean()
            ssmi_promedio=ssmi_batch.mean()

            metricas_loss=(torch.abs(0.39-(0.01*psnr_promedio))+torch.abs(0.1-(0.1*ssmi_promedio)))

            tv_losss=tv_loss(generated_images)
            L1=l1_loss(generated_images,real_images)

            #generator_loss = loss_imagen+(torch.abs(0.39-(0.01*psnr_promedio)))+0.006*content_loss+(0.001*loss_g)+  2e-8 *tv_losss  #loss total del generador
            generator_loss = content_loss+(0.001*loss_g)+(0.0006*content_loss_vgg)+metricas_loss+ 2e-8 *(tv_losss)

            generator_loss.backward()
            g_optimizador.step()


            #resultados por batch:
            resultados["d_loss"].append(discriminator_loss.item())
            resultados["g_loss"].append(generator_loss.item())
            resultados["psnr"].append(psnr_promedio.detach().cpu())
            resultados["ssmi"].append(ssmi_promedio.detach().cpu())

            data_loader_hr.set_description(desc="[%d/%d] Loss_D: %.4f Loss_G: %.4f psnr: %.4f ssmi: %.4f" % (
            epoch, num_epochs, np.mean(resultados['d_loss']),
            np.mean(resultados['g_loss']) ,
            np.mean( resultados['psnr']) ,
            np.mean( resultados['ssmi']) ,
            ))

        data_loader_hr.close()
        # Imprimir estadísticas y visualizar imágenes generadas al final de cada época
        print(f'Época [{epoch}/{num_epochs}] '
                      f'd_loss_total: {np.mean(resultados["d_loss"]):.4f}, '
                      f'g_loss_total: {np.mean(resultados["g_loss"]):.4f}',f'psnr_total:{np.mean(resultados["psnr"]):.4f}',f'ssmi_total:{np.mean(resultados["ssmi"]):.4f}')

        with torch.no_grad():
            generador.eval()
            generated_images = generador(lw_img)

            show_comparacion(hr_img[0],generated_images[0])


#--------------------------------------------------------------------------------------------



num_epochs=30




d=Discriminator()
g=Generador(2)

d.load_state_dict(torch.load("/content/srgan_d.pt"))
g.load_state_dict(torch.load("/content/srgan_g.pt"))

lr_g = 0.0002
lr_d = 0.0002
d_optimizer=optim.Adam(d.parameters(),lr=lr_d)
g_optimizer=optim.Adam(g.parameters(),lr=lr_g)

criterio_d=nn.BCELoss()
criterio_g=nn.MSELoss()


print(f"learning rate discrimiador:{lr_d}")
print(f"learning rate generador:{lr_g}")

GAN(d,g,data_loaderLw,data_loaderHr,num_epochs,batch_size,criterio_g,criterio_d,d_optimizer,g_optimizer,device)

# %%
torch.save(g.state_dict(), 'srgan_g.pt')
torch.save(d.state_dict(), 'srgan_d.pt')

# %%
d.load_state_dict(torch.load("/content/srgan_d.pt"))

# %%
from PIL import Image
# Suponiendo que "Generador" es la clase de tu generador y "ruta_modelo" es la ruta del modelo guardado
generador = Generador(2)  # creando generado
generador.load_state_dict(torch.load("/content/srgan_g.pt"))
generador.to(device)
generador.eval()

ruta_imagen = "/content/baboon.png"
imagen_pil = Image.open(ruta_imagen)

transformaciones = transforms.Compose([
    transforms.ToTensor(),  # Convierte la imagen a un tensor

])

imagen_transformada = transformaciones(imagen_pil)
imagen_transformada=imagen_transformada.to(device)
with torch.no_grad():
    generador.eval()

    generated_image = generador(imagen_transformada.unsqueeze(0)).detach().cpu()

# Convertir la imagen al rango [0, 1]
# generated_image = (generated_image + 1) / 2.0

generated_image_np = generated_image.squeeze().permute(1, 2, 0).numpy()

print(generated_image.shape)
# Visualizar la imagen generada
plt.imshow(generated_image_np)
plt.axis('off')
plt.show()


# Convertir el tensor a una imagen
tensor_a_imagen = transforms.ToPILImage()(generated_image.squeeze())

# Guardar la imagen
tensor_a_imagen.save("imagen_guardadahd.jpg")
# Out:
# 64
# 64
# torch.Size([1, 3, 480, 500])
