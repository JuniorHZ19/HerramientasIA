# %% [markdown]
# <a href="https://colab.research.google.com/github/JuniorHZ19/HerramientasIA/blob/main/srgan5.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# !unzip DIV2K_train_HR.zip # This is our dataset link. I will include this command in the description
# Out:
# --2024-02-01 23:46:02--  http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.178, 2001:67c:10ec:36c2::178
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip [following]
# --2024-02-01 23:46:02--  https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3530603713 (3.3G) [application/zip]
# Saving to: ‘DIV2K_train_HR.zip’
#
# DIV2K_train_HR.zip  100%[===================>]   3.29G  18.5MB/s    in 3m 2s
#
# 2024-02-01 23:49:05 (18.5 MB/s) - ‘DIV2K_train_HR.zip’ saved [3530603713/3530603713]
#
# Archive:  DIV2K_train_HR.zip
#    creating: DIV2K_train_HR/
#   inflating: DIV2K_train_HR/0103.png
#   inflating: DIV2K_train_HR/0413.png
#   inflating: DIV2K_train_HR/0031.png
#   inflating: DIV2K_train_HR/0660.png
#   inflating: DIV2K_train_HR/0126.png
#   inflating: DIV2K_train_HR/0793.png
#   inflating: DIV2K_train_HR/0764.png
#   inflating: DIV2K_train_HR/0550.png
#   inflating: DIV2K_train_HR/0437.png
#   inflating: DIV2K_train_HR/0374.png
#   inflating: DIV2K_train_HR/0755.png
#   inflating: DIV2K_train_HR/0614.png
#   inflating: DIV2K_train_HR/0646.png
#   inflating: DIV2K_train_HR/0371.png
#   inflating: DIV2K_train_HR/0312.png
#   inflating: DIV2K_train_HR/0108.png
#   inflating: DIV2K_train_HR/0556.png
#   inflating: DIV2K_train_HR/0794.png
#   inflating: DIV2K_train_HR/0722.png
#   inflating: DIV2K_train_HR/0780.png
#   inflating: DIV2K_train_HR/0555.png
#   inflating: DIV2K_train_HR/0439.png
#   inflating: DIV2K_train_HR/0396.png
#   inflating: DIV2K_train_HR/0666.png
#   inflating: DIV2K_train_HR/0254.png
#   inflating: DIV2K_train_HR/0344.png
#   inflating: DIV2K_train_HR/0062.png
#   inflating: DIV2K_train_HR/0657.png
#   inflating: DIV2K_train_HR/0117.png
#   inflating: DIV2K_train_HR/0395.png
#   inflating: DIV2K_train_HR/0015.png
#   inflating: DIV2K_train_HR/0335.png
#   inflating: DIV2K_train_HR/0578.png
#   inflating: DIV2K_train_HR/0142.png
#   inflating: DIV2K_train_HR/0719.png
#   inflating: DIV2K_train_HR/0101.png
#   inflating: DIV2K_train_HR/0579.png
#   inflating: DIV2K_train_HR/0504.png
#   inflating: DIV2K_train_HR/0576.png
#   inflating: DIV2K_train_HR/0590.png
#   inflating: DIV2K_train_HR/0158.png
#   inflating: DIV2K_train_HR/0384.png
#   inflating: DIV2K_train_HR/0795.png
#   inflating: DIV2K_train_HR/0668.png
#   inflating: DIV2K_train_HR/0144.png
#   inflating: DIV2K_train_HR/0642.png
#   inflating: DIV2K_train_HR/0427.png
#   inflating: DIV2K_train_HR/0593.png
#   inflating: DIV2K_train_HR/0080.png
#   inflating: DIV2K_train_HR/0050.png
#   inflating: DIV2K_train_HR/0617.png
#   inflating: DIV2K_train_HR/0608.png
#   inflating: DIV2K_train_HR/0118.png
#   inflating: DIV2K_train_HR/0082.png
#   inflating: DIV2K_train_HR/0788.png
#   inflating: DIV2K_train_HR/0042.png
#   inflating: DIV2K_train_HR/0333.png
#   inflating: DIV2K_train_HR/0346.png
#   inflating: DIV2K_train_HR/0705.png
#   inflating: DIV2K_train_HR/0195.png
#   inflating: DIV2K_train_HR/0671.png
#   inflating: DIV2K_train_HR/0213.png
#   inflating: DIV2K_train_HR/0692.png
#   inflating: DIV2K_train_HR/0253.png
#   inflating: DIV2K_train_HR/0191.png
#   inflating: DIV2K_train_HR/0628.png
#   inflating: DIV2K_train_HR/0354.png
#   inflating: DIV2K_train_HR/0003.png
#   inflating: DIV2K_train_HR/0393.png
#   inflating: DIV2K_train_HR/0336.png
#   inflating: DIV2K_train_HR/0674.png
#   inflating: DIV2K_train_HR/0586.png
#   inflating: DIV2K_train_HR/0074.png
#   inflating: DIV2K_train_HR/0116.png
#   inflating: DIV2K_train_HR/0270.png
#   inflating: DIV2K_train_HR/0376.png
#   inflating: DIV2K_train_HR/0650.png
#   inflating: DIV2K_train_HR/0462.png
#   inflating: DIV2K_train_HR/0046.png
#   inflating: DIV2K_train_HR/0545.png
#   inflating: DIV2K_train_HR/0347.png
#   inflating: DIV2K_train_HR/0187.png
#   inflating: DIV2K_train_HR/0713.png
#   inflating: DIV2K_train_HR/0558.png
#   inflating: DIV2K_train_HR/0319.png
#   inflating: DIV2K_train_HR/0073.png
#   inflating: DIV2K_train_HR/0033.png
#   inflating: DIV2K_train_HR/0207.png
#   inflating: DIV2K_train_HR/0290.png
#   inflating: DIV2K_train_HR/0194.png
#   inflating: DIV2K_train_HR/0246.png
#   inflating: DIV2K_train_HR/0034.png
#   inflating: DIV2K_train_HR/0621.png
#   inflating: DIV2K_train_HR/0768.png
#   inflating: DIV2K_train_HR/0366.png
#   inflating: DIV2K_train_HR/0490.png
#   inflating: DIV2K_train_HR/0471.png
#   inflating: DIV2K_train_HR/0475.png
#   inflating: DIV2K_train_HR/0152.png
#   inflating: DIV2K_train_HR/0636.png
#   inflating: DIV2K_train_HR/0338.png
#   inflating: DIV2K_train_HR/0358.png
#   inflating: DIV2K_train_HR/0523.png
#   inflating: DIV2K_train_HR/0456.png
#   inflating: DIV2K_train_HR/0470.png
#   inflating: DIV2K_train_HR/0522.png
#   inflating: DIV2K_train_HR/0426.png
#   inflating: DIV2K_train_HR/0587.png
#   inflating: DIV2K_train_HR/0465.png
#   inflating: DIV2K_train_HR/0236.png
#   inflating: DIV2K_train_HR/0192.png
#   inflating: DIV2K_train_HR/0458.png
#   inflating: DIV2K_train_HR/0438.png
#   inflating: DIV2K_train_HR/0176.png
#   inflating: DIV2K_train_HR/0016.png
#   inflating: DIV2K_train_HR/0392.png
#   inflating: DIV2K_train_HR/0054.png
#   inflating: DIV2K_train_HR/0063.png
#   inflating: DIV2K_train_HR/0537.png
#   inflating: DIV2K_train_HR/0271.png
#   inflating: DIV2K_train_HR/0409.png
#   inflating: DIV2K_train_HR/0328.png
#   inflating: DIV2K_train_HR/0582.png
#   inflating: DIV2K_train_HR/0532.png
#   inflating: DIV2K_train_HR/0706.png
#   inflating: DIV2K_train_HR/0153.png
#   inflating: DIV2K_train_HR/0401.png
#   inflating: DIV2K_train_HR/0110.png
#   inflating: DIV2K_train_HR/0316.png
#   inflating: DIV2K_train_HR/0069.png
#   inflating: DIV2K_train_HR/0209.png
#   inflating: DIV2K_train_HR/0351.png
#   inflating: DIV2K_train_HR/0433.png
#   inflating: DIV2K_train_HR/0534.png
#   inflating: DIV2K_train_HR/0525.png
#   inflating: DIV2K_train_HR/0353.png
#   inflating: DIV2K_train_HR/0018.png
#   inflating: DIV2K_train_HR/0592.png
#   inflating: DIV2K_train_HR/0041.png
#   inflating: DIV2K_train_HR/0398.png
#   inflating: DIV2K_train_HR/0355.png
#   inflating: DIV2K_train_HR/0492.png
#   inflating: DIV2K_train_HR/0258.png
#   inflating: DIV2K_train_HR/0051.png
#   inflating: DIV2K_train_HR/0339.png
#   inflating: DIV2K_train_HR/0156.png
#   inflating: DIV2K_train_HR/0174.png
#   inflating: DIV2K_train_HR/0526.png
#   inflating: DIV2K_train_HR/0168.png
#   inflating: DIV2K_train_HR/0515.png
#   inflating: DIV2K_train_HR/0289.png
#   inflating: DIV2K_train_HR/0700.png
#   inflating: DIV2K_train_HR/0711.png
#   inflating: DIV2K_train_HR/0317.png
#   inflating: DIV2K_train_HR/0310.png
#   inflating: DIV2K_train_HR/0075.png
#   inflating: DIV2K_train_HR/0533.png
#   inflating: DIV2K_train_HR/0345.png
#   inflating: DIV2K_train_HR/0238.png
#   inflating: DIV2K_train_HR/0493.png
#   inflating: DIV2K_train_HR/0019.png
#   inflating: DIV2K_train_HR/0559.png
#   inflating: DIV2K_train_HR/0268.png
#   inflating: DIV2K_train_HR/0746.png
#   inflating: DIV2K_train_HR/0648.png
#   inflating: DIV2K_train_HR/0112.png
#   inflating: DIV2K_train_HR/0639.png
#   inflating: DIV2K_train_HR/0216.png
#   inflating: DIV2K_train_HR/0170.png
#   inflating: DIV2K_train_HR/0408.png
#   inflating: DIV2K_train_HR/0461.png
#   inflating: DIV2K_train_HR/0774.png
#   inflating: DIV2K_train_HR/0308.png
#   inflating: DIV2K_train_HR/0368.png
#   inflating: DIV2K_train_HR/0341.png
#   inflating: DIV2K_train_HR/0535.png
#   inflating: DIV2K_train_HR/0585.png
#   inflating: DIV2K_train_HR/0004.png
#   inflating: DIV2K_train_HR/0496.png
#   inflating: DIV2K_train_HR/0662.png
#   inflating: DIV2K_train_HR/0173.png
#   inflating: DIV2K_train_HR/0200.png
#   inflating: DIV2K_train_HR/0752.png
#   inflating: DIV2K_train_HR/0106.png
#   inflating: DIV2K_train_HR/0520.png
#   inflating: DIV2K_train_HR/0519.png
#   inflating: DIV2K_train_HR/0157.png
#   inflating: DIV2K_train_HR/0552.png
#   inflating: DIV2K_train_HR/0735.png
#   inflating: DIV2K_train_HR/0362.png
#   inflating: DIV2K_train_HR/0410.png
#   inflating: DIV2K_train_HR/0286.png
#   inflating: DIV2K_train_HR/0627.png
#   inflating: DIV2K_train_HR/0557.png
#   inflating: DIV2K_train_HR/0266.png
#   inflating: DIV2K_train_HR/0252.png
#   inflating: DIV2K_train_HR/0206.png
#   inflating: DIV2K_train_HR/0330.png
#   inflating: DIV2K_train_HR/0088.png
#   inflating: DIV2K_train_HR/0728.png
#   inflating: DIV2K_train_HR/0641.png
#   inflating: DIV2K_train_HR/0350.png
#   inflating: DIV2K_train_HR/0083.png
#   inflating: DIV2K_train_HR/0682.png
#   inflating: DIV2K_train_HR/0549.png
#   inflating: DIV2K_train_HR/0564.png
#   inflating: DIV2K_train_HR/0476.png
#   inflating: DIV2K_train_HR/0760.png
#   inflating: DIV2K_train_HR/0629.png
#   inflating: DIV2K_train_HR/0630.png
#   inflating: DIV2K_train_HR/0032.png
#   inflating: DIV2K_train_HR/0581.png
#   inflating: DIV2K_train_HR/0056.png
#   inflating: DIV2K_train_HR/0040.png
#   inflating: DIV2K_train_HR/0169.png
#   inflating: DIV2K_train_HR/0400.png
#   inflating: DIV2K_train_HR/0172.png
#   inflating: DIV2K_train_HR/0182.png
#   inflating: DIV2K_train_HR/0269.png
#   inflating: DIV2K_train_HR/0612.png
#   inflating: DIV2K_train_HR/0649.png
#   inflating: DIV2K_train_HR/0311.png
#   inflating: DIV2K_train_HR/0723.png
#   inflating: DIV2K_train_HR/0166.png
#   inflating: DIV2K_train_HR/0155.png
#   inflating: DIV2K_train_HR/0072.png
#   inflating: DIV2K_train_HR/0149.png
#   inflating: DIV2K_train_HR/0425.png
#   inflating: DIV2K_train_HR/0715.png
#   inflating: DIV2K_train_HR/0670.png
#   inflating: DIV2K_train_HR/0460.png
#   inflating: DIV2K_train_HR/0748.png
#   inflating: DIV2K_train_HR/0147.png
#   inflating: DIV2K_train_HR/0602.png
#   inflating: DIV2K_train_HR/0610.png
#   inflating: DIV2K_train_HR/0479.png
#   inflating: DIV2K_train_HR/0603.png
#   inflating: DIV2K_train_HR/0043.png
#   inflating: DIV2K_train_HR/0190.png
#   inflating: DIV2K_train_HR/0503.png
#   inflating: DIV2K_train_HR/0055.png
#   inflating: DIV2K_train_HR/0337.png
#   inflating: DIV2K_train_HR/0453.png
#   inflating: DIV2K_train_HR/0219.png
#   inflating: DIV2K_train_HR/0548.png
#   inflating: DIV2K_train_HR/0661.png
#   inflating: DIV2K_train_HR/0718.png
#   inflating: DIV2K_train_HR/0489.png
#   inflating: DIV2K_train_HR/0775.png
#   inflating: DIV2K_train_HR/0323.png
#   inflating: DIV2K_train_HR/0664.png
#   inflating: DIV2K_train_HR/0002.png
#   inflating: DIV2K_train_HR/0127.png
#   inflating: DIV2K_train_HR/0322.png
#   inflating: DIV2K_train_HR/0640.png
#   inflating: DIV2K_train_HR/0473.png
#   inflating: DIV2K_train_HR/0730.png
#   inflating: DIV2K_train_HR/0008.png
#   inflating: DIV2K_train_HR/0486.png
#   inflating: DIV2K_train_HR/0597.png
#   inflating: DIV2K_train_HR/0064.png
#   inflating: DIV2K_train_HR/0068.png
#   inflating: DIV2K_train_HR/0510.png
#   inflating: DIV2K_train_HR/0594.png
#   inflating: DIV2K_train_HR/0685.png
#   inflating: DIV2K_train_HR/0497.png
#   inflating: DIV2K_train_HR/0637.png
#   inflating: DIV2K_train_HR/0332.png
#   inflating: DIV2K_train_HR/0208.png
#   inflating: DIV2K_train_HR/0241.png
#   inflating: DIV2K_train_HR/0201.png
#   inflating: DIV2K_train_HR/0044.png
#   inflating: DIV2K_train_HR/0141.png
#   inflating: DIV2K_train_HR/0381.png
#   inflating: DIV2K_train_HR/0412.png
#   inflating: DIV2K_train_HR/0035.png
#   inflating: DIV2K_train_HR/0049.png
#   inflating: DIV2K_train_HR/0181.png
#   inflating: DIV2K_train_HR/0340.png
#   inflating: DIV2K_train_HR/0272.png
#   inflating: DIV2K_train_HR/0279.png
#   inflating: DIV2K_train_HR/0307.png
#   inflating: DIV2K_train_HR/0733.png
#   inflating: DIV2K_train_HR/0250.png
#   inflating: DIV2K_train_HR/0739.png
#   inflating: DIV2K_train_HR/0654.png
#   inflating: DIV2K_train_HR/0343.png
#   inflating: DIV2K_train_HR/0422.png
#   inflating: DIV2K_train_HR/0297.png
#   inflating: DIV2K_train_HR/0360.png
#   inflating: DIV2K_train_HR/0099.png
#   inflating: DIV2K_train_HR/0541.png
#   inflating: DIV2K_train_HR/0616.png
#   inflating: DIV2K_train_HR/0352.png
#   inflating: DIV2K_train_HR/0092.png
#   inflating: DIV2K_train_HR/0528.png
#   inflating: DIV2K_train_HR/0483.png
#   inflating: DIV2K_train_HR/0631.png
#   inflating: DIV2K_train_HR/0134.png
#   inflating: DIV2K_train_HR/0625.png
#   inflating: DIV2K_train_HR/0530.png
#   inflating: DIV2K_train_HR/0454.png
#   inflating: DIV2K_train_HR/0624.png
#   inflating: DIV2K_train_HR/0501.png
#   inflating: DIV2K_train_HR/0038.png
#   inflating: DIV2K_train_HR/0365.png
#   inflating: DIV2K_train_HR/0789.png
#   inflating: DIV2K_train_HR/0010.png
#   inflating: DIV2K_train_HR/0543.png
#   inflating: DIV2K_train_HR/0635.png
#   inflating: DIV2K_train_HR/0418.png
#   inflating: DIV2K_train_HR/0159.png
#   inflating: DIV2K_train_HR/0689.png
#   inflating: DIV2K_train_HR/0429.png
#   inflating: DIV2K_train_HR/0276.png
#   inflating: DIV2K_train_HR/0255.png
#   inflating: DIV2K_train_HR/0293.png
#   inflating: DIV2K_train_HR/0327.png
#   inflating: DIV2K_train_HR/0488.png
#   inflating: DIV2K_train_HR/0244.png
#   inflating: DIV2K_train_HR/0721.png
#   inflating: DIV2K_train_HR/0652.png
#   inflating: DIV2K_train_HR/0779.png
#   inflating: DIV2K_train_HR/0687.png
#   inflating: DIV2K_train_HR/0326.png
#   inflating: DIV2K_train_HR/0161.png
#   inflating: DIV2K_train_HR/0498.png
#   inflating: DIV2K_train_HR/0264.png
#   inflating: DIV2K_train_HR/0136.png
#   inflating: DIV2K_train_HR/0006.png
#   inflating: DIV2K_train_HR/0741.png
#   inflating: DIV2K_train_HR/0421.png
#   inflating: DIV2K_train_HR/0229.png
#   inflating: DIV2K_train_HR/0373.png
#   inflating: DIV2K_train_HR/0703.png
#   inflating: DIV2K_train_HR/0516.png
#   inflating: DIV2K_train_HR/0234.png
#   inflating: DIV2K_train_HR/0405.png
#   inflating: DIV2K_train_HR/0763.png
#   inflating: DIV2K_train_HR/0619.png
#   inflating: DIV2K_train_HR/0138.png
#   inflating: DIV2K_train_HR/0513.png
#   inflating: DIV2K_train_HR/0432.png
#   inflating: DIV2K_train_HR/0177.png
#   inflating: DIV2K_train_HR/0017.png
#   inflating: DIV2K_train_HR/0736.png
#   inflating: DIV2K_train_HR/0459.png
#   inflating: DIV2K_train_HR/0505.png
#   inflating: DIV2K_train_HR/0397.png
#   inflating: DIV2K_train_HR/0591.png
#   inflating: DIV2K_train_HR/0196.png
#   inflating: DIV2K_train_HR/0724.png
#   inflating: DIV2K_train_HR/0740.png
#   inflating: DIV2K_train_HR/0223.png
#   inflating: DIV2K_train_HR/0442.png
#   inflating: DIV2K_train_HR/0165.png
#   inflating: DIV2K_train_HR/0302.png
#   inflating: DIV2K_train_HR/0386.png
#   inflating: DIV2K_train_HR/0601.png
#   inflating: DIV2K_train_HR/0370.png
#   inflating: DIV2K_train_HR/0647.png
#   inflating: DIV2K_train_HR/0267.png
#   inflating: DIV2K_train_HR/0380.png
#   inflating: DIV2K_train_HR/0441.png
#   inflating: DIV2K_train_HR/0037.png
#   inflating: DIV2K_train_HR/0678.png
#   inflating: DIV2K_train_HR/0304.png
#   inflating: DIV2K_train_HR/0494.png
#   inflating: DIV2K_train_HR/0028.png
#   inflating: DIV2K_train_HR/0613.png
#   inflating: DIV2K_train_HR/0257.png
#   inflating: DIV2K_train_HR/0100.png
#   inflating: DIV2K_train_HR/0097.png
#   inflating: DIV2K_train_HR/0604.png
#   inflating: DIV2K_train_HR/0023.png
#   inflating: DIV2K_train_HR/0782.png
#   inflating: DIV2K_train_HR/0446.png
#   inflating: DIV2K_train_HR/0378.png
#   inflating: DIV2K_train_HR/0411.png
#   inflating: DIV2K_train_HR/0320.png
#   inflating: DIV2K_train_HR/0390.png
#   inflating: DIV2K_train_HR/0148.png
#   inflating: DIV2K_train_HR/0577.png
#   inflating: DIV2K_train_HR/0684.png
#   inflating: DIV2K_train_HR/0595.png
#   inflating: DIV2K_train_HR/0765.png
#   inflating: DIV2K_train_HR/0203.png
#   inflating: DIV2K_train_HR/0288.png
#   inflating: DIV2K_train_HR/0058.png
#   inflating: DIV2K_train_HR/0790.png
#   inflating: DIV2K_train_HR/0605.png
#   inflating: DIV2K_train_HR/0248.png
#   inflating: DIV2K_train_HR/0467.png
#   inflating: DIV2K_train_HR/0210.png
#   inflating: DIV2K_train_HR/0517.png
#   inflating: DIV2K_train_HR/0707.png
#   inflating: DIV2K_train_HR/0566.png
#   inflating: DIV2K_train_HR/0224.png
#   inflating: DIV2K_train_HR/0114.png
#   inflating: DIV2K_train_HR/0761.png
#   inflating: DIV2K_train_HR/0468.png
#   inflating: DIV2K_train_HR/0716.png
#   inflating: DIV2K_train_HR/0420.png
#   inflating: DIV2K_train_HR/0669.png
#   inflating: DIV2K_train_HR/0375.png
#   inflating: DIV2K_train_HR/0140.png
#   inflating: DIV2K_train_HR/0792.png
#   inflating: DIV2K_train_HR/0240.png
#   inflating: DIV2K_train_HR/0546.png
#   inflating: DIV2K_train_HR/0235.png
#   inflating: DIV2K_train_HR/0077.png
#   inflating: DIV2K_train_HR/0260.png
#   inflating: DIV2K_train_HR/0212.png
#   inflating: DIV2K_train_HR/0584.png
#   inflating: DIV2K_train_HR/0633.png
#   inflating: DIV2K_train_HR/0060.png
#   inflating: DIV2K_train_HR/0164.png
#   inflating: DIV2K_train_HR/0622.png
#   inflating: DIV2K_train_HR/0105.png
#   inflating: DIV2K_train_HR/0005.png
#   inflating: DIV2K_train_HR/0679.png
#   inflating: DIV2K_train_HR/0089.png
#   inflating: DIV2K_train_HR/0466.png
#   inflating: DIV2K_train_HR/0645.png
#   inflating: DIV2K_train_HR/0301.png
#   inflating: DIV2K_train_HR/0499.png
#   inflating: DIV2K_train_HR/0020.png
#   inflating: DIV2K_train_HR/0070.png
#   inflating: DIV2K_train_HR/0404.png
#   inflating: DIV2K_train_HR/0749.png
#   inflating: DIV2K_train_HR/0770.png
#   inflating: DIV2K_train_HR/0772.png
#   inflating: DIV2K_train_HR/0450.png
#   inflating: DIV2K_train_HR/0120.png
#   inflating: DIV2K_train_HR/0653.png
#   inflating: DIV2K_train_HR/0563.png
#   inflating: DIV2K_train_HR/0171.png
#   inflating: DIV2K_train_HR/0784.png
#   inflating: DIV2K_train_HR/0688.png
#   inflating: DIV2K_train_HR/0045.png
#   inflating: DIV2K_train_HR/0066.png
#   inflating: DIV2K_train_HR/0583.png
#   inflating: DIV2K_train_HR/0632.png
#   inflating: DIV2K_train_HR/0512.png
#   inflating: DIV2K_train_HR/0767.png
#   inflating: DIV2K_train_HR/0623.png
#   inflating: DIV2K_train_HR/0406.png
#   inflating: DIV2K_train_HR/0419.png
#   inflating: DIV2K_train_HR/0273.png
#   inflating: DIV2K_train_HR/0198.png
#   inflating: DIV2K_train_HR/0750.png
#   inflating: DIV2K_train_HR/0220.png
#   inflating: DIV2K_train_HR/0482.png
#   inflating: DIV2K_train_HR/0407.png
#   inflating: DIV2K_train_HR/0704.png
#   inflating: DIV2K_train_HR/0547.png
#   inflating: DIV2K_train_HR/0589.png
#   inflating: DIV2K_train_HR/0012.png
#   inflating: DIV2K_train_HR/0150.png
#   inflating: DIV2K_train_HR/0481.png
#   inflating: DIV2K_train_HR/0357.png
#   inflating: DIV2K_train_HR/0677.png
#   inflating: DIV2K_train_HR/0315.png
#   inflating: DIV2K_train_HR/0394.png
#   inflating: DIV2K_train_HR/0160.png
#   inflating: DIV2K_train_HR/0667.png
#   inflating: DIV2K_train_HR/0568.png
#   inflating: DIV2K_train_HR/0435.png
#   inflating: DIV2K_train_HR/0606.png
#   inflating: DIV2K_train_HR/0464.png
#   inflating: DIV2K_train_HR/0364.png
#   inflating: DIV2K_train_HR/0245.png
#   inflating: DIV2K_train_HR/0508.png
#   inflating: DIV2K_train_HR/0356.png
#   inflating: DIV2K_train_HR/0135.png
#   inflating: DIV2K_train_HR/0146.png
#   inflating: DIV2K_train_HR/0574.png
#   inflating: DIV2K_train_HR/0698.png
#   inflating: DIV2K_train_HR/0222.png
#   inflating: DIV2K_train_HR/0261.png
#   inflating: DIV2K_train_HR/0444.png
#   inflating: DIV2K_train_HR/0078.png
#   inflating: DIV2K_train_HR/0123.png
#   inflating: DIV2K_train_HR/0797.png
#   inflating: DIV2K_train_HR/0274.png
#   inflating: DIV2K_train_HR/0225.png
#   inflating: DIV2K_train_HR/0180.png
#   inflating: DIV2K_train_HR/0325.png
#   inflating: DIV2K_train_HR/0372.png
#   inflating: DIV2K_train_HR/0029.png
#   inflating: DIV2K_train_HR/0318.png
#   inflating: DIV2K_train_HR/0452.png
#   inflating: DIV2K_train_HR/0115.png
#   inflating: DIV2K_train_HR/0423.png
#   inflating: DIV2K_train_HR/0615.png
#   inflating: DIV2K_train_HR/0672.png
#   inflating: DIV2K_train_HR/0231.png
#   inflating: DIV2K_train_HR/0731.png
#   inflating: DIV2K_train_HR/0389.png
#   inflating: DIV2K_train_HR/0680.png
#   inflating: DIV2K_train_HR/0329.png
#   inflating: DIV2K_train_HR/0663.png
#   inflating: DIV2K_train_HR/0659.png
#   inflating: DIV2K_train_HR/0292.png
#   inflating: DIV2K_train_HR/0284.png
#   inflating: DIV2K_train_HR/0133.png
#   inflating: DIV2K_train_HR/0727.png
#   inflating: DIV2K_train_HR/0445.png
#   inflating: DIV2K_train_HR/0139.png
#   inflating: DIV2K_train_HR/0298.png
#   inflating: DIV2K_train_HR/0282.png
#   inflating: DIV2K_train_HR/0778.png
#   inflating: DIV2K_train_HR/0565.png
#   inflating: DIV2K_train_HR/0485.png
#   inflating: DIV2K_train_HR/0495.png
#   inflating: DIV2K_train_HR/0215.png
#   inflating: DIV2K_train_HR/0694.png
#   inflating: DIV2K_train_HR/0321.png
#   inflating: DIV2K_train_HR/0094.png
#   inflating: DIV2K_train_HR/0598.png
#   inflating: DIV2K_train_HR/0430.png
#   inflating: DIV2K_train_HR/0021.png
#   inflating: DIV2K_train_HR/0036.png
#   inflating: DIV2K_train_HR/0188.png
#   inflating: DIV2K_train_HR/0334.png
#   inflating: DIV2K_train_HR/0759.png
#   inflating: DIV2K_train_HR/0217.png
#   inflating: DIV2K_train_HR/0562.png
#   inflating: DIV2K_train_HR/0124.png
#   inflating: DIV2K_train_HR/0690.png
#   inflating: DIV2K_train_HR/0385.png
#   inflating: DIV2K_train_HR/0695.png
#   inflating: DIV2K_train_HR/0708.png
#   inflating: DIV2K_train_HR/0745.png
#   inflating: DIV2K_train_HR/0007.png
#   inflating: DIV2K_train_HR/0226.png
#   inflating: DIV2K_train_HR/0256.png
#   inflating: DIV2K_train_HR/0673.png
#   inflating: DIV2K_train_HR/0451.png
#   inflating: DIV2K_train_HR/0143.png
#   inflating: DIV2K_train_HR/0403.png
#   inflating: DIV2K_train_HR/0125.png
#   inflating: DIV2K_train_HR/0132.png
#   inflating: DIV2K_train_HR/0644.png
#   inflating: DIV2K_train_HR/0796.png
#   inflating: DIV2K_train_HR/0076.png
#   inflating: DIV2K_train_HR/0211.png
#   inflating: DIV2K_train_HR/0676.png
#   inflating: DIV2K_train_HR/0121.png
#   inflating: DIV2K_train_HR/0415.png
#   inflating: DIV2K_train_HR/0536.png
#   inflating: DIV2K_train_HR/0620.png
#   inflating: DIV2K_train_HR/0331.png
#   inflating: DIV2K_train_HR/0277.png
#   inflating: DIV2K_train_HR/0611.png
#   inflating: DIV2K_train_HR/0262.png
#   inflating: DIV2K_train_HR/0305.png
#   inflating: DIV2K_train_HR/0521.png
#   inflating: DIV2K_train_HR/0221.png
#   inflating: DIV2K_train_HR/0699.png
#   inflating: DIV2K_train_HR/0743.png
#   inflating: DIV2K_train_HR/0742.png
#   inflating: DIV2K_train_HR/0111.png
#   inflating: DIV2K_train_HR/0480.png
#   inflating: DIV2K_train_HR/0720.png
#   inflating: DIV2K_train_HR/0402.png
#   inflating: DIV2K_train_HR/0561.png
#   inflating: DIV2K_train_HR/0729.png
#   inflating: DIV2K_train_HR/0296.png
#   inflating: DIV2K_train_HR/0379.png
#   inflating: DIV2K_train_HR/0014.png
#   inflating: DIV2K_train_HR/0714.png
#   inflating: DIV2K_train_HR/0754.png
#   inflating: DIV2K_train_HR/0634.png
#   inflating: DIV2K_train_HR/0725.png
#   inflating: DIV2K_train_HR/0309.png
#   inflating: DIV2K_train_HR/0197.png
#   inflating: DIV2K_train_HR/0039.png
#   inflating: DIV2K_train_HR/0696.png
#   inflating: DIV2K_train_HR/0758.png
#   inflating: DIV2K_train_HR/0599.png
#   inflating: DIV2K_train_HR/0228.png
#   inflating: DIV2K_train_HR/0712.png
#   inflating: DIV2K_train_HR/0539.png
#   inflating: DIV2K_train_HR/0781.png
#   inflating: DIV2K_train_HR/0009.png
#   inflating: DIV2K_train_HR/0145.png
#   inflating: DIV2K_train_HR/0527.png
#   inflating: DIV2K_train_HR/0263.png
#   inflating: DIV2K_train_HR/0122.png
#   inflating: DIV2K_train_HR/0506.png
#   inflating: DIV2K_train_HR/0363.png
#   inflating: DIV2K_train_HR/0249.png
#   inflating: DIV2K_train_HR/0104.png
#   inflating: DIV2K_train_HR/0800.png
#   inflating: DIV2K_train_HR/0214.png
#   inflating: DIV2K_train_HR/0658.png
#   inflating: DIV2K_train_HR/0399.png
#   inflating: DIV2K_train_HR/0572.png
#   inflating: DIV2K_train_HR/0204.png
#   inflating: DIV2K_train_HR/0651.png
#   inflating: DIV2K_train_HR/0061.png
#   inflating: DIV2K_train_HR/0026.png
#   inflating: DIV2K_train_HR/0300.png
#   inflating: DIV2K_train_HR/0162.png
#   inflating: DIV2K_train_HR/0478.png
#   inflating: DIV2K_train_HR/0022.png
#   inflating: DIV2K_train_HR/0079.png
#   inflating: DIV2K_train_HR/0285.png
#   inflating: DIV2K_train_HR/0511.png
#   inflating: DIV2K_train_HR/0025.png
#   inflating: DIV2K_train_HR/0428.png
#   inflating: DIV2K_train_HR/0436.png
#   inflating: DIV2K_train_HR/0324.png
#   inflating: DIV2K_train_HR/0447.png
#   inflating: DIV2K_train_HR/0457.png
#   inflating: DIV2K_train_HR/0424.png
#   inflating: DIV2K_train_HR/0675.png
#   inflating: DIV2K_train_HR/0469.png
#   inflating: DIV2K_train_HR/0090.png
#   inflating: DIV2K_train_HR/0179.png
#   inflating: DIV2K_train_HR/0771.png
#   inflating: DIV2K_train_HR/0431.png
#   inflating: DIV2K_train_HR/0726.png
#   inflating: DIV2K_train_HR/0609.png
#   inflating: DIV2K_train_HR/0184.png
#   inflating: DIV2K_train_HR/0747.png
#   inflating: DIV2K_train_HR/0154.png
#   inflating: DIV2K_train_HR/0391.png
#   inflating: DIV2K_train_HR/0573.png
#   inflating: DIV2K_train_HR/0071.png
#   inflating: DIV2K_train_HR/0798.png
#   inflating: DIV2K_train_HR/0693.png
#   inflating: DIV2K_train_HR/0280.png
#   inflating: DIV2K_train_HR/0414.png
#   inflating: DIV2K_train_HR/0119.png
#   inflating: DIV2K_train_HR/0757.png
#   inflating: DIV2K_train_HR/0762.png
#   inflating: DIV2K_train_HR/0734.png
#   inflating: DIV2K_train_HR/0001.png
#   inflating: DIV2K_train_HR/0265.png
#   inflating: DIV2K_train_HR/0643.png
#   inflating: DIV2K_train_HR/0567.png
#   inflating: DIV2K_train_HR/0130.png
#   inflating: DIV2K_train_HR/0580.png
#   inflating: DIV2K_train_HR/0463.png
#   inflating: DIV2K_train_HR/0218.png
#   inflating: DIV2K_train_HR/0769.png
#   inflating: DIV2K_train_HR/0507.png
#   inflating: DIV2K_train_HR/0013.png
#   inflating: DIV2K_train_HR/0233.png
#   inflating: DIV2K_train_HR/0087.png
#   inflating: DIV2K_train_HR/0093.png
#   inflating: DIV2K_train_HR/0709.png
#   inflating: DIV2K_train_HR/0027.png
#   inflating: DIV2K_train_HR/0570.png
#   inflating: DIV2K_train_HR/0342.png
#   inflating: DIV2K_train_HR/0011.png
#   inflating: DIV2K_train_HR/0287.png
#   inflating: DIV2K_train_HR/0524.png
#   inflating: DIV2K_train_HR/0791.png
#   inflating: DIV2K_train_HR/0701.png
#   inflating: DIV2K_train_HR/0783.png
#   inflating: DIV2K_train_HR/0349.png
#   inflating: DIV2K_train_HR/0766.png
#   inflating: DIV2K_train_HR/0232.png
#   inflating: DIV2K_train_HR/0314.png
#   inflating: DIV2K_train_HR/0303.png
#   inflating: DIV2K_train_HR/0697.png
#   inflating: DIV2K_train_HR/0514.png
#   inflating: DIV2K_train_HR/0377.png
#   inflating: DIV2K_train_HR/0085.png
#   inflating: DIV2K_train_HR/0113.png
#   inflating: DIV2K_train_HR/0540.png
#   inflating: DIV2K_train_HR/0383.png
#   inflating: DIV2K_train_HR/0243.png
#   inflating: DIV2K_train_HR/0086.png
#   inflating: DIV2K_train_HR/0091.png
#   inflating: DIV2K_train_HR/0151.png
#   inflating: DIV2K_train_HR/0502.png
#   inflating: DIV2K_train_HR/0294.png
#   inflating: DIV2K_train_HR/0281.png
#   inflating: DIV2K_train_HR/0656.png
#   inflating: DIV2K_train_HR/0500.png
#   inflating: DIV2K_train_HR/0237.png
#   inflating: DIV2K_train_HR/0387.png
#   inflating: DIV2K_train_HR/0178.png
#   inflating: DIV2K_train_HR/0518.png
#   inflating: DIV2K_train_HR/0239.png
#   inflating: DIV2K_train_HR/0131.png
#   inflating: DIV2K_train_HR/0655.png
#   inflating: DIV2K_train_HR/0417.png
#   inflating: DIV2K_train_HR/0776.png
#   inflating: DIV2K_train_HR/0560.png
#   inflating: DIV2K_train_HR/0737.png
#   inflating: DIV2K_train_HR/0048.png
#   inflating: DIV2K_train_HR/0128.png
#   inflating: DIV2K_train_HR/0052.png
#   inflating: DIV2K_train_HR/0137.png
#   inflating: DIV2K_train_HR/0686.png
#   inflating: DIV2K_train_HR/0053.png
#   inflating: DIV2K_train_HR/0665.png
#   inflating: DIV2K_train_HR/0691.png
#   inflating: DIV2K_train_HR/0167.png
#   inflating: DIV2K_train_HR/0313.png
#   inflating: DIV2K_train_HR/0531.png
#   inflating: DIV2K_train_HR/0569.png
#   inflating: DIV2K_train_HR/0553.png
#   inflating: DIV2K_train_HR/0047.png
#   inflating: DIV2K_train_HR/0096.png
#   inflating: DIV2K_train_HR/0756.png
#   inflating: DIV2K_train_HR/0440.png
#   inflating: DIV2K_train_HR/0199.png
#   inflating: DIV2K_train_HR/0283.png
#   inflating: DIV2K_train_HR/0247.png
#   inflating: DIV2K_train_HR/0024.png
#   inflating: DIV2K_train_HR/0193.png
#   inflating: DIV2K_train_HR/0084.png
#   inflating: DIV2K_train_HR/0102.png
#   inflating: DIV2K_train_HR/0551.png
#   inflating: DIV2K_train_HR/0575.png
#   inflating: DIV2K_train_HR/0477.png
#   inflating: DIV2K_train_HR/0098.png
#   inflating: DIV2K_train_HR/0554.png
#   inflating: DIV2K_train_HR/0189.png
#   inflating: DIV2K_train_HR/0717.png
#   inflating: DIV2K_train_HR/0732.png
#   inflating: DIV2K_train_HR/0702.png
#   inflating: DIV2K_train_HR/0183.png
#   inflating: DIV2K_train_HR/0448.png
#   inflating: DIV2K_train_HR/0455.png
#   inflating: DIV2K_train_HR/0367.png
#   inflating: DIV2K_train_HR/0251.png
#   inflating: DIV2K_train_HR/0744.png
#   inflating: DIV2K_train_HR/0785.png
#   inflating: DIV2K_train_HR/0067.png
#   inflating: DIV2K_train_HR/0163.png
#   inflating: DIV2K_train_HR/0751.png
#   inflating: DIV2K_train_HR/0299.png
#   inflating: DIV2K_train_HR/0129.png
#   inflating: DIV2K_train_HR/0291.png
#   inflating: DIV2K_train_HR/0607.png
#   inflating: DIV2K_train_HR/0242.png
#   inflating: DIV2K_train_HR/0107.png
#   inflating: DIV2K_train_HR/0175.png
#   inflating: DIV2K_train_HR/0753.png
#   inflating: DIV2K_train_HR/0278.png
#   inflating: DIV2K_train_HR/0369.png
#   inflating: DIV2K_train_HR/0571.png
#   inflating: DIV2K_train_HR/0202.png
#   inflating: DIV2K_train_HR/0030.png
#   inflating: DIV2K_train_HR/0799.png
#   inflating: DIV2K_train_HR/0474.png
#   inflating: DIV2K_train_HR/0491.png
#   inflating: DIV2K_train_HR/0638.png
#   inflating: DIV2K_train_HR/0600.png
#   inflating: DIV2K_train_HR/0596.png
#   inflating: DIV2K_train_HR/0059.png
#   inflating: DIV2K_train_HR/0186.png
#   inflating: DIV2K_train_HR/0509.png
#   inflating: DIV2K_train_HR/0529.png
#   inflating: DIV2K_train_HR/0787.png
#   inflating: DIV2K_train_HR/0382.png
#   inflating: DIV2K_train_HR/0777.png
#   inflating: DIV2K_train_HR/0109.png
#   inflating: DIV2K_train_HR/0227.png
#   inflating: DIV2K_train_HR/0388.png
#   inflating: DIV2K_train_HR/0618.png
#   inflating: DIV2K_train_HR/0681.png
#   inflating: DIV2K_train_HR/0205.png
#   inflating: DIV2K_train_HR/0472.png
#   inflating: DIV2K_train_HR/0306.png
#   inflating: DIV2K_train_HR/0361.png
#   inflating: DIV2K_train_HR/0738.png
#   inflating: DIV2K_train_HR/0230.png
#   inflating: DIV2K_train_HR/0081.png
#   inflating: DIV2K_train_HR/0095.png
#   inflating: DIV2K_train_HR/0449.png
#   inflating: DIV2K_train_HR/0626.png
#   inflating: DIV2K_train_HR/0065.png
#   inflating: DIV2K_train_HR/0443.png
#   inflating: DIV2K_train_HR/0275.png
#   inflating: DIV2K_train_HR/0542.png
#   inflating: DIV2K_train_HR/0484.png
#   inflating: DIV2K_train_HR/0359.png
#   inflating: DIV2K_train_HR/0773.png
#   inflating: DIV2K_train_HR/0434.png
#   inflating: DIV2K_train_HR/0544.png
#   inflating: DIV2K_train_HR/0416.png
#   inflating: DIV2K_train_HR/0295.png
#   inflating: DIV2K_train_HR/0538.png
#   inflating: DIV2K_train_HR/0259.png
#   inflating: DIV2K_train_HR/0348.png
#   inflating: DIV2K_train_HR/0588.png
#   inflating: DIV2K_train_HR/0710.png
#   inflating: DIV2K_train_HR/0786.png
#   inflating: DIV2K_train_HR/0185.png
#   inflating: DIV2K_train_HR/0057.png
#   inflating: DIV2K_train_HR/0487.png
#   inflating: DIV2K_train_HR/0683.png

# %%
#@markdown # *0) ** Instalando libreria(OBLIGATORIO)

# !pip install torch torchvision torchaudio

# %%
#@markdown # *1) ** Clase Para manejo de directorios de datasets de imagenes


import os
import cv2
import pandas as pd
from PIL import Image
import torch
from torchvision import transforms
# Recorre el directorio  y elmiina los archvios que no tiene las extensioens permitidas

class DataSetManage:




 def comprobar_ext_directorios(self,directorio):

  for clase,[directorio,etiquetas] in(directorio.items()):
   lista_directorio=os.listdir(directorio)
   self._validarExt(directorio)



 def  _validarExt(self,directorio):
  print(directorio)
   # Extensiones permitidas
  extensiones_permitidas = {".jpg", ".jpeg", ".png"}
  for root, dirs, files in os.walk(directorio):

    for file in files:
        # Obtiene la extensión del archivo
        _, extension = os.path.splitext(file)

        # Verifica si la extensión no está en la lista de extensiones permitidas y elimina el archivo
        if extension.lower() not in extensiones_permitidas:
            archivo_a_eliminar = os.path.join(root, file)
            os.remove(archivo_a_eliminar)
            print(f"Se eliminó: {archivo_a_eliminar}")


# Cambia nombre de cada archivo dentro del directorio a un valor secuencial

 def cambiar_nombres_directorios(self,directorio):
   for clase,[directorio,etiquetas] in(directorio.items()):
     lista_directorio=os.listdir(directorio)
     self._cambiarNombre(directorio,clase)
     print(directorio)


 def _cambiarNombre(self,directorios,subfijo):
  archivos_en_directorio = os.listdir(directorios)
  for i, archivo in enumerate(archivos_en_directorio, start=1):
    # Construir el nuevo nombre del archivo
    nuevo_nombre = f"{subfijo}{i}{os.path.splitext(archivo)[1]}"

    # Ruta completa del archivo antiguo y nuevo
    ruta_antigua = os.path.join(directorios, archivo)
    ruta_nueva = os.path.join(directorios, nuevo_nombre)

    # Cambiar el nombre del archivo
    os.rename(ruta_antigua, ruta_nueva)
    print(f"Se cambió el nombre de {ruta_antigua} a {ruta_nueva}")


#Obtiene la cantidad de elemntos que tiene la carpeta

 def len_directorio(self,directorio):
    cantidad_elementos = sum(1 for elemento in os.listdir(directorio) if os.path.isfile(os.path.join(directorio, elemento)))
    return cantidad_elementos


#----------------------------------------------------------------------------------------------

#Valida si la imagen se puede leer usando  pill o cv2 si no se puede leer se elimina

 def validar_Img_Pill(self,directorio,):
  for etiqueta,[directorio,clase] in(directorio.items()):

    lista_paths=os.listdir(directorio)
    self._validarLecturaImgPill(directorio,lista_paths)
  print(f"Se ah validado todas las imagenes")

 def validar_Img_cv2(self,directorio):
  for etiqueta,[directorio,clase] in(directorio.items()):

    lista_paths=os.listdir(directorio)
    self._validarLecturaImg(directorio,lista_paths)
  print(f"Se ah validado todas las imagenes")

 def _validarLecturaImg(self,directorio,lista):

  for ruta in(lista):
   imagen=cv2.imread(directorio+ruta)
   if  imagen is None:
     os.remove(directorio+ruta)
     print(f"No se pudo leer y se elimino archivo:{directorio+ruta}")

 def _validarLecturaImgPill(self,directorio,lista):
    for ruta in(lista):
     try:
      imagen=Image.open(directorio+ruta)
     except Exception as e:
      os.remove(directorio+ruta)
      print(f"Archivo '{directorio+ruta}' eliminado.")



#vamos a recorrer el dicionario y validar ruta por ruta si se puede leer sino se elminara
#vamos guaradno al mismo tiempo 3 listas, los directorios , listas de paths de los directiros y de las clases ,para usarlo luego usarlo al crear el csv

 def separar_datos_directorios(self,directorios):
  listas_directorios=[]
  listas_listas_directorios=[]
  listas_clases=[]

  for etiqueta,[directorio,clase] in(directorios.items()):

       lista_paths=os.listdir(directorio)
       listas_directorios.append(directorio)
       listas_listas_directorios.append(lista_paths)
       listas_clases.append(clase)

  return listas_directorios,listas_listas_directorios,listas_clases

 def emparejar_listas_paths(self,lista_listas):

   #Tomamos el minimo tamaño dentro de las lista de cada clase
   tamaño_minimo = min(len(arr) for arr in lista_listas)

   #Vamos a emparejar todas las listas con un tamaño igual que sea la del minimo tamaño de todas,esto para tener un set de datos parejo por cada clase
   Reducido_lista_paths=[]

   #Reduce cada lista de los paths a la cantidad minimo para que todos tenga iaugal cantidad
   for listas in(lista_listas):
    Reducido_lista_paths.append(listas[:tamaño_minimo])

   return Reducido_lista_paths
#---------------------------------------------------------------------------------


 def crear_paths_csv(self,directorio_base,lista_paths,clases,nombre_archivo):

   columnas=["path","etiqueta"]
   datos_csv=[]

   for dir_base,dir_path,clase in  zip(directorio_base,lista_paths,clases):

    for path  in (dir_path):

     datos_csv.append([dir_base+path ,clase])


   df_lista=pd.DataFrame(datos_csv,columns=columnas)
   df_lista.to_csv(nombre_archivo,index=False)
   print("Csv Creado")
#---------------------------------------------------------------------------------

#devuelve cuatnos elemtnos tiene cada clase
 def total_elementos(self,directorio,csv_path):
    df=pd.read_csv(csv_path)
    for clase,[directorio,etiqueta] in (directorio.items()):
     tamaño_etiqueta=(df["etiqueta"] == etiqueta).sum()
     print(f"la clase {clase} tiene :{tamaño_etiqueta} elementos")


#-------------------------------------------------------------------------------------------------

  #Funciones para data aumentation
 def   data_aumentation_conjunto(self,input_imagen_folder,output_path_folder,iteraciones,transformaciones):  #ingresa trnasformacioens como compose donde se aplicara las trasnfomracioens conjutnos pero se repteira un numero de veces por cada imagen

   for filename in os.listdir(input_imagen_folder):

    if filename.endswith('.jpg') or filename.endswith('.png'):

        input_path = os.path.join(input_imagen_folder, filename)
        output_path = os.path.join(output_path_folder, f'transformed_{filename}')
        # Aplica las transformaciones
        print(output_path)
        self._apply_transfomaciones_conjunto_it(input_path,output_path,int(iteraciones),transformaciones)


 def   data_aumentation_individual(self,input_imagen_folder,output_path_folder,transformaciones):  #las trnasfomaciones solo pasaremos la lista ya que ira aplicando la transformacion una por una por cada imagen

  for filename in os.listdir(input_imagen_folder):

    if filename.endswith('.jpg') or filename.endswith('.png'):
        input_path = os.path.join(input_imagen_folder, filename)
        output_path = os.path.join(output_path_folder, f'transformed_{filename}')

        # Aplica las transformaciones
        self._apply_transfomaciones_conjunto(input_path,output_path,transformaciones)



 def _apply_transfomaciones_conjunto_it(self,input_imagen_path,output_iamgen_path,iteraciones,transformations=None,): #aplica las transfomracioens  conjutas por iteracion y se guarda las iamgenes

   imagen=Image.open(input_imagen_path)


   for i in range(iteraciones):
      imagen_trasformada=transformations(imagen)

      out_root, out_extension = os.path.splitext(output_iamgen_path)
      imagen_trasformada.save(f"{out_root}_{i}{out_extension}")


 def _apply_transfomaciones_conjunto(self,input_imagen_path,output_iamgen_path,transformations=None): #aplica las transfomracioens individuales  y se guarda las iamgenes

  imagen=Image.open(input_imagen_path)

  for i,transformacion in enumerate(transformations):
   imagen_transformada=transformacion(imagen)
   out_root, out_extension = os.path.splitext(output_iamgen_path)
   imagen_transformada.save(f"{out_root}_{i}{out_extension}")

# %%
#Creamos los arhcivo baja resolucion aparitr de imangenes alta resoulcion en hr , estos archios iran a carpaeta lw
directorio_in="/content/DIV2K_train_HR"
directorio_out_lw="/content/lw/"
directorio_out_hr="/content/hr/"

#antes de otrogar mediads de hr y lw , chekea como el generador va votando las resolucioens hr_fake segun la resolucion lw que especifics tiene qeu conicidr
#ya que el discriminador necsita la misma medidades tanto para el hr y el hr_fake que genera el generador

transformaciones_hr=transforms.Compose([
transforms.Resize((216,216)),
])

transformaciones_lw=transforms.Compose([
transforms.Resize((60,60)),
])


datasetmanage=DataSetManage()
datasetmanage.data_aumentation_conjunto(directorio_in,directorio_out_lw,1,transformaciones_lw)
datasetmanage.data_aumentation_conjunto(directorio_in,directorio_out_hr,1,transformaciones_hr)
# Out:
# /content/lw/transformed_0661.png
# /content/lw/transformed_0412.png
# /content/lw/transformed_0119.png
# /content/lw/transformed_0740.png
# /content/lw/transformed_0538.png
# /content/lw/transformed_0651.png
# /content/lw/transformed_0489.png
# /content/lw/transformed_0734.png
# /content/lw/transformed_0275.png
# /content/lw/transformed_0298.png
# /content/lw/transformed_0122.png
# /content/lw/transformed_0589.png
# /content/lw/transformed_0437.png
# /content/lw/transformed_0020.png
# /content/lw/transformed_0761.png
# /content/lw/transformed_0214.png
# /content/lw/transformed_0383.png
# /content/lw/transformed_0598.png
# /content/lw/transformed_0400.png
# /content/lw/transformed_0386.png
# /content/lw/transformed_0196.png
# /content/lw/transformed_0299.png
# /content/lw/transformed_0392.png
# /content/lw/transformed_0697.png
# /content/lw/transformed_0374.png
# /content/lw/transformed_0560.png
# /content/lw/transformed_0059.png
# /content/lw/transformed_0266.png
# /content/lw/transformed_0760.png
# /content/lw/transformed_0686.png
# /content/lw/transformed_0447.png
# /content/lw/transformed_0722.png
# /content/lw/transformed_0249.png
# /content/lw/transformed_0566.png
# /content/lw/transformed_0260.png
# /content/lw/transformed_0229.png
# /content/lw/transformed_0346.png
# /content/lw/transformed_0093.png
# /content/lw/transformed_0036.png
# /content/lw/transformed_0494.png
# /content/lw/transformed_0440.png
# /content/lw/transformed_0219.png
# /content/lw/transformed_0064.png
# /content/lw/transformed_0526.png
# /content/lw/transformed_0203.png
# /content/lw/transformed_0604.png
# /content/lw/transformed_0426.png
# /content/lw/transformed_0292.png
# /content/lw/transformed_0623.png
# /content/lw/transformed_0111.png
# /content/lw/transformed_0323.png
# /content/lw/transformed_0702.png
# /content/lw/transformed_0040.png
# /content/lw/transformed_0062.png
# /content/lw/transformed_0283.png
# /content/lw/transformed_0106.png
# /content/lw/transformed_0096.png
# /content/lw/transformed_0684.png
# /content/lw/transformed_0330.png
# /content/lw/transformed_0197.png
# /content/lw/transformed_0179.png
# /content/lw/transformed_0278.png
# /content/lw/transformed_0377.png
# /content/lw/transformed_0058.png
# /content/lw/transformed_0621.png
# /content/lw/transformed_0116.png
# /content/lw/transformed_0342.png
# /content/lw/transformed_0646.png
# /content/lw/transformed_0300.png
# /content/lw/transformed_0512.png
# /content/lw/transformed_0099.png
# /content/lw/transformed_0038.png
# /content/lw/transformed_0484.png
# /content/lw/transformed_0480.png
# /content/lw/transformed_0200.png
# /content/lw/transformed_0037.png
# /content/lw/transformed_0596.png
# /content/lw/transformed_0507.png
# /content/lw/transformed_0573.png
# /content/lw/transformed_0302.png
# /content/lw/transformed_0312.png
# /content/lw/transformed_0376.png
# /content/lw/transformed_0656.png
# /content/lw/transformed_0347.png
# /content/lw/transformed_0105.png
# /content/lw/transformed_0259.png
# /content/lw/transformed_0359.png
# /content/lw/transformed_0608.png
# /content/lw/transformed_0365.png
# /content/lw/transformed_0654.png
# /content/lw/transformed_0042.png
# /content/lw/transformed_0728.png
# /content/lw/transformed_0733.png
# /content/lw/transformed_0367.png
# /content/lw/transformed_0044.png
# /content/lw/transformed_0559.png
# /content/lw/transformed_0474.png
# /content/lw/transformed_0189.png
# /content/lw/transformed_0372.png
# /content/lw/transformed_0749.png
# /content/lw/transformed_0531.png
# /content/lw/transformed_0241.png
# /content/lw/transformed_0286.png
# /content/lw/transformed_0446.png
# /content/lw/transformed_0644.png
# /content/lw/transformed_0790.png
# /content/lw/transformed_0581.png
# /content/lw/transformed_0530.png
# /content/lw/transformed_0503.png
# /content/lw/transformed_0421.png
# /content/lw/transformed_0565.png
# /content/lw/transformed_0393.png
# /content/lw/transformed_0567.png
# /content/lw/transformed_0787.png
# /content/lw/transformed_0542.png
# /content/lw/transformed_0731.png
# /content/lw/transformed_0409.png
# /content/lw/transformed_0757.png
# /content/lw/transformed_0416.png
# /content/lw/transformed_0334.png
# /content/lw/transformed_0013.png
# /content/lw/transformed_0235.png
# /content/lw/transformed_0584.png
# /content/lw/transformed_0716.png
# /content/lw/transformed_0263.png
# /content/lw/transformed_0777.png
# /content/lw/transformed_0054.png
# /content/lw/transformed_0508.png
# /content/lw/transformed_0071.png
# /content/lw/transformed_0738.png
# /content/lw/transformed_0764.png
# /content/lw/transformed_0319.png
# /content/lw/transformed_0250.png
# /content/lw/transformed_0167.png
# /content/lw/transformed_0158.png
# /content/lw/transformed_0659.png
# /content/lw/transformed_0001.png
# /content/lw/transformed_0540.png
# /content/lw/transformed_0637.png
# /content/lw/transformed_0149.png
# /content/lw/transformed_0382.png
# /content/lw/transformed_0743.png
# /content/lw/transformed_0423.png
# /content/lw/transformed_0320.png
# /content/lw/transformed_0394.png
# /content/lw/transformed_0086.png
# /content/lw/transformed_0121.png
# /content/lw/transformed_0438.png
# /content/lw/transformed_0124.png
# /content/lw/transformed_0046.png
# /content/lw/transformed_0703.png
# /content/lw/transformed_0193.png
# /content/lw/transformed_0308.png
# /content/lw/transformed_0264.png
# /content/lw/transformed_0500.png
# /content/lw/transformed_0142.png
# /content/lw/transformed_0354.png
# /content/lw/transformed_0052.png
# /content/lw/transformed_0653.png
# /content/lw/transformed_0638.png
# /content/lw/transformed_0714.png
# /content/lw/transformed_0456.png
# /content/lw/transformed_0242.png
# /content/lw/transformed_0690.png
# /content/lw/transformed_0136.png
# /content/lw/transformed_0458.png
# /content/lw/transformed_0220.png
# /content/lw/transformed_0297.png
# /content/lw/transformed_0397.png
# /content/lw/transformed_0685.png
# /content/lw/transformed_0171.png
# /content/lw/transformed_0455.png
# /content/lw/transformed_0504.png
# /content/lw/transformed_0290.png
# /content/lw/transformed_0138.png
# /content/lw/transformed_0025.png
# /content/lw/transformed_0274.png
# /content/lw/transformed_0256.png
# /content/lw/transformed_0120.png
# /content/lw/transformed_0190.png
# /content/lw/transformed_0194.png
# /content/lw/transformed_0663.png
# /content/lw/transformed_0195.png
# /content/lw/transformed_0771.png
# /content/lw/transformed_0576.png
# /content/lw/transformed_0030.png
# /content/lw/transformed_0407.png
# /content/lw/transformed_0066.png
# /content/lw/transformed_0439.png
# /content/lw/transformed_0422.png
# /content/lw/transformed_0371.png
# /content/lw/transformed_0405.png
# /content/lw/transformed_0073.png
# /content/lw/transformed_0271.png
# /content/lw/transformed_0079.png
# /content/lw/transformed_0170.png
# /content/lw/transformed_0452.png
# /content/lw/transformed_0113.png
# /content/lw/transformed_0629.png
# /content/lw/transformed_0705.png
# /content/lw/transformed_0600.png
# /content/lw/transformed_0467.png
# /content/lw/transformed_0406.png
# /content/lw/transformed_0198.png
# /content/lw/transformed_0692.png
# /content/lw/transformed_0524.png
# /content/lw/transformed_0449.png
# /content/lw/transformed_0349.png
# /content/lw/transformed_0461.png
# /content/lw/transformed_0450.png
# /content/lw/transformed_0244.png
# /content/lw/transformed_0724.png
# /content/lw/transformed_0129.png
# /content/lw/transformed_0534.png
# /content/lw/transformed_0162.png
# /content/lw/transformed_0026.png
# /content/lw/transformed_0336.png
# /content/lw/transformed_0226.png
# /content/lw/transformed_0350.png
# /content/lw/transformed_0578.png
# /content/lw/transformed_0097.png
# /content/lw/transformed_0381.png
# /content/lw/transformed_0739.png
# /content/lw/transformed_0301.png
# /content/lw/transformed_0378.png
# /content/lw/transformed_0785.png
# /content/lw/transformed_0799.png
# /content/lw/transformed_0707.png
# /content/lw/transformed_0753.png
# /content/lw/transformed_0485.png
# /content/lw/transformed_0649.png
# /content/lw/transformed_0257.png
# /content/lw/transformed_0166.png
# /content/lw/transformed_0012.png
# /content/lw/transformed_0175.png
# /content/lw/transformed_0270.png
# /content/lw/transformed_0303.png
# /content/lw/transformed_0582.png
# /content/lw/transformed_0313.png
# /content/lw/transformed_0146.png
# /content/lw/transformed_0496.png
# /content/lw/transformed_0732.png
# /content/lw/transformed_0564.png
# /content/lw/transformed_0181.png
# /content/lw/transformed_0725.png
# /content/lw/transformed_0137.png
# /content/lw/transformed_0607.png
# /content/lw/transformed_0341.png
# /content/lw/transformed_0543.png
# /content/lw/transformed_0131.png
# /content/lw/transformed_0095.png
# /content/lw/transformed_0635.png
# /content/lw/transformed_0068.png
# /content/lw/transformed_0276.png
# /content/lw/transformed_0495.png
# /content/lw/transformed_0670.png
# /content/lw/transformed_0344.png
# /content/lw/transformed_0082.png
# /content/lw/transformed_0601.png
# /content/lw/transformed_0483.png
# /content/lw/transformed_0184.png
# /content/lw/transformed_0636.png
# /content/lw/transformed_0080.png
# /content/lw/transformed_0609.png
# /content/lw/transformed_0172.png
# /content/lw/transformed_0763.png
# /content/lw/transformed_0612.png
# /content/lw/transformed_0708.png
# /content/lw/transformed_0585.png
# /content/lw/transformed_0210.png
# /content/lw/transformed_0432.png
# /content/lw/transformed_0280.png
# /content/lw/transformed_0436.png
# /content/lw/transformed_0689.png
# /content/lw/transformed_0135.png
# /content/lw/transformed_0388.png
# /content/lw/transformed_0048.png
# /content/lw/transformed_0579.png
# /content/lw/transformed_0599.png
# /content/lw/transformed_0768.png
# /content/lw/transformed_0509.png
# /content/lw/transformed_0352.png
# /content/lw/transformed_0366.png
# /content/lw/transformed_0173.png
# /content/lw/transformed_0152.png
# /content/lw/transformed_0533.png
# /content/lw/transformed_0390.png
# /content/lw/transformed_0694.png
# /content/lw/transformed_0529.png
# /content/lw/transformed_0110.png
# /content/lw/transformed_0652.png
# /content/lw/transformed_0165.png
# /content/lw/transformed_0017.png
# /content/lw/transformed_0441.png
# /content/lw/transformed_0444.png
# /content/lw/transformed_0544.png
# /content/lw/transformed_0502.png
# /content/lw/transformed_0340.png
# /content/lw/transformed_0351.png
# /content/lw/transformed_0681.png
# /content/lw/transformed_0577.png
# /content/lw/transformed_0032.png
# /content/lw/transformed_0693.png
# /content/lw/transformed_0481.png
# /content/lw/transformed_0328.png
# /content/lw/transformed_0523.png
# /content/lw/transformed_0295.png
# /content/lw/transformed_0217.png
# /content/lw/transformed_0238.png
# /content/lw/transformed_0002.png
# /content/lw/transformed_0568.png
# /content/lw/transformed_0798.png
# /content/lw/transformed_0701.png
# /content/lw/transformed_0678.png
# /content/lw/transformed_0227.png
# /content/lw/transformed_0729.png
# /content/lw/transformed_0786.png
# /content/lw/transformed_0185.png
# /content/lw/transformed_0306.png
# /content/lw/transformed_0279.png
# /content/lw/transformed_0223.png
# /content/lw/transformed_0711.png
# /content/lw/transformed_0669.png
# /content/lw/transformed_0325.png
# /content/lw/transformed_0310.png
# /content/lw/transformed_0060.png
# /content/lw/transformed_0683.png
# /content/lw/transformed_0548.png
# /content/lw/transformed_0191.png
# /content/lw/transformed_0765.png
# /content/lw/transformed_0519.png
# /content/lw/transformed_0587.png
# /content/lw/transformed_0034.png
# /content/lw/transformed_0333.png
# /content/lw/transformed_0329.png
# /content/lw/transformed_0688.png
# /content/lw/transformed_0053.png
# /content/lw/transformed_0443.png
# /content/lw/transformed_0176.png
# /content/lw/transformed_0776.png
# /content/lw/transformed_0029.png
# /content/lw/transformed_0157.png
# /content/lw/transformed_0140.png
# /content/lw/transformed_0385.png
# /content/lw/transformed_0339.png
# /content/lw/transformed_0468.png
# /content/lw/transformed_0766.png
# /content/lw/transformed_0331.png
# /content/lw/transformed_0031.png
# /content/lw/transformed_0327.png
# /content/lw/transformed_0466.png
# /content/lw/transformed_0041.png
# /content/lw/transformed_0597.png
# /content/lw/transformed_0691.png
# /content/lw/transformed_0417.png
# /content/lw/transformed_0248.png
# /content/lw/transformed_0518.png
# /content/lw/transformed_0522.png
# /content/lw/transformed_0355.png
# /content/lw/transformed_0547.png
# /content/lw/transformed_0267.png
# /content/lw/transformed_0216.png
# /content/lw/transformed_0212.png
# /content/lw/transformed_0442.png
# /content/lw/transformed_0035.png
# /content/lw/transformed_0616.png
# /content/lw/transformed_0645.png
# /content/lw/transformed_0552.png
# /content/lw/transformed_0492.png
# /content/lw/transformed_0513.png
# /content/lw/transformed_0199.png
# /content/lw/transformed_0482.png
# /content/lw/transformed_0265.png
# /content/lw/transformed_0183.png
# /content/lw/transformed_0373.png
# /content/lw/transformed_0399.png
# /content/lw/transformed_0076.png
# /content/lw/transformed_0783.png
# /content/lw/transformed_0464.png
# /content/lw/transformed_0090.png
# /content/lw/transformed_0730.png
# /content/lw/transformed_0427.png
# /content/lw/transformed_0130.png
# /content/lw/transformed_0408.png
# /content/lw/transformed_0748.png
# /content/lw/transformed_0141.png
# /content/lw/transformed_0532.png
# /content/lw/transformed_0050.png
# /content/lw/transformed_0254.png
# /content/lw/transformed_0396.png
# /content/lw/transformed_0401.png
# /content/lw/transformed_0159.png
# /content/lw/transformed_0192.png
# /content/lw/transformed_0402.png
# /content/lw/transformed_0593.png
# /content/lw/transformed_0268.png
# /content/lw/transformed_0209.png
# /content/lw/transformed_0003.png
# /content/lw/transformed_0774.png
# /content/lw/transformed_0795.png
# /content/lw/transformed_0433.png
# /content/lw/transformed_0348.png
# /content/lw/transformed_0258.png
# /content/lw/transformed_0285.png
# /content/lw/transformed_0756.png
# /content/lw/transformed_0676.png
# /content/lw/transformed_0706.png
# /content/lw/transformed_0362.png
# /content/lw/transformed_0117.png
# /content/lw/transformed_0520.png
# /content/lw/transformed_0506.png
# /content/lw/transformed_0118.png
# /content/lw/transformed_0511.png
# /content/lw/transformed_0527.png
# /content/lw/transformed_0673.png
# /content/lw/transformed_0477.png
# /content/lw/transformed_0168.png
# /content/lw/transformed_0631.png
# /content/lw/transformed_0134.png
# /content/lw/transformed_0514.png
# /content/lw/transformed_0043.png
# /content/lw/transformed_0572.png
# /content/lw/transformed_0010.png
# /content/lw/transformed_0231.png
# /content/lw/transformed_0245.png
# /content/lw/transformed_0699.png
# /content/lw/transformed_0018.png
# /content/lw/transformed_0201.png
# /content/lw/transformed_0435.png
# /content/lw/transformed_0364.png
# /content/lw/transformed_0115.png
# /content/lw/transformed_0712.png
# /content/lw/transformed_0709.png
# /content/lw/transformed_0370.png
# /content/lw/transformed_0750.png
# /content/lw/transformed_0475.png
# /content/lw/transformed_0796.png
# /content/lw/transformed_0677.png
# /content/lw/transformed_0553.png
# /content/lw/transformed_0788.png
# /content/lw/transformed_0139.png
# /content/lw/transformed_0057.png
# /content/lw/transformed_0664.png
# /content/lw/transformed_0800.png
# /content/lw/transformed_0627.png
# /content/lw/transformed_0737.png
# /content/lw/transformed_0428.png
# /content/lw/transformed_0462.png
# /content/lw/transformed_0180.png
# /content/lw/transformed_0065.png
# /content/lw/transformed_0695.png
# /content/lw/transformed_0225.png
# /content/lw/transformed_0178.png
# /content/lw/transformed_0132.png
# /content/lw/transformed_0586.png
# /content/lw/transformed_0571.png
# /content/lw/transformed_0498.png
# /content/lw/transformed_0398.png
# /content/lw/transformed_0261.png
# /content/lw/transformed_0516.png
# /content/lw/transformed_0445.png
# /content/lw/transformed_0791.png
# /content/lw/transformed_0528.png
# /content/lw/transformed_0782.png
# /content/lw/transformed_0023.png
# /content/lw/transformed_0657.png
# /content/lw/transformed_0318.png
# /content/lw/transformed_0413.png
# /content/lw/transformed_0622.png
# /content/lw/transformed_0643.png
# /content/lw/transformed_0156.png
# /content/lw/transformed_0793.png
# /content/lw/transformed_0675.png
# /content/lw/transformed_0431.png
# /content/lw/transformed_0092.png
# /content/lw/transformed_0687.png
# /content/lw/transformed_0639.png
# /content/lw/transformed_0727.png
# /content/lw/transformed_0145.png
# /content/lw/transformed_0252.png
# /content/lw/transformed_0655.png
# /content/lw/transformed_0337.png
# /content/lw/transformed_0109.png
# /content/lw/transformed_0304.png
# /content/lw/transformed_0497.png
# /content/lw/transformed_0754.png
# /content/lw/transformed_0700.png
# /content/lw/transformed_0499.png
# /content/lw/transformed_0602.png
# /content/lw/transformed_0391.png
# /content/lw/transformed_0590.png
# /content/lw/transformed_0233.png
# /content/lw/transformed_0569.png
# /content/lw/transformed_0617.png
# /content/lw/transformed_0575.png
# /content/lw/transformed_0187.png
# /content/lw/transformed_0471.png
# /content/lw/transformed_0128.png
# /content/lw/transformed_0781.png
# /content/lw/transformed_0089.png
# /content/lw/transformed_0284.png
# /content/lw/transformed_0488.png
# /content/lw/transformed_0717.png
# /content/lw/transformed_0634.png
# /content/lw/transformed_0647.png
# /content/lw/transformed_0668.png
# /content/lw/transformed_0723.png
# /content/lw/transformed_0368.png
# /content/lw/transformed_0403.png
# /content/lw/transformed_0067.png
# /content/lw/transformed_0169.png
# /content/lw/transformed_0772.png
# /content/lw/transformed_0752.png
# /content/lw/transformed_0562.png
# /content/lw/transformed_0620.png
# /content/lw/transformed_0228.png
# /content/lw/transformed_0541.png
# /content/lw/transformed_0465.png
# /content/lw/transformed_0287.png
# /content/lw/transformed_0742.png
# /content/lw/transformed_0624.png
# /content/lw/transformed_0735.png
# /content/lw/transformed_0127.png
# /content/lw/transformed_0672.png
# /content/lw/transformed_0460.png
# /content/lw/transformed_0570.png
# /content/lw/transformed_0015.png
# /content/lw/transformed_0335.png
# /content/lw/transformed_0539.png
# /content/lw/transformed_0779.png
# /content/lw/transformed_0221.png
# /content/lw/transformed_0282.png
# /content/lw/transformed_0087.png
# /content/lw/transformed_0454.png
# /content/lw/transformed_0008.png
# /content/lw/transformed_0272.png
# /content/lw/transformed_0155.png
# /content/lw/transformed_0517.png
# /content/lw/transformed_0164.png
# /content/lw/transformed_0490.png
# /content/lw/transformed_0642.png
# /content/lw/transformed_0088.png
# /content/lw/transformed_0478.png
# /content/lw/transformed_0463.png
# /content/lw/transformed_0505.png
# /content/lw/transformed_0202.png
# /content/lw/transformed_0719.png
# /content/lw/transformed_0338.png
# /content/lw/transformed_0698.png
# /content/lw/transformed_0133.png
# /content/lw/transformed_0789.png
# /content/lw/transformed_0049.png
# /content/lw/transformed_0580.png
# /content/lw/transformed_0353.png
# /content/lw/transformed_0021.png
# /content/lw/transformed_0551.png
# /content/lw/transformed_0453.png
# /content/lw/transformed_0075.png
# /content/lw/transformed_0150.png
# /content/lw/transformed_0557.png
# /content/lw/transformed_0603.png
# /content/lw/transformed_0369.png
# /content/lw/transformed_0360.png
# /content/lw/transformed_0537.png
# /content/lw/transformed_0291.png
# /content/lw/transformed_0418.png
# /content/lw/transformed_0102.png
# /content/lw/transformed_0535.png
# /content/lw/transformed_0648.png
# /content/lw/transformed_0595.png
# /content/lw/transformed_0100.png
# /content/lw/transformed_0161.png
# /content/lw/transformed_0332.png
# /content/lw/transformed_0493.png
# /content/lw/transformed_0224.png
# /content/lw/transformed_0558.png
# /content/lw/transformed_0315.png
# /content/lw/transformed_0696.png
# /content/lw/transformed_0154.png
# /content/lw/transformed_0083.png
# /content/lw/transformed_0615.png
# /content/lw/transformed_0055.png
# /content/lw/transformed_0628.png
# /content/lw/transformed_0770.png
# /content/lw/transformed_0033.png
# /content/lw/transformed_0415.png
# /content/lw/transformed_0759.png
# /content/lw/transformed_0356.png
# /content/lw/transformed_0746.png
# /content/lw/transformed_0108.png
# /content/lw/transformed_0317.png
# /content/lw/transformed_0213.png
# /content/lw/transformed_0472.png
# /content/lw/transformed_0780.png
# /content/lw/transformed_0011.png
# /content/lw/transformed_0027.png
# /content/lw/transformed_0794.png
# /content/lw/transformed_0611.png
# /content/lw/transformed_0243.png
# /content/lw/transformed_0114.png
# /content/lw/transformed_0641.png
# /content/lw/transformed_0112.png
# /content/lw/transformed_0098.png
# /content/lw/transformed_0767.png
# /content/lw/transformed_0236.png
# /content/lw/transformed_0143.png
# /content/lw/transformed_0510.png
# /content/lw/transformed_0163.png
# /content/lw/transformed_0469.png
# /content/lw/transformed_0293.png
# /content/lw/transformed_0081.png
# /content/lw/transformed_0208.png
# /content/lw/transformed_0671.png
# /content/lw/transformed_0736.png
# /content/lw/transformed_0022.png
# /content/lw/transformed_0554.png
# /content/lw/transformed_0125.png
# /content/lw/transformed_0182.png
# /content/lw/transformed_0094.png
# /content/lw/transformed_0063.png
# /content/lw/transformed_0045.png
# /content/lw/transformed_0741.png
# /content/lw/transformed_0188.png
# /content/lw/transformed_0232.png
# /content/lw/transformed_0479.png
# /content/lw/transformed_0429.png
# /content/lw/transformed_0726.png
# /content/lw/transformed_0215.png
# /content/lw/transformed_0591.png
# /content/lw/transformed_0207.png
# /content/lw/transformed_0047.png
# /content/lw/transformed_0665.png
# /content/lw/transformed_0556.png
# /content/lw/transformed_0594.png
# /content/lw/transformed_0521.png
# /content/lw/transformed_0574.png
# /content/lw/transformed_0324.png
# /content/lw/transformed_0343.png
# /content/lw/transformed_0316.png
# /content/lw/transformed_0322.png
# /content/lw/transformed_0640.png
# /content/lw/transformed_0550.png
# /content/lw/transformed_0588.png
# /content/lw/transformed_0387.png
# /content/lw/transformed_0345.png
# /content/lw/transformed_0459.png
# /content/lw/transformed_0549.png
# /content/lw/transformed_0720.png
# /content/lw/transformed_0246.png
# /content/lw/transformed_0177.png
# /content/lw/transformed_0476.png
# /content/lw/transformed_0072.png
# /content/lw/transformed_0204.png
# /content/lw/transformed_0411.png
# /content/lw/transformed_0536.png
# /content/lw/transformed_0289.png
# /content/lw/transformed_0666.png
# /content/lw/transformed_0762.png
# /content/lw/transformed_0434.png
# /content/lw/transformed_0592.png
# /content/lw/transformed_0751.png
# /content/lw/transformed_0658.png
# /content/lw/transformed_0126.png
# /content/lw/transformed_0039.png
# /content/lw/transformed_0151.png
# /content/lw/transformed_0239.png
# /content/lw/transformed_0077.png
# /content/lw/transformed_0755.png
# /content/lw/transformed_0085.png
# /content/lw/transformed_0251.png
# /content/lw/transformed_0662.png
# /content/lw/transformed_0419.png
# /content/lw/transformed_0174.png
# /content/lw/transformed_0773.png
# /content/lw/transformed_0305.png
# /content/lw/transformed_0321.png
# /content/lw/transformed_0358.png
# /content/lw/transformed_0758.png
# /content/lw/transformed_0606.png
# /content/lw/transformed_0379.png
# /content/lw/transformed_0153.png
# /content/lw/transformed_0545.png
# /content/lw/transformed_0309.png
# /content/lw/transformed_0680.png
# /content/lw/transformed_0473.png
# /content/lw/transformed_0491.png
# /content/lw/transformed_0614.png
# /content/lw/transformed_0101.png
# /content/lw/transformed_0721.png
# /content/lw/transformed_0019.png
# /content/lw/transformed_0074.png
# /content/lw/transformed_0525.png
# /content/lw/transformed_0363.png
# /content/lw/transformed_0515.png
# /content/lw/transformed_0205.png
# /content/lw/transformed_0288.png
# /content/lw/transformed_0078.png
# /content/lw/transformed_0103.png
# /content/lw/transformed_0667.png
# /content/lw/transformed_0710.png
# /content/lw/transformed_0084.png
# /content/lw/transformed_0361.png
# /content/lw/transformed_0273.png
# /content/lw/transformed_0016.png
# /content/lw/transformed_0028.png
# /content/lw/transformed_0056.png
# /content/lw/transformed_0007.png
# /content/lw/transformed_0148.png
# /content/lw/transformed_0294.png
# /content/lw/transformed_0160.png
# /content/lw/transformed_0004.png
# /content/lw/transformed_0410.png
# /content/lw/transformed_0247.png
# /content/lw/transformed_0704.png
# /content/lw/transformed_0262.png
# /content/lw/transformed_0618.png
# /content/lw/transformed_0380.png
# /content/lw/transformed_0660.png
# /content/lw/transformed_0784.png
# /content/lw/transformed_0091.png
# /content/lw/transformed_0314.png
# /content/lw/transformed_0457.png
# /content/lw/transformed_0051.png
# /content/lw/transformed_0613.png
# /content/lw/transformed_0797.png
# /content/lw/transformed_0486.png
# /content/lw/transformed_0630.png
# /content/lw/transformed_0745.png
# /content/lw/transformed_0389.png
# /content/lw/transformed_0277.png
# /content/lw/transformed_0674.png
# /content/lw/transformed_0206.png
# /content/lw/transformed_0633.png
# /content/lw/transformed_0296.png
# /content/lw/transformed_0311.png
# /content/lw/transformed_0218.png
# /content/lw/transformed_0357.png
# /content/lw/transformed_0307.png
# /content/lw/transformed_0107.png
# /content/lw/transformed_0404.png
# /content/lw/transformed_0375.png
# /content/lw/transformed_0234.png
# /content/lw/transformed_0625.png
# /content/lw/transformed_0070.png
# /content/lw/transformed_0024.png
# /content/lw/transformed_0104.png
# /content/lw/transformed_0269.png
# /content/lw/transformed_0326.png
# /content/lw/transformed_0144.png
# /content/lw/transformed_0555.png
# /content/lw/transformed_0281.png
# /content/lw/transformed_0561.png
# /content/lw/transformed_0619.png
# /content/lw/transformed_0006.png
# /content/lw/transformed_0747.png
# /content/lw/transformed_0424.png
# /content/lw/transformed_0605.png
# /content/lw/transformed_0610.png
# /content/lw/transformed_0769.png
# /content/lw/transformed_0230.png
# /content/lw/transformed_0237.png
# /content/lw/transformed_0679.png
# /content/lw/transformed_0451.png
# /content/lw/transformed_0425.png
# /content/lw/transformed_0718.png
# /content/lw/transformed_0009.png
# /content/lw/transformed_0448.png
# /content/lw/transformed_0682.png
# /content/lw/transformed_0583.png
# /content/lw/transformed_0487.png
# /content/lw/transformed_0713.png
# /content/lw/transformed_0005.png
# /content/lw/transformed_0395.png
# /content/lw/transformed_0069.png
# /content/lw/transformed_0715.png
# /content/lw/transformed_0650.png
# /content/lw/transformed_0147.png
# /content/lw/transformed_0123.png
# /content/lw/transformed_0792.png
# /content/lw/transformed_0240.png
# /content/lw/transformed_0744.png
# /content/lw/transformed_0061.png
# /content/lw/transformed_0546.png
# /content/lw/transformed_0470.png
# /content/lw/transformed_0501.png
# /content/lw/transformed_0211.png
# /content/lw/transformed_0414.png
# /content/lw/transformed_0014.png
# /content/lw/transformed_0186.png
# /content/lw/transformed_0420.png
# /content/lw/transformed_0222.png
# /content/lw/transformed_0253.png
# /content/lw/transformed_0430.png
# /content/lw/transformed_0775.png
# /content/lw/transformed_0632.png
# /content/lw/transformed_0626.png
# /content/lw/transformed_0563.png
# /content/lw/transformed_0255.png
# /content/lw/transformed_0778.png
# /content/lw/transformed_0384.png
# /content/hr/transformed_0661.png
# /content/hr/transformed_0412.png
# /content/hr/transformed_0119.png
# /content/hr/transformed_0740.png
# /content/hr/transformed_0538.png
# /content/hr/transformed_0651.png
# /content/hr/transformed_0489.png
# /content/hr/transformed_0734.png
# /content/hr/transformed_0275.png
# /content/hr/transformed_0298.png
# /content/hr/transformed_0122.png
# /content/hr/transformed_0589.png
# /content/hr/transformed_0437.png
# /content/hr/transformed_0020.png
# /content/hr/transformed_0761.png
# /content/hr/transformed_0214.png
# /content/hr/transformed_0383.png
# /content/hr/transformed_0598.png
# /content/hr/transformed_0400.png
# /content/hr/transformed_0386.png
# /content/hr/transformed_0196.png
# /content/hr/transformed_0299.png
# /content/hr/transformed_0392.png
# /content/hr/transformed_0697.png
# /content/hr/transformed_0374.png
# /content/hr/transformed_0560.png
# /content/hr/transformed_0059.png
# /content/hr/transformed_0266.png
# /content/hr/transformed_0760.png
# /content/hr/transformed_0686.png
# /content/hr/transformed_0447.png
# /content/hr/transformed_0722.png
# /content/hr/transformed_0249.png
# /content/hr/transformed_0566.png
# /content/hr/transformed_0260.png
# /content/hr/transformed_0229.png
# /content/hr/transformed_0346.png
# /content/hr/transformed_0093.png
# /content/hr/transformed_0036.png
# /content/hr/transformed_0494.png
# /content/hr/transformed_0440.png
# /content/hr/transformed_0219.png
# /content/hr/transformed_0064.png
# /content/hr/transformed_0526.png
# /content/hr/transformed_0203.png
# /content/hr/transformed_0604.png
# /content/hr/transformed_0426.png
# /content/hr/transformed_0292.png
# /content/hr/transformed_0623.png
# /content/hr/transformed_0111.png
# /content/hr/transformed_0323.png
# /content/hr/transformed_0702.png
# /content/hr/transformed_0040.png
# /content/hr/transformed_0062.png
# /content/hr/transformed_0283.png
# /content/hr/transformed_0106.png
# /content/hr/transformed_0096.png
# /content/hr/transformed_0684.png
# /content/hr/transformed_0330.png
# /content/hr/transformed_0197.png
# /content/hr/transformed_0179.png
# /content/hr/transformed_0278.png
# /content/hr/transformed_0377.png
# /content/hr/transformed_0058.png
# /content/hr/transformed_0621.png
# /content/hr/transformed_0116.png
# /content/hr/transformed_0342.png
# /content/hr/transformed_0646.png
# /content/hr/transformed_0300.png
# /content/hr/transformed_0512.png
# /content/hr/transformed_0099.png
# /content/hr/transformed_0038.png
# /content/hr/transformed_0484.png
# /content/hr/transformed_0480.png
# /content/hr/transformed_0200.png
# /content/hr/transformed_0037.png
# /content/hr/transformed_0596.png
# /content/hr/transformed_0507.png
# /content/hr/transformed_0573.png
# /content/hr/transformed_0302.png
# /content/hr/transformed_0312.png
# /content/hr/transformed_0376.png
# /content/hr/transformed_0656.png
# /content/hr/transformed_0347.png
# /content/hr/transformed_0105.png
# /content/hr/transformed_0259.png
# /content/hr/transformed_0359.png
# /content/hr/transformed_0608.png
# /content/hr/transformed_0365.png
# /content/hr/transformed_0654.png
# /content/hr/transformed_0042.png
# /content/hr/transformed_0728.png
# /content/hr/transformed_0733.png
# /content/hr/transformed_0367.png
# /content/hr/transformed_0044.png
# /content/hr/transformed_0559.png
# /content/hr/transformed_0474.png
# /content/hr/transformed_0189.png
# /content/hr/transformed_0372.png
# /content/hr/transformed_0749.png
# /content/hr/transformed_0531.png
# /content/hr/transformed_0241.png
# /content/hr/transformed_0286.png
# /content/hr/transformed_0446.png
# /content/hr/transformed_0644.png
# /content/hr/transformed_0790.png
# /content/hr/transformed_0581.png
# /content/hr/transformed_0530.png
# /content/hr/transformed_0503.png
# /content/hr/transformed_0421.png
# /content/hr/transformed_0565.png
# /content/hr/transformed_0393.png
# /content/hr/transformed_0567.png
# /content/hr/transformed_0787.png
# /content/hr/transformed_0542.png
# /content/hr/transformed_0731.png
# /content/hr/transformed_0409.png
# /content/hr/transformed_0757.png
# /content/hr/transformed_0416.png
# /content/hr/transformed_0334.png
# /content/hr/transformed_0013.png
# /content/hr/transformed_0235.png
# /content/hr/transformed_0584.png
# /content/hr/transformed_0716.png
# /content/hr/transformed_0263.png
# /content/hr/transformed_0777.png
# /content/hr/transformed_0054.png
# /content/hr/transformed_0508.png
# /content/hr/transformed_0071.png
# /content/hr/transformed_0738.png
# /content/hr/transformed_0764.png
# /content/hr/transformed_0319.png
# /content/hr/transformed_0250.png
# /content/hr/transformed_0167.png
# /content/hr/transformed_0158.png
# /content/hr/transformed_0659.png
# /content/hr/transformed_0001.png
# /content/hr/transformed_0540.png
# /content/hr/transformed_0637.png
# /content/hr/transformed_0149.png
# /content/hr/transformed_0382.png
# /content/hr/transformed_0743.png
# /content/hr/transformed_0423.png
# /content/hr/transformed_0320.png
# /content/hr/transformed_0394.png
# /content/hr/transformed_0086.png
# /content/hr/transformed_0121.png
# /content/hr/transformed_0438.png
# /content/hr/transformed_0124.png
# /content/hr/transformed_0046.png
# /content/hr/transformed_0703.png
# /content/hr/transformed_0193.png
# /content/hr/transformed_0308.png
# /content/hr/transformed_0264.png
# /content/hr/transformed_0500.png
# /content/hr/transformed_0142.png
# /content/hr/transformed_0354.png
# /content/hr/transformed_0052.png
# /content/hr/transformed_0653.png
# /content/hr/transformed_0638.png
# /content/hr/transformed_0714.png
# /content/hr/transformed_0456.png
# /content/hr/transformed_0242.png
# /content/hr/transformed_0690.png
# /content/hr/transformed_0136.png
# /content/hr/transformed_0458.png
# /content/hr/transformed_0220.png
# /content/hr/transformed_0297.png
# /content/hr/transformed_0397.png
# /content/hr/transformed_0685.png
# /content/hr/transformed_0171.png
# /content/hr/transformed_0455.png
# /content/hr/transformed_0504.png
# /content/hr/transformed_0290.png
# /content/hr/transformed_0138.png
# /content/hr/transformed_0025.png
# /content/hr/transformed_0274.png
# /content/hr/transformed_0256.png
# /content/hr/transformed_0120.png
# /content/hr/transformed_0190.png
# /content/hr/transformed_0194.png
# /content/hr/transformed_0663.png
# /content/hr/transformed_0195.png
# /content/hr/transformed_0771.png
# /content/hr/transformed_0576.png
# /content/hr/transformed_0030.png
# /content/hr/transformed_0407.png
# /content/hr/transformed_0066.png
# /content/hr/transformed_0439.png
# /content/hr/transformed_0422.png
# /content/hr/transformed_0371.png
# /content/hr/transformed_0405.png
# /content/hr/transformed_0073.png
# /content/hr/transformed_0271.png
# /content/hr/transformed_0079.png
# /content/hr/transformed_0170.png
# /content/hr/transformed_0452.png
# /content/hr/transformed_0113.png
# /content/hr/transformed_0629.png
# /content/hr/transformed_0705.png
# /content/hr/transformed_0600.png
# /content/hr/transformed_0467.png
# /content/hr/transformed_0406.png
# /content/hr/transformed_0198.png
# /content/hr/transformed_0692.png
# /content/hr/transformed_0524.png
# /content/hr/transformed_0449.png
# /content/hr/transformed_0349.png
# /content/hr/transformed_0461.png
# /content/hr/transformed_0450.png
# /content/hr/transformed_0244.png
# /content/hr/transformed_0724.png
# /content/hr/transformed_0129.png
# /content/hr/transformed_0534.png
# /content/hr/transformed_0162.png
# /content/hr/transformed_0026.png
# /content/hr/transformed_0336.png
# /content/hr/transformed_0226.png
# /content/hr/transformed_0350.png
# /content/hr/transformed_0578.png
# /content/hr/transformed_0097.png
# /content/hr/transformed_0381.png
# /content/hr/transformed_0739.png
# /content/hr/transformed_0301.png
# /content/hr/transformed_0378.png
# /content/hr/transformed_0785.png
# /content/hr/transformed_0799.png
# /content/hr/transformed_0707.png
# /content/hr/transformed_0753.png
# /content/hr/transformed_0485.png
# /content/hr/transformed_0649.png
# /content/hr/transformed_0257.png
# /content/hr/transformed_0166.png
# /content/hr/transformed_0012.png
# /content/hr/transformed_0175.png
# /content/hr/transformed_0270.png
# /content/hr/transformed_0303.png
# /content/hr/transformed_0582.png
# /content/hr/transformed_0313.png
# /content/hr/transformed_0146.png
# /content/hr/transformed_0496.png
# /content/hr/transformed_0732.png
# /content/hr/transformed_0564.png
# /content/hr/transformed_0181.png
# /content/hr/transformed_0725.png
# /content/hr/transformed_0137.png
# /content/hr/transformed_0607.png
# /content/hr/transformed_0341.png
# /content/hr/transformed_0543.png
# /content/hr/transformed_0131.png
# /content/hr/transformed_0095.png
# /content/hr/transformed_0635.png
# /content/hr/transformed_0068.png
# /content/hr/transformed_0276.png
# /content/hr/transformed_0495.png
# /content/hr/transformed_0670.png
# /content/hr/transformed_0344.png
# /content/hr/transformed_0082.png
# /content/hr/transformed_0601.png
# /content/hr/transformed_0483.png
# /content/hr/transformed_0184.png
# /content/hr/transformed_0636.png
# /content/hr/transformed_0080.png
# /content/hr/transformed_0609.png
# /content/hr/transformed_0172.png
# /content/hr/transformed_0763.png
# /content/hr/transformed_0612.png
# /content/hr/transformed_0708.png
# /content/hr/transformed_0585.png
# /content/hr/transformed_0210.png
# /content/hr/transformed_0432.png
# /content/hr/transformed_0280.png
# /content/hr/transformed_0436.png
# /content/hr/transformed_0689.png
# /content/hr/transformed_0135.png
# /content/hr/transformed_0388.png
# /content/hr/transformed_0048.png
# /content/hr/transformed_0579.png
# /content/hr/transformed_0599.png
# /content/hr/transformed_0768.png
# /content/hr/transformed_0509.png
# /content/hr/transformed_0352.png
# /content/hr/transformed_0366.png
# /content/hr/transformed_0173.png
# /content/hr/transformed_0152.png
# /content/hr/transformed_0533.png
# /content/hr/transformed_0390.png
# /content/hr/transformed_0694.png
# /content/hr/transformed_0529.png
# /content/hr/transformed_0110.png
# /content/hr/transformed_0652.png
# /content/hr/transformed_0165.png
# /content/hr/transformed_0017.png
# /content/hr/transformed_0441.png
# /content/hr/transformed_0444.png
# /content/hr/transformed_0544.png
# /content/hr/transformed_0502.png
# /content/hr/transformed_0340.png
# /content/hr/transformed_0351.png
# /content/hr/transformed_0681.png
# /content/hr/transformed_0577.png
# /content/hr/transformed_0032.png
# /content/hr/transformed_0693.png
# /content/hr/transformed_0481.png
# /content/hr/transformed_0328.png
# /content/hr/transformed_0523.png
# /content/hr/transformed_0295.png
# /content/hr/transformed_0217.png
# /content/hr/transformed_0238.png
# /content/hr/transformed_0002.png
# /content/hr/transformed_0568.png
# /content/hr/transformed_0798.png
# /content/hr/transformed_0701.png
# /content/hr/transformed_0678.png
# /content/hr/transformed_0227.png
# /content/hr/transformed_0729.png
# /content/hr/transformed_0786.png
# /content/hr/transformed_0185.png
# /content/hr/transformed_0306.png
# /content/hr/transformed_0279.png
# /content/hr/transformed_0223.png
# /content/hr/transformed_0711.png
# /content/hr/transformed_0669.png
# /content/hr/transformed_0325.png
# /content/hr/transformed_0310.png
# /content/hr/transformed_0060.png
# /content/hr/transformed_0683.png
# /content/hr/transformed_0548.png
# /content/hr/transformed_0191.png
# /content/hr/transformed_0765.png
# /content/hr/transformed_0519.png
# /content/hr/transformed_0587.png
# /content/hr/transformed_0034.png
# /content/hr/transformed_0333.png
# /content/hr/transformed_0329.png
# /content/hr/transformed_0688.png
# /content/hr/transformed_0053.png
# /content/hr/transformed_0443.png
# /content/hr/transformed_0176.png
# /content/hr/transformed_0776.png
# /content/hr/transformed_0029.png
# /content/hr/transformed_0157.png
# /content/hr/transformed_0140.png
# /content/hr/transformed_0385.png
# /content/hr/transformed_0339.png
# /content/hr/transformed_0468.png
# /content/hr/transformed_0766.png
# /content/hr/transformed_0331.png
# /content/hr/transformed_0031.png
# /content/hr/transformed_0327.png
# /content/hr/transformed_0466.png
# /content/hr/transformed_0041.png
# /content/hr/transformed_0597.png
# /content/hr/transformed_0691.png
# /content/hr/transformed_0417.png
# /content/hr/transformed_0248.png
# /content/hr/transformed_0518.png
# /content/hr/transformed_0522.png
# /content/hr/transformed_0355.png
# /content/hr/transformed_0547.png
# /content/hr/transformed_0267.png
# /content/hr/transformed_0216.png
# /content/hr/transformed_0212.png
# /content/hr/transformed_0442.png
# /content/hr/transformed_0035.png
# /content/hr/transformed_0616.png
# /content/hr/transformed_0645.png
# /content/hr/transformed_0552.png
# /content/hr/transformed_0492.png
# /content/hr/transformed_0513.png
# /content/hr/transformed_0199.png
# /content/hr/transformed_0482.png
# /content/hr/transformed_0265.png
# /content/hr/transformed_0183.png
# /content/hr/transformed_0373.png
# /content/hr/transformed_0399.png
# /content/hr/transformed_0076.png
# /content/hr/transformed_0783.png
# /content/hr/transformed_0464.png
# /content/hr/transformed_0090.png
# /content/hr/transformed_0730.png
# /content/hr/transformed_0427.png
# /content/hr/transformed_0130.png
# /content/hr/transformed_0408.png
# /content/hr/transformed_0748.png
# /content/hr/transformed_0141.png
# /content/hr/transformed_0532.png
# /content/hr/transformed_0050.png
# /content/hr/transformed_0254.png
# /content/hr/transformed_0396.png
# /content/hr/transformed_0401.png
# /content/hr/transformed_0159.png
# /content/hr/transformed_0192.png
# /content/hr/transformed_0402.png
# /content/hr/transformed_0593.png
# /content/hr/transformed_0268.png
# /content/hr/transformed_0209.png
# /content/hr/transformed_0003.png
# /content/hr/transformed_0774.png
# /content/hr/transformed_0795.png
# /content/hr/transformed_0433.png
# /content/hr/transformed_0348.png
# /content/hr/transformed_0258.png
# /content/hr/transformed_0285.png
# /content/hr/transformed_0756.png
# /content/hr/transformed_0676.png
# /content/hr/transformed_0706.png
# /content/hr/transformed_0362.png
# /content/hr/transformed_0117.png
# /content/hr/transformed_0520.png
# /content/hr/transformed_0506.png
# /content/hr/transformed_0118.png
# /content/hr/transformed_0511.png
# /content/hr/transformed_0527.png
# /content/hr/transformed_0673.png
# /content/hr/transformed_0477.png
# /content/hr/transformed_0168.png
# /content/hr/transformed_0631.png
# /content/hr/transformed_0134.png
# /content/hr/transformed_0514.png
# /content/hr/transformed_0043.png
# /content/hr/transformed_0572.png
# /content/hr/transformed_0010.png
# /content/hr/transformed_0231.png
# /content/hr/transformed_0245.png
# /content/hr/transformed_0699.png
# /content/hr/transformed_0018.png
# /content/hr/transformed_0201.png
# /content/hr/transformed_0435.png
# /content/hr/transformed_0364.png
# /content/hr/transformed_0115.png
# /content/hr/transformed_0712.png
# /content/hr/transformed_0709.png
# /content/hr/transformed_0370.png
# /content/hr/transformed_0750.png
# /content/hr/transformed_0475.png
# /content/hr/transformed_0796.png
# /content/hr/transformed_0677.png
# /content/hr/transformed_0553.png
# /content/hr/transformed_0788.png
# /content/hr/transformed_0139.png
# /content/hr/transformed_0057.png
# /content/hr/transformed_0664.png
# /content/hr/transformed_0800.png
# /content/hr/transformed_0627.png
# /content/hr/transformed_0737.png
# /content/hr/transformed_0428.png
# /content/hr/transformed_0462.png
# /content/hr/transformed_0180.png
# /content/hr/transformed_0065.png
# /content/hr/transformed_0695.png
# /content/hr/transformed_0225.png
# /content/hr/transformed_0178.png
# /content/hr/transformed_0132.png
# /content/hr/transformed_0586.png
# /content/hr/transformed_0571.png
# /content/hr/transformed_0498.png
# /content/hr/transformed_0398.png
# /content/hr/transformed_0261.png
# /content/hr/transformed_0516.png
# /content/hr/transformed_0445.png
# /content/hr/transformed_0791.png
# /content/hr/transformed_0528.png
# /content/hr/transformed_0782.png
# /content/hr/transformed_0023.png
# /content/hr/transformed_0657.png
# /content/hr/transformed_0318.png
# /content/hr/transformed_0413.png
# /content/hr/transformed_0622.png
# /content/hr/transformed_0643.png
# /content/hr/transformed_0156.png
# /content/hr/transformed_0793.png
# /content/hr/transformed_0675.png
# /content/hr/transformed_0431.png
# /content/hr/transformed_0092.png
# /content/hr/transformed_0687.png
# /content/hr/transformed_0639.png
# /content/hr/transformed_0727.png
# /content/hr/transformed_0145.png
# /content/hr/transformed_0252.png
# /content/hr/transformed_0655.png
# /content/hr/transformed_0337.png
# /content/hr/transformed_0109.png
# /content/hr/transformed_0304.png
# /content/hr/transformed_0497.png
# /content/hr/transformed_0754.png
# /content/hr/transformed_0700.png
# /content/hr/transformed_0499.png
# /content/hr/transformed_0602.png
# /content/hr/transformed_0391.png
# /content/hr/transformed_0590.png
# /content/hr/transformed_0233.png
# /content/hr/transformed_0569.png
# /content/hr/transformed_0617.png
# /content/hr/transformed_0575.png
# /content/hr/transformed_0187.png
# /content/hr/transformed_0471.png
# /content/hr/transformed_0128.png
# /content/hr/transformed_0781.png
# /content/hr/transformed_0089.png
# /content/hr/transformed_0284.png
# /content/hr/transformed_0488.png
# /content/hr/transformed_0717.png
# /content/hr/transformed_0634.png
# /content/hr/transformed_0647.png
# /content/hr/transformed_0668.png
# /content/hr/transformed_0723.png
# /content/hr/transformed_0368.png
# /content/hr/transformed_0403.png
# /content/hr/transformed_0067.png
# /content/hr/transformed_0169.png
# /content/hr/transformed_0772.png
# /content/hr/transformed_0752.png
# /content/hr/transformed_0562.png
# /content/hr/transformed_0620.png
# /content/hr/transformed_0228.png
# /content/hr/transformed_0541.png
# /content/hr/transformed_0465.png
# /content/hr/transformed_0287.png
# /content/hr/transformed_0742.png
# /content/hr/transformed_0624.png
# /content/hr/transformed_0735.png
# /content/hr/transformed_0127.png
# /content/hr/transformed_0672.png
# /content/hr/transformed_0460.png
# /content/hr/transformed_0570.png
# /content/hr/transformed_0015.png
# /content/hr/transformed_0335.png
# /content/hr/transformed_0539.png
# /content/hr/transformed_0779.png
# /content/hr/transformed_0221.png
# /content/hr/transformed_0282.png
# /content/hr/transformed_0087.png
# /content/hr/transformed_0454.png
# /content/hr/transformed_0008.png
# /content/hr/transformed_0272.png
# /content/hr/transformed_0155.png
# /content/hr/transformed_0517.png
# /content/hr/transformed_0164.png
# /content/hr/transformed_0490.png
# /content/hr/transformed_0642.png
# /content/hr/transformed_0088.png
# /content/hr/transformed_0478.png
# /content/hr/transformed_0463.png
# /content/hr/transformed_0505.png
# /content/hr/transformed_0202.png
# /content/hr/transformed_0719.png
# /content/hr/transformed_0338.png
# /content/hr/transformed_0698.png
# /content/hr/transformed_0133.png
# /content/hr/transformed_0789.png
# /content/hr/transformed_0049.png
# /content/hr/transformed_0580.png
# /content/hr/transformed_0353.png
# /content/hr/transformed_0021.png
# /content/hr/transformed_0551.png
# /content/hr/transformed_0453.png
# /content/hr/transformed_0075.png
# /content/hr/transformed_0150.png
# /content/hr/transformed_0557.png
# /content/hr/transformed_0603.png
# /content/hr/transformed_0369.png
# /content/hr/transformed_0360.png
# /content/hr/transformed_0537.png
# /content/hr/transformed_0291.png
# /content/hr/transformed_0418.png
# /content/hr/transformed_0102.png
# /content/hr/transformed_0535.png
# /content/hr/transformed_0648.png
# /content/hr/transformed_0595.png
# /content/hr/transformed_0100.png
# /content/hr/transformed_0161.png
# /content/hr/transformed_0332.png
# /content/hr/transformed_0493.png
# /content/hr/transformed_0224.png
# /content/hr/transformed_0558.png
# /content/hr/transformed_0315.png
# /content/hr/transformed_0696.png
# /content/hr/transformed_0154.png
# /content/hr/transformed_0083.png
# /content/hr/transformed_0615.png
# /content/hr/transformed_0055.png
# /content/hr/transformed_0628.png
# /content/hr/transformed_0770.png
# /content/hr/transformed_0033.png
# /content/hr/transformed_0415.png
# /content/hr/transformed_0759.png
# /content/hr/transformed_0356.png
# /content/hr/transformed_0746.png
# /content/hr/transformed_0108.png
# /content/hr/transformed_0317.png
# /content/hr/transformed_0213.png
# /content/hr/transformed_0472.png
# /content/hr/transformed_0780.png
# /content/hr/transformed_0011.png
# /content/hr/transformed_0027.png
# /content/hr/transformed_0794.png
# /content/hr/transformed_0611.png
# /content/hr/transformed_0243.png
# /content/hr/transformed_0114.png
# /content/hr/transformed_0641.png
# /content/hr/transformed_0112.png
# /content/hr/transformed_0098.png
# /content/hr/transformed_0767.png
# /content/hr/transformed_0236.png
# /content/hr/transformed_0143.png
# /content/hr/transformed_0510.png
# /content/hr/transformed_0163.png
# /content/hr/transformed_0469.png
# /content/hr/transformed_0293.png
# /content/hr/transformed_0081.png
# /content/hr/transformed_0208.png
# /content/hr/transformed_0671.png
# /content/hr/transformed_0736.png
# /content/hr/transformed_0022.png
# /content/hr/transformed_0554.png
# /content/hr/transformed_0125.png
# /content/hr/transformed_0182.png
# /content/hr/transformed_0094.png
# /content/hr/transformed_0063.png
# /content/hr/transformed_0045.png
# /content/hr/transformed_0741.png
# /content/hr/transformed_0188.png
# /content/hr/transformed_0232.png
# /content/hr/transformed_0479.png
# /content/hr/transformed_0429.png
# /content/hr/transformed_0726.png
# /content/hr/transformed_0215.png
# /content/hr/transformed_0591.png
# /content/hr/transformed_0207.png
# /content/hr/transformed_0047.png
# /content/hr/transformed_0665.png
# /content/hr/transformed_0556.png
# /content/hr/transformed_0594.png
# /content/hr/transformed_0521.png
# /content/hr/transformed_0574.png
# /content/hr/transformed_0324.png
# /content/hr/transformed_0343.png
# /content/hr/transformed_0316.png
# /content/hr/transformed_0322.png
# /content/hr/transformed_0640.png
# /content/hr/transformed_0550.png
# /content/hr/transformed_0588.png
# /content/hr/transformed_0387.png
# /content/hr/transformed_0345.png
# /content/hr/transformed_0459.png
# /content/hr/transformed_0549.png
# /content/hr/transformed_0720.png
# /content/hr/transformed_0246.png
# /content/hr/transformed_0177.png
# /content/hr/transformed_0476.png
# /content/hr/transformed_0072.png
# /content/hr/transformed_0204.png
# /content/hr/transformed_0411.png
# /content/hr/transformed_0536.png
# /content/hr/transformed_0289.png
# /content/hr/transformed_0666.png
# /content/hr/transformed_0762.png
# /content/hr/transformed_0434.png
# /content/hr/transformed_0592.png
# /content/hr/transformed_0751.png
# /content/hr/transformed_0658.png
# /content/hr/transformed_0126.png
# /content/hr/transformed_0039.png
# /content/hr/transformed_0151.png
# /content/hr/transformed_0239.png
# /content/hr/transformed_0077.png
# /content/hr/transformed_0755.png
# /content/hr/transformed_0085.png
# /content/hr/transformed_0251.png
# /content/hr/transformed_0662.png
# /content/hr/transformed_0419.png
# /content/hr/transformed_0174.png
# /content/hr/transformed_0773.png
# /content/hr/transformed_0305.png
# /content/hr/transformed_0321.png
# /content/hr/transformed_0358.png
# /content/hr/transformed_0758.png
# /content/hr/transformed_0606.png
# /content/hr/transformed_0379.png
# /content/hr/transformed_0153.png
# /content/hr/transformed_0545.png
# /content/hr/transformed_0309.png
# /content/hr/transformed_0680.png
# /content/hr/transformed_0473.png
# /content/hr/transformed_0491.png
# /content/hr/transformed_0614.png
# /content/hr/transformed_0101.png
# /content/hr/transformed_0721.png
# /content/hr/transformed_0019.png
# /content/hr/transformed_0074.png
# /content/hr/transformed_0525.png
# /content/hr/transformed_0363.png
# /content/hr/transformed_0515.png
# /content/hr/transformed_0205.png
# /content/hr/transformed_0288.png
# /content/hr/transformed_0078.png
# /content/hr/transformed_0103.png
# /content/hr/transformed_0667.png
# /content/hr/transformed_0710.png
# /content/hr/transformed_0084.png
# /content/hr/transformed_0361.png
# /content/hr/transformed_0273.png
# /content/hr/transformed_0016.png
# /content/hr/transformed_0028.png
# /content/hr/transformed_0056.png
# /content/hr/transformed_0007.png
# /content/hr/transformed_0148.png
# /content/hr/transformed_0294.png
# /content/hr/transformed_0160.png
# /content/hr/transformed_0004.png
# /content/hr/transformed_0410.png
# /content/hr/transformed_0247.png
# /content/hr/transformed_0704.png
# /content/hr/transformed_0262.png
# /content/hr/transformed_0618.png
# /content/hr/transformed_0380.png
# /content/hr/transformed_0660.png
# /content/hr/transformed_0784.png
# /content/hr/transformed_0091.png
# /content/hr/transformed_0314.png
# /content/hr/transformed_0457.png
# /content/hr/transformed_0051.png
# /content/hr/transformed_0613.png
# /content/hr/transformed_0797.png
# /content/hr/transformed_0486.png
# /content/hr/transformed_0630.png
# /content/hr/transformed_0745.png
# /content/hr/transformed_0389.png
# /content/hr/transformed_0277.png
# /content/hr/transformed_0674.png
# /content/hr/transformed_0206.png
# /content/hr/transformed_0633.png
# /content/hr/transformed_0296.png
# /content/hr/transformed_0311.png
# /content/hr/transformed_0218.png
# /content/hr/transformed_0357.png
# /content/hr/transformed_0307.png
# /content/hr/transformed_0107.png
# /content/hr/transformed_0404.png
# /content/hr/transformed_0375.png
# /content/hr/transformed_0234.png
# /content/hr/transformed_0625.png
# /content/hr/transformed_0070.png
# /content/hr/transformed_0024.png
# /content/hr/transformed_0104.png
# /content/hr/transformed_0269.png
# /content/hr/transformed_0326.png
# /content/hr/transformed_0144.png
# /content/hr/transformed_0555.png
# /content/hr/transformed_0281.png
# /content/hr/transformed_0561.png
# /content/hr/transformed_0619.png
# /content/hr/transformed_0006.png
# /content/hr/transformed_0747.png
# /content/hr/transformed_0424.png
# /content/hr/transformed_0605.png
# /content/hr/transformed_0610.png
# /content/hr/transformed_0769.png
# /content/hr/transformed_0230.png
# /content/hr/transformed_0237.png
# /content/hr/transformed_0679.png
# /content/hr/transformed_0451.png
# /content/hr/transformed_0425.png
# /content/hr/transformed_0718.png
# /content/hr/transformed_0009.png
# /content/hr/transformed_0448.png
# /content/hr/transformed_0682.png
# /content/hr/transformed_0583.png
# /content/hr/transformed_0487.png
# /content/hr/transformed_0713.png
# /content/hr/transformed_0005.png
# /content/hr/transformed_0395.png
# /content/hr/transformed_0069.png
# /content/hr/transformed_0715.png
# /content/hr/transformed_0650.png
# /content/hr/transformed_0147.png
# /content/hr/transformed_0123.png
# /content/hr/transformed_0792.png
# /content/hr/transformed_0240.png
# /content/hr/transformed_0744.png
# /content/hr/transformed_0061.png
# /content/hr/transformed_0546.png
# /content/hr/transformed_0470.png
# /content/hr/transformed_0501.png
# /content/hr/transformed_0211.png
# /content/hr/transformed_0414.png
# /content/hr/transformed_0014.png
# /content/hr/transformed_0186.png
# /content/hr/transformed_0420.png
# /content/hr/transformed_0222.png
# /content/hr/transformed_0253.png
# /content/hr/transformed_0430.png
# /content/hr/transformed_0775.png
# /content/hr/transformed_0632.png
# /content/hr/transformed_0626.png
# /content/hr/transformed_0563.png
# /content/hr/transformed_0255.png
# /content/hr/transformed_0778.png
# /content/hr/transformed_0384.png

# %%
dmg=DataSetManage()

directoriolw={
     "lw":["/content/lw/",0],
}

directoriohr={
     "hr":["/content/hr/",1],
}




listas_directorios,listas_paths_directorios,listas_clases=dmg.separar_datos_directorios(directoriolw)
Dataset_csv="lw_dataset.csv" #nombre que tenda nuestlo csv
dmg.crear_paths_csv(listas_directorios,listas_paths_directorios,listas_clases,Dataset_csv)


listas_directorios,listas_paths_directorios,listas_clases=dmg.separar_datos_directorios(directoriohr)
Dataset_csv="hr_dataset.csv" #nombre que tendla nuestlo csv
dmg.crear_paths_csv(listas_directorios,listas_paths_directorios,listas_clases,Dataset_csv)
# Out:
# Csv Creado
# Csv Creado

# %%
#@markdown # *2) ** Creacion de clase DATASET(OBLIGATORIO)
import torch
from torch.utils.data import Dataset,DataLoader
import pandas as pd
import numpy as np
import cv2
from PIL import Image


class MiDataSet(Dataset):

  def __init__(self,csv_file, transform=None):


     self.data=pd.read_csv(csv_file)

     self.x=self.data["path"]
     self.y=self.data["etiqueta"]

     self.transform=transform

     self.samples=self.data["path"].shape[0]

  def __getitem__(self,id):

    rut_imagen=self.x[id]
    imagen=cv2.imread(rut_imagen)
    etiqueta=self.y[id]


    if imagen is None:
      pillow_image = Image.open(rut_imagen)
      numpy_image = np.array(pillow_image)
      imagen=cv2.cvtColor(numpy_image, cv2.COLOR_RGB2BGR)


    imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)


    if self.transform:
      imagen_rgb = self.transform(imagen_rgb)

    return imagen_rgb,etiqueta


  def __len__(self):
   return self.samples

# %%
#@markdown # *0) ** Creando clase Discriminadora y Geneaadora:

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
from torch.utils.data import Dataset,DataLoader
import torchvision.transforms as transforms
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as F

class Discriminator (nn.Module):
  def __init__(self):
   super(Discriminator,self).__init__()

   self.conv1=nn.Conv2d(3,64,kernel_size=3,stride=1, bias=False)
   self.conv2=nn.Conv2d(64,64,kernel_size=3,stride=2, bias=False)
   self.btchnorm64=nn.BatchNorm2d(64)

   self.conv3=nn.Conv2d(64,128,kernel_size=3,stride=1, bias=False)
   self.conv4=nn.Conv2d(128,128,kernel_size=3,stride=2, bias=False)
   self.btchnorm128=nn.BatchNorm2d(128)

   self.conv5=nn.Conv2d(128,256,kernel_size=3,stride=1, bias=False)
   self.conv6=nn.Conv2d(256,256,kernel_size=3,stride=2, bias=False)
   self.btchnorm256=nn.BatchNorm2d(256)

   self.conv7=nn.Conv2d(256,512,kernel_size=3,stride=1, bias=False)
   self.conv8=nn.Conv2d(512,512,kernel_size=3,stride=2, bias=False)
   self.btchnorm512=nn.BatchNorm2d(512)
   self.flatt=nn.Flatten()

   self.oculta1=nn.LazyLinear(1024)
   self.salida= nn.LazyLinear(1)


  def forward(self,x):

    x=self.conv1(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv2(x)
    x=self.btchnorm64(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv3(x)
    x=self.btchnorm128(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv4(x)
    x=self.btchnorm128(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv5(x)
    x=self.btchnorm256(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv6(x)
    x=self.btchnorm256(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv7(x)
    x=self.btchnorm512(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.conv8(x)
    x=self.btchnorm512(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.flatt(x)
    x=self.oculta1(x)
    x= nn.LeakyReLU(0.1)(x)

    x=self.salida(x)
    out=torch.sigmoid(x)

    return out

# %%
discriminador=Discriminator()
discriminador=discriminador.to("cuda")
x=torch.randn(20,3,208,208).to("cuda")

print(discriminador(x))

# %%
#------------------------------------------------------------------------
import torch.nn.functional as F
class Generador(nn.Module):

  def __init__(self,factor_escala):
   super(Generador,self).__init__()

   self.convInicial=nn.Conv2d(3,64,kernel_size=9,stride=1)

  #Bloques residuales

   res_blocks = []
   for _ in range(6):
       res_blocks.append(ResidualBlock(64))
   self.res_blocks = nn.Sequential(*res_blocks)

   self.convSalida1=nn.Conv2d(64,64,kernel_size=3,stride=1,padding=1)
   self.btchnorm=nn.BatchNorm2d(64)

  #vamos a obligar que la salida anterior se ajuste a la entrada del bloque umsampling que es 256/factor al cuadrado, asi no tengamos problemas en el bluque

   self.convextra=nn.Conv2d(64,int(256/factor_escala**2),kernel_size=1,stride=1,padding=1)

  #Bloques upsampling

   upsampling = []
   for out_features in range(2):
        upsampling.append(upsampling_block(256,factor_escala))

   self.upsampling = nn.Sequential(*upsampling)

   self.prelu_layer=nn.PReLU();
   self.convlast=nn.Conv2d(int(256/factor_escala**2),3,kernel_size=9,stride=1,padding=4)



  def forward(self,x):


    x=self.convInicial(x)
    x= self.prelu_layer(x)
    x_inicial=x

    x=self.res_blocks(x)
    x= self.convSalida1(x)

    x=torch.add(x,x_inicial)
    x=self.convextra(x)

    x=self.upsampling(x)



    x=self.convlast(x)
    out= ((torch.tanh(x) + 1) / 2)
    return out


class upsampling_block(nn.Module):
    def __init__(self, out_features,factor):
        super(upsampling_block, self).__init__()
        print(int(out_features/factor**2))
        self.conv_block = nn.Sequential(
                nn.Conv2d(int(out_features/factor**2), out_features, 3, 1, 1),
                nn.BatchNorm2d(out_features),
                nn.PixelShuffle(upscale_factor=factor),
                nn.PReLU(),
        )

    def forward(self, x):
        return self.conv_block(x)


class ResidualBlock(nn.Module):
    def __init__(self, in_features):
        super(ResidualBlock, self).__init__()
        self.conv_block = nn.Sequential(
            nn.Conv2d(in_features, in_features, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(in_features, 0.8),
            nn.PReLU(),
            nn.Conv2d(in_features, in_features, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(in_features, 0.8),
        )

    def forward(self, x):
        return x + self.conv_block(x)

# %%
#VAMOS A VER QUE MEDIADES EL GENERADOR DA COMO RESUTLADO CON LW RESOLUTIONS MEDIDAES:

discriminador=Generador(2)
discriminador=discriminador.to("cuda")
x=torch.randn(20,3,60,60).to("cuda")

print(discriminador(x).shape)
# Out:
# 64
# 64
# torch.Size([20, 3, 216, 216])

# %%
#PROBAMOS EL GENERADOR INCIAL:

from PIL import Image
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt


#--------------------------------------------------------------------------------------------------------
def show_comparacion(real,generado): #deben de ingrenar don tennoren de imagen generada y real
 print(generado.shape)
 print(real.shape)
 real=real.detach().squeeze().cpu().numpy().transpose(1, 2, 0)
 generado=generado.squeeze().cpu().detach().numpy().transpose(1, 2, 0)
# Primer subgráfico: imagen original
 plt.subplot(1, 2, 1)
 plt.imshow(generado)  # Convertir a NumPy y transponer dimensiones
 plt.title('Imagen Generada')
 plt.axis('off')

# Segundo subgráfico: imagen transformada
 plt.subplot(1, 2, 2)
 plt.imshow(real)  # Convertir a NumPy y transponer dimensiones
 plt.title('Imagen Real')
 plt.axis('off')

# Ajustar el diseño para evitar superposición de títulos
 plt.tight_layout()

# Mostrar la figura
 plt.show()


 plt.figure(figsize=(10, 5))
#-----------------------------------------------------------------------------------
generador=Generador(2).to("cuda")

ruta_imagen = "/content/lw/transformed_0001_0.png"
imagen = Image.open(ruta_imagen)

transformador = ToTensor()

#original iamgen tensor
tensor_imagen = transformador(imagen).unsqueeze(0)
tensor_imagen=tensor_imagen.to("cuda")
#imagen generada
imagen_generada=generador(tensor_imagen)



show_comparacion(tensor_imagen,imagen_generada)
# Out:
# 64
# 64
# torch.Size([1, 3, 216, 216])
# torch.Size([1, 3, 60, 60])

# %%
from torchvision import models
class Feature_Extractor(nn.Module):
    def __init__(self):
        super(Feature_Extractor, self).__init__()
        # Cargar un modelo VGG-19 preentrenado
        vgg19_model = models.vgg19(pretrained=True).features.eval()

        # No actualizar los pesos del modelo VGG durante el entrenamiento
        for param in vgg19_model.parameters():
            param.requires_grad = False

        selected_layers = list(vgg19_model.children())[:18]

        self.vgg=nn.Sequential(*selected_layers)

    def forward(self, img):

        # Extraer características de las imágenes generada y real
        feature_img = self.vgg(img)

        return feature_img

# %%
import matplotlib.pyplot as plt
import torch
import torchvision.utils as vutils
import sklearn
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset
# ...

#d=Discriminator(image_dim).to(device)
#g=Generador(dim_vector_ruido,image_dim).to(device)

#d.load_state_dict(torch.load("/content/modelo_gatos_d.pt"))
#g.load_state_dict(torch.load("/content/modelo_gatos_g.pt"))

#d=d.to(device)
#g=g.to(device)


# Supongamos que ya has definido las instancias de los modelos Generador (g) y Discriminador (d),
# y has configurado los optimizadores (g_optimizer y d_optimizer) y la función de pérdida (criterio).



def GAN(discriminador, generador, data_loader_lw,data_loader_hr, num_epochs, batch_size, criterio_g,criterio_d, d_optimizador, g_optimizador, device):
    discriminador=discriminador.to(device)
    generador=generador.to(device)
    feature_extractor=Feature_Extractor().to(device)
    i=0
    for epoch in range(num_epochs):
        for  (lw, hr) in zip(data_loader_lw,data_loader_hr):

            hr_img,hrlbl=hr
            lw_img,lwlbl=lw

            hr_img=hr_img.to(device)
            lw_img=lw_img.to(device)

            generador.eval()
            discriminador.train()

            real_images = hr_img.float()

            real_labels = hrlbl.view(-1, 1).float().to(device)

            # Entrenar el discriminador con imágenes reales
            d_optimizador.zero_grad()

            prediction_real = discriminador(real_images)

            real_loss = criterio_d(prediction_real, real_labels)


            # Entrenar el discriminador con imágenes generadas

            fake_images = generador(lw_img)
            fake_labels = torch.zeros(lw_img.size(0), 1).to(device)

            prediction_fake = discriminador(fake_images)

            fake_loss = criterio_d(prediction_fake, fake_labels).to(device)
            discriminator_loss = (real_loss + fake_loss)/2

            discriminator_loss.backward(retain_graph=True)

            d_optimizador.step()

            # Entrenar el generador
            generador.train()
            discriminador.eval()
            g_optimizador.zero_grad()

            generated_images = generador(lw_img)
            loss_g=criterio_g(discriminador(generated_images),real_labels)

            generated_features=feature_extractor(generated_images)
            real_features=feature_extractor(real_images)
            content_loss=(criterio_g(generated_features, real_features))

            generator_loss = content_loss + (0.001*loss_g)

            torch.autograd.set_detect_anomaly(True)
            generator_loss.backward()
            g_optimizador.step()

            if i % 100 == 0:
                print(f'Época [{epoch}/{num_epochs}], Paso [{i}/{len(data_loader_lw)}], '
                      f'Pérdida del Discriminador: {discriminator_loss.item():.4f}, '
                      f'Pérdida del Generador: {generator_loss.item():.4f}')
            i=i+1
        # Imprimir estadísticas y visualizar imágenes generadas al final de cada época
        with torch.no_grad():
            generador.eval()
            generated_images = generador(lw_img)
            print(hr_img.shape)
            print(generated_images.shape)
            show_comparacion(hr_img[0],generated_images[0])


#--------------------------------------------------------------------------------------------
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("CUDA está disponible.")
    device = torch.device("cuda")
else:
    print("CUDA no está disponible. Se utilizará la CPU.")
    device = torch.device("cpu")

batch_size=20
num_epochs=60

transformaciones = transforms.Compose([
    transforms.ToTensor(),

])

DatasetHr=MiDataSet("/content/hr_dataset.csv",transformaciones)
data_loaderHr=DataLoader(DatasetHr,batch_size=batch_size)

DatasetLw=MiDataSet("/content/lw_dataset.csv",transformaciones)
data_loaderLw=DataLoader(DatasetLw,batch_size=batch_size)



d=Discriminator()
g=Generador(2)


lr_g = 0.00008
lr_d = 0.00008
d_optimizer=optim.Adam(d.parameters(),lr=lr_d)
g_optimizer=optim.Adam(g.parameters(),lr=lr_g)

criterio_d=nn.BCELoss()
criterio_g=nn.MSELoss()


print(f"learning rate discrimiador:{lr_d}")
print(f"learning rate generador:{lr_g}")

GAN(d,g,data_loaderLw,data_loaderHr,num_epochs,batch_size,criterio_g,criterio_d,d_optimizer,g_optimizer,device)
# Out:
# CUDA está disponible.
# 64
# 64
# learning rate discrimiador:8e-05
# learning rate generador:8e-05
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Época [0/60], Paso [0/40], Pérdida del Discriminador: 0.7016, Pérdida del Generador: 8.2375

# %%
torch.save(g.state_dict(), 'srgan_g.pt')
torch.save(d.state_dict(), 'srgan_d.pt')

# %%
torch.cuda.empty_cache()

# %%
from PIL import Image
# Suponiendo que "Generador" es la clase de tu generador y "ruta_modelo" es la ruta del modelo guardado
generador = Generador(2)  # creando generado
generador.load_state_dict(torch.load("/content/srgan_g.pt"))
generador.to(device)
generador.eval()

ruta_imagen = "/content/hr/transformed_0004_0.png"
imagen_pil = Image.open(ruta_imagen)

transformaciones = transforms.Compose([
    transforms.ToTensor(),  # Convierte la imagen a un tensor
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  # Normaliza los valores de los píxeles
])

imagen_transformada = transformaciones(imagen_pil)
imagen_transformada=imagen_transformada.to(device)
with torch.no_grad():
    generador.eval()

    generated_image = generador(imagen_transformada.unsqueeze(0)).detach().cpu()

# Convertir la imagen al rango [0, 1]
generated_image = (generated_image + 1) / 2.0

generated_image_np = generated_image.squeeze().permute(1, 2, 0).numpy()

print(generated_image.shape)
# Visualizar la imagen generada
plt.imshow(generated_image_np)
plt.axis('off')
plt.show()
# Out:
# torch.Size([1, 3, 760, 760])
